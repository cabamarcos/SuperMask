# %%
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, random_split
import copy
import matplotlib.pyplot as plt

from utils import MaskedForward

# %%
# Configuración
batch_size = 64
threshold_accuracy = 0.70
sparsity_percentage = 0.3  # Porcentaje de pesos a conservar (más altos)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Configuración de reinicios organizados en diccionario
restart_checks = {
    # 7: {"accuracy": 0.50, "message": "VERY EARLY RESTART"},
    # 11: {"accuracy": 0.30, "message": "VERY EARLY RESTART"},
    # 33: {"accuracy": 0.55, "message": "EARLY RESTART"},
    # 70: {"accuracy": 0.50, "message": "RESTART"}
}

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.4914, 0.4822, 0.4465],
                         std=[0.2023, 0.1994, 0.2010])
])

data_dir = '../../data/cifar10'

train_dataset = datasets.CIFAR10(root= data_dir, train=True, download=True, transform=transform)
test_dataset = datasets.CIFAR10(root= data_dir, train=False, download=True, transform=transform)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1)
        self.fc1 = nn.Linear(128 * 4 * 4, 128)  # Back to original dimensions for 32x32
        self.fc2 = nn.Linear(128, 10)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.max_pool2d(x, 2)
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2)
        x = F.relu(self.conv3(x))
        x = F.max_pool2d(x, 2)
        x = x.view(-1, 128 * 4 * 4)  # Back to original dimensions for 32x32
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x  # Devuelve logits sin procesar

net = Net()
mask = Net()

net.to(device)
mask.to(device)
# Out:
# Net(
#   (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (fc1): Linear(in_features=2048, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=10, bias=True)
# )

# %%
# Congelar los parámetros de net (no se entrenarán)
for param in net.parameters():
    param.requires_grad = False

# %%
def restart_training():
    """Función para reinicializar net, mask y métricas"""
    global net, mask, optimizer, epoch, losses, accuracies, saved, restart_count
    
    restart_count += 1
    print("Reinicializando net y máscara, y reiniciando el entrenamiento...")
    
    # Reinicializar net (nueva inicialización aleatoria)
    net = Net()
    net.to(device)
    
    # Congelar los parámetros de net
    for param in net.parameters():
        param.requires_grad = False
    
    # Reinicializar la máscara
    mask = Net()
    mask.to(device)
    
    # Reinicializar el optimizador
    optimizer = optim.Adam(mask.parameters(), lr=0.001)
    
    # Reinicializar métricas
    epoch = 0
    losses = []
    accuracies = []
    saved = False

def check_restart_conditions():
    """Verifica todas las condiciones de reinicio usando el diccionario de configuración"""
    current_max_accuracy = max(accuracies) if accuracies else 0
    
    for check_epoch, config in restart_checks.items():
        min_acc = config["accuracy"] * 100
        restart_type = config["message"]
        
        # Para época mayor, verificar si es mayor o igual; para otras, verificar igualdad exacta
        should_check = epoch == check_epoch
        
        if should_check and current_max_accuracy < min_acc:
            print(f"\n!!! {restart_type} {restart_count + 1} !!!")
            print(f"No se alcanzó {min_acc}% de accuracy en época {check_epoch}.")
            restart_training()
            return True
    
    return False

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(mask.parameters(), lr=0.001)
epoch = 0
saved = False
losses = []
accuracies = []
restart_count = 0

while True:
    # Verificar condiciones de reinicio
    if check_restart_conditions():
        continue
    
    masked_model = MaskedForward(net, mask, sparsity_percentage).to(device)
    masked_model.train()
    running_loss = 0.0

    epoch += 1
    print(f"\n===== Epoch {epoch} (Restart {restart_count}) =====")

    for batch_idx, (images, labels) in enumerate(train_loader):
        images, labels = images.to(device), labels.to(device)
    
        optimizer.zero_grad()
        outputs = masked_model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

    avg_loss = running_loss / len(train_loader)
    losses.append(avg_loss)

    # Evaluación
    masked_model.eval()
    correct, total = 0, 0
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = masked_model(images)
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    accuracy = 100.0 * correct / total
    accuracies.append(accuracy)

    print(f"Epoch {epoch}: Avg Loss = {avg_loss:.4f}, Test Accuracy = {accuracy:.2f}%")

    if accuracy >= threshold_accuracy * 100:
        print("Reached target accuracy. Stopping training.")
        if not saved:
            torch.save(net.state_dict(), "net_cnn_10.pth")
            torch.save(mask.state_dict(), "mask_cnn_10.pth")
            print(f"Models saved")
            saved = True
        else:
            print("Model already saved, skipping save.")
        break
# Out:
# ===== Epoch 1 (Restart 0) =====
# Epoch 1: Avg Loss = 1.8852, Test Accuracy = 36.18%
#
# ===== Epoch 2 (Restart 0) =====
# Epoch 2: Avg Loss = 1.7497, Test Accuracy = 38.07%
#
# ===== Epoch 3 (Restart 0) =====
# Epoch 3: Avg Loss = 1.7297, Test Accuracy = 37.87%
#
# ===== Epoch 4 (Restart 0) =====
# Epoch 4: Avg Loss = 1.7202, Test Accuracy = 39.11%
#
# ===== Epoch 5 (Restart 0) =====
# Epoch 5: Avg Loss = 1.7140, Test Accuracy = 38.94%
#
# ===== Epoch 6 (Restart 0) =====
# Epoch 6: Avg Loss = 1.7123, Test Accuracy = 38.45%
#
# ===== Epoch 7 (Restart 0) =====
# Epoch 7: Avg Loss = 1.7132, Test Accuracy = 39.25%
#
# ===== Epoch 8 (Restart 0) =====
# Epoch 8: Avg Loss = 1.7118, Test Accuracy = 39.15%
#
# ===== Epoch 9 (Restart 0) =====
# Epoch 9: Avg Loss = 1.7103, Test Accuracy = 39.37%
#
# ===== Epoch 10 (Restart 0) =====
# Epoch 10: Avg Loss = 1.7086, Test Accuracy = 38.99%
#
# ===== Epoch 11 (Restart 0) =====
# Epoch 11: Avg Loss = 1.7094, Test Accuracy = 39.38%
#
# ===== Epoch 12 (Restart 0) =====
# Epoch 12: Avg Loss = 1.7093, Test Accuracy = 39.21%
#
# ===== Epoch 13 (Restart 0) =====
# Epoch 13: Avg Loss = 1.7067, Test Accuracy = 38.33%
#
# ===== Epoch 14 (Restart 0) =====
# Epoch 14: Avg Loss = 1.7058, Test Accuracy = 39.06%
#
# ===== Epoch 15 (Restart 0) =====
# Epoch 15: Avg Loss = 1.7061, Test Accuracy = 38.63%
#
# ===== Epoch 16 (Restart 0) =====
# Epoch 16: Avg Loss = 1.7047, Test Accuracy = 39.02%
#
# ===== Epoch 17 (Restart 0) =====
# Epoch 17: Avg Loss = 1.7053, Test Accuracy = 37.89%
#
# ===== Epoch 18 (Restart 0) =====
# Epoch 18: Avg Loss = 1.7036, Test Accuracy = 39.11%
#
# ===== Epoch 19 (Restart 0) =====
# Epoch 19: Avg Loss = 1.7034, Test Accuracy = 38.74%
#
# ===== Epoch 20 (Restart 0) =====
# Epoch 20: Avg Loss = 1.7047, Test Accuracy = 37.84%
#
# ===== Epoch 21 (Restart 0) =====
# Epoch 21: Avg Loss = 1.7055, Test Accuracy = 39.20%
#
# ===== Epoch 22 (Restart 0) =====
# Epoch 22: Avg Loss = 1.7068, Test Accuracy = 38.96%
#
# ===== Epoch 23 (Restart 0) =====
# Epoch 23: Avg Loss = 1.7049, Test Accuracy = 39.98%
#
# ===== Epoch 24 (Restart 0) =====
# Epoch 24: Avg Loss = 1.7070, Test Accuracy = 39.02%
#
# ===== Epoch 25 (Restart 0) =====
# Epoch 25: Avg Loss = 1.7069, Test Accuracy = 38.61%
#
# ===== Epoch 26 (Restart 0) =====
# Epoch 26: Avg Loss = 1.7054, Test Accuracy = 39.25%
#
# ===== Epoch 27 (Restart 0) =====
# Epoch 27: Avg Loss = 1.7067, Test Accuracy = 38.92%
#
# ===== Epoch 28 (Restart 0) =====
# Epoch 28: Avg Loss = 1.7067, Test Accuracy = 38.99%
#
# ===== Epoch 29 (Restart 0) =====
# Epoch 29: Avg Loss = 1.7080, Test Accuracy = 39.72%
#
# ===== Epoch 30 (Restart 0) =====
# Epoch 30: Avg Loss = 1.7088, Test Accuracy = 39.69%
#
# ===== Epoch 31 (Restart 0) =====
# Epoch 31: Avg Loss = 1.7053, Test Accuracy = 38.29%
#
# ===== Epoch 32 (Restart 0) =====
# Epoch 32: Avg Loss = 1.7050, Test Accuracy = 38.75%
#
# ===== Epoch 33 (Restart 0) =====
# Epoch 33: Avg Loss = 1.7077, Test Accuracy = 39.53%
#
# ===== Epoch 34 (Restart 0) =====
# Epoch 34: Avg Loss = 1.7064, Test Accuracy = 38.37%
#
# ===== Epoch 35 (Restart 0) =====
# Epoch 35: Avg Loss = 1.7084, Test Accuracy = 39.76%
#
# ===== Epoch 36 (Restart 0) =====
# Epoch 36: Avg Loss = 1.7083, Test Accuracy = 38.63%
#
# ===== Epoch 37 (Restart 0) =====
# Epoch 37: Avg Loss = 1.7086, Test Accuracy = 39.34%
#
# ===== Epoch 38 (Restart 0) =====
# Epoch 38: Avg Loss = 1.7070, Test Accuracy = 39.34%
#
# ===== Epoch 39 (Restart 0) =====
# Epoch 39: Avg Loss = 1.7063, Test Accuracy = 39.28%
#
# ===== Epoch 40 (Restart 0) =====
# Epoch 40: Avg Loss = 1.7063, Test Accuracy = 38.93%
#
# ===== Epoch 41 (Restart 0) =====
# Epoch 41: Avg Loss = 1.7066, Test Accuracy = 38.87%
#
# ===== Epoch 42 (Restart 0) =====
# Epoch 42: Avg Loss = 1.7086, Test Accuracy = 37.94%
#
# ===== Epoch 43 (Restart 0) =====
# Epoch 43: Avg Loss = 1.7069, Test Accuracy = 39.60%
#
# ===== Epoch 44 (Restart 0) =====
# Epoch 44: Avg Loss = 1.7044, Test Accuracy = 38.13%
#
# ===== Epoch 45 (Restart 0) =====
# Epoch 45: Avg Loss = 1.7068, Test Accuracy = 39.06%
#
# ===== Epoch 46 (Restart 0) =====
# Epoch 46: Avg Loss = 1.7059, Test Accuracy = 39.84%
#
# ===== Epoch 47 (Restart 0) =====
# Epoch 47: Avg Loss = 1.7055, Test Accuracy = 39.28%
#
# ===== Epoch 48 (Restart 0) =====
# Epoch 48: Avg Loss = 1.7044, Test Accuracy = 39.69%
#
# ===== Epoch 49 (Restart 0) =====
# Epoch 49: Avg Loss = 1.7036, Test Accuracy = 39.08%
#
# ===== Epoch 50 (Restart 0) =====
# Epoch 50: Avg Loss = 1.7036, Test Accuracy = 39.49%
#
# ===== Epoch 51 (Restart 0) =====
# Epoch 51: Avg Loss = 1.7048, Test Accuracy = 39.02%
#
# ===== Epoch 52 (Restart 0) =====
# Epoch 52: Avg Loss = 1.7067, Test Accuracy = 39.64%
#
# ===== Epoch 53 (Restart 0) =====
# Epoch 53: Avg Loss = 1.7043, Test Accuracy = 38.94%
#
# ===== Epoch 54 (Restart 0) =====
# Epoch 54: Avg Loss = 1.7055, Test Accuracy = 39.59%
#
# ===== Epoch 55 (Restart 0) =====
# Epoch 55: Avg Loss = 1.7034, Test Accuracy = 40.09%
#
# ===== Epoch 56 (Restart 0) =====
# Epoch 56: Avg Loss = 1.7028, Test Accuracy = 38.37%
#
# ===== Epoch 57 (Restart 0) =====
# Epoch 57: Avg Loss = 1.7015, Test Accuracy = 39.69%
#
# ===== Epoch 58 (Restart 0) =====
# Epoch 58: Avg Loss = 1.7006, Test Accuracy = 38.98%
#
# ===== Epoch 59 (Restart 0) =====
# Epoch 59: Avg Loss = 1.7016, Test Accuracy = 39.40%
#
# ===== Epoch 60 (Restart 0) =====
# Epoch 60: Avg Loss = 1.6987, Test Accuracy = 39.51%
#
# ===== Epoch 61 (Restart 0) =====
# Epoch 61: Avg Loss = 1.6994, Test Accuracy = 39.89%
#
# ===== Epoch 62 (Restart 0) =====
# Epoch 62: Avg Loss = 1.6990, Test Accuracy = 38.90%
#
# ===== Epoch 63 (Restart 0) =====
# Epoch 63: Avg Loss = 1.7007, Test Accuracy = 38.67%
#
# ===== Epoch 64 (Restart 0) =====
# Epoch 64: Avg Loss = 1.6993, Test Accuracy = 39.78%
#
# ===== Epoch 65 (Restart 0) =====
# Epoch 65: Avg Loss = 1.6993, Test Accuracy = 39.71%
#
# ===== Epoch 66 (Restart 0) =====
# Epoch 66: Avg Loss = 1.6988, Test Accuracy = 40.26%
#
# ===== Epoch 67 (Restart 0) =====
# Epoch 67: Avg Loss = 1.7001, Test Accuracy = 39.68%
#
# ===== Epoch 68 (Restart 0) =====
# Epoch 68: Avg Loss = 1.6988, Test Accuracy = 39.24%
#
# ===== Epoch 69 (Restart 0) =====
# Epoch 69: Avg Loss = 1.7012, Test Accuracy = 39.10%
#
# ===== Epoch 70 (Restart 0) =====
# Epoch 70: Avg Loss = 1.6985, Test Accuracy = 39.30%
#
# ===== Epoch 71 (Restart 0) =====
# Epoch 71: Avg Loss = 1.6995, Test Accuracy = 39.22%
#
# ===== Epoch 72 (Restart 0) =====
# Epoch 72: Avg Loss = 1.7000, Test Accuracy = 39.98%
#
# ===== Epoch 73 (Restart 0) =====
# Epoch 73: Avg Loss = 1.6984, Test Accuracy = 39.99%
#
# ===== Epoch 74 (Restart 0) =====
# Epoch 74: Avg Loss = 1.6983, Test Accuracy = 39.91%
#
# ===== Epoch 75 (Restart 0) =====
# Epoch 75: Avg Loss = 1.6986, Test Accuracy = 39.20%
#
# ===== Epoch 76 (Restart 0) =====
# Epoch 76: Avg Loss = 1.6998, Test Accuracy = 39.12%
#
# ===== Epoch 77 (Restart 0) =====
# Epoch 77: Avg Loss = 1.6978, Test Accuracy = 38.99%
#
# ===== Epoch 78 (Restart 0) =====
# Epoch 78: Avg Loss = 1.6993, Test Accuracy = 39.94%
#
# ===== Epoch 79 (Restart 0) =====
# Epoch 79: Avg Loss = 1.6998, Test Accuracy = 39.50%
#
# ===== Epoch 80 (Restart 0) =====
# Epoch 80: Avg Loss = 1.6999, Test Accuracy = 39.43%
#
# ===== Epoch 81 (Restart 0) =====
# Epoch 81: Avg Loss = 1.6978, Test Accuracy = 39.95%
#
# ===== Epoch 82 (Restart 0) =====
# Epoch 82: Avg Loss = 1.6989, Test Accuracy = 38.55%
#
# ===== Epoch 83 (Restart 0) =====
# Epoch 83: Avg Loss = 1.7002, Test Accuracy = 39.63%
#
# ===== Epoch 84 (Restart 0) =====
# Epoch 84: Avg Loss = 1.6983, Test Accuracy = 38.95%
#
# ===== Epoch 85 (Restart 0) =====
# Epoch 85: Avg Loss = 1.6991, Test Accuracy = 39.66%
#
# ===== Epoch 86 (Restart 0) =====
# Epoch 86: Avg Loss = 1.6978, Test Accuracy = 39.32%
#
# ===== Epoch 87 (Restart 0) =====
# Epoch 87: Avg Loss = 1.6977, Test Accuracy = 39.68%
#
# ===== Epoch 88 (Restart 0) =====
# Epoch 88: Avg Loss = 1.6993, Test Accuracy = 39.53%
#
# ===== Epoch 89 (Restart 0) =====
# Epoch 89: Avg Loss = 1.6981, Test Accuracy = 39.68%
#
# ===== Epoch 90 (Restart 0) =====
# Epoch 90: Avg Loss = 1.6982, Test Accuracy = 39.16%
#
# ===== Epoch 91 (Restart 0) =====
# Epoch 91: Avg Loss = 1.6993, Test Accuracy = 38.58%
#
# ===== Epoch 92 (Restart 0) =====
# Epoch 92: Avg Loss = 1.6989, Test Accuracy = 39.44%
#
# ===== Epoch 93 (Restart 0) =====
# Epoch 93: Avg Loss = 1.6989, Test Accuracy = 38.84%
#
# ===== Epoch 94 (Restart 0) =====
# Epoch 94: Avg Loss = 1.6992, Test Accuracy = 38.70%
#
# ===== Epoch 95 (Restart 0) =====
# Epoch 95: Avg Loss = 1.6990, Test Accuracy = 39.29%
#
# ===== Epoch 96 (Restart 0) =====
# Epoch 96: Avg Loss = 1.6988, Test Accuracy = 39.44%
#
# ===== Epoch 97 (Restart 0) =====
# Epoch 97: Avg Loss = 1.6999, Test Accuracy = 39.61%
#
# ===== Epoch 98 (Restart 0) =====
# Epoch 98: Avg Loss = 1.7014, Test Accuracy = 39.67%
#
# ===== Epoch 99 (Restart 0) =====
# Epoch 99: Avg Loss = 1.7000, Test Accuracy = 39.56%
#
# ===== Epoch 100 (Restart 0) =====
# Epoch 100: Avg Loss = 1.6996, Test Accuracy = 39.21%
#
# ===== Epoch 101 (Restart 0) =====
# Epoch 101: Avg Loss = 1.7014, Test Accuracy = 39.39%
#
# ===== Epoch 102 (Restart 0) =====
# Epoch 102: Avg Loss = 1.6977, Test Accuracy = 39.48%
#
# ===== Epoch 103 (Restart 0) =====
# Epoch 103: Avg Loss = 1.7011, Test Accuracy = 38.70%
#
# ===== Epoch 104 (Restart 0) =====
# Epoch 104: Avg Loss = 1.6990, Test Accuracy = 39.60%
#
# ===== Epoch 105 (Restart 0) =====
# Epoch 105: Avg Loss = 1.7009, Test Accuracy = 39.76%
#
# ===== Epoch 106 (Restart 0) =====
# Epoch 106: Avg Loss = 1.7000, Test Accuracy = 39.26%
#
# ===== Epoch 107 (Restart 0) =====
# Epoch 107: Avg Loss = 1.6990, Test Accuracy = 39.46%
#
# ===== Epoch 108 (Restart 0) =====
# Epoch 108: Avg Loss = 1.6981, Test Accuracy = 39.71%
#
# ===== Epoch 109 (Restart 0) =====
# Epoch 109: Avg Loss = 1.7007, Test Accuracy = 39.67%
#
# ===== Epoch 110 (Restart 0) =====
# Epoch 110: Avg Loss = 1.6994, Test Accuracy = 38.92%
#
# ===== Epoch 111 (Restart 0) =====
# Epoch 111: Avg Loss = 1.6989, Test Accuracy = 39.58%
#
# ===== Epoch 112 (Restart 0) =====
# Epoch 112: Avg Loss = 1.7000, Test Accuracy = 39.68%
#
# ===== Epoch 113 (Restart 0) =====
# Epoch 113: Avg Loss = 1.7028, Test Accuracy = 39.57%
#
# ===== Epoch 114 (Restart 0) =====
# Epoch 114: Avg Loss = 1.7009, Test Accuracy = 39.71%
#
# ===== Epoch 115 (Restart 0) =====
# Epoch 115: Avg Loss = 1.6997, Test Accuracy = 39.41%
#
# ===== Epoch 116 (Restart 0) =====
# Epoch 116: Avg Loss = 1.6985, Test Accuracy = 39.53%
#
# ===== Epoch 117 (Restart 0) =====
# Epoch 117: Avg Loss = 1.7018, Test Accuracy = 39.64%
#
# ===== Epoch 118 (Restart 0) =====
# Epoch 118: Avg Loss = 1.7009, Test Accuracy = 39.01%
#
# ===== Epoch 119 (Restart 0) =====
# Epoch 119: Avg Loss = 1.6995, Test Accuracy = 39.38%
#
# ===== Epoch 120 (Restart 0) =====
# Epoch 120: Avg Loss = 1.7013, Test Accuracy = 40.00%
#
# ===== Epoch 121 (Restart 0) =====
# Epoch 121: Avg Loss = 1.7011, Test Accuracy = 39.98%
#
# ===== Epoch 122 (Restart 0) =====
# Epoch 122: Avg Loss = 1.6997, Test Accuracy = 38.78%
#
# ===== Epoch 123 (Restart 0) =====
# Epoch 123: Avg Loss = 1.6991, Test Accuracy = 39.36%
#
# ===== Epoch 124 (Restart 0) =====
# Epoch 124: Avg Loss = 1.7007, Test Accuracy = 39.15%
#
# ===== Epoch 125 (Restart 0) =====
# Epoch 125: Avg Loss = 1.6990, Test Accuracy = 39.90%
#
# ===== Epoch 126 (Restart 0) =====
# Epoch 126: Avg Loss = 1.7006, Test Accuracy = 39.60%
#
# ===== Epoch 127 (Restart 0) =====
# Epoch 127: Avg Loss = 1.6996, Test Accuracy = 38.96%
#
# ===== Epoch 128 (Restart 0) =====
# Epoch 128: Avg Loss = 1.6996, Test Accuracy = 39.27%
#
# ===== Epoch 129 (Restart 0) =====
# Epoch 129: Avg Loss = 1.7022, Test Accuracy = 39.27%
#
# ===== Epoch 130 (Restart 0) =====
# Epoch 130: Avg Loss = 1.7013, Test Accuracy = 39.34%
#
# ===== Epoch 131 (Restart 0) =====
# Epoch 131: Avg Loss = 1.7007, Test Accuracy = 39.58%
#
# ===== Epoch 132 (Restart 0) =====
# Epoch 132: Avg Loss = 1.7002, Test Accuracy = 39.51%
#
# ===== Epoch 133 (Restart 0) =====
# Epoch 133: Avg Loss = 1.7005, Test Accuracy = 39.64%
#
# ===== Epoch 134 (Restart 0) =====
# Epoch 134: Avg Loss = 1.7017, Test Accuracy = 39.11%
#
# ===== Epoch 135 (Restart 0) =====
# Epoch 135: Avg Loss = 1.7011, Test Accuracy = 39.42%
#
# ===== Epoch 136 (Restart 0) =====
# Epoch 136: Avg Loss = 1.7018, Test Accuracy = 39.49%
#
# ===== Epoch 137 (Restart 0) =====
# Epoch 137: Avg Loss = 1.7000, Test Accuracy = 39.45%
#
# ===== Epoch 138 (Restart 0) =====
# Epoch 138: Avg Loss = 1.7016, Test Accuracy = 38.83%
#
# ===== Epoch 139 (Restart 0) =====
# Epoch 139: Avg Loss = 1.7004, Test Accuracy = 38.75%
#
# ===== Epoch 140 (Restart 0) =====
# Epoch 140: Avg Loss = 1.7012, Test Accuracy = 39.55%
#
# ===== Epoch 141 (Restart 0) =====
# Epoch 141: Avg Loss = 1.6993, Test Accuracy = 39.88%
#
# ===== Epoch 142 (Restart 0) =====
# Epoch 142: Avg Loss = 1.6988, Test Accuracy = 39.05%
#
# ===== Epoch 143 (Restart 0) =====
# Epoch 143: Avg Loss = 1.7014, Test Accuracy = 39.02%
#
# ===== Epoch 144 (Restart 0) =====
# Epoch 144: Avg Loss = 1.7016, Test Accuracy = 39.50%
#
# ===== Epoch 145 (Restart 0) =====
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 39
#      37 correct, total = 0, 0
#      38 with torch.no_grad():
# ---> 39     for images, labels in test_loader:
#      40         images, labels = images.to(device), labels.to(device)
#      41         outputs = masked_model(images)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\utils\data\dataloader.py:701, in _BaseDataLoaderIter.__next__(self)
#     698 if self._sampler_iter is None:
#     699     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     700     self._reset()  # type: ignore[call-arg]
# --> 701 data = self._next_data()
#     702 self._num_yielded += 1
#     703 if (
#     704     self._dataset_kind == _DatasetKind.Iterable
#     705     and self._IterableDataset_len_called is not None
#     706     and self._num_yielded > self._IterableDataset_len_called
#     707 ):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\utils\data\dataloader.py:757, in _SingleProcessDataLoaderIter._next_data(self)
#     755 def _next_data(self):
#     756     index = self._next_index()  # may raise StopIteration
# --> 757     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     758     if self._pin_memory:
#     759         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\utils\data\_utils\fetch.py:52, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
# ---> 52         data = [self.dataset[idx] for idx in possibly_batched_index]
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\utils\data\_utils\fetch.py:52, in <listcomp>(.0)
#      50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
# ---> 52         data = [self.dataset[idx] for idx in possibly_batched_index]
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torchvision\datasets\cifar.py:119, in CIFAR10.__getitem__(self, index)
#     116 img = Image.fromarray(img)
#     118 if self.transform is not None:
# --> 119     img = self.transform(img)
#     121 if self.target_transform is not None:
#     122     target = self.target_transform(target)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torchvision\transforms\transforms.py:95, in Compose.__call__(self, img)
#      93 def __call__(self, img):
#      94     for t in self.transforms:
# ---> 95         img = t(img)
#      96     return img
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torchvision\transforms\transforms.py:277, in Normalize.forward(self, tensor)
#     269 def forward(self, tensor: Tensor) -> Tensor:
#     270     """
#     271     Args:
#     272         tensor (Tensor): Tensor image to be normalized.
#    (...)
#     275         Tensor: Normalized Tensor image.
#     276     """
# --> 277     return F.normalize(tensor, self.mean, self.std, self.inplace)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torchvision\transforms\functional.py:350, in normalize(tensor, mean, std, inplace)
#     347 if not isinstance(tensor, torch.Tensor):
#     348     raise TypeError(f"img should be Tensor Image. Got {type(tensor)}")
# --> 350 return F_t.normalize(tensor, mean=mean, std=std, inplace=inplace)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torchvision\transforms\_functional_tensor.py:917, in normalize(tensor, mean, std, inplace)
#     912     raise ValueError(
#     913         f"Expected tensor to be a tensor image of size (..., C, H, W). Got tensor.size() = {tensor.size()}"
#     914     )
#     916 if not inplace:
# --> 917     tensor = tensor.clone()
#     919 dtype = tensor.dtype
#     920 mean = torch.as_tensor(mean, dtype=dtype, device=tensor.device)
#
# KeyboardInterrupt:

# %%
torch.save(net.state_dict(), "./models/net_cnn_30.pth")
torch.save(mask.state_dict(), "./models/mask_cnn_30.pth")

# %%
# Gráficos de pérdida y precisión en una sola figura
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# Gráfico de pérdida
ax1.plot(range(1, len(losses)+1), losses, label='Loss', color='red')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.set_title('Training Loss per Epoch')
ax1.legend()
ax1.grid(True)

# Gráfico de precisión
ax2.plot(range(1, len(accuracies)+1), accuracies, label='Accuracy', color='green')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Accuracy (%)')
ax2.set_title('Test Accuracy per Epoch')
ax2.legend()
ax2.grid(True)

plt.tight_layout()
plt.show()

# %%
print(losses)
print(len(losses))
print(accuracies)
print(len(accuracies))
print(epoch)
# Out:
# [1.8851531431498125, 1.7497104577091345, 1.729705436912644, 1.720160679286703, 1.7139745792159644, 1.7123310925710538, 1.7132178401703115, 1.711777025171558, 1.7102789313287077, 1.7086403029958914, 1.7094052063534633, 1.7092729752021067, 1.706689773922991, 1.7058012790387245, 1.7060514109213945, 1.704683889665872, 1.7052710730096567, 1.7035968785395708, 1.7034123716756815, 1.704668270809876, 1.7055058768948022, 1.7068111189186115, 1.704901672994999, 1.7069562108010587, 1.7068802496356428, 1.7054299108512567, 1.7067337440102912, 1.706679449514355, 1.7080303663792817, 1.7087539983222553, 1.7052503911125692, 1.7049521299274377, 1.7076692543066372, 1.7064363364978214, 1.708354294757404, 1.708303957948904, 1.7085550468596047, 1.7069918623055949, 1.7063412701382357, 1.7062995295085566, 1.7065913623861035, 1.708557420831812, 1.7069463338083624, 1.7043946173489857, 1.7068083580497586, 1.705949341854476, 1.705520874246612, 1.7044047487666234, 1.7035734008645158, 1.7036468787571353, 1.7047520633548727, 1.7066941730811467, 1.7043061143601947, 1.7054848245647558, 1.7033882830149072, 1.7027607374179088, 1.701482055284788, 1.70061573058443, 1.7015619899915613, 1.6987392228582632, 1.6994375121562988, 1.69896898672099, 1.7007436740124011, 1.6993107490832238, 1.6992867343565996, 1.6988353695710907, 1.7001260430611613, 1.6987877314352928, 1.7011693836478017, 1.6985317500655914, 1.6995017127612668, 1.6999704377425602, 1.6984308299506108, 1.6983441808034696, 1.698603436312712, 1.69978224575672, 1.697761006367481, 1.6992822882464476, 1.6998389953237665, 1.699935963696531, 1.6977710434238014, 1.6989464323843837, 1.7002192816466017, 1.6982599504463507, 1.6990719259242573, 1.6977534260591278, 1.6976650660605077, 1.699293938286774, 1.6981149480470916, 1.6982112540613354, 1.699290138833663, 1.6989216380716894, 1.6988711681817195, 1.6991626777307456, 1.6990178381390584, 1.6987678916253093, 1.699906967942367, 1.7014010403772144, 1.7000273693248134, 1.6995603393410783, 1.7013718824252448, 1.6976920687938895, 1.7010623298947463, 1.699032262767977, 1.700915031878235, 1.700038787958872, 1.6989647393946148, 1.698063773114968, 1.7007105627938, 1.699400915056848, 1.6989198923110962, 1.7000053919794615, 1.7028374301503078, 1.7008876687730365, 1.6996718125270152, 1.6985347084986888, 1.7018392973238854, 1.7008519270231046, 1.6994906401695193, 1.701331915452962, 1.7011313749396282, 1.6997404863767307, 1.6990582176181666, 1.7006638911374086, 1.6989744622689074, 1.700592567701169, 1.699561962843551, 1.6996177684925402, 1.702172303291233, 1.7012660835710023, 1.7006961560005422, 1.7002057074890722, 1.7004969860891552, 1.701728521253142, 1.7010502614023741, 1.701780242535769, 1.700045625724451, 1.7016238176914127, 1.700377016116286, 1.7011682630499916, 1.699344660772387, 1.6987989791823774, 1.7014443665514212, 1.701646242910029, 1.7001088333251837]
# 145
# [36.18, 38.07, 37.87, 39.11, 38.94, 38.45, 39.25, 39.15, 39.37, 38.99, 39.38, 39.21, 38.33, 39.06, 38.63, 39.02, 37.89, 39.11, 38.74, 37.84, 39.2, 38.96, 39.98, 39.02, 38.61, 39.25, 38.92, 38.99, 39.72, 39.69, 38.29, 38.75, 39.53, 38.37, 39.76, 38.63, 39.34, 39.34, 39.28, 38.93, 38.87, 37.94, 39.6, 38.13, 39.06, 39.84, 39.28, 39.69, 39.08, 39.49, 39.02, 39.64, 38.94, 39.59, 40.09, 38.37, 39.69, 38.98, 39.4, 39.51, 39.89, 38.9, 38.67, 39.78, 39.71, 40.26, 39.68, 39.24, 39.1, 39.3, 39.22, 39.98, 39.99, 39.91, 39.2, 39.12, 38.99, 39.94, 39.5, 39.43, 39.95, 38.55, 39.63, 38.95, 39.66, 39.32, 39.68, 39.53, 39.68, 39.16, 38.58, 39.44, 38.84, 38.7, 39.29, 39.44, 39.61, 39.67, 39.56, 39.21, 39.39, 39.48, 38.7, 39.6, 39.76, 39.26, 39.46, 39.71, 39.67, 38.92, 39.58, 39.68, 39.57, 39.71, 39.41, 39.53, 39.64, 39.01, 39.38, 40.0, 39.98, 38.78, 39.36, 39.15, 39.9, 39.6, 38.96, 39.27, 39.27, 39.34, 39.58, 39.51, 39.64, 39.11, 39.42, 39.49, 39.45, 38.83, 38.75, 39.55, 39.88, 39.05, 39.02, 39.5]
# 144
# 145
