# %%
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms, models
from torch.utils.data import DataLoader, random_split
import copy
import matplotlib.pyplot as plt

from utils.apply_mask_alexnet import *

# %%
# Configuración
batch_size = 64
threshold_accuracy = 0.55
sparsity_percentage = 0.1  # Porcentaje de pesos a conservar (más altos)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# Dataset Animals10
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
])

data_dir = "../../data/animals10"

train_dataset = datasets.ImageFolder(root=os.path.join(data_dir, "train"), transform=transform)
test_dataset = datasets.ImageFolder(root=os.path.join(data_dir, "test"), transform=transform)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
net = models.alexnet(pretrained=False)
net.classifier[6] = nn.Linear(net.classifier[6].in_features, 10)

mask = models.alexnet(pretrained=False)
mask.classifier[6] = nn.Linear(mask.classifier[6].in_features, 10)

net.to(device)
mask.to(device)
# Out:
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=4096, out_features=10, bias=True)
#   )
# )

# %%
# Congelar los parámetros de net (no se entrenarán)
for param in net.parameters():
    param.requires_grad = False

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(mask.parameters(), lr=0.001)
epoch = 0
saved = False
losses = []
accuracies = []

while True:
    masked_model = MaskedForward(net, mask, sparsity_percentage).to(device)
    # Guardar copia de los pesos de net para verificar que no cambian
    # net_before = [p.clone().detach() for p in net.parameters()]
    masked_model.train()
    running_loss = 0.0

    epoch += 1

    print(f"\n===== Epoch {epoch} =====")

        # Guardar copia de los pesos de mask
    # mask_before = [p.clone().detach() for p in mask.parameters()]

    for batch_idx, (images, labels) in enumerate(train_loader):
        images, labels = images.to(device), labels.to(device)
    
        optimizer.zero_grad()
        outputs = masked_model(images)
        loss = criterion(outputs, labels)
        loss.backward()

        # # Verificar gradientes
        # for name, param in mask.named_parameters():
        #     if param.grad is not None:
        #         print(f"[Grad] {name}: grad norm = {param.grad.norm().item():.6f}")
        #     else:
        #         print(f"[Grad] {name}: NO grad")
        optimizer.step()

        running_loss += loss.item()
        # if batch_idx % 10 == 0:
        #     print(f"Batch {batch_idx}, Loss: {loss.item():.4f}")

    avg_loss = running_loss / len(train_loader)
    losses.append(avg_loss)

    # Evaluación
    masked_model.eval()
    correct, total = 0, 0
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = masked_model(images)
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    accuracy = 100.0 * correct / total
    accuracies.append(accuracy)

    #     # Verificar cambios en los parámetros de mask
    # for (before, after), name in zip(zip(mask_before, mask.parameters()), mask.state_dict().keys()):
    #     delta = (after - before).abs().sum().item()
    #     print(f"[Update] {name}: Δ = {delta:.6f}")

    # # Verificar que net no ha sido modificado
    # for (before, after), name in zip(zip(net_before, net.parameters()), net.state_dict().keys()):
    #     delta = (after - before).abs().sum().item()
    #     print(f"[Check Net] {name}: Δ = {delta:.6f}")

    print(f"Epoch {epoch}: Avg Loss = {avg_loss:.4f}, Test Accuracy = {accuracy:.2f}%")

    if accuracy >= threshold_accuracy * 100:
        print("Reached target accuracy. Stopping training.")
        if not saved:
            # Guardar net y mask
            torch.save(net.state_dict(), "net.pth")
            torch.save(mask.state_dict(), "mask.pth")
            print(f"Models saved)")
            saved = True
        else:
            print("Model already saved, skipping save.")
        break
# Out:
# ===== Epoch 1 =====
# Epoch 1: Avg Loss = 2.2183, Test Accuracy = 18.41%
#
# ===== Epoch 2 =====
# Epoch 2: Avg Loss = 2.2109, Test Accuracy = 18.41%
#
# ===== Epoch 3 =====
# Epoch 3: Avg Loss = 2.2115, Test Accuracy = 18.57%
#
# ===== Epoch 4 =====
# Epoch 4: Avg Loss = 2.2026, Test Accuracy = 18.43%
#
# ===== Epoch 5 =====
# Epoch 5: Avg Loss = 2.1553, Test Accuracy = 22.93%
#
# ===== Epoch 6 =====
# Epoch 6: Avg Loss = 2.0827, Test Accuracy = 22.25%
#
# ===== Epoch 7 =====
# Epoch 7: Avg Loss = 2.0242, Test Accuracy = 29.12%
#
# ===== Epoch 8 =====
# Epoch 8: Avg Loss = 1.9728, Test Accuracy = 30.45%
#
# ===== Epoch 9 =====
# Epoch 9: Avg Loss = 1.9386, Test Accuracy = 31.88%
#
# ===== Epoch 10 =====
# Epoch 10: Avg Loss = 1.9094, Test Accuracy = 30.72%
#
# ===== Epoch 11 =====
# Epoch 11: Avg Loss = 1.8806, Test Accuracy = 33.39%
#
# ===== Epoch 12 =====
# Epoch 12: Avg Loss = 1.8516, Test Accuracy = 34.19%
#
# ===== Epoch 13 =====
# Epoch 13: Avg Loss = 1.8371, Test Accuracy = 35.70%
#
# ===== Epoch 14 =====
# Epoch 14: Avg Loss = 1.8126, Test Accuracy = 35.18%
#
# ===== Epoch 15 =====
# Epoch 15: Avg Loss = 1.8060, Test Accuracy = 35.99%
#
# ===== Epoch 16 =====
# Epoch 16: Avg Loss = 1.7920, Test Accuracy = 36.88%
#
# ===== Epoch 17 =====
# Epoch 17: Avg Loss = 1.7809, Test Accuracy = 37.66%
#
# ===== Epoch 18 =====
# Epoch 18: Avg Loss = 1.7669, Test Accuracy = 37.05%
#
# ===== Epoch 19 =====
# Epoch 19: Avg Loss = 1.7630, Test Accuracy = 37.53%
#
# ===== Epoch 20 =====
# Epoch 20: Avg Loss = 1.7515, Test Accuracy = 35.49%
#
# ===== Epoch 21 =====
# Epoch 21: Avg Loss = 1.7472, Test Accuracy = 38.54%
#
# ===== Epoch 22 =====
# Epoch 22: Avg Loss = 1.7314, Test Accuracy = 32.86%
#
# ===== Epoch 23 =====
# Epoch 23: Avg Loss = 1.7228, Test Accuracy = 39.63%
#
# ===== Epoch 24 =====
# Epoch 24: Avg Loss = 1.7164, Test Accuracy = 39.57%
#
# ===== Epoch 25 =====
# Epoch 25: Avg Loss = 1.7110, Test Accuracy = 40.11%
#
# ===== Epoch 26 =====
# Epoch 26: Avg Loss = 1.6975, Test Accuracy = 39.15%
#
# ===== Epoch 27 =====
# Epoch 27: Avg Loss = 1.7036, Test Accuracy = 40.07%
#
# ===== Epoch 28 =====
# Epoch 28: Avg Loss = 1.6953, Test Accuracy = 39.23%
#
# ===== Epoch 29 =====
# Epoch 29: Avg Loss = 1.6883, Test Accuracy = 39.38%
#
# ===== Epoch 30 =====
# Epoch 30: Avg Loss = 1.6860, Test Accuracy = 38.85%
#
# ===== Epoch 31 =====
# Epoch 31: Avg Loss = 1.6808, Test Accuracy = 40.91%
#
# ===== Epoch 32 =====
# Epoch 32: Avg Loss = 1.6834, Test Accuracy = 40.41%
#
# ===== Epoch 33 =====
# Epoch 33: Avg Loss = 1.6800, Test Accuracy = 41.25%
#
# ===== Epoch 34 =====
# Epoch 34: Avg Loss = 1.6789, Test Accuracy = 41.82%
#
# ===== Epoch 35 =====
# Epoch 35: Avg Loss = 1.6677, Test Accuracy = 41.52%
#
# ===== Epoch 36 =====
# Epoch 36: Avg Loss = 1.6637, Test Accuracy = 42.00%
#
# ===== Epoch 37 =====
# Epoch 37: Avg Loss = 1.6663, Test Accuracy = 42.26%
#
# ===== Epoch 38 =====
# Epoch 38: Avg Loss = 1.6552, Test Accuracy = 40.49%
#
# ===== Epoch 39 =====
# Epoch 39: Avg Loss = 1.6508, Test Accuracy = 40.56%
#
# ===== Epoch 40 =====
# Epoch 40: Avg Loss = 1.6586, Test Accuracy = 41.46%
#
# ===== Epoch 41 =====
# Epoch 41: Avg Loss = 1.6465, Test Accuracy = 42.59%
#
# ===== Epoch 42 =====
# Epoch 42: Avg Loss = 1.6414, Test Accuracy = 42.11%
#
# ===== Epoch 43 =====
# Epoch 43: Avg Loss = 1.6382, Test Accuracy = 42.93%
#
# ===== Epoch 44 =====
# Epoch 44: Avg Loss = 1.6401, Test Accuracy = 42.32%
#
# ===== Epoch 45 =====
# Epoch 45: Avg Loss = 1.6326, Test Accuracy = 43.48%
#
# ===== Epoch 46 =====
# Epoch 46: Avg Loss = 1.6290, Test Accuracy = 41.63%
#
# ===== Epoch 47 =====
# Epoch 47: Avg Loss = 1.6301, Test Accuracy = 43.27%
#
# ===== Epoch 48 =====
# Epoch 48: Avg Loss = 1.6316, Test Accuracy = 43.24%
#
# ===== Epoch 49 =====
# Epoch 49: Avg Loss = 1.6265, Test Accuracy = 43.08%
#
# ===== Epoch 50 =====
# Epoch 50: Avg Loss = 1.6216, Test Accuracy = 42.61%
#
# ===== Epoch 51 =====
# Epoch 51: Avg Loss = 1.6196, Test Accuracy = 43.54%
#
# ===== Epoch 52 =====
# Epoch 52: Avg Loss = 1.6156, Test Accuracy = 43.73%
#
# ===== Epoch 53 =====
# Epoch 53: Avg Loss = 1.6101, Test Accuracy = 42.09%
#
# ===== Epoch 54 =====
# Epoch 54: Avg Loss = 1.6112, Test Accuracy = 41.31%
#
# ===== Epoch 55 =====
# Epoch 55: Avg Loss = 1.6163, Test Accuracy = 43.75%
#
# ===== Epoch 56 =====
# Epoch 56: Avg Loss = 1.6086, Test Accuracy = 42.84%
#
# ===== Epoch 57 =====
# Epoch 57: Avg Loss = 1.6135, Test Accuracy = 43.22%
#
# ===== Epoch 58 =====
# Epoch 58: Avg Loss = 1.6049, Test Accuracy = 40.66%
#
# ===== Epoch 59 =====
# Epoch 59: Avg Loss = 1.6035, Test Accuracy = 43.67%
#
# ===== Epoch 60 =====
# Epoch 60: Avg Loss = 1.6041, Test Accuracy = 43.43%
#
# ===== Epoch 61 =====
# Epoch 61: Avg Loss = 1.5997, Test Accuracy = 43.12%
#
# ===== Epoch 62 =====
# Epoch 62: Avg Loss = 1.5995, Test Accuracy = 42.01%
#
# ===== Epoch 63 =====
# Epoch 63: Avg Loss = 1.5992, Test Accuracy = 43.22%
#
# ===== Epoch 64 =====
# Epoch 64: Avg Loss = 1.5989, Test Accuracy = 43.81%
#
# ===== Epoch 65 =====
# Epoch 65: Avg Loss = 1.6000, Test Accuracy = 44.00%
#
# ===== Epoch 66 =====
# Epoch 66: Avg Loss = 1.5987, Test Accuracy = 44.19%
#
# ===== Epoch 67 =====
# Epoch 67: Avg Loss = 1.5977, Test Accuracy = 43.18%
#
# ===== Epoch 68 =====
# Epoch 68: Avg Loss = 1.5927, Test Accuracy = 42.85%
#
# ===== Epoch 69 =====
# Epoch 69: Avg Loss = 1.5985, Test Accuracy = 44.95%
#
# ===== Epoch 70 =====
# Epoch 70: Avg Loss = 1.5959, Test Accuracy = 42.45%
#
# ===== Epoch 71 =====
# Epoch 71: Avg Loss = 1.5933, Test Accuracy = 44.84%
#
# ===== Epoch 72 =====
# Epoch 72: Avg Loss = 1.5941, Test Accuracy = 43.58%
#
# ===== Epoch 73 =====
# Epoch 73: Avg Loss = 1.5906, Test Accuracy = 43.29%
#
# ===== Epoch 74 =====
# Epoch 74: Avg Loss = 1.5897, Test Accuracy = 43.87%
#
# ===== Epoch 75 =====
# Epoch 75: Avg Loss = 1.6023, Test Accuracy = 44.63%
#
# ===== Epoch 76 =====
# Epoch 76: Avg Loss = 1.5896, Test Accuracy = 45.41%
#
# ===== Epoch 77 =====
# Epoch 77: Avg Loss = 1.5868, Test Accuracy = 42.89%
#
# ===== Epoch 78 =====
# Epoch 78: Avg Loss = 1.5888, Test Accuracy = 44.09%
#
# ===== Epoch 79 =====
# Epoch 79: Avg Loss = 1.5903, Test Accuracy = 42.76%
#
# ===== Epoch 80 =====
# Epoch 80: Avg Loss = 1.5844, Test Accuracy = 43.96%
#
# ===== Epoch 81 =====
# Epoch 81: Avg Loss = 1.5829, Test Accuracy = 44.27%
#
# ===== Epoch 82 =====
# Epoch 82: Avg Loss = 1.5765, Test Accuracy = 44.76%
#
# ===== Epoch 83 =====
# Epoch 83: Avg Loss = 1.5843, Test Accuracy = 45.09%
#
# ===== Epoch 84 =====
# Epoch 84: Avg Loss = 1.5788, Test Accuracy = 45.14%
#
# ===== Epoch 85 =====
# Epoch 85: Avg Loss = 1.5764, Test Accuracy = 45.32%
#
# ===== Epoch 86 =====
# Epoch 86: Avg Loss = 1.5784, Test Accuracy = 44.13%
#
# ===== Epoch 87 =====
# Epoch 87: Avg Loss = 1.5722, Test Accuracy = 44.36%
#
# ===== Epoch 88 =====
# Epoch 88: Avg Loss = 1.5751, Test Accuracy = 44.46%
#
# ===== Epoch 89 =====
# Epoch 89: Avg Loss = 1.5716, Test Accuracy = 44.32%
#
# ===== Epoch 90 =====
# Epoch 90: Avg Loss = 1.5718, Test Accuracy = 43.37%
#
# ===== Epoch 91 =====
# Epoch 91: Avg Loss = 1.5724, Test Accuracy = 44.61%
#
# ===== Epoch 92 =====
# Epoch 92: Avg Loss = 1.5753, Test Accuracy = 45.03%
#
# ===== Epoch 93 =====
# Epoch 93: Avg Loss = 1.5726, Test Accuracy = 44.15%
#
# ===== Epoch 94 =====
# Epoch 94: Avg Loss = 1.5685, Test Accuracy = 44.84%
#
# ===== Epoch 95 =====
# Epoch 95: Avg Loss = 1.5766, Test Accuracy = 43.10%
#
# ===== Epoch 96 =====
# Epoch 96: Avg Loss = 1.5795, Test Accuracy = 45.60%
#
# ===== Epoch 97 =====
# Epoch 97: Avg Loss = 1.5727, Test Accuracy = 45.47%
#
# ===== Epoch 98 =====
# Epoch 98: Avg Loss = 1.5696, Test Accuracy = 45.16%
#
# ===== Epoch 99 =====
# Epoch 99: Avg Loss = 1.5730, Test Accuracy = 45.93%
#
# ===== Epoch 100 =====
# Epoch 100: Avg Loss = 1.5704, Test Accuracy = 45.33%
#
# ===== Epoch 101 =====
# Epoch 101: Avg Loss = 1.5690, Test Accuracy = 45.51%
#
# ===== Epoch 102 =====
# Epoch 102: Avg Loss = 1.5686, Test Accuracy = 44.63%
#
# ===== Epoch 103 =====
# Epoch 103: Avg Loss = 1.5685, Test Accuracy = 45.01%
#
# ===== Epoch 104 =====
# Epoch 104: Avg Loss = 1.5624, Test Accuracy = 44.02%
#
# ===== Epoch 105 =====
# Epoch 105: Avg Loss = 1.5620, Test Accuracy = 45.05%
#
# ===== Epoch 106 =====
# Epoch 106: Avg Loss = 1.5685, Test Accuracy = 41.60%
#
# ===== Epoch 107 =====
# Epoch 107: Avg Loss = 1.5643, Test Accuracy = 45.81%
#
# ===== Epoch 108 =====
# Epoch 108: Avg Loss = 1.5605, Test Accuracy = 45.45%
#
# ===== Epoch 109 =====
# Epoch 109: Avg Loss = 1.5597, Test Accuracy = 45.96%
#
# ===== Epoch 110 =====
# Epoch 110: Avg Loss = 1.5598, Test Accuracy = 45.85%
#
# ===== Epoch 111 =====
# Epoch 111: Avg Loss = 1.5560, Test Accuracy = 46.08%
#
# ===== Epoch 112 =====
# Epoch 112: Avg Loss = 1.5583, Test Accuracy = 44.93%
#
# ===== Epoch 113 =====
# Epoch 113: Avg Loss = 1.5556, Test Accuracy = 45.98%
#
# ===== Epoch 114 =====
# Epoch 114: Avg Loss = 1.5589, Test Accuracy = 43.62%
#
# ===== Epoch 115 =====
# Epoch 115: Avg Loss = 1.5616, Test Accuracy = 45.72%
#
# ===== Epoch 116 =====
# Epoch 116: Avg Loss = 1.5582, Test Accuracy = 45.16%
#
# ===== Epoch 117 =====
# Epoch 117: Avg Loss = 1.5609, Test Accuracy = 45.70%
#
# ===== Epoch 118 =====
# Epoch 118: Avg Loss = 1.5587, Test Accuracy = 46.00%
#
# ===== Epoch 119 =====
# Epoch 119: Avg Loss = 1.5557, Test Accuracy = 45.95%
#
# ===== Epoch 120 =====
# Epoch 120: Avg Loss = 1.5557, Test Accuracy = 46.14%
#
# ===== Epoch 121 =====
# Epoch 121: Avg Loss = 1.5489, Test Accuracy = 44.84%
#
# ===== Epoch 122 =====
# Epoch 122: Avg Loss = 1.5534, Test Accuracy = 46.33%
#
# ===== Epoch 123 =====
# Epoch 123: Avg Loss = 1.5501, Test Accuracy = 45.09%
#
# ===== Epoch 124 =====
# Epoch 124: Avg Loss = 1.5469, Test Accuracy = 46.14%
#
# ===== Epoch 125 =====
# Epoch 125: Avg Loss = 1.5460, Test Accuracy = 45.85%
#
# ===== Epoch 126 =====
# Epoch 126: Avg Loss = 1.5532, Test Accuracy = 46.38%
#
# ===== Epoch 127 =====
# Epoch 127: Avg Loss = 1.5464, Test Accuracy = 45.24%
#
# ===== Epoch 128 =====
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 38
#      30     # # Verificar gradientes
#      31     # for name, param in mask.named_parameters():
#      32     #     if param.grad is not None:
#      33     #         print(f"[Grad] {name}: grad norm = {param.grad.norm().item():.6f}")
#      34     #     else:
#      35     #         print(f"[Grad] {name}: NO grad")
#      36     optimizer.step()
# ---> 38     running_loss += loss.item()
#      39     # if batch_idx % 10 == 0:
#      40     #     print(f"Batch {batch_idx}, Loss: {loss.item():.4f}")
#      42 avg_loss = running_loss / len(train_loader)
#
# KeyboardInterrupt:

# %%
# Gráficos de pérdida y precisión
plt.figure()
plt.plot(range(1, len(losses)+1), losses, label='Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss per Epoch')
plt.legend()
plt.grid(True)
plt.show()

plt.figure()
plt.plot(range(1, len(accuracies)+1), accuracies, label='Accuracy', color='green')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.title('Test Accuracy per Epoch')
plt.legend()
plt.grid(True)
plt.show()

# %%
print(losses)
print(len(losses))
print(accuracies)
print(len(accuracies))
print(epoch)
# Out:
# [2.2183438067029164, 2.210913127515374, 2.2114884191896858, 2.2026477368866524, 2.155341180359445, 2.082736165421765, 2.0242487897233263, 1.9728002955273884, 1.9386098999075774, 1.909446878404152, 1.8805541788659446, 1.8515967076144568, 1.83706165050588, 1.8126129322662585, 1.8060193621530765, 1.7920020219029449, 1.7809180697289908, 1.7669468954568956, 1.7630338407144315, 1.7514616221916386, 1.7471732130137885, 1.731395414326249, 1.7228486992237044, 1.7164038743187742, 1.711033069869367, 1.6975117383933649, 1.7035612907351516, 1.6953431356970856, 1.6882822081083204, 1.6860493287080671, 1.6808052440968955, 1.6833724891994057, 1.67998380595591, 1.67893911389316, 1.6676697189488061, 1.6637405716791385, 1.6662868613876947, 1.65518673709253, 1.6508201353433656, 1.6586288798873017, 1.6465184048908512, 1.6414457217949192, 1.6381517016306155, 1.6401115572307168, 1.6325869207702033, 1.6289763574193163, 1.6301061191209933, 1.631561930950095, 1.6264634564882372, 1.6215604841709137, 1.6196424673970153, 1.6156155866820638, 1.6101403138259562, 1.6111954879469987, 1.6162951661319267, 1.608641587016059, 1.613542212945659, 1.6049302591056358, 1.6034594581621449, 1.6040757258490819, 1.599742938469096, 1.5995154635208408, 1.599246843195543, 1.5988635337207375, 1.600024856081823, 1.598709094088252, 1.5977277315971328, 1.5926822900045208, 1.5984713184397394, 1.5958906248575304, 1.5933085363812562, 1.5940943356694244, 1.5905973842231238, 1.5896737099420735, 1.6022825677220414, 1.5895990126016664, 1.5868085742723652, 1.5887595662256566, 1.590344489347644, 1.5843682285489105, 1.5829270496601011, 1.5764919646629474, 1.5842818363410671, 1.5787570683694467, 1.5763746187454317, 1.57836523070568, 1.5722117336784922, 1.5751238330835249, 1.5716085172281034, 1.571796625125699, 1.5724453297330112, 1.575260843809058, 1.5725857237490213, 1.5684999467396155, 1.576643160567051, 1.579522926269508, 1.5726684150172443, 1.5696124983269995, 1.5730471607388519, 1.5703954765709436, 1.5689764146397753, 1.5685581579440977, 1.5684993663212148, 1.5624051897264108, 1.562006942382673, 1.568521286292774, 1.5643144591552456, 1.5604851805582278, 1.5597221033602227, 1.5598179988744783, 1.5559564301880395, 1.5582922806100148, 1.5555674371922887, 1.5589253480841474, 1.5616477822385184, 1.558171205767771, 1.5608976701410806, 1.5587331823459485, 1.555694283508673, 1.5556777839253588, 1.5488582893115719, 1.5534087514005057, 1.5500783985707818, 1.546905550287991, 1.5460474600152272, 1.553203944752856, 1.5463661904015191]
# 127
# [18.41251669528716, 18.41251669528716, 18.565159320740317, 18.431597023468804, 22.93455447433696, 22.247662659797747, 29.116580805189848, 30.45220377790498, 31.883228391528334, 30.719328372448008, 33.39057431787827, 34.19194810150734, 35.69929402785728, 35.184125166952875, 35.98549895058195, 36.88227437511925, 37.66456783056669, 37.05399732875406, 37.53100553329517, 35.48941041785919, 38.54226292692234, 32.856325128792214, 39.629841633276094, 39.57260064873116, 40.10684983781721, 39.15283342873497, 40.06868918145392, 39.22915474146156, 39.38179736691471, 38.847548177828656, 40.90822362144629, 40.412135088723524, 41.251669528715894, 41.82407937416524, 41.51879412325892, 41.995802327800035, 42.26292692234306, 40.48845640145011, 40.564777714176685, 41.46155313871399, 42.58729250143102, 42.11028429688991, 42.93073840870063, 42.320167906887995, 43.484067925968326, 41.63327609234879, 43.27418431597023, 43.23602365960694, 43.08338103415379, 42.60637282961267, 43.54130891051326, 43.73211219232971, 42.091203968708264, 41.30891051326083, 43.75119252051135, 42.835336767792406, 43.2169433314253, 40.66017935508491, 43.674871207784776, 43.42682694142339, 43.12154169051708, 42.01488265598168, 43.2169433314253, 43.808433505056286, 43.999236786872736, 44.19004006868918, 43.17878267506201, 42.85441709597405, 44.95325319595497, 42.45373020415951, 44.8387712268651, 43.57946956687655, 43.29326464415188, 43.86567448960122, 44.62888761686701, 45.41118107231444, 42.89257775233734, 44.09463842778096, 42.75901545506583, 43.96107613050945, 44.26636138141576, 44.76244991413852, 45.08681549322648, 45.144056477771414, 45.31577943140622, 44.132799084144246, 44.361763022323984, 44.457164663232206, 44.323602365960696, 43.36958595687846, 44.60980728868537, 45.02957450868155, 44.15187941232589, 44.8387712268651, 43.10246136233543, 45.60198435413089, 45.468422056859374, 45.163136805953066, 45.92634993321885, 45.334859759587864, 45.50658271322267, 44.62888761686701, 45.010494180499904, 44.01831711505438, 45.04865483686319, 41.5951154359855, 45.811867964128986, 45.44934172867773, 45.96451058958214, 45.850028620492274, 46.078992558672006, 44.93417286777333, 45.983590917763784, 43.61763022323984, 45.71646632322076, 45.163136805953066, 45.69738599503911, 46.00267124594543, 45.945430261400496, 46.136233543216946, 44.8387712268651, 46.32703682503339, 45.08681549322648, 46.136233543216946, 45.850028620492274, 46.38427780957832, 45.23945811867964]
# 127
# 128

# %%
# Guardar net y mask
torch.save(net.state_dict(), "net.pth")
torch.save(mask.state_dict(), "mask.pth")
print(f"Models saved")
# Out:
# Models saved

# %%
while True:
    masked_model = MaskedForward(net, mask, sparsity_percentage).to(device)
    # Guardar copia de los pesos de net para verificar que no cambian
    # net_before = [p.clone().detach() for p in net.parameters()]
    masked_model.train()
    running_loss = 0.0

    epoch += 1

    print(f"\n===== Epoch {epoch} =====")

        # Guardar copia de los pesos de mask
    # mask_before = [p.clone().detach() for p in mask.parameters()]

    for batch_idx, (images, labels) in enumerate(train_loader):
        images, labels = images.to(device), labels.to(device)
    
        optimizer.zero_grad()
        outputs = masked_model(images)
        loss = criterion(outputs, labels)
        loss.backward()

        # # Verificar gradientes
        # for name, param in mask.named_parameters():
        #     if param.grad is not None:
        #         print(f"[Grad] {name}: grad norm = {param.grad.norm().item():.6f}")
        #     else:
        #         print(f"[Grad] {name}: NO grad")
        optimizer.step()

        running_loss += loss.item()
        # if batch_idx % 10 == 0:
        #     print(f"Batch {batch_idx}, Loss: {loss.item():.4f}")

    avg_loss = running_loss / len(train_loader)
    losses.append(avg_loss)

    # Evaluación
    masked_model.eval()
    correct, total = 0, 0
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = masked_model(images)
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    accuracy = 100.0 * correct / total
    accuracies.append(accuracy)

    #     # Verificar cambios en los parámetros de mask
    # for (before, after), name in zip(zip(mask_before, mask.parameters()), mask.state_dict().keys()):
    #     delta = (after - before).abs().sum().item()
    #     print(f"[Update] {name}: Δ = {delta:.6f}")

    # # Verificar que net no ha sido modificado
    # for (before, after), name in zip(zip(net_before, net.parameters()), net.state_dict().keys()):
    #     delta = (after - before).abs().sum().item()
    #     print(f"[Check Net] {name}: Δ = {delta:.6f}")

    print(f"Epoch {epoch}: Avg Loss = {avg_loss:.4f}, Test Accuracy = {accuracy:.2f}%")

    if accuracy >= threshold_accuracy * 100:
        print("Reached target accuracy. Stopping training.")
        if not saved:
            # Guardar net y mask
            torch.save(net.state_dict(), "net.pth")
            torch.save(mask.state_dict(), "mask.pth")
            print(f"Models saved)")
            saved = True
        else:
            print("Model already saved, skipping save.")
        break
