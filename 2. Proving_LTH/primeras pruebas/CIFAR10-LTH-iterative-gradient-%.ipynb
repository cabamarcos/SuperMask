# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
import torch.nn.functional as F

import matplotlib.pyplot as plt
import time

# %%
class SimpleMLP(nn.Module):
    def __init__(self):
        super(SimpleMLP, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1)
        self.fc1 = nn.Linear(128 * 4 * 4, 128)  # Adjusted dimensions here
        self.fc2 = nn.Linear(128, 10)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.max_pool2d(x, 2)
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2)
        x = F.relu(self.conv3(x))
        x = F.max_pool2d(x, 2)
        x = x.view(-1, 128 * 4 * 4)  # Adjusted dimensions here
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return F.log_softmax(x, dim=1)

# %%
def train_model1(model, dataloader, criterion, optimizer, iteration, epochs=5): 
    model.train()
    accuracies = []
    for epoch in range(epochs):
        total_loss = 0
        for batch_idx, (inputs, targets) in enumerate(dataloader):
            inputs, targets = inputs.to(device), targets.to(device)

            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            loss.backward()            
            optimizer.step()

            total_loss += loss.item()

        # Evaluate at each epoch
        accuracy = evaluate_model(model, test_loader)
        accuracies.append(accuracy)

    print(f'Accuracy: {max(accuracies):.2%}')
    return total_loss / len(dataloader), accuracies

def train_model(model, prune_mask, dataloader, criterion, optimizer, iteration, epochs=5): 
    model.train()
    accuracies = []
    for epoch in range(epochs):
        total_loss = 0
        for batch_idx, (inputs, targets) in enumerate(dataloader):
            inputs, targets = inputs.to(device), targets.to(device)

            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            loss.backward()

            # Zero out the gradients of pruned weights
            zero_out_pruned_gradients(model, prune_mask)
            
            optimizer.step()

            total_loss += loss.item()

        # Evaluate at each epoch
        accuracy = evaluate_model(model, test_loader)
        accuracies.append(accuracy)

    print(f'Accuracy: {max(accuracies):.2%}')
    return total_loss / len(dataloader), accuracies

# %%
def evaluate_model(model, test_loader):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for inputs, targets in test_loader:
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model(inputs)
            _, predicted = outputs.max(1)
            correct += (predicted == targets).sum().item()
            total += targets.size(0)
    return correct / total

# %%
def create_prune_mask(model, prune_percentage=0.2):
    mask = {}
    for name, param in model.named_parameters():
        if 'weight' in name:
            # Calculate threshold as the top (1 - prune_percentage) quantile of the absolute weights
            threshold = torch.quantile(param.abs(), 1- prune_percentage)
            mask[name] = (param.abs() > threshold).float().to(device)
    return mask

def prune_model_and_freeze(model, mask):
    with torch.no_grad():
        for name, param in model.named_parameters():
            if name in mask:
                # Aplicar la máscara a los pesos
                param.data *= mask[name]
                
                # Configurar requires_grad según la máscara
                param.requires_grad = True
                frozen_mask = mask[name] == 0  # Identificar pesos podados
                if frozen_mask.sum() > 0:
                    param.requires_grad = True  # Solo los pesos no podados pueden actualizarse

def zero_out_pruned_gradients(model, mask):
    for name, param in model.named_parameters():
        if name in mask and param.grad is not None:
            # Anular gradientes de los pesos podados
            param.grad *= mask[name]

# %%
def count_zero_weights(model):
    total_weights = 0
    zero_weights = 0
    for param in model.parameters():
        if param.requires_grad:  # Only consider weights that are not frozen
            total_weights += param.numel()
            zero_weights += (param.data == 0).sum().item()
    return zero_weights, total_weights

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
batch_size = 64
epochs =5
iterations = 3

transform = transforms.ToTensor()
train_dataset = datasets.CIFAR10(root="./data", train=True, transform=transform, download=True)
test_dataset = datasets.CIFAR10(root="./data", train=False, transform=transform, download=True)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
results = {}

model = SimpleMLP().to(device)
model_entrenado = SimpleMLP().to(device)
criterion = nn.CrossEntropyLoss()

model_inicial = model.state_dict()
prune_percentages = [80, 70, 60, 50, 40, 30, 20, 15, 10, 8, 5, 3]

def run_experiment():
    global results
    print(f"===== Modelo original =====")
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    _, accuracies_original = train_model1(model,train_loader, criterion, optimizer, iteration=1, epochs=1)

    print(f"Final accuracies for original model: {accuracies_original}")
    results[100] = {
        "accuracies": accuracies_original
    }

    for prune_percentage in prune_percentages:
        model.load_state_dict(model_inicial)
        print(f"===== Pruning al {prune_percentage}% =====")

        accuracies_pruned = []
        for iteration in range(1, iterations + 1):
            print(f"Iteración {iteration}/{iterations}")

            prune_mask = create_prune_mask(model_entrenado, prune_percentage / 100.0)
            prune_model_and_freeze(model, prune_mask)

            optimizer = optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=0.001)
            zero_weights, total_weights = count_zero_weights(model)
            print(f"After pruning {prune_percentage}%: Zero weights = {zero_weights}, Total weights = {total_weights}, Percentage = {100 * zero_weights / total_weights:.2f}%")

            _, accuracies = train_model(model, prune_mask, train_loader, criterion, optimizer, iteration, epochs)
            accuracies_pruned.extend(accuracies)

            zero_weights, total_weights = count_zero_weights(model)
            print(f"After training: Zero weights = {zero_weights}, Total weights = {total_weights}, Percentage = {100 * zero_weights / total_weights:.2f}%")

            results[prune_percentage] = {
                "accuracies": accuracies
            }

            print(f"Final accuracies for pruning at {prune_percentage}%: {accuracies}")

start = time.time()

run_experiment()

end = time.time()
print(f"Tiempo de ejecución: {end - start} segundos")
# Out:
# ===== Modelo original =====
# Accuracy: 53.57%
# Final accuracies for original model: [0.5357]
# ===== Pruning al 80% =====
# Iteración 1/3
# After pruning 80%: Zero weights = 71291, Total weights = 356810, Percentage = 19.98%
# Accuracy: 70.66%
# After training: Zero weights = 71291, Total weights = 356810, Percentage = 19.98%
# Final accuracies for pruning at 80%: [0.5905, 0.6399, 0.6761, 0.6899, 0.7066]
# Iteración 2/3
# After pruning 80%: Zero weights = 71291, Total weights = 356810, Percentage = 19.98%
# Accuracy: 73.09%
# After training: Zero weights = 71291, Total weights = 356810, Percentage = 19.98%
# Final accuracies for pruning at 80%: [0.7247, 0.7305, 0.7294, 0.7289, 0.7309]
# Iteración 3/3
# After pruning 80%: Zero weights = 71291, Total weights = 356810, Percentage = 19.98%
# Accuracy: 74.12%
# After training: Zero weights = 71291, Total weights = 356810, Percentage = 19.98%
# Final accuracies for pruning at 80%: [0.7412, 0.7337, 0.7349, 0.7291, 0.7266]
# ===== Pruning al 70% =====
# Iteración 1/3
# After pruning 70%: Zero weights = 106935, Total weights = 356810, Percentage = 29.97%
# Accuracy: 73.42%
# After training: Zero weights = 106935, Total weights = 356810, Percentage = 29.97%
# Final accuracies for pruning at 70%: [0.7267, 0.7209, 0.7342, 0.7307, 0.7251]
# Iteración 2/3
# After pruning 70%: Zero weights = 106935, Total weights = 356810, Percentage = 29.97%
# Accuracy: 72.24%
# After training: Zero weights = 106935, Total weights = 356810, Percentage = 29.97%
# Final accuracies for pruning at 70%: [0.7219, 0.7197, 0.7198, 0.722, 0.7224]
# Iteración 3/3
# After pruning 70%: Zero weights = 106935, Total weights = 356810, Percentage = 29.97%
# Accuracy: 72.49%
# After training: Zero weights = 106935, Total weights = 356810, Percentage = 29.97%
# Final accuracies for pruning at 70%: [0.7249, 0.7241, 0.7109, 0.7231, 0.7212]
# ===== Pruning al 60% =====
# Iteración 1/3
# After pruning 60%: Zero weights = 142580, Total weights = 356810, Percentage = 39.96%
# Accuracy: 72.11%
# After training: Zero weights = 142580, Total weights = 356810, Percentage = 39.96%
# Final accuracies for pruning at 60%: [0.7105, 0.7143, 0.7178, 0.72, 0.7211]
# Iteración 2/3
# After pruning 60%: Zero weights = 142580, Total weights = 356810, Percentage = 39.96%
# Accuracy: 71.76%
# After training: Zero weights = 142580, Total weights = 356810, Percentage = 39.96%
# Final accuracies for pruning at 60%: [0.7168, 0.7174, 0.7176, 0.7166, 0.7158]
# Iteración 3/3
# After pruning 60%: Zero weights = 142580, Total weights = 356810, Percentage = 39.96%
# Accuracy: 71.67%
# After training: Zero weights = 142580, Total weights = 356810, Percentage = 39.96%
# Final accuracies for pruning at 60%: [0.71, 0.7097, 0.708, 0.7167, 0.7122]
# ===== Pruning al 50% =====
# Iteración 1/3
# After pruning 50%: Zero weights = 178224, Total weights = 356810, Percentage = 49.95%
# Accuracy: 71.26%
# After training: Zero weights = 178224, Total weights = 356810, Percentage = 49.95%
# Final accuracies for pruning at 50%: [0.6959, 0.7096, 0.7092, 0.7126, 0.7086]
# Iteración 2/3
# After pruning 50%: Zero weights = 178224, Total weights = 356810, Percentage = 49.95%
# Accuracy: 71.10%
# After training: Zero weights = 178224, Total weights = 356810, Percentage = 49.95%
# Final accuracies for pruning at 50%: [0.711, 0.7028, 0.7076, 0.6975, 0.7036]
# Iteración 3/3
# After pruning 50%: Zero weights = 178224, Total weights = 356810, Percentage = 49.95%
# Accuracy: 71.00%
# After training: Zero weights = 178224, Total weights = 356810, Percentage = 49.95%
# Final accuracies for pruning at 50%: [0.71, 0.6995, 0.7065, 0.6999, 0.6996]
# ===== Pruning al 40% =====
# Iteración 1/3
# After pruning 40%: Zero weights = 213868, Total weights = 356810, Percentage = 59.94%
# Accuracy: 70.95%
# After training: Zero weights = 213868, Total weights = 356810, Percentage = 59.94%
# Final accuracies for pruning at 40%: [0.6765, 0.699, 0.7049, 0.7095, 0.6964]
# Iteración 2/3
# After pruning 40%: Zero weights = 213868, Total weights = 356810, Percentage = 59.94%
# Accuracy: 71.05%
# After training: Zero weights = 213868, Total weights = 356810, Percentage = 59.94%
# Final accuracies for pruning at 40%: [0.702, 0.7105, 0.707, 0.6983, 0.7027]
# Iteración 3/3
# After pruning 40%: Zero weights = 213868, Total weights = 356810, Percentage = 59.94%
# Accuracy: 70.56%
# After training: Zero weights = 213868, Total weights = 356810, Percentage = 59.94%
# Final accuracies for pruning at 40%: [0.7056, 0.7006, 0.7052, 0.6979, 0.6991]
# ===== Pruning al 30% =====
# Iteración 1/3
# After pruning 30%: Zero weights = 249513, Total weights = 356810, Percentage = 69.93%
# Accuracy: 70.86%
# After training: Zero weights = 249513, Total weights = 356810, Percentage = 69.93%
# Final accuracies for pruning at 30%: [0.651, 0.6827, 0.6935, 0.7086, 0.7048]
# Iteración 2/3
# After pruning 30%: Zero weights = 249513, Total weights = 356810, Percentage = 69.93%
# Accuracy: 71.59%
# After training: Zero weights = 249513, Total weights = 356810, Percentage = 69.93%
# Final accuracies for pruning at 30%: [0.7159, 0.7029, 0.7119, 0.7125, 0.6997]
# Iteración 3/3
# After pruning 30%: Zero weights = 249513, Total weights = 356810, Percentage = 69.93%
# Accuracy: 71.05%
# After training: Zero weights = 249513, Total weights = 356810, Percentage = 69.93%
# Final accuracies for pruning at 30%: [0.7067, 0.708, 0.7018, 0.7011, 0.7105]
# ===== Pruning al 20% =====
# Iteración 1/3
# After pruning 20%: Zero weights = 285157, Total weights = 356810, Percentage = 79.92%
# Accuracy: 68.23%
# After training: Zero weights = 285157, Total weights = 356810, Percentage = 79.92%
# Final accuracies for pruning at 20%: [0.5969, 0.6403, 0.6604, 0.6682, 0.6823]
# Iteración 2/3
# After pruning 20%: Zero weights = 285157, Total weights = 356810, Percentage = 79.92%
# Accuracy: 69.71%
# After training: Zero weights = 285157, Total weights = 356810, Percentage = 79.92%
# Final accuracies for pruning at 20%: [0.6701, 0.6845, 0.6971, 0.6895, 0.6919]
# Iteración 3/3
# After pruning 20%: Zero weights = 285157, Total weights = 356810, Percentage = 79.92%
# Accuracy: 69.67%
# After training: Zero weights = 285157, Total weights = 356810, Percentage = 79.92%
# Final accuracies for pruning at 20%: [0.6918, 0.6908, 0.6967, 0.6919, 0.6926]
# ===== Pruning al 15% =====
# Iteración 1/3
# After pruning 15%: Zero weights = 302979, Total weights = 356810, Percentage = 84.91%
# Accuracy: 66.39%
# After training: Zero weights = 302979, Total weights = 356810, Percentage = 84.91%
# Final accuracies for pruning at 15%: [0.5777, 0.619, 0.6391, 0.6493, 0.6639]
# Iteración 2/3
# After pruning 15%: Zero weights = 302979, Total weights = 356810, Percentage = 84.91%
# Accuracy: 68.09%
# After training: Zero weights = 302979, Total weights = 356810, Percentage = 84.91%
# Final accuracies for pruning at 15%: [0.667, 0.6695, 0.6684, 0.6773, 0.6809]
# Iteración 3/3
# After pruning 15%: Zero weights = 302979, Total weights = 356810, Percentage = 84.91%
# Accuracy: 69.07%
# After training: Zero weights = 302979, Total weights = 356810, Percentage = 84.91%
# Final accuracies for pruning at 15%: [0.6793, 0.6785, 0.6907, 0.6853, 0.6867]
# ===== Pruning al 10% =====
# Iteración 1/3
# After pruning 10%: Zero weights = 320801, Total weights = 356810, Percentage = 89.91%
# Accuracy: 61.43%
# After training: Zero weights = 320801, Total weights = 356810, Percentage = 89.91%
# Final accuracies for pruning at 10%: [0.5251, 0.5754, 0.5985, 0.6143, 0.6068]
# Iteración 2/3
# After pruning 10%: Zero weights = 320801, Total weights = 356810, Percentage = 89.91%
# Accuracy: 65.35%
# After training: Zero weights = 320801, Total weights = 356810, Percentage = 89.91%
# Final accuracies for pruning at 10%: [0.6292, 0.6393, 0.6463, 0.6377, 0.6535]
# Iteración 3/3
# After pruning 10%: Zero weights = 320801, Total weights = 356810, Percentage = 89.91%
# Accuracy: 66.46%
# After training: Zero weights = 320801, Total weights = 356810, Percentage = 89.91%
# Final accuracies for pruning at 10%: [0.6463, 0.6567, 0.6607, 0.6581, 0.6646]
# ===== Pruning al 8% =====
# Iteración 1/3
# After pruning 8%: Zero weights = 327929, Total weights = 356810, Percentage = 91.91%
# Accuracy: 61.91%
# After training: Zero weights = 327929, Total weights = 356810, Percentage = 91.91%
# Final accuracies for pruning at 8%: [0.5504, 0.5885, 0.6003, 0.6082, 0.6191]
# Iteración 2/3
# After pruning 8%: Zero weights = 327929, Total weights = 356810, Percentage = 91.91%
# Accuracy: 63.30%
# After training: Zero weights = 327929, Total weights = 356810, Percentage = 91.91%
# Final accuracies for pruning at 8%: [0.6241, 0.633, 0.6283, 0.6171, 0.628]
# Iteración 3/3
# After pruning 8%: Zero weights = 327929, Total weights = 356810, Percentage = 91.91%
# Accuracy: 64.36%
# After training: Zero weights = 327929, Total weights = 356810, Percentage = 91.91%
# Final accuracies for pruning at 8%: [0.6367, 0.6386, 0.6374, 0.6351, 0.6436]
# ===== Pruning al 5% =====
# Iteración 1/3
# After pruning 5%: Zero weights = 338623, Total weights = 356810, Percentage = 94.90%
# Accuracy: 53.73%
# After training: Zero weights = 338623, Total weights = 356810, Percentage = 94.90%
# Final accuracies for pruning at 5%: [0.4476, 0.4903, 0.5083, 0.5276, 0.5373]
# Iteración 2/3
# After pruning 5%: Zero weights = 338623, Total weights = 356810, Percentage = 94.90%
# Accuracy: 56.00%
# After training: Zero weights = 338623, Total weights = 356810, Percentage = 94.90%
# Final accuracies for pruning at 5%: [0.5446, 0.5499, 0.5475, 0.555, 0.56]
# Iteración 3/3
# After pruning 5%: Zero weights = 338623, Total weights = 356810, Percentage = 94.90%
# Accuracy: 57.83%
# After training: Zero weights = 338623, Total weights = 356810, Percentage = 94.90%
# Final accuracies for pruning at 5%: [0.5655, 0.5671, 0.5704, 0.5693, 0.5783]
# ===== Pruning al 3% =====
# Iteración 1/3
# After pruning 3%: Zero weights = 345753, Total weights = 356810, Percentage = 96.90%
# Accuracy: 42.32%
# After training: Zero weights = 345753, Total weights = 356810, Percentage = 96.90%
# Final accuracies for pruning at 3%: [0.2723, 0.3408, 0.3769, 0.4082, 0.4232]
# Iteración 2/3
# After pruning 3%: Zero weights = 345753, Total weights = 356810, Percentage = 96.90%
# Accuracy: 46.20%
# After training: Zero weights = 345753, Total weights = 356810, Percentage = 96.90%
# Final accuracies for pruning at 3%: [0.4361, 0.4415, 0.4506, 0.459, 0.462]
# Iteración 3/3
# After pruning 3%: Zero weights = 345753, Total weights = 356810, Percentage = 96.90%
# Accuracy: 48.15%
# After training: Zero weights = 345753, Total weights = 356810, Percentage = 96.90%
# Final accuracies for pruning at 3%: [0.4679, 0.4662, 0.4687, 0.4728, 0.4815]
# Tiempo de ejecución: 1407.4669382572174 segundos

# %%
hours, rem = divmod(end-start, 3600)
minutes, seconds = divmod(rem, 60)
print("{:0>2}:{:0>2}:{:05.2f}".format(int(hours),int(minutes),seconds))
# Out:
# 00:23:27.47

# %%
# Función para obtener la mejor accuracy de cada porcentaje de pruning
def extract_best_accuracies(results):
    best_accuracies = []
    pruning_percentages = []
    for percentage, data in results.items():
        pruning_percentages.append(percentage)
        best_accuracy = max(data["accuracies"])  # Mejor accuracy de todas las iteraciones para ese porcentaje
        best_accuracies.append(best_accuracy)
    return pruning_percentages, best_accuracies

# Extraer los datos
pruning_percentages, best_accuracies = extract_best_accuracies(results)

# Generar la gráfica
plt.figure(figsize=(10, 6))
plt.plot(pruning_percentages, [acc * 100 for acc in best_accuracies], marker='o', color='b')
plt.title('Accuracy más alto vs Porcentaje de Pruning')
plt.xlabel('Porcentaje de Pruning (%)')
plt.ylabel('Accuracy más alto (%)')
plt.grid(True)
plt.xticks(pruning_percentages)
plt.show()
