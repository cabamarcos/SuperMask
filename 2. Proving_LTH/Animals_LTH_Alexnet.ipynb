# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms, models
from torch.utils.data import DataLoader

import numpy as np
import matplotlib
matplotlib.use("agg")
import matplotlib.pyplot as plt
import os

from utils import *

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Usando dispositivo: {device}")
# Out:
# Usando dispositivo: cuda

# %%
batch_size = 64
epochs = 10
num_experiments = 10
data_dir = "../data/animals10"

results = {}

active_weights_percentages = [70, 50, 30, 20, 15, 10, 8, 5, 3]

# %%
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

train_dataset = datasets.ImageFolder(root=os.path.join(data_dir, "train"), transform=transform)
test_dataset = datasets.ImageFolder(root=os.path.join(data_dir, "test"), transform=transform)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
def run_experiment():
    global results

    # ── Baseline: 10 redes completas sin podar (100% pesos activos) ──
    print(f"\n{'='*50}")
    print("Baseline: Red completa (100% pesos activos)")
    print(f"{'='*50}")
    baseline_accuracies = []
    for exp in range(num_experiments):
        print(f"\n--- Experimento {exp+1}/{num_experiments} ---")
        model = create_alexnet().to(device)
        criterion = nn.CrossEntropyLoss()
        optimizer = optim.Adam(model.parameters(), lr=0.0001)
        train_model(model, train_loader, criterion, optimizer, epochs)
        acc = evaluate_model(model, test_loader)
        baseline_accuracies.append(acc * 100)
        print(f"Accuracy: {acc:.2%}")
    results[100] = baseline_accuracies
    print(f"\n>> Baseline (100% activos) — Mean: {sum(baseline_accuracies)/len(baseline_accuracies):.2f}%")

    # ── Experimentos LTH por cada nivel de pesos activos ─────────
    for active_pct in active_weights_percentages:
        prune_pct = 100 - active_pct
        print(f"\n{'='*50}")
        print(f"Pesos activos: {active_pct}% (podando {prune_pct}%)")
        print(f"{'='*50}")

        pruned_accuracies = []

        for exp in range(num_experiments):
            print(f"\n--- Experimento {exp+1}/{num_experiments} ---")

            # Crear modelo con nueva inicialización aleatoria
            model = create_alexnet().to(device)
            initial_state_dict = {k: v.clone() for k, v in model.state_dict().items()}

            # Entrenar modelo original
            criterion = nn.CrossEntropyLoss()
            optimizer = optim.Adam(model.parameters(), lr=0.0001)
            train_model(model, train_loader, criterion, optimizer, epochs)

            # Crear máscara de poda sobre el modelo entrenado
            prune_mask = create_prune_mask(model, prune_pct / 100.0)

            # Reiniciar a los pesos iniciales y aplicar máscara
            model.load_state_dict(initial_state_dict)
            prune_model(model, prune_mask)

            # Verificar % de pesos activos
            total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
            nonzero_params = sum((p != 0).sum().item() for p in model.parameters() if p.requires_grad)
            actual_active_pct = (nonzero_params / total_params) * 100
            print(f"Pesos activos reales: {actual_active_pct:.1f}% (objetivo: {active_pct}%)")

            # Entrenar modelo podado con máscara mantenida
            optimizer = optim.Adam(model.parameters(), lr=0.0001)
            train_model_with_mask(model, train_loader, criterion, optimizer, epochs, prune_mask)
            acc_pruned = evaluate_model(model, test_loader)
            pruned_accuracies.append(acc_pruned * 100)

            print(f"Accuracy pruned: {acc_pruned:.2%}")

        results[active_pct] = pruned_accuracies
        print(f"\n>> {active_pct}% activos — Mean: {sum(pruned_accuracies)/len(pruned_accuracies):.2f}%, "
              f"Std: {(sum((x - sum(pruned_accuracies)/len(pruned_accuracies))**2 for x in pruned_accuracies)/len(pruned_accuracies))**0.5:.2f}%")

run_experiment()
# Out:
# ==================================================
# Baseline: Red completa (100% pesos activos)
# ==================================================
#
# --- Experimento 1/10 ---
# C:\Users\Usuario\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\Usuario\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Accuracy: 75.81%
#
# --- Experimento 2/10 ---
# Accuracy: 75.67%
#
# --- Experimento 3/10 ---
# Accuracy: 77.24%
#
# --- Experimento 4/10 ---
# Accuracy: 74.53%
#
# --- Experimento 5/10 ---
# Accuracy: 74.36%
#
# --- Experimento 6/10 ---
# Accuracy: 75.65%
#
# --- Experimento 7/10 ---
# Accuracy: 73.21%
#
# --- Experimento 8/10 ---
# Accuracy: 74.20%
#
# --- Experimento 9/10 ---
# Accuracy: 75.29%
#
# --- Experimento 10/10 ---
# Accuracy: 74.01%
#
# >> Baseline (100% activos) — Mean: 75.00%
#
# ==================================================
# Pesos activos: 70% (podando 30%)
# ==================================================
#
# --- Experimento 1/10 ---
# Pesos activos reales: 70.0% (objetivo: 70%)
# Accuracy pruned: 76.82%
#
# --- Experimento 2/10 ---
# Pesos activos reales: 70.0% (objetivo: 70%)
# Accuracy pruned: 77.05%
#
# --- Experimento 3/10 ---
# Pesos activos reales: 70.0% (objetivo: 70%)
# Accuracy pruned: 77.03%
#
# --- Experimento 4/10 ---
# Pesos activos reales: 70.0% (objetivo: 70%)
# Accuracy pruned: 76.40%
#
# --- Experimento 5/10 ---
# Pesos activos reales: 70.0% (objetivo: 70%)
# Accuracy pruned: 76.44%
#
# --- Experimento 6/10 ---
# Pesos activos reales: 70.0% (objetivo: 70%)
# Accuracy pruned: 74.95%
#
# --- Experimento 7/10 ---
# Pesos activos reales: 70.0% (objetivo: 70%)
# Accuracy pruned: 76.24%
#
# --- Experimento 8/10 ---
# Pesos activos reales: 70.0% (objetivo: 70%)
# Accuracy pruned: 78.21%
#
# --- Experimento 9/10 ---
# Pesos activos reales: 70.0% (objetivo: 70%)
# Accuracy pruned: 75.96%
#
# --- Experimento 10/10 ---
# Pesos activos reales: 70.0% (objetivo: 70%)
# Accuracy pruned: 76.68%
#
# >> 70% activos — Mean: 76.58%, Std: 0.80%
#
# ==================================================
# Pesos activos: 50% (podando 50%)
# ==================================================
#
# --- Experimento 1/10 ---
# Pesos activos reales: 50.0% (objetivo: 50%)
# Accuracy pruned: 74.81%
#
# --- Experimento 2/10 ---
# Pesos activos reales: 50.0% (objetivo: 50%)
# Accuracy pruned: 75.46%
#
# --- Experimento 3/10 ---
# Pesos activos reales: 50.0% (objetivo: 50%)
# Accuracy pruned: 77.03%
#
# --- Experimento 4/10 ---
# Pesos activos reales: 50.0% (objetivo: 50%)
# Accuracy pruned: 76.07%
#
# --- Experimento 5/10 ---
# Pesos activos reales: 50.0% (objetivo: 50%)
# Accuracy pruned: 75.60%
#
# --- Experimento 6/10 ---
# Pesos activos reales: 50.0% (objetivo: 50%)
# Accuracy pruned: 77.70%
#
# --- Experimento 7/10 ---
# Pesos activos reales: 50.0% (objetivo: 50%)
# Accuracy pruned: 76.63%
#
# --- Experimento 8/10 ---
# Pesos activos reales: 50.0% (objetivo: 50%)
# Accuracy pruned: 78.50%
#
# --- Experimento 9/10 ---
# Pesos activos reales: 50.0% (objetivo: 50%)
# Accuracy pruned: 77.07%
#
# --- Experimento 10/10 ---
# Pesos activos reales: 50.0% (objetivo: 50%)
# Accuracy pruned: 77.22%
#
# >> 50% activos — Mean: 76.61%, Std: 1.07%
#
# ==================================================
# Pesos activos: 30% (podando 70%)
# ==================================================
#
# --- Experimento 1/10 ---
# Pesos activos reales: 30.0% (objetivo: 30%)
# Accuracy pruned: 77.96%
#
# --- Experimento 2/10 ---
# Pesos activos reales: 30.0% (objetivo: 30%)
# Accuracy pruned: 76.82%
#
# --- Experimento 3/10 ---
# Pesos activos reales: 30.0% (objetivo: 30%)
# Accuracy pruned: 78.19%
#
# --- Experimento 4/10 ---
# Pesos activos reales: 30.0% (objetivo: 30%)
# Accuracy pruned: 77.90%
#
# --- Experimento 5/10 ---
# Pesos activos reales: 30.0% (objetivo: 30%)
# Accuracy pruned: 77.92%
#
# --- Experimento 6/10 ---
# Pesos activos reales: 30.0% (objetivo: 30%)
# Accuracy pruned: 76.86%
#
# --- Experimento 7/10 ---
# Pesos activos reales: 30.0% (objetivo: 30%)
# Accuracy pruned: 77.18%
#
# --- Experimento 8/10 ---
# Pesos activos reales: 30.0% (objetivo: 30%)
# Accuracy pruned: 77.85%
#
# --- Experimento 9/10 ---
# Pesos activos reales: 30.0% (objetivo: 30%)
# Accuracy pruned: 77.24%
#
# --- Experimento 10/10 ---
# Pesos activos reales: 30.0% (objetivo: 30%)
# Accuracy pruned: 77.60%
#
# >> 30% activos — Mean: 77.55%, Std: 0.47%
#
# ==================================================
# Pesos activos: 20% (podando 80%)
# ==================================================
#
# --- Experimento 1/10 ---
# Pesos activos reales: 20.0% (objetivo: 20%)
# Accuracy pruned: 78.21%
#
# --- Experimento 2/10 ---
# Pesos activos reales: 20.0% (objetivo: 20%)
# Accuracy pruned: 78.42%
#
# --- Experimento 3/10 ---
# Pesos activos reales: 20.0% (objetivo: 20%)
# Accuracy pruned: 78.92%
#
# --- Experimento 4/10 ---
# Pesos activos reales: 20.0% (objetivo: 20%)
# Accuracy pruned: 78.02%
#
# --- Experimento 5/10 ---
# Pesos activos reales: 20.0% (objetivo: 20%)
# Accuracy pruned: 79.28%
#
# --- Experimento 6/10 ---
# Pesos activos reales: 20.0% (objetivo: 20%)
# Accuracy pruned: 77.45%
#
# --- Experimento 7/10 ---
# Pesos activos reales: 20.0% (objetivo: 20%)
# Accuracy pruned: 78.21%
#
# --- Experimento 8/10 ---
# Pesos activos reales: 20.0% (objetivo: 20%)
# Accuracy pruned: 77.62%
#
# --- Experimento 9/10 ---
# Pesos activos reales: 20.0% (objetivo: 20%)
# Accuracy pruned: 76.86%
#
# --- Experimento 10/10 ---
# Pesos activos reales: 20.0% (objetivo: 20%)
# Accuracy pruned: 78.27%
#
# >> 20% activos — Mean: 78.12%, Std: 0.66%
#
# ==================================================
# Pesos activos: 15% (podando 85%)
# ==================================================
#
# --- Experimento 1/10 ---
# Pesos activos reales: 15.0% (objetivo: 15%)
# Accuracy pruned: 78.17%
#
# --- Experimento 2/10 ---
# Pesos activos reales: 15.0% (objetivo: 15%)
# Accuracy pruned: 78.50%
#
# --- Experimento 3/10 ---
# Pesos activos reales: 15.0% (objetivo: 15%)
# Accuracy pruned: 78.59%
#
# --- Experimento 4/10 ---
# Pesos activos reales: 15.0% (objetivo: 15%)
# Accuracy pruned: 78.40%
#
# --- Experimento 5/10 ---
# Pesos activos reales: 15.0% (objetivo: 15%)
# Accuracy pruned: 79.05%
#
# --- Experimento 6/10 ---
# Pesos activos reales: 15.0% (objetivo: 15%)
# Accuracy pruned: 77.60%
#
# --- Experimento 7/10 ---
# Pesos activos reales: 15.0% (objetivo: 15%)
# Accuracy pruned: 77.68%
#
# --- Experimento 8/10 ---
# Pesos activos reales: 15.0% (objetivo: 15%)
# Accuracy pruned: 77.64%
#
# --- Experimento 9/10 ---
# Pesos activos reales: 15.0% (objetivo: 15%)
# Accuracy pruned: 78.15%
#
# --- Experimento 10/10 ---
# Pesos activos reales: 15.0% (objetivo: 15%)
# Accuracy pruned: 77.83%
#
# >> 15% activos — Mean: 78.16%, Std: 0.46%
#
# ==================================================
# Pesos activos: 10% (podando 90%)
# ==================================================
#
# --- Experimento 1/10 ---
# Pesos activos reales: 10.0% (objetivo: 10%)
# Accuracy pruned: 78.53%
#
# --- Experimento 2/10 ---
# Pesos activos reales: 10.0% (objetivo: 10%)
# Accuracy pruned: 77.92%
#
# --- Experimento 3/10 ---
# Pesos activos reales: 10.0% (objetivo: 10%)
# Accuracy pruned: 78.86%
#
# --- Experimento 4/10 ---
# Pesos activos reales: 10.0% (objetivo: 10%)
# Accuracy pruned: 77.43%
#
# --- Experimento 5/10 ---
# Pesos activos reales: 10.0% (objetivo: 10%)
# Accuracy pruned: 77.10%
#
# --- Experimento 6/10 ---
# Pesos activos reales: 10.0% (objetivo: 10%)
# Accuracy pruned: 76.78%
#
# --- Experimento 7/10 ---
# Pesos activos reales: 10.0% (objetivo: 10%)
# Accuracy pruned: 77.73%
#
# --- Experimento 8/10 ---
# Pesos activos reales: 10.0% (objetivo: 10%)
# Accuracy pruned: 78.76%
#
# --- Experimento 9/10 ---
# Pesos activos reales: 10.0% (objetivo: 10%)
# Accuracy pruned: 79.09%
#
# --- Experimento 10/10 ---
# Pesos activos reales: 10.0% (objetivo: 10%)
# Accuracy pruned: 78.88%
#
# >> 10% activos — Mean: 78.11%, Std: 0.78%
#
# ==================================================
# Pesos activos: 8% (podando 92%)
# ==================================================
#
# --- Experimento 1/10 ---
# Pesos activos reales: 8.0% (objetivo: 8%)
# Accuracy pruned: 78.15%
#
# --- Experimento 2/10 ---
# Pesos activos reales: 8.0% (objetivo: 8%)
# Accuracy pruned: 78.11%
#
# --- Experimento 3/10 ---
# Pesos activos reales: 8.0% (objetivo: 8%)
# Accuracy pruned: 78.08%
#
# --- Experimento 4/10 ---
# Pesos activos reales: 8.0% (objetivo: 8%)
# Accuracy pruned: 77.31%
#
# --- Experimento 5/10 ---
# Pesos activos reales: 8.0% (objetivo: 8%)
# Accuracy pruned: 78.11%
#
# --- Experimento 6/10 ---
# Pesos activos reales: 8.0% (objetivo: 8%)
# Accuracy pruned: 77.94%
#
# --- Experimento 7/10 ---
# Pesos activos reales: 8.0% (objetivo: 8%)
# Accuracy pruned: 78.67%
#
# --- Experimento 8/10 ---
# Pesos activos reales: 8.0% (objetivo: 8%)
# Accuracy pruned: 75.63%
#
# --- Experimento 9/10 ---
# Pesos activos reales: 8.0% (objetivo: 8%)
# Accuracy pruned: 78.08%
#
# --- Experimento 10/10 ---
# Pesos activos reales: 8.0% (objetivo: 8%)
# Accuracy pruned: 78.06%
#
# >> 8% activos — Mean: 77.82%, Std: 0.79%
#
# ==================================================
# Pesos activos: 5% (podando 95%)
# ==================================================
#
# --- Experimento 1/10 ---
# Pesos activos reales: 5.0% (objetivo: 5%)
# Accuracy pruned: 76.87%
#
# --- Experimento 2/10 ---
# Pesos activos reales: 5.0% (objetivo: 5%)
# Accuracy pruned: 76.87%
#
# --- Experimento 3/10 ---
# Pesos activos reales: 5.0% (objetivo: 5%)
# Accuracy pruned: 76.42%
#
# --- Experimento 4/10 ---
# Pesos activos reales: 5.0% (objetivo: 5%)
# Accuracy pruned: 76.47%
#
# --- Experimento 5/10 ---
# Pesos activos reales: 5.0% (objetivo: 5%)
# Accuracy pruned: 77.45%
#
# --- Experimento 6/10 ---
# Pesos activos reales: 5.0% (objetivo: 5%)
# Accuracy pruned: 76.42%
#
# --- Experimento 7/10 ---
# Pesos activos reales: 5.0% (objetivo: 5%)
# Accuracy pruned: 76.40%
#
# --- Experimento 8/10 ---
# Pesos activos reales: 5.0% (objetivo: 5%)
# Accuracy pruned: 76.57%
#
# --- Experimento 9/10 ---
# Pesos activos reales: 5.0% (objetivo: 5%)
# Accuracy pruned: 76.47%
#
# --- Experimento 10/10 ---
# Pesos activos reales: 5.0% (objetivo: 5%)
# Accuracy pruned: 77.58%
#
# >> 5% activos — Mean: 76.75%, Std: 0.42%
#
# ==================================================
# Pesos activos: 3% (podando 97%)
# ==================================================
#
# --- Experimento 1/10 ---
# Pesos activos reales: 3.0% (objetivo: 3%)
# Accuracy pruned: 73.17%
#
# --- Experimento 2/10 ---
# Pesos activos reales: 3.0% (objetivo: 3%)
# Accuracy pruned: 72.87%
#
# --- Experimento 3/10 ---
# Pesos activos reales: 3.0% (objetivo: 3%)
# Accuracy pruned: 72.20%
#
# --- Experimento 4/10 ---
# Pesos activos reales: 3.0% (objetivo: 3%)
# Accuracy pruned: 72.94%
#
# --- Experimento 5/10 ---
# Pesos activos reales: 3.0% (objetivo: 3%)
# Accuracy pruned: 72.89%
#
# --- Experimento 6/10 ---
# Pesos activos reales: 3.0% (objetivo: 3%)
# Accuracy pruned: 74.85%
#
# --- Experimento 7/10 ---
# Pesos activos reales: 3.0% (objetivo: 3%)
# Accuracy pruned: 72.39%
#
# --- Experimento 8/10 ---
# Pesos activos reales: 3.0% (objetivo: 3%)
# Accuracy pruned: 71.72%
#
# --- Experimento 9/10 ---
# Pesos activos reales: 3.0% (objetivo: 3%)
# Accuracy pruned: 71.82%
#
# --- Experimento 10/10 ---
# Pesos activos reales: 3.0% (objetivo: 3%)
# Accuracy pruned: 73.34%
#
# >> 3% activos — Mean: 72.82%, Std: 0.86%

# %%
# ── Preparar datos para boxplot ───────────────────────────────────
# Eje X: % de pesos activos ordenados de mayor a menor (100% → 3%)
all_active_pcts = [100] + sorted(active_weights_percentages, reverse=True)
data_for_boxplot = [results[ap] for ap in all_active_pcts]

# ── Publication-quality style ─────────────────────────────────────
matplotlib.rcParams.update(matplotlib.rcParamsDefault)
plt.rcParams.update({
    "font.family": "serif",
    "font.serif": ["Times New Roman", "DejaVu Serif"],
    "text.usetex": False,
    "mathtext.fontset": "dejavuserif",
    "axes.labelsize": 11,
    "font.size": 10,
    "legend.fontsize": 9,
    "xtick.labelsize": 9,
    "ytick.labelsize": 9,
    "figure.dpi": 150,
    "savefig.dpi": 300,
    "savefig.bbox": "tight",
})

# ── Boxplot ────────────────────────────────────────────────────────
fig, ax = plt.subplots(figsize=(7, 4))

bp = ax.boxplot(data_for_boxplot,
                positions=range(len(all_active_pcts)),
                widths=0.5,
                patch_artist=True,
                showmeans=True,
                meanprops=dict(marker='D', markerfacecolor='#EE6677', markersize=4),
                medianprops=dict(color='black', linewidth=1.2),
                boxprops=dict(facecolor='#BBDEFB', edgecolor='black', linewidth=0.8),
                whiskerprops=dict(color='black', linewidth=0.8),
                capprops=dict(color='black', linewidth=0.8),
                flierprops=dict(marker='o', markersize=3, markerfacecolor='gray'))

# Colorear el baseline con un color distinto
bp['boxes'][0].set_facecolor('#C8E6C9')

# Superponer puntos individuales
for i, data in enumerate(data_for_boxplot):
    jitter = np.random.default_rng(42).uniform(-0.12, 0.12, size=len(data))
    ax.scatter([i + j for j in jitter], data,
               color='#EE6677', s=12, alpha=0.6, zorder=5, edgecolors='none')

# Etiquetas del eje X
ax.set_xticks(range(len(all_active_pcts)))
ax.set_xticklabels([f"{ap}%" for ap in all_active_pcts])

# Labels
ax.set_xlabel("Active Weights (%)", labelpad=6)
ax.set_ylabel("Test Accuracy (%)", labelpad=6)
ax.set_title(f"Lottery Ticket Hypothesis — ANIMALS10 (AlexNet)",
             fontsize=12, pad=10)

# Grid (horizontal only)
ax.yaxis.grid(True, linestyle="--", alpha=0.5, linewidth=0.5)
ax.set_axisbelow(True)

# Clean spines
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)

fig.tight_layout(pad=0.5)
fig.savefig("lth_animals10_alexnet_boxplot.png", bbox_inches="tight")
plt.show()
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_22772\766459474.py:67: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
print(results)
# Out:
# {100: [75.80614386567449, 75.67258156840298, 77.23716847929785, 74.52776187750429, 74.35603892386949, 75.65350124022133, 73.2112192329708, 74.20339629841634, 75.29097500477008, 74.01259301659988], 70: [76.81740125930166, 77.04636519748139, 77.02728486929975, 76.39763403930547, 76.43579469566876, 74.94752909750048, 76.24499141385232, 78.21026521656172, 75.95878649112765, 76.68383896203015], 50: [74.81396680022895, 75.46269795840489, 77.02728486929975, 76.07326846021752, 75.5962602556764, 77.69509635565733, 76.6265979774852, 78.4964701392864, 77.06544552566305, 77.2180881511162], 30: [77.96222095020035, 76.81740125930166, 78.19118488838008, 77.90497996565541, 77.92406029383704, 76.85556191566495, 77.1799274947529, 77.84773898111047, 77.23716847929785, 77.59969471474909], 20: [78.21026521656172, 78.42014882655982, 78.91623735928258, 78.01946193474528, 79.27876359473383, 77.44705208929594, 78.21026521656172, 77.61877504293075, 76.85556191566495, 78.26750620110666], 15: [78.17210456019843, 78.4964701392864, 78.59187178019462, 78.40106849837817, 79.04979965655409, 77.59969471474909, 77.67601602747567, 77.63785537111238, 78.15302423201679, 77.82865865292882], 10: [78.53463079564969, 77.92406029383704, 78.85899637473764, 77.42797176111429, 77.10360618202633, 76.77924060293837, 77.7332570120206, 78.76359473382942, 79.08796031291739, 78.87807670291929], 8: [78.15302423201679, 78.1148635756535, 78.07670291929021, 77.31348979202443, 78.1148635756535, 77.9431406220187, 78.6681930929212, 75.63442091203969, 78.07670291929021, 78.05762259110857], 5: [76.8746422438466, 76.8746422438466, 76.41671436748713, 76.47395535203205, 77.44705208929594, 76.41671436748713, 76.39763403930547, 76.56935699294027, 76.47395535203205, 77.58061438656745], 3: [73.17305857660752, 72.86777332570121, 72.19996183934364, 72.94409463842779, 72.88685365388284, 74.85212745659226, 72.39076512116009, 71.72295363480252, 71.81835527571074, 73.34478153024232]}
