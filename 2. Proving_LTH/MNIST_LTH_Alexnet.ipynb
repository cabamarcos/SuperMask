# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms, models
from torchvision.datasets import MNIST
from torch.utils.data import DataLoader

import numpy as np
import matplotlib
matplotlib.use("agg")
import matplotlib.pyplot as plt
import numpy as np
import copy

from utils import *

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Usando dispositivo: {device}")

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
batch_size = 64
epochs = 5
num_experiments = 10

results = {}

active_weights_percentages = [70, 50, 30, 20, 15, 10, 8, 5, 3]
# Out:
# Usando dispositivo: cuda

# %%
transform = transforms.Compose([
    transforms.Grayscale(3),
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.1307, 0.1307, 0.1307],
                         std=[0.3081, 0.3081, 0.3081])
])

train_dataset = MNIST(root= '../data/MNIST', train=True, download=True, transform=transform)
test_dataset = MNIST(root= '../data/MNIST', train=False, download=True, transform=transform)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
def run_experiment():
    global results

    # ── Baseline: 10 redes completas sin podar (100% pesos activos) ──
    print(f"\n{'='*50}")
    print("Baseline: Red completa (100% pesos activos)")
    print(f"{'='*50}")
    baseline_accuracies = []
    for exp in range(num_experiments):
        print(f"\n--- Experimento {exp+1}/{num_experiments} ---")
        model = create_alexnet().to(device)
        criterion = nn.CrossEntropyLoss()
        optimizer = optim.Adam(model.parameters(), lr=0.0001)
        train_model(model, train_loader, criterion, optimizer, epochs)
        acc = evaluate_model(model, test_loader)
        baseline_accuracies.append(acc * 100)
        print(f"Accuracy: {acc:.2%}")
    results[100] = baseline_accuracies
    print(f"\n>> Baseline (100% activos) — Mean: {sum(baseline_accuracies)/len(baseline_accuracies):.2f}%")

    # ── Experimentos LTH por cada nivel de pesos activos ─────────
    for active_pct in active_weights_percentages:
        prune_pct = 100 - active_pct
        print(f"\n{'='*50}")
        print(f"Pesos activos: {active_pct}% (podando {prune_pct}%)")
        print(f"{'='*50}")

        pruned_accuracies = []
        
        for exp in range(num_experiments):
            print(f"\n--- Experimento {exp+1}/{num_experiments} ---")

            # Crear modelo con nueva inicialización aleatoria
            model = create_alexnet().to(device)
            initial_state_dict = {k: v.clone() for k, v in model.state_dict().items()}

            # Entrenar modelo original
            criterion = nn.CrossEntropyLoss()
            optimizer = optim.Adam(model.parameters(), lr=0.0001)
            train_model(model, train_loader, criterion, optimizer, epochs)

            # Crear máscara de poda sobre el modelo entrenado
            prune_mask = create_prune_mask(model, prune_pct / 100.0)

            # Reiniciar a los pesos iniciales y aplicar máscara
            model.load_state_dict(initial_state_dict)
            prune_model(model, prune_mask)

            # Verificar % de pesos activos
            total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
            nonzero_params = sum((p != 0).sum().item() for p in model.parameters() if p.requires_grad)
            actual_active_pct = (nonzero_params / total_params) * 100
            print(f"Pesos activos reales: {actual_active_pct:.1f}% (objetivo: {active_pct}%)")

            # Entrenar modelo podado con máscara mantenida
            optimizer = optim.Adam(model.parameters(), lr=0.0001)
            train_model_with_mask(model, train_loader, criterion, optimizer, epochs, prune_mask)
            acc_pruned = evaluate_model(model, test_loader)
            pruned_accuracies.append(acc_pruned * 100)

            print(f"Accuracy pruned: {acc_pruned:.2%}")

        results[active_pct] = pruned_accuracies
        print(f"\n>> {active_pct}% activos — Mean: {sum(pruned_accuracies)/len(pruned_accuracies):.2f}%, "
              f"Std: {(sum((x - sum(pruned_accuracies)/len(pruned_accuracies))**2 for x in pruned_accuracies)/len(pruned_accuracies))**0.5:.2f}%")

run_experiment()
# Out:
# ==================================================
# Baseline: Red completa (100% pesos activos)
# ==================================================
#
# --- Experimento 1/10 ---
# C:\Users\Usuario\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\Usuario\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Accuracy: 99.26%
#
# --- Experimento 2/10 ---
# Accuracy: 99.40%
#
# --- Experimento 3/10 ---
# Accuracy: 99.52%
#
# --- Experimento 4/10 ---
# Accuracy: 99.39%
#
# --- Experimento 5/10 ---
# Accuracy: 99.41%
#
# --- Experimento 6/10 ---
# Accuracy: 99.45%
#
# --- Experimento 7/10 ---
# Accuracy: 99.15%
#
# --- Experimento 8/10 ---
# Accuracy: 99.36%
#
# --- Experimento 9/10 ---
# Accuracy: 99.45%
#
# --- Experimento 10/10 ---
# Accuracy: 99.31%
#
# >> Baseline (100% activos) — Mean: 99.37%
#
# ==================================================
# Pesos activos: 70% (podando 30%)
# ==================================================
#
# --- Experimento 1/10 ---
# Pesos activos reales: 70.0% (objetivo: 70%)
# Accuracy pruned: 99.50%
#
# --- Experimento 2/10 ---
# Pesos activos reales: 70.0% (objetivo: 70%)
# Accuracy pruned: 99.48%
#
# --- Experimento 3/10 ---
# Pesos activos reales: 70.0% (objetivo: 70%)
# Accuracy pruned: 99.46%
#
# --- Experimento 4/10 ---
# Pesos activos reales: 70.0% (objetivo: 70%)
# Accuracy pruned: 99.24%
#
# --- Experimento 5/10 ---
# Pesos activos reales: 70.0% (objetivo: 70%)
# Accuracy pruned: 99.51%
#
# --- Experimento 6/10 ---
# Pesos activos reales: 70.0% (objetivo: 70%)
# Accuracy pruned: 99.51%
#
# --- Experimento 7/10 ---
# Pesos activos reales: 70.0% (objetivo: 70%)
# Accuracy pruned: 99.41%
#
# --- Experimento 8/10 ---
# Pesos activos reales: 70.0% (objetivo: 70%)
# Accuracy pruned: 99.54%
#
# --- Experimento 9/10 ---
# Pesos activos reales: 70.0% (objetivo: 70%)
# Accuracy pruned: 99.50%
#
# --- Experimento 10/10 ---
# Pesos activos reales: 70.0% (objetivo: 70%)
# Accuracy pruned: 99.37%
#
# >> 70% activos — Mean: 99.45%, Std: 0.09%
#
# ==================================================
# Pesos activos: 50% (podando 50%)
# ==================================================
#
# --- Experimento 1/10 ---
# Pesos activos reales: 50.0% (objetivo: 50%)
# Accuracy pruned: 99.48%
#
# --- Experimento 2/10 ---
# Pesos activos reales: 50.0% (objetivo: 50%)
# Accuracy pruned: 99.32%
#
# --- Experimento 3/10 ---
# Pesos activos reales: 50.0% (objetivo: 50%)
# Accuracy pruned: 99.39%
#
# --- Experimento 4/10 ---
# Pesos activos reales: 50.0% (objetivo: 50%)
# Accuracy pruned: 99.51%
#
# --- Experimento 5/10 ---
# Pesos activos reales: 50.0% (objetivo: 50%)
# Accuracy pruned: 99.44%
#
# --- Experimento 6/10 ---
# Pesos activos reales: 50.0% (objetivo: 50%)
# Accuracy pruned: 99.58%
#
# --- Experimento 7/10 ---
# Pesos activos reales: 50.0% (objetivo: 50%)
# Accuracy pruned: 99.49%
#
# --- Experimento 8/10 ---
# Pesos activos reales: 50.0% (objetivo: 50%)
# Accuracy pruned: 99.55%
#
# --- Experimento 9/10 ---
# Pesos activos reales: 50.0% (objetivo: 50%)
# Accuracy pruned: 99.44%
#
# --- Experimento 10/10 ---
# Pesos activos reales: 50.0% (objetivo: 50%)
# Accuracy pruned: 99.43%
#
# >> 50% activos — Mean: 99.46%, Std: 0.07%
#
# ==================================================
# Pesos activos: 30% (podando 70%)
# ==================================================
#
# --- Experimento 1/10 ---
# Pesos activos reales: 30.0% (objetivo: 30%)
# Accuracy pruned: 99.43%
#
# --- Experimento 2/10 ---
# Pesos activos reales: 30.0% (objetivo: 30%)
# Accuracy pruned: 99.49%
#
# --- Experimento 3/10 ---
# Pesos activos reales: 30.0% (objetivo: 30%)
# Accuracy pruned: 99.48%
#
# --- Experimento 4/10 ---
# Pesos activos reales: 30.0% (objetivo: 30%)
# Accuracy pruned: 99.56%
#
# --- Experimento 5/10 ---
# Pesos activos reales: 30.0% (objetivo: 30%)
# Accuracy pruned: 99.48%
#
# --- Experimento 6/10 ---
# Pesos activos reales: 30.0% (objetivo: 30%)
# Accuracy pruned: 99.50%
#
# --- Experimento 7/10 ---
# Pesos activos reales: 30.0% (objetivo: 30%)
# Accuracy pruned: 99.47%
#
# --- Experimento 8/10 ---
# Pesos activos reales: 30.0% (objetivo: 30%)
# Accuracy pruned: 99.56%
#
# --- Experimento 9/10 ---
# Pesos activos reales: 30.0% (objetivo: 30%)
# Accuracy pruned: 99.50%
#
# --- Experimento 10/10 ---
# Pesos activos reales: 30.0% (objetivo: 30%)
# Accuracy pruned: 99.44%
#
# >> 30% activos — Mean: 99.49%, Std: 0.04%
#
# ==================================================
# Pesos activos: 20% (podando 80%)
# ==================================================
#
# --- Experimento 1/10 ---
# Pesos activos reales: 20.0% (objetivo: 20%)
# Accuracy pruned: 99.46%
#
# --- Experimento 2/10 ---
# Pesos activos reales: 20.0% (objetivo: 20%)
# Accuracy pruned: 99.48%
#
# --- Experimento 3/10 ---
# Pesos activos reales: 20.0% (objetivo: 20%)
# Accuracy pruned: 99.49%
#
# --- Experimento 4/10 ---
# Pesos activos reales: 20.0% (objetivo: 20%)
# Accuracy pruned: 99.57%
#
# --- Experimento 5/10 ---
# Pesos activos reales: 20.0% (objetivo: 20%)
# Accuracy pruned: 99.53%
#
# --- Experimento 6/10 ---
# Pesos activos reales: 20.0% (objetivo: 20%)
# Accuracy pruned: 99.36%
#
# --- Experimento 7/10 ---
# Pesos activos reales: 20.0% (objetivo: 20%)
# Accuracy pruned: 99.52%
#
# --- Experimento 8/10 ---
# Pesos activos reales: 20.0% (objetivo: 20%)
# Accuracy pruned: 99.55%
#
# --- Experimento 9/10 ---
# Pesos activos reales: 20.0% (objetivo: 20%)
# Accuracy pruned: 99.69%
#
# --- Experimento 10/10 ---
# Pesos activos reales: 20.0% (objetivo: 20%)
# Accuracy pruned: 99.47%
#
# >> 20% activos — Mean: 99.51%, Std: 0.08%
#
# ==================================================
# Pesos activos: 15% (podando 85%)
# ==================================================
#
# --- Experimento 1/10 ---
# Pesos activos reales: 15.0% (objetivo: 15%)
# Accuracy pruned: 99.53%
#
# --- Experimento 2/10 ---
# Pesos activos reales: 15.0% (objetivo: 15%)
# Accuracy pruned: 99.49%
#
# --- Experimento 3/10 ---
# Pesos activos reales: 15.0% (objetivo: 15%)
# Accuracy pruned: 99.63%
#
# --- Experimento 4/10 ---
# Pesos activos reales: 15.0% (objetivo: 15%)
# Accuracy pruned: 99.59%
#
# --- Experimento 5/10 ---
# Pesos activos reales: 15.0% (objetivo: 15%)
# Accuracy pruned: 99.62%
#
# --- Experimento 6/10 ---
# Pesos activos reales: 15.0% (objetivo: 15%)
# Accuracy pruned: 99.50%
#
# --- Experimento 7/10 ---
# Pesos activos reales: 15.0% (objetivo: 15%)
# Accuracy pruned: 99.51%
#
# --- Experimento 8/10 ---
# Pesos activos reales: 15.0% (objetivo: 15%)
# Accuracy pruned: 99.46%
#
# --- Experimento 9/10 ---
# Pesos activos reales: 15.0% (objetivo: 15%)
# Accuracy pruned: 99.55%
#
# --- Experimento 10/10 ---
# Pesos activos reales: 15.0% (objetivo: 15%)
# Accuracy pruned: 99.55%
#
# >> 15% activos — Mean: 99.54%, Std: 0.05%
#
# ==================================================
# Pesos activos: 10% (podando 90%)
# ==================================================
#
# --- Experimento 1/10 ---
# Pesos activos reales: 10.0% (objetivo: 10%)
# Accuracy pruned: 99.60%
#
# --- Experimento 2/10 ---
# Pesos activos reales: 10.0% (objetivo: 10%)
# Accuracy pruned: 99.58%
#
# --- Experimento 3/10 ---
# Pesos activos reales: 10.0% (objetivo: 10%)
# Accuracy pruned: 99.64%
#
# --- Experimento 4/10 ---
# Pesos activos reales: 10.0% (objetivo: 10%)
# Accuracy pruned: 99.56%
#
# --- Experimento 5/10 ---
# Pesos activos reales: 10.0% (objetivo: 10%)
# Accuracy pruned: 99.55%
#
# --- Experimento 6/10 ---
# Pesos activos reales: 10.0% (objetivo: 10%)
# Accuracy pruned: 99.43%
#
# --- Experimento 7/10 ---
# Pesos activos reales: 10.0% (objetivo: 10%)
# Accuracy pruned: 99.57%
#
# --- Experimento 8/10 ---
# Pesos activos reales: 10.0% (objetivo: 10%)
# Accuracy pruned: 99.55%
#
# --- Experimento 9/10 ---
# Pesos activos reales: 10.0% (objetivo: 10%)
# Accuracy pruned: 99.52%
#
# --- Experimento 10/10 ---
# Pesos activos reales: 10.0% (objetivo: 10%)
# Accuracy pruned: 99.51%
#
# >> 10% activos — Mean: 99.55%, Std: 0.05%
#
# ==================================================
# Pesos activos: 8% (podando 92%)
# ==================================================
#
# --- Experimento 1/10 ---
# Pesos activos reales: 8.0% (objetivo: 8%)
# Accuracy pruned: 99.55%
#
# --- Experimento 2/10 ---
# Pesos activos reales: 8.0% (objetivo: 8%)
# Accuracy pruned: 99.55%
#
# --- Experimento 3/10 ---
# Pesos activos reales: 8.0% (objetivo: 8%)
# Accuracy pruned: 99.42%
#
# --- Experimento 4/10 ---
# Pesos activos reales: 8.0% (objetivo: 8%)
# Accuracy pruned: 99.47%
#
# --- Experimento 5/10 ---
# Pesos activos reales: 8.0% (objetivo: 8%)
# Accuracy pruned: 99.40%
#
# --- Experimento 6/10 ---
# Pesos activos reales: 8.0% (objetivo: 8%)
# Accuracy pruned: 99.57%
#
# --- Experimento 7/10 ---
# Pesos activos reales: 8.0% (objetivo: 8%)
# Accuracy pruned: 99.56%
#
# --- Experimento 8/10 ---
# Pesos activos reales: 8.0% (objetivo: 8%)
# Accuracy pruned: 99.59%
#
# --- Experimento 9/10 ---
# Pesos activos reales: 8.0% (objetivo: 8%)
# Accuracy pruned: 99.59%
#
# --- Experimento 10/10 ---
# Pesos activos reales: 8.0% (objetivo: 8%)
# Accuracy pruned: 99.50%
#
# >> 8% activos — Mean: 99.52%, Std: 0.07%
#
# ==================================================
# Pesos activos: 5% (podando 95%)
# ==================================================
#
# --- Experimento 1/10 ---
# Pesos activos reales: 5.0% (objetivo: 5%)
# Accuracy pruned: 99.52%
#
# --- Experimento 2/10 ---
# Pesos activos reales: 5.0% (objetivo: 5%)
# Accuracy pruned: 99.49%
#
# --- Experimento 3/10 ---
# Pesos activos reales: 5.0% (objetivo: 5%)
# Accuracy pruned: 99.46%
#
# --- Experimento 4/10 ---
# Pesos activos reales: 5.0% (objetivo: 5%)
# Accuracy pruned: 99.61%
#
# --- Experimento 5/10 ---
# Pesos activos reales: 5.0% (objetivo: 5%)
# Accuracy pruned: 99.54%
#
# --- Experimento 6/10 ---
# Pesos activos reales: 5.0% (objetivo: 5%)
# Accuracy pruned: 99.59%
#
# --- Experimento 7/10 ---
# Pesos activos reales: 5.0% (objetivo: 5%)
# Accuracy pruned: 99.49%
#
# --- Experimento 8/10 ---
# Pesos activos reales: 5.0% (objetivo: 5%)
# Accuracy pruned: 99.54%
#
# --- Experimento 9/10 ---
# Pesos activos reales: 5.0% (objetivo: 5%)
# Accuracy pruned: 99.57%
#
# --- Experimento 10/10 ---
# Pesos activos reales: 5.0% (objetivo: 5%)
# Accuracy pruned: 99.59%
#
# >> 5% activos — Mean: 99.54%, Std: 0.05%
#
# ==================================================
# Pesos activos: 3% (podando 97%)
# ==================================================
#
# --- Experimento 1/10 ---
# Pesos activos reales: 3.0% (objetivo: 3%)
# Accuracy pruned: 99.52%
#
# --- Experimento 2/10 ---
# Pesos activos reales: 3.0% (objetivo: 3%)
# Accuracy pruned: 99.60%
#
# --- Experimento 3/10 ---
# Pesos activos reales: 3.0% (objetivo: 3%)
# Accuracy pruned: 99.61%
#
# --- Experimento 4/10 ---
# Pesos activos reales: 3.0% (objetivo: 3%)
# Accuracy pruned: 99.57%
#
# --- Experimento 5/10 ---
# Pesos activos reales: 3.0% (objetivo: 3%)
# Accuracy pruned: 99.62%
#
# --- Experimento 6/10 ---
# Pesos activos reales: 3.0% (objetivo: 3%)
# Accuracy pruned: 99.51%
#
# --- Experimento 7/10 ---
# Pesos activos reales: 3.0% (objetivo: 3%)
# Accuracy pruned: 99.55%
#
# --- Experimento 8/10 ---
# Pesos activos reales: 3.0% (objetivo: 3%)
# Accuracy pruned: 99.51%
#
# --- Experimento 9/10 ---
# Pesos activos reales: 3.0% (objetivo: 3%)
# Accuracy pruned: 99.52%
#
# --- Experimento 10/10 ---
# Pesos activos reales: 3.0% (objetivo: 3%)
# Accuracy pruned: 99.48%
#
# >> 3% activos — Mean: 99.55%, Std: 0.05%

# %%
import numpy as np
import matplotlib
matplotlib.use("agg")
import matplotlib.pyplot as plt

# ── Preparar datos para boxplot ───────────────────────────────────
# Eje X: % de pesos activos ordenados de mayor a menor (100% → 3%)
all_active_pcts = [100] + sorted(active_weights_percentages, reverse=True)
data_for_boxplot = [results[ap] for ap in all_active_pcts]

# ── Publication-quality style ─────────────────────────────────────
matplotlib.rcParams.update(matplotlib.rcParamsDefault)
plt.rcParams.update({
    "font.family": "serif",
    "font.serif": ["Times New Roman", "DejaVu Serif"],
    "text.usetex": False,
    "mathtext.fontset": "dejavuserif",
    "axes.labelsize": 11,
    "font.size": 10,
    "legend.fontsize": 9,
    "xtick.labelsize": 9,
    "ytick.labelsize": 9,
    "figure.dpi": 150,
    "savefig.dpi": 300,
    "savefig.bbox": "tight",
})

# ── Boxplot ────────────────────────────────────────────────────────
fig, ax = plt.subplots(figsize=(7, 4))

bp = ax.boxplot(data_for_boxplot,
                positions=range(len(all_active_pcts)),
                widths=0.5,
                patch_artist=True,
                showmeans=True,
                meanprops=dict(marker='D', markerfacecolor='#EE6677', markersize=4),
                medianprops=dict(color='black', linewidth=1.2),
                boxprops=dict(facecolor='#BBDEFB', edgecolor='black', linewidth=0.8),
                whiskerprops=dict(color='black', linewidth=0.8),
                capprops=dict(color='black', linewidth=0.8),
                flierprops=dict(marker='o', markersize=3, markerfacecolor='gray'))

# Colorear el baseline con un color distinto
bp['boxes'][0].set_facecolor('#C8E6C9')

# Superponer puntos individuales
for i, data in enumerate(data_for_boxplot):
    jitter = np.random.default_rng(42).uniform(-0.12, 0.12, size=len(data))
    ax.scatter([i + j for j in jitter], data,
               color='#EE6677', s=12, alpha=0.6, zorder=5, edgecolors='none')

# Etiquetas del eje X
ax.set_xticks(range(len(all_active_pcts)))
ax.set_xticklabels([f"{ap}%" for ap in all_active_pcts])

# Labels
ax.set_xlabel("Active Weights (%)", labelpad=6)
ax.set_ylabel("Test Accuracy (%)", labelpad=6)
ax.set_title(f"Lottery Ticket Hypothesis — MNIST (AlexNet)",
             fontsize=12, pad=10)

# Grid (horizontal only)
ax.yaxis.grid(True, linestyle="--", alpha=0.5, linewidth=0.5)
ax.set_axisbelow(True)

# Clean spines
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)

fig.tight_layout(pad=0.5)
fig.savefig("lth_mnist_alexnet_boxplot.png", bbox_inches="tight")
plt.show()
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_28560\158864789.py:72: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
print(results)
# Out:
# {100: [99.26, 99.4, 99.52, 99.39, 99.41, 99.45, 99.15, 99.36, 99.45, 99.31], 70: [99.5, 99.48, 99.46000000000001, 99.24, 99.51, 99.51, 99.41, 99.53999999999999, 99.5, 99.37], 50: [99.48, 99.32, 99.39, 99.51, 99.44, 99.58, 99.49, 99.55000000000001, 99.44, 99.42999999999999], 30: [99.42999999999999, 99.49, 99.48, 99.56, 99.48, 99.5, 99.47, 99.56, 99.5, 99.44], 20: [99.46000000000001, 99.48, 99.49, 99.57000000000001, 99.53, 99.36, 99.52, 99.55000000000001, 99.69, 99.47], 15: [99.53, 99.49, 99.63, 99.59, 99.62, 99.5, 99.51, 99.46000000000001, 99.55000000000001, 99.55000000000001], 10: [99.6, 99.58, 99.64, 99.56, 99.55000000000001, 99.42999999999999, 99.57000000000001, 99.55000000000001, 99.52, 99.51], 8: [99.55000000000001, 99.55000000000001, 99.42, 99.47, 99.4, 99.57000000000001, 99.56, 99.59, 99.59, 99.5], 5: [99.52, 99.49, 99.46000000000001, 99.61, 99.53999999999999, 99.59, 99.49, 99.53999999999999, 99.57000000000001, 99.59], 3: [99.52, 99.6, 99.61, 99.57000000000001, 99.62, 99.51, 99.55000000000001, 99.51, 99.52, 99.48]}
