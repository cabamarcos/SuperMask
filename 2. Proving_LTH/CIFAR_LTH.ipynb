# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

import numpy as np
import matplotlib
matplotlib.use("agg")
import matplotlib.pyplot as plt

from utils import *

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1)
        self.fc1 = nn.Linear(128 * 4 * 4, 128)  # Adjusted dimensions here
        self.fc2 = nn.Linear(128, 10)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.max_pool2d(x, 2)
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2)
        x = F.relu(self.conv3(x))
        x = F.max_pool2d(x, 2)
        x = x.view(-1, 128 * 4 * 4)  # Adjusted dimensions here
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x  # Devuelve logits sin procesar

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
batch_size = 64
epochs = 20
num_experiments = 10

results = {}

active_weights_percentages = [70, 50, 30, 20, 15, 10, 8, 5, 3]

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.4914, 0.4822, 0.4465],
                         std=[0.2023, 0.1994, 0.2010])
])

train_dataset = datasets.CIFAR10(root="../data/cifar10", train=True, transform=transform, download=True)
test_dataset = datasets.CIFAR10(root="../data/cifar10", train=False, transform=transform, download=True)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
def run_experiment():
    global results

    # ── Baseline: 10 redes completas sin podar (100% pesos activos) ──
    print(f"\n{'='*50}")
    print("Baseline: Red completa (100% pesos activos)")
    print(f"{'='*50}")
    baseline_accuracies = []
    for exp in range(num_experiments):
        print(f"\n--- Experimento {exp+1}/{num_experiments} ---")
        model = Net().to(device)
        criterion = nn.CrossEntropyLoss()
        optimizer = optim.Adam(model.parameters(), lr=0.0001)
        train_model(model, train_loader, criterion, optimizer, epochs)
        acc = evaluate_model(model, test_loader)
        baseline_accuracies.append(acc * 100)
        print(f"Accuracy: {acc:.2%}")
    results[100] = baseline_accuracies
    print(f"\n>> Baseline (100% activos) — Mean: {sum(baseline_accuracies)/len(baseline_accuracies):.2f}%")

    # ── Experimentos LTH por cada nivel de pesos activos ─────────
    for active_pct in active_weights_percentages:
        prune_pct = 100 - active_pct
        print(f"\n{'='*50}")
        print(f"Pesos activos: {active_pct}% (podando {prune_pct}%)")
        print(f"{'='*50}")

        pruned_accuracies = []

        for exp in range(num_experiments):
            print(f"\n--- Experimento {exp+1}/{num_experiments} ---")

            # Crear modelo con nueva inicialización aleatoria
            model = Net().to(device)
            initial_state_dict = {k: v.clone() for k, v in model.state_dict().items()}

            # Entrenar modelo original
            criterion = nn.CrossEntropyLoss()
            optimizer = optim.Adam(model.parameters(), lr=0.0001)
            train_model(model, train_loader, criterion, optimizer, epochs)

            # Crear máscara de poda sobre el modelo entrenado
            prune_mask = create_prune_mask(model, prune_pct / 100.0)

            # Reiniciar a los pesos iniciales y aplicar máscara
            model.load_state_dict(initial_state_dict)
            prune_model(model, prune_mask)

            # Verificar % de pesos activos
            total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
            nonzero_params = sum((p != 0).sum().item() for p in model.parameters() if p.requires_grad)
            actual_active_pct = (nonzero_params / total_params) * 100
            print(f"Pesos activos reales: {actual_active_pct:.1f}% (objetivo: {active_pct}%)")

            # Entrenar modelo podado con máscara mantenida
            optimizer = optim.Adam(model.parameters(), lr=0.0001)
            train_model_with_mask(model, train_loader, criterion, optimizer, epochs, prune_mask)
            acc_pruned = evaluate_model(model, test_loader)
            pruned_accuracies.append(acc_pruned * 100)

            print(f"Accuracy pruned: {acc_pruned:.2%}")

        results[active_pct] = pruned_accuracies
        print(f"\n>> {active_pct}% activos — Mean: {sum(pruned_accuracies)/len(pruned_accuracies):.2f}%, "
              f"Std: {(sum((x - sum(pruned_accuracies)/len(pruned_accuracies))**2 for x in pruned_accuracies)/len(pruned_accuracies))**0.5:.2f}%")

run_experiment()
# Out:
# ...
# Baseline: Red completa (100% pesos activos)
# ...
#
# --- Experimento 1/10 ---
# Accuracy: 71.94%
#
# --- Experimento 2/10 ---
# Accuracy: 72.56%
#
# --- Experimento 3/10 ---
# Accuracy: 72.46%
#
# --- Experimento 4/10 ---
# Accuracy: 71.94%
#
# --- Experimento 5/10 ---
# Accuracy: 72.62%
#
# --- Experimento 6/10 ---
# Accuracy: 72.31%
#
# --- Experimento 7/10 ---
# Accuracy: 73.14%
#
# --- Experimento 8/10 ---
# Accuracy: 71.95%
#
# --- Experimento 9/10 ---
# Accuracy: 73.21%
#
# --- Experimento 10/10 ---
# Accuracy: 73.11%
#
# >> Baseline (100% activos) — Mean: 72.52%
#
# ...
# Pesos activos: 70% (podando 30%)
# ...
#
# --- Experimento 1/10 ---
# Pesos activos reales: 70.0% (objetivo: 70%)
# Accuracy pruned: 73.60%
#
# --- Experimento 2/10 ---
# Pesos activos reales: 70.0% (objetivo: 70%)
# Accuracy pruned: 73.76%
#
# --- Experimento 3/10 ---
# Pesos activos reales: 70.0% (objetivo: 70%)
# Accuracy pruned: 72.75%
#
# --- Experimento 4/10 ---
# Pesos activos reales: 70.0% (objetivo: 70%)
# ...

# %%
# ── Preparar datos para boxplot ───────────────────────────────────
# Eje X: % de pesos activos ordenados de mayor a menor (100% → 3%)
all_active_pcts = [100] + sorted(active_weights_percentages, reverse=True)
data_for_boxplot = [results[ap] for ap in all_active_pcts]

# ── Publication-quality style ─────────────────────────────────────
matplotlib.rcParams.update(matplotlib.rcParamsDefault)
plt.rcParams.update({
    "font.family": "serif",
    "font.serif": ["Times New Roman", "DejaVu Serif"],
    "text.usetex": False,
    "mathtext.fontset": "dejavuserif",
    "axes.labelsize": 11,
    "font.size": 10,
    "legend.fontsize": 9,
    "xtick.labelsize": 9,
    "ytick.labelsize": 9,
    "figure.dpi": 150,
    "savefig.dpi": 300,
    "savefig.bbox": "tight",
})

# ── Boxplot ────────────────────────────────────────────────────────
fig, ax = plt.subplots(figsize=(7, 4))

bp = ax.boxplot(data_for_boxplot,
                positions=range(len(all_active_pcts)),
                widths=0.5,
                patch_artist=True,
                showmeans=True,
                meanprops=dict(marker='D', markerfacecolor='#EE6677', markersize=4),
                medianprops=dict(color='black', linewidth=1.2),
                boxprops=dict(facecolor='#BBDEFB', edgecolor='black', linewidth=0.8),
                whiskerprops=dict(color='black', linewidth=0.8),
                capprops=dict(color='black', linewidth=0.8),
                flierprops=dict(marker='o', markersize=3, markerfacecolor='gray'))

# Colorear el baseline con un color distinto
bp['boxes'][0].set_facecolor('#C8E6C9')

# Superponer puntos individuales
for i, data in enumerate(data_for_boxplot):
    jitter = np.random.default_rng(42).uniform(-0.12, 0.12, size=len(data))
    ax.scatter([i + j for j in jitter], data,
               color='#EE6677', s=12, alpha=0.6, zorder=5, edgecolors='none')

# Etiquetas del eje X
ax.set_xticks(range(len(all_active_pcts)))
ax.set_xticklabels([f"{ap}%" for ap in all_active_pcts])

# Labels
ax.set_xlabel("Active Weights (%)", labelpad=6)
ax.set_ylabel("Test Accuracy (%)", labelpad=6)
ax.set_title(f"Lottery Ticket Hypothesis — CIFAR10 (SimpleCNN)",
             fontsize=12, pad=10)

# Grid (horizontal only)
ax.yaxis.grid(True, linestyle="--", alpha=0.5, linewidth=0.5)
ax.set_axisbelow(True)

# Clean spines
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)

fig.tight_layout(pad=0.5)
fig.savefig("lth_cifar10_boxplot.png", bbox_inches="tight")
plt.show()
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_18736\1919984640.py:67: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
print(results)
# Out:
# {100: [71.94, 72.56, 72.46000000000001, 71.94, 72.61999999999999, 72.31, 73.14, 71.95, 73.21, 73.11], 70: [73.6, 73.76, 72.75, 74.29, 73.42999999999999, 73.18, 73.24000000000001, 74.22, 73.29, 73.36], 50: [73.18, 73.45, 72.91, 72.58, 73.15, 71.73, 73.34, 73.04, 72.85000000000001, 73.2], 30: [71.96000000000001, 72.75, 73.74000000000001, 74.14, 73.17, 73.82, 72.33000000000001, 72.83, 73.05, 73.14], 20: [72.77, 72.63, 73.94, 73.53, 72.59, 73.52, 73.22, 72.67, 73.07000000000001, 72.61999999999999], 15: [72.53, 72.76, 72.61, 72.15, 73.21, 71.17999999999999, 71.66, 73.15, 72.89, 73.36], 10: [72.44, 71.73, 71.15, 71.84, 71.26, 71.93, 70.89999999999999, 71.78999999999999, 70.76, 72.15], 8: [70.36, 69.67, 69.94, 70.3, 70.82000000000001, 70.30999999999999, 69.95, 70.78999999999999, 69.87, 70.45], 5: [67.06, 66.97999999999999, 67.14, 67.63, 65.25, 66.84, 67.06, 66.91, 67.65, 67.05], 3: [59.24, 58.79, 59.050000000000004, 60.419999999999995, 60.11, 60.0, 60.050000000000004, 60.980000000000004, 59
# ...
