# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
import torch.nn.functional as F

import matplotlib.pyplot as plt
import time

# %%
class SimpleMLP(nn.Module):
    def __init__(self):
        super(SimpleMLP, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1)
        self.fc1 = nn.Linear(128 * 4 * 4, 128)  # Adjusted dimensions here
        self.fc2 = nn.Linear(128, 10)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.max_pool2d(x, 2)
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2)
        x = F.relu(self.conv3(x))
        x = F.max_pool2d(x, 2)
        x = x.view(-1, 128 * 4 * 4)  # Adjusted dimensions here
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return F.log_softmax(x, dim=1)

# %%
def train_model(model, dataloader, criterion, optimizer, iteration, epochs=5):
    model.train()
    accuracies = []
    for epoch in range(epochs):
        total_loss = 0
        for batch_idx, (inputs, targets) in enumerate(dataloader):
            inputs, targets = inputs.to(device), targets.to(device)

            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            loss.backward()
            optimizer.step()

            total_loss += loss.item()

        # Evaluar en cada época para registrar todas las accuracies
        accuracy = evaluate_model(model, test_loader)
        accuracies.append(accuracy)

    print(f'Accuracy: {max(accuracies):.2%}')
    return total_loss / len(dataloader), accuracies

# %%
def evaluate_model(model, test_loader):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for inputs, targets in test_loader:
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model(inputs)
            _, predicted = outputs.max(1)
            correct += (predicted == targets).sum().item()
            total += targets.size(0)
    return correct / total

# %%
def create_prune_mask(model, prune_percentage=0.2):
    mask = {}
    for name, param in model.named_parameters():
        if 'weight' in name:
            # Calculate threshold as the top (1 - prune_percentage) quantile of the absolute weights
            threshold = torch.quantile(param.abs(), 1- prune_percentage)
            mask[name] = (param.abs() > threshold).float().to(device)
    return mask

def prune_model(model, mask):
    with torch.no_grad():
        for name, param in model.named_parameters():
            if name in mask:
                param.data *= mask[name]

# %%
def count_zero_weights(model):
    total_weights = 0
    zero_weights = 0
    for param in model.parameters():
        if param.requires_grad:  # Only consider weights that are not frozen
            total_weights += param.numel()
            zero_weights += (param.data == 0).sum().item()
    return zero_weights, total_weights

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
batch_size = 64
epochs = 5
iterations = 3

transform = transforms.ToTensor()
train_dataset = datasets.CIFAR10(root="./data", train=True, transform=transform, download=True)
test_dataset = datasets.CIFAR10(root="./data", train=False, transform=transform, download=True)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
results = {}

model = SimpleMLP().to(device)
model_entrenado = SimpleMLP().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

model_inicial = model.state_dict()
prune_percentages = [80, 70, 60, 50, 40, 30, 20, 15, 10, 8, 5, 3]

def run_experiment():
    global results
    print(f"===== Modelo original =====")
    _, accuracies_original = train_model(model, train_loader, criterion, optimizer, 0, epochs)

    print(f"Final accuracies for original model: {accuracies_original}")
    results[100] = {
        "accuracies": accuracies_original
    }
    
    for prune_percentage in prune_percentages:
        model.load_state_dict(model_inicial)
        print(f"===== Pruning al {prune_percentage}% =====")

        accuracies_pruned = []
        for iteration in range(1, iterations + 1):
            print(f"Iteración {iteration}/{iterations}")

            prune_mask = create_prune_mask(model_entrenado, prune_percentage / 100.0)
            prune_model(model, prune_mask)

            zero_weights, total_weights = count_zero_weights(model)
            print(f"After pruning {prune_percentage}%: Zero weights = {zero_weights}, Total weights = {total_weights}, Percentage = {100 * zero_weights / total_weights:.2f}%")


            _, accuracies = train_model(model, train_loader, criterion, optimizer, iteration, epochs)
            
            zero_weights, total_weights = count_zero_weights(model)
            print(f"After training: Zero weights = {zero_weights}, Total weights = {total_weights}, Percentage = {100 * zero_weights / total_weights:.2f}%")

            accuracies_pruned.extend(accuracies)

        results[prune_percentage] = {
            "accuracies": accuracies_pruned
        }

        print(f"Final accuracies for pruning at {prune_percentage}%: {accuracies_pruned}")

start = time.time()

run_experiment()

end = time.time()
print(f"Tiempo de ejecución: {end - start} segundos")
# Out:
# ===== Modelo original =====
# Accuracy: 69.15%
# Final accuracies for original model: [0.5296, 0.6112, 0.6586, 0.6828, 0.6915]
# ===== Pruning al 80% =====
# Iteración 1/3
# After pruning 80%: Zero weights = 71291, Total weights = 356810, Percentage = 19.98%
# Accuracy: 74.10%
# After training: Zero weights = 9621, Total weights = 356810, Percentage = 2.70%
# Iteración 2/3
# After pruning 80%: Zero weights = 71291, Total weights = 356810, Percentage = 19.98%
# Accuracy: 73.71%
# After training: Zero weights = 9324, Total weights = 356810, Percentage = 2.61%
# Iteración 3/3
# After pruning 80%: Zero weights = 71291, Total weights = 356810, Percentage = 19.98%
# Accuracy: 73.51%
# After training: Zero weights = 9148, Total weights = 356810, Percentage = 2.56%
# Final accuracies for pruning at 80%: [0.6952, 0.7307, 0.7168, 0.7249, 0.741, 0.7243, 0.7252, 0.7354, 0.7359, 0.7371, 0.7351, 0.7215, 0.7237, 0.7301, 0.7207]
# ===== Pruning al 70% =====
# Iteración 1/3
# After pruning 70%: Zero weights = 106936, Total weights = 356810, Percentage = 29.97%
# Accuracy: 73.42%
# After training: Zero weights = 13375, Total weights = 356810, Percentage = 3.75%
# Iteración 2/3
# After pruning 70%: Zero weights = 106936, Total weights = 356810, Percentage = 29.97%
# Accuracy: 72.64%
# After training: Zero weights = 13152, Total weights = 356810, Percentage = 3.69%
# Iteración 3/3
# After pruning 70%: Zero weights = 106936, Total weights = 356810, Percentage = 29.97%
# Accuracy: 72.69%
# After training: Zero weights = 12803, Total weights = 356810, Percentage = 3.59%
# Final accuracies for pruning at 70%: [0.7342, 0.7267, 0.725, 0.7248, 0.7243, 0.7197, 0.7264, 0.7206, 0.7189, 0.7142, 0.7238, 0.7142, 0.7066, 0.7269, 0.7102]
# ===== Pruning al 60% =====
# Iteración 1/3
# After pruning 60%: Zero weights = 142580, Total weights = 356810, Percentage = 39.96%
# Accuracy: 71.89%
# After training: Zero weights = 16517, Total weights = 356810, Percentage = 4.63%
# Iteración 2/3
# After pruning 60%: Zero weights = 142580, Total weights = 356810, Percentage = 39.96%
# Accuracy: 71.86%
# After training: Zero weights = 16447, Total weights = 356810, Percentage = 4.61%
# Iteración 3/3
# After pruning 60%: Zero weights = 142580, Total weights = 356810, Percentage = 39.96%
# Accuracy: 71.95%
# After training: Zero weights = 16344, Total weights = 356810, Percentage = 4.58%
# Final accuracies for pruning at 60%: [0.7146, 0.715, 0.7179, 0.7189, 0.709, 0.7152, 0.7175, 0.7086, 0.7186, 0.7108, 0.713, 0.7095, 0.7195, 0.7153, 0.7076]
# ===== Pruning al 50% =====
# Iteración 1/3
# After pruning 50%: Zero weights = 178224, Total weights = 356810, Percentage = 49.95%
# Accuracy: 72.52%
# After training: Zero weights = 19177, Total weights = 356810, Percentage = 5.37%
# Iteración 2/3
# After pruning 50%: Zero weights = 178224, Total weights = 356810, Percentage = 49.95%
# Accuracy: 71.95%
# After training: Zero weights = 18939, Total weights = 356810, Percentage = 5.31%
# Iteración 3/3
# After pruning 50%: Zero weights = 178224, Total weights = 356810, Percentage = 49.95%
# Accuracy: 72.12%
# After training: Zero weights = 18939, Total weights = 356810, Percentage = 5.31%
# Final accuracies for pruning at 50%: [0.712, 0.7226, 0.723, 0.7166, 0.7252, 0.717, 0.7195, 0.7162, 0.7105, 0.7153, 0.7069, 0.7181, 0.7101, 0.7002, 0.7212]
# ===== Pruning al 40% =====
# Iteración 1/3
# After pruning 40%: Zero weights = 213868, Total weights = 356810, Percentage = 59.94%
# Accuracy: 73.12%
# After training: Zero weights = 21928, Total weights = 356810, Percentage = 6.15%
# Iteración 2/3
# After pruning 40%: Zero weights = 213868, Total weights = 356810, Percentage = 59.94%
# Accuracy: 72.25%
# After training: Zero weights = 21924, Total weights = 356810, Percentage = 6.14%
# Iteración 3/3
# After pruning 40%: Zero weights = 213868, Total weights = 356810, Percentage = 59.94%
# Accuracy: 72.38%
# After training: Zero weights = 21924, Total weights = 356810, Percentage = 6.14%
# Final accuracies for pruning at 40%: [0.7156, 0.7212, 0.7312, 0.713, 0.7236, 0.715, 0.7149, 0.7217, 0.7222, 0.7225, 0.7198, 0.7238, 0.7129, 0.7216, 0.715]
# ===== Pruning al 30% =====
# Iteración 1/3
# After pruning 30%: Zero weights = 249513, Total weights = 356810, Percentage = 69.93%
# Accuracy: 73.28%
# After training: Zero weights = 24624, Total weights = 356810, Percentage = 6.90%
# Iteración 2/3
# After pruning 30%: Zero weights = 249513, Total weights = 356810, Percentage = 69.93%
# Accuracy: 73.03%
# After training: Zero weights = 24539, Total weights = 356810, Percentage = 6.88%
# Iteración 3/3
# After pruning 30%: Zero weights = 249513, Total weights = 356810, Percentage = 69.93%
# Accuracy: 73.09%
# After training: Zero weights = 24524, Total weights = 356810, Percentage = 6.87%
# Final accuracies for pruning at 30%: [0.7074, 0.729, 0.7238, 0.7328, 0.7273, 0.7118, 0.7236, 0.7231, 0.7303, 0.7264, 0.7145, 0.7286, 0.7216, 0.7229, 0.7309]
# ===== Pruning al 20% =====
# Iteración 1/3
# After pruning 20%: Zero weights = 285157, Total weights = 356810, Percentage = 79.92%
# Accuracy: 74.00%
# After training: Zero weights = 27621, Total weights = 356810, Percentage = 7.74%
# Iteración 2/3
# After pruning 20%: Zero weights = 285157, Total weights = 356810, Percentage = 79.92%
# Accuracy: 73.82%
# After training: Zero weights = 27354, Total weights = 356810, Percentage = 7.67%
# Iteración 3/3
# After pruning 20%: Zero weights = 285157, Total weights = 356810, Percentage = 79.92%
# Accuracy: 74.24%
# After training: Zero weights = 27045, Total weights = 356810, Percentage = 7.58%
# Final accuracies for pruning at 20%: [0.6662, 0.7053, 0.725, 0.74, 0.7362, 0.6997, 0.7258, 0.734, 0.7382, 0.7314, 0.7054, 0.7209, 0.7256, 0.7424, 0.7363]
# ===== Pruning al 15% =====
# Iteración 1/3
# After pruning 15%: Zero weights = 302979, Total weights = 356810, Percentage = 84.91%
# Accuracy: 73.74%
# After training: Zero weights = 28320, Total weights = 356810, Percentage = 7.94%
# Iteración 2/3
# After pruning 15%: Zero weights = 302979, Total weights = 356810, Percentage = 84.91%
# Accuracy: 74.36%
# After training: Zero weights = 27913, Total weights = 356810, Percentage = 7.82%
# Iteración 3/3
# After pruning 15%: Zero weights = 302979, Total weights = 356810, Percentage = 84.91%
# Accuracy: 73.41%
# After training: Zero weights = 27908, Total weights = 356810, Percentage = 7.82%
# Final accuracies for pruning at 15%: [0.6607, 0.6975, 0.6975, 0.7222, 0.7374, 0.6948, 0.7154, 0.7333, 0.7279, 0.7436, 0.7019, 0.7211, 0.7341, 0.7273, 0.725]
# ===== Pruning al 10% =====
# Iteración 1/3
# After pruning 10%: Zero weights = 320801, Total weights = 356810, Percentage = 89.91%
# Accuracy: 71.89%
# After training: Zero weights = 29310, Total weights = 356810, Percentage = 8.21%
# Iteración 2/3
# After pruning 10%: Zero weights = 320801, Total weights = 356810, Percentage = 89.91%
# Accuracy: 72.12%
# After training: Zero weights = 29109, Total weights = 356810, Percentage = 8.16%
# Iteración 3/3
# After pruning 10%: Zero weights = 320801, Total weights = 356810, Percentage = 89.91%
# Accuracy: 72.50%
# After training: Zero weights = 28966, Total weights = 356810, Percentage = 8.12%
# Final accuracies for pruning at 10%: [0.555, 0.6537, 0.6665, 0.6945, 0.7189, 0.6311, 0.6863, 0.7097, 0.7208, 0.7212, 0.6296, 0.6911, 0.7098, 0.719, 0.725]
# ===== Pruning al 8% =====
# Iteración 1/3
# After pruning 8%: Zero weights = 327930, Total weights = 356810, Percentage = 91.91%
# Accuracy: 71.13%
# After training: Zero weights = 29360, Total weights = 356810, Percentage = 8.23%
# Iteración 2/3
# After pruning 8%: Zero weights = 327930, Total weights = 356810, Percentage = 91.91%
# Accuracy: 72.00%
# After training: Zero weights = 29359, Total weights = 356810, Percentage = 8.23%
# Iteración 3/3
# After pruning 8%: Zero weights = 327930, Total weights = 356810, Percentage = 91.91%
# Accuracy: 72.54%
# After training: Zero weights = 29358, Total weights = 356810, Percentage = 8.23%
# Final accuracies for pruning at 8%: [0.5891, 0.6498, 0.678, 0.6874, 0.7113, 0.6124, 0.6672, 0.6892, 0.7011, 0.72, 0.6265, 0.6598, 0.7035, 0.7156, 0.7254]
# ===== Pruning al 5% =====
# Iteración 1/3
# After pruning 5%: Zero weights = 338623, Total weights = 356810, Percentage = 94.90%
# Accuracy: 68.95%
# After training: Zero weights = 29508, Total weights = 356810, Percentage = 8.27%
# Iteración 2/3
# After pruning 5%: Zero weights = 338623, Total weights = 356810, Percentage = 94.90%
# Accuracy: 68.96%
# After training: Zero weights = 28791, Total weights = 356810, Percentage = 8.07%
# Iteración 3/3
# After pruning 5%: Zero weights = 338623, Total weights = 356810, Percentage = 94.90%
# Accuracy: 70.19%
# After training: Zero weights = 28543, Total weights = 356810, Percentage = 8.00%
# Final accuracies for pruning at 5%: [0.5805, 0.6082, 0.641, 0.6795, 0.6895, 0.5814, 0.6309, 0.6625, 0.6851, 0.6896, 0.5745, 0.6514, 0.6677, 0.6894, 0.7019]
# ===== Pruning al 3% =====
# Iteración 1/3
# After pruning 3%: Zero weights = 345753, Total weights = 356810, Percentage = 96.90%
# Accuracy: 69.33%
# After training: Zero weights = 27585, Total weights = 356810, Percentage = 7.73%
# Iteración 2/3
# After pruning 3%: Zero weights = 345753, Total weights = 356810, Percentage = 96.90%
# Accuracy: 68.27%
# After training: Zero weights = 27366, Total weights = 356810, Percentage = 7.67%
# Iteración 3/3
# After pruning 3%: Zero weights = 345753, Total weights = 356810, Percentage = 96.90%
# Accuracy: 69.50%
# After training: Zero weights = 27281, Total weights = 356810, Percentage = 7.65%
# Final accuracies for pruning at 3%: [0.5508, 0.6319, 0.6601, 0.6779, 0.6933, 0.5749, 0.6362, 0.6683, 0.6803, 0.6827, 0.5577, 0.6464, 0.6684, 0.6818, 0.695]
# Tiempo de ejecución: 1485.028553724289 segundos

# %%
hours, rem = divmod(end-start, 3600)
minutes, seconds = divmod(rem, 60)
print("{:0>2}:{:0>2}:{:05.2f}".format(int(hours),int(minutes),seconds))
# Out:
# 00:24:45.03

# %%
# Función para obtener la mejor accuracy de cada porcentaje de pruning
def extract_best_accuracies(results):
    best_accuracies = []
    pruning_percentages = []
    for percentage, data in results.items():
        pruning_percentages.append(percentage)
        best_accuracy = max(data["accuracies"])  # Mejor accuracy de todas las iteraciones para ese porcentaje
        best_accuracies.append(best_accuracy)
    return pruning_percentages, best_accuracies

# Extraer los datos
pruning_percentages, best_accuracies = extract_best_accuracies(results)

# Generar la gráfica
plt.figure(figsize=(10, 6))
plt.plot(pruning_percentages, [acc * 100 for acc in best_accuracies], marker='o', color='b')
plt.title('Accuracy más alto vs Porcentaje de Pruning')
plt.xlabel('Porcentaje de Pruning (%)')
plt.ylabel('Accuracy más alto (%)')
plt.grid(True)
plt.xticks(pruning_percentages)
plt.show()
