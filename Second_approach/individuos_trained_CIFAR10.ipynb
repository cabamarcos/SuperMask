# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import torch.nn.init as init

import numpy as np
import matplotlib.pyplot as plt
import copy
from ast import Param
import json
import math

from utils.prune import apply_mask
from utils.count_improvement import improvements
from utils.normalize import normalize_weights

# %%
# Verificar si la GPU está disponible y establecer el dispositivo
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1)
        self.fc1 = nn.Linear(128 * 4 * 4, 128)  # Adjusted dimensions here
        self.fc2 = nn.Linear(128, 10)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.max_pool2d(x, 2)
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2)
        x = F.relu(self.conv3(x))
        x = F.max_pool2d(x, 2)
        x = x.view(-1, 128 * 4 * 4)  # Adjusted dimensions here
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return F.log_softmax(x, dim=1)

# %%
net = Net().to(device)
varianzas_net = Net().to(device)
individuo = Net().to(device)

# %% [markdown]
# Cargamos los datos

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

train_dataset = datasets.CIFAR10('./data', train=True, download=True, transform=transform)
test_dataset = datasets.CIFAR10('./data', train=False, download=True, transform=transform)

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True, num_workers=4)
test_loader = DataLoader(test_dataset, batch_size=1000, shuffle=False, num_workers=4)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# Definimos la función de pérdida para calcular el error
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr=0.001)

# %% [markdown]
# Realizamos el "entrenamiento"

# %%
# train loop
train_loss = []
train_loss_mean = []
test_accuracies = []
n_individuo = 1
accuracy_threshold = 0.95

# Multiplicamos los pesos de varianzas para que sean numero sgrandes
with torch.no_grad():
    for param in varianzas_net.parameters():
        param *= 10000

#Guardo el mejor individuo y la red original que tendrá que ser reestablecida cad epoca
best_individo_state_dict = individuo.state_dict()
net_state_dict = net.state_dict()

#train loop
while True:
    net.load_state_dict(net_state_dict)
    if n_individuo == 1:
        print(f" --------------------- Individuo {n_individuo} --------------------- ")

        masked_net = apply_mask(net, individuo)
        #guardar el estado de la red en un txt en una carpeta
        # with open(f'pesos/individuo{n_individuo}.txt', 'w') as f:
        #     f.write(str(masked_net.state_dict()))
        masked_net.train()
        running_loss = 0.0
        # Train for 1 epoch
        for i, data in enumerate(train_loader, 0):
            inputs, labels = data[0].to(device), data[1].to(device)
            optimizer.zero_grad()
            outputs = masked_net(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
        train_loss.append(running_loss / len(train_loader))

        masked_net.eval()
        correct = 0
        total = 0
        with torch.no_grad():
            for data in test_loader:
                images, labels = data[0].to(device), data[1].to(device)
                outputs = masked_net(images)
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
        accuracy = correct / total
        #train_loss_mean.append(np.mean(train_loss))
        test_accuracies.append(accuracy)
        #print(f"Accuracy: {accuracy}, loss mean: {train_loss_mean[-1]}")
        print(f"Accuracy: {accuracy}", f"Loss: {train_loss[-1]}")
        best_loss = train_loss[-1]
        if accuracy > accuracy_threshold:
            break
        n_individuo += 1

        #sumamos varianzas para crear un nuevo individuo desde el anterior
        nuevo_individuo = Net().to(device)
        state_dict_ind = individuo.state_dict()
        state_dict_var = varianzas_net.state_dict()
        state_dict_suma = {}

        for key in state_dict_ind:
            if state_dict_ind[key].size() == state_dict_var[key].size():  
                std_dev = state_dict_var[key]
                noise = torch.normal(0, torch.abs(std_dev))
                state_dict_suma[key] = state_dict_ind[key] + torch.sign(std_dev) * noise
            else:
                state_dict_suma[key] = state_dict_ind[key]

        nuevo_individuo.load_state_dict(state_dict_suma)
        
    else:
        print(f" --------------------- Individuo {n_individuo} --------------------- ")

        masked_net = apply_mask(net, nuevo_individuo)
        #guardar el estado de la red en un txt en una carpeta
        # with open(f'pesos/individuo{n_individuo}.txt', 'w') as f:
        #     f.write(str(masked_net.state_dict()))
        masked_net.train()
        running_loss = 0.0
        # Train for 1 epoch
        for i, data in enumerate(train_loader, 0):
            inputs, labels = data[0].to(device), data[1].to(device)
            optimizer.zero_grad()
            outputs = masked_net(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
        train_loss.append(running_loss / len(train_loader))

        masked_net.eval()
        correct = 0
        total = 0
        with torch.no_grad():
            for data in test_loader:
                images, labels = data[0].to(device), data[1].to(device)
                outputs = masked_net(images)
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
        accuracy = correct / total
        test_accuracies.append(accuracy)
        print(f"Accuracy: {accuracy}", f"Loss: {train_loss[-1]}")
        if accuracy > accuracy_threshold:
            break

        # Verificamos que individuo tiene mejor desempeño
        if train_loss[-1] < best_loss:
            print("Nuevo mejor individuo")
            best_loss = train_loss[-1]
            best_individo_state_dict = nuevo_individuo.state_dict()
        
        # actualizamos el individuo
        individuo.load_state_dict(best_individo_state_dict)

        if n_individuo >10:
            # actualizmos el vector de varianzas
            print("Aumentando varianzas")
            if improvements(train_loss) > 2:## +mejoras que peoras (lejos de la solucion)
                with torch.no_grad():
                    for param in varianzas_net.parameters():
                        param *= (1/0.82)

            elif improvements(train_loss) < 2: ## -mejoras que peoras (cerca de la solucion)
                print("Disminuyendo varianzas")
                with torch.no_grad():
                    for param in varianzas_net.parameters():
                        param *= 0.82
        
            else:
                pass

        #sumamos varianzas para crear un nuevo individuo desde el anterior
        nuevo_individuo = Net().to(device)
        state_dict_ind = individuo.state_dict()
        state_dict_var = varianzas_net.state_dict()
        state_dict_suma = {}

        for key in state_dict_ind:
            if state_dict_ind[key].size() == state_dict_var[key].size():  
                std_dev = state_dict_var[key]
                noise = torch.normal(0, torch.abs(std_dev))
                state_dict_suma[key] = state_dict_ind[key] + torch.sign(std_dev) * noise
            else:
                state_dict_suma[key] = state_dict_ind[key]

        nuevo_individuo.load_state_dict(state_dict_suma)

        n_individuo += 1
# Out:
#  --------------------- Individuo 1 ---------------------
# Accuracy: 0.5656 Loss: 1.50049149418426
#  --------------------- Individuo 2 ---------------------
# Accuracy: 0.5522 Loss: 1.4854221944613835
# Nuevo mejor individuo
#  --------------------- Individuo 3 ---------------------
# Accuracy: 0.578 Loss: 1.502713525234281
#  --------------------- Individuo 4 ---------------------
# Accuracy: 0.5779 Loss: 1.456143736991736
# Nuevo mejor individuo
#  --------------------- Individuo 5 ---------------------
# Accuracy: 0.5542 Loss: 1.5378741287361934
#  --------------------- Individuo 6 ---------------------
# Accuracy: 0.5723 Loss: 1.5945767589542261
#  --------------------- Individuo 7 ---------------------
# Accuracy: 0.5456 Loss: 1.566473709271692
#  --------------------- Individuo 8 ---------------------
# Accuracy: 0.5573 Loss: 1.5893139355170451
#  --------------------- Individuo 9 ---------------------
# Accuracy: 0.5736 Loss: 1.5708447819018303
#  --------------------- Individuo 10 ---------------------
# Accuracy: 0.5349 Loss: 1.684862087907084
#  --------------------- Individuo 11 ---------------------
# Accuracy: 0.5305 Loss: 1.6647542186100464
# Aumentando varianzas
#  --------------------- Individuo 12 ---------------------
# Accuracy: 0.5217 Loss: 1.6321755649183718
# Aumentando varianzas
#  --------------------- Individuo 13 ---------------------
# Accuracy: 0.5613 Loss: 1.5640829590427907
# Aumentando varianzas
#  --------------------- Individuo 14 ---------------------
# Accuracy: 0.5209 Loss: 1.6644935703948331
# Aumentando varianzas
#  --------------------- Individuo 15 ---------------------
# Accuracy: 0.5016 Loss: 1.6495685908190734
# Aumentando varianzas
#  --------------------- Individuo 16 ---------------------
# Accuracy: 0.5518 Loss: 1.625822213299744
# Aumentando varianzas
#  --------------------- Individuo 17 ---------------------
# Accuracy: 0.5447 Loss: 1.592269683128123
# Aumentando varianzas
#  --------------------- Individuo 18 ---------------------
# Accuracy: 0.53 Loss: 1.6300708468612808
# Aumentando varianzas
#  --------------------- Individuo 19 ---------------------
# Accuracy: 0.5284 Loss: 1.6479128995514891
# Aumentando varianzas
#  --------------------- Individuo 20 ---------------------
# Accuracy: 0.5652 Loss: 1.5828428027574972
# Aumentando varianzas
#  --------------------- Individuo 21 ---------------------
# Accuracy: 0.5549 Loss: 1.6212999533356913
# Aumentando varianzas
#  --------------------- Individuo 22 ---------------------
# Accuracy: 0.5333 Loss: 1.596006612110016
# Aumentando varianzas
#  --------------------- Individuo 23 ---------------------
# Accuracy: 0.5367 Loss: 1.6269523623349416
# Aumentando varianzas
#  --------------------- Individuo 24 ---------------------
# Accuracy: 0.545 Loss: 1.65605999754213
# Aumentando varianzas
#  --------------------- Individuo 25 ---------------------
# Accuracy: 0.5565 Loss: 1.6284000397948049
# Aumentando varianzas
#  --------------------- Individuo 26 ---------------------
# Accuracy: 0.5371 Loss: 1.6226268135525685
# Aumentando varianzas
#  --------------------- Individuo 27 ---------------------
# Accuracy: 0.5652 Loss: 1.5650270791614758
# Aumentando varianzas
#  --------------------- Individuo 28 ---------------------
# Accuracy: 0.5573 Loss: 1.6382954407226094
# Aumentando varianzas
#  --------------------- Individuo 29 ---------------------
# Accuracy: 0.5478 Loss: 1.5933403094558765
# Aumentando varianzas
#  --------------------- Individuo 30 ---------------------
# Accuracy: 0.5055 Loss: 1.650374567264791
# Aumentando varianzas
#  --------------------- Individuo 31 ---------------------
# Accuracy: 0.5324 Loss: 1.6436801672439136
# Aumentando varianzas
#  --------------------- Individuo 32 ---------------------
# Accuracy: 0.5574 Loss: 1.6108134983445677
# Aumentando varianzas
#  --------------------- Individuo 33 ---------------------
# Accuracy: 0.5549 Loss: 1.6159259391867595
# Aumentando varianzas
#  --------------------- Individuo 34 ---------------------
# Accuracy: 0.5367 Loss: 1.6440200740876405
# Aumentando varianzas
#  --------------------- Individuo 35 ---------------------
# Accuracy: 0.5289 Loss: 1.6666604381083223
# Aumentando varianzas
#  --------------------- Individuo 36 ---------------------
# Accuracy: 0.5347 Loss: 1.6816236559692246
# Aumentando varianzas
#  --------------------- Individuo 37 ---------------------
# Accuracy: 0.5329 Loss: 1.6231622400186252
# Aumentando varianzas
#  --------------------- Individuo 38 ---------------------
# Accuracy: 0.5354 Loss: 1.6538348298548433
# Aumentando varianzas
#  --------------------- Individuo 39 ---------------------
# Accuracy: 0.523 Loss: 1.604066467346133
# Aumentando varianzas
#  --------------------- Individuo 40 ---------------------
# Accuracy: 0.5456 Loss: 1.6089378187571035
# Aumentando varianzas
#  --------------------- Individuo 41 ---------------------
# Accuracy: 0.5728 Loss: 1.5875594734078478
# Aumentando varianzas
#  --------------------- Individuo 42 ---------------------
# Accuracy: 0.5441 Loss: 1.6456133354350428
# Aumentando varianzas
#  --------------------- Individuo 43 ---------------------
# Accuracy: 0.5453 Loss: 1.6213259707631358
# Aumentando varianzas
#  --------------------- Individuo 44 ---------------------
# Accuracy: 0.5664 Loss: 1.6212913247630418
# Aumentando varianzas
#  --------------------- Individuo 45 ---------------------
# Accuracy: 0.5416 Loss: 1.626642387846242
# Aumentando varianzas
#  --------------------- Individuo 46 ---------------------
# Accuracy: 0.5302 Loss: 1.6606902022800787
# Aumentando varianzas
#  --------------------- Individuo 47 ---------------------
# Accuracy: 0.531 Loss: 1.673521928775036
# Aumentando varianzas
#  --------------------- Individuo 48 ---------------------
# Accuracy: 0.5525 Loss: 1.634678560754527
# Aumentando varianzas
#  --------------------- Individuo 49 ---------------------
# Accuracy: 0.5339 Loss: 1.6504350807660682
# Aumentando varianzas
#  --------------------- Individuo 50 ---------------------
# Accuracy: 0.5473 Loss: 1.6160396458700186
# Aumentando varianzas
#  --------------------- Individuo 51 ---------------------
# Accuracy: 0.5174 Loss: 1.6255797688918345
# Aumentando varianzas
#  --------------------- Individuo 52 ---------------------
# Accuracy: 0.5348 Loss: 1.6414442100488316
# Aumentando varianzas
#  --------------------- Individuo 53 ---------------------
# Accuracy: 0.54 Loss: 1.6568484373409729
# Aumentando varianzas
#  --------------------- Individuo 54 ---------------------
# Accuracy: 0.56 Loss: 1.6392777782419454
# Aumentando varianzas
#  --------------------- Individuo 55 ---------------------
# Accuracy: 0.5773 Loss: 1.5750227930295804
# Aumentando varianzas
#  --------------------- Individuo 56 ---------------------
# Accuracy: 0.5614 Loss: 1.5850846227020254
# Aumentando varianzas
#  --------------------- Individuo 57 ---------------------
# Accuracy: 0.5343 Loss: 1.6120051761417438
# Aumentando varianzas
#  --------------------- Individuo 58 ---------------------
# Accuracy: 0.5449 Loss: 1.6290588232562364
# Aumentando varianzas
#  --------------------- Individuo 59 ---------------------
# Accuracy: 0.5472 Loss: 1.6226494158320415
# Aumentando varianzas
#  --------------------- Individuo 60 ---------------------
# Accuracy: 0.5423 Loss: 1.6212548991603315
# Aumentando varianzas
#  --------------------- Individuo 61 ---------------------
# Accuracy: 0.5443 Loss: 1.6094301772087127
# Aumentando varianzas
#  --------------------- Individuo 62 ---------------------
# Accuracy: 0.5086 Loss: 1.6429283482491817
# Aumentando varianzas
#  --------------------- Individuo 63 ---------------------
# Accuracy: 0.5581 Loss: 1.6290760247603706
# Aumentando varianzas
#  --------------------- Individuo 64 ---------------------
# Accuracy: 0.5626 Loss: 1.5902481768137353
# Aumentando varianzas
#  --------------------- Individuo 65 ---------------------
# Accuracy: 0.5801 Loss: 1.577808750788574
# Aumentando varianzas
#  --------------------- Individuo 66 ---------------------
# Accuracy: 0.5183 Loss: 1.685256895964103
# Aumentando varianzas
#  --------------------- Individuo 67 ---------------------
# Accuracy: 0.5567 Loss: 1.6168798906418977
# Aumentando varianzas
#  --------------------- Individuo 68 ---------------------
# Accuracy: 0.5218 Loss: 1.6545948250519344
# Aumentando varianzas
#  --------------------- Individuo 69 ---------------------
# Accuracy: 0.5712 Loss: 1.5920297043097904
# Aumentando varianzas
#  --------------------- Individuo 70 ---------------------
# Accuracy: 0.5407 Loss: 1.6116608330203444
# Aumentando varianzas
#  --------------------- Individuo 71 ---------------------
# Accuracy: 0.5485 Loss: 1.6113057452851853
# Aumentando varianzas
#  --------------------- Individuo 72 ---------------------
# Accuracy: 0.5577 Loss: 1.6313841659242234
# Aumentando varianzas
#  --------------------- Individuo 73 ---------------------
# Accuracy: 0.5528 Loss: 1.655106450361974
# Aumentando varianzas
#  --------------------- Individuo 74 ---------------------
# Accuracy: 0.5419 Loss: 1.6743646929483584
# Aumentando varianzas
#  --------------------- Individuo 75 ---------------------
# Accuracy: 0.5401 Loss: 1.6528211453229265
# Aumentando varianzas
#  --------------------- Individuo 76 ---------------------
# Accuracy: 0.5532 Loss: 1.640007507313243
# Aumentando varianzas
#  --------------------- Individuo 77 ---------------------
# Accuracy: 0.5479 Loss: 1.6419761743386994
# Aumentando varianzas
#  --------------------- Individuo 78 ---------------------
# Accuracy: 0.5507 Loss: 1.5845655345398446
# Aumentando varianzas
#  --------------------- Individuo 79 ---------------------
# Accuracy: 0.5715 Loss: 1.5739381298842028
# Aumentando varianzas
#  --------------------- Individuo 80 ---------------------
# Accuracy: 0.5466 Loss: 1.6402111633506882
# Aumentando varianzas
#  --------------------- Individuo 81 ---------------------
# Accuracy: 0.5272 Loss: 1.6271158555127165
# Aumentando varianzas
#  --------------------- Individuo 82 ---------------------
# Accuracy: 0.5419 Loss: 1.6514654908033892
# Aumentando varianzas
#  --------------------- Individuo 83 ---------------------
# Accuracy: 0.579 Loss: 1.5901622224951644
# Aumentando varianzas
#  --------------------- Individuo 84 ---------------------
# Accuracy: 0.5147 Loss: 1.6636948169344832
# Aumentando varianzas
#  --------------------- Individuo 85 ---------------------
# Accuracy: 0.5581 Loss: 1.6001427559291614
# Aumentando varianzas
#  --------------------- Individuo 86 ---------------------
# Accuracy: 0.5485 Loss: 1.6006339302148356
# Aumentando varianzas
#  --------------------- Individuo 87 ---------------------
# Accuracy: 0.5407 Loss: 1.6889831789619172
# Aumentando varianzas
#  --------------------- Individuo 88 ---------------------
# Accuracy: 0.5592 Loss: 1.6041511053319477
# Aumentando varianzas
#  --------------------- Individuo 89 ---------------------
# Accuracy: 0.5592 Loss: 1.6435913645550417
# Aumentando varianzas
#  --------------------- Individuo 90 ---------------------
# Accuracy: 0.531 Loss: 1.691973575164595
# Aumentando varianzas
#  --------------------- Individuo 91 ---------------------
# Accuracy: 0.5428 Loss: 1.6441459716738338
# Aumentando varianzas
#  --------------------- Individuo 92 ---------------------
# Accuracy: 0.5552 Loss: 1.6417090096284666
# Aumentando varianzas
#  --------------------- Individuo 93 ---------------------
# Accuracy: 0.5301 Loss: 1.590454183271169
# Aumentando varianzas
#  --------------------- Individuo 94 ---------------------
# Accuracy: 0.5479 Loss: 1.6511521261671316
# Aumentando varianzas
#  --------------------- Individuo 95 ---------------------
# Accuracy: 0.5462 Loss: 1.6279642296874004
# Aumentando varianzas
#  --------------------- Individuo 96 ---------------------
# Accuracy: 0.5617 Loss: 1.6249019072946076
# Aumentando varianzas
#  --------------------- Individuo 97 ---------------------
# Accuracy: 0.547 Loss: 1.6027096295753098
# Aumentando varianzas
#  --------------------- Individuo 98 ---------------------
# Accuracy: 0.527 Loss: 1.6050194703099672
# Aumentando varianzas
#  --------------------- Individuo 99 ---------------------
# Accuracy: 0.5311 Loss: 1.5941728888570195
# Aumentando varianzas
#  --------------------- Individuo 100 ---------------------
# Accuracy: 0.521 Loss: 1.6522009560976492
# Aumentando varianzas
#  --------------------- Individuo 101 ---------------------
# Accuracy: 0.5348 Loss: 1.6457131376961613
# Aumentando varianzas
#  --------------------- Individuo 102 ---------------------
# Accuracy: 0.5335 Loss: 1.64914761060644
# Aumentando varianzas
#  --------------------- Individuo 103 ---------------------
# Accuracy: 0.5319 Loss: 1.611734612289902
# Aumentando varianzas
#  --------------------- Individuo 104 ---------------------
# Accuracy: 0.5449 Loss: 1.663099401137408
# Aumentando varianzas
#  --------------------- Individuo 105 ---------------------
# Accuracy: 0.5635 Loss: 1.6310878957019133
# Aumentando varianzas
#  --------------------- Individuo 106 ---------------------
# Accuracy: 0.5507 Loss: 1.613982433858125
# Aumentando varianzas
#  --------------------- Individuo 107 ---------------------
# Accuracy: 0.5478 Loss: 1.5771373216148532
# Aumentando varianzas
#  --------------------- Individuo 108 ---------------------
# Accuracy: 0.5447 Loss: 1.6690866576741115
# Aumentando varianzas
#  --------------------- Individuo 109 ---------------------
# Accuracy: 0.565 Loss: 1.6047897697104823
# Aumentando varianzas
#  --------------------- Individuo 110 ---------------------
# Accuracy: 0.5542 Loss: 1.6283500177018784
# Aumentando varianzas
#  --------------------- Individuo 111 ---------------------
# Accuracy: 0.5469 Loss: 1.5994416104100855
# Aumentando varianzas
#  --------------------- Individuo 112 ---------------------
# Accuracy: 0.5229 Loss: 1.6323253701410025
# Aumentando varianzas
#  --------------------- Individuo 113 ---------------------
# Accuracy: 0.5516 Loss: 1.6174605096240178
# Aumentando varianzas
#  --------------------- Individuo 114 ---------------------
# Accuracy: 0.5274 Loss: 1.6275673736544216
# Aumentando varianzas
#  --------------------- Individuo 115 ---------------------
# Accuracy: 0.5474 Loss: 1.627254960405857
# Aumentando varianzas
#  --------------------- Individuo 116 ---------------------
# Accuracy: 0.5549 Loss: 1.6664224181638654
# Aumentando varianzas
#  --------------------- Individuo 117 ---------------------
# Accuracy: 0.5643 Loss: 1.6227773946264517
# Aumentando varianzas
#  --------------------- Individuo 118 ---------------------
# Accuracy: 0.5515 Loss: 1.6187341104230613
# Aumentando varianzas
#  --------------------- Individuo 119 ---------------------
# Accuracy: 0.5588 Loss: 1.5919852336806715
# Aumentando varianzas
#  --------------------- Individuo 120 ---------------------
# Accuracy: 0.5549 Loss: 1.6459430574303697
# Aumentando varianzas
#  --------------------- Individuo 121 ---------------------
# Accuracy: 0.5558 Loss: 1.581606644651164
# Aumentando varianzas
#  --------------------- Individuo 122 ---------------------
# Accuracy: 0.5304 Loss: 1.6449115963085839
# Aumentando varianzas
#  --------------------- Individuo 123 ---------------------
# Accuracy: 0.5264 Loss: 1.6499635656471447
# Aumentando varianzas
#  --------------------- Individuo 124 ---------------------
# Accuracy: 0.5283 Loss: 1.6429334273728569
# Aumentando varianzas
#  --------------------- Individuo 125 ---------------------
# Accuracy: 0.5326 Loss: 1.6829654796196676
# Aumentando varianzas
#  --------------------- Individuo 126 ---------------------
# Accuracy: 0.556 Loss: 1.6168088580641296
# Aumentando varianzas
#  --------------------- Individuo 127 ---------------------
# Accuracy: 0.5468 Loss: 1.6588396196779998
# Aumentando varianzas
#  --------------------- Individuo 128 ---------------------
# Accuracy: 0.5503 Loss: 1.61562898701719
# Aumentando varianzas
#  --------------------- Individuo 129 ---------------------
# Accuracy: 0.5404 Loss: 1.6006755324275903
# Aumentando varianzas
#  --------------------- Individuo 130 ---------------------
# Accuracy: 0.5391 Loss: 1.618086317463604
# Aumentando varianzas
#  --------------------- Individuo 131 ---------------------
# Accuracy: 0.5577 Loss: 1.5716471765047448
# Aumentando varianzas
#  --------------------- Individuo 132 ---------------------
# Accuracy: 0.5372 Loss: 1.660652843125336
# Aumentando varianzas
#  --------------------- Individuo 133 ---------------------
# Accuracy: 0.5668 Loss: 1.593792756347705
# Aumentando varianzas
#  --------------------- Individuo 134 ---------------------
# Accuracy: 0.5612 Loss: 1.6207587751738555
# Aumentando varianzas
#  --------------------- Individuo 135 ---------------------
# Accuracy: 0.5477 Loss: 1.6081700205345593
# Aumentando varianzas
#  --------------------- Individuo 136 ---------------------
# Accuracy: 0.5479 Loss: 1.6261041058451318
# Aumentando varianzas
#  --------------------- Individuo 137 ---------------------
# Accuracy: 0.552 Loss: 1.634837568111127
# Aumentando varianzas
#  --------------------- Individuo 138 ---------------------
# Accuracy: 0.5583 Loss: 1.6077997759175118
# Aumentando varianzas
#  --------------------- Individuo 139 ---------------------
# Accuracy: 0.5543 Loss: 1.5918938972608512
# Aumentando varianzas
#  --------------------- Individuo 140 ---------------------
# Accuracy: 0.5365 Loss: 1.672303950542684
# Aumentando varianzas
#  --------------------- Individuo 141 ---------------------
# Accuracy: 0.5609 Loss: 1.6155163992548842
# Aumentando varianzas
#  --------------------- Individuo 142 ---------------------
# Accuracy: 0.5442 Loss: 1.6368911235838595
# Aumentando varianzas
#  --------------------- Individuo 143 ---------------------
# Accuracy: 0.4925 Loss: 1.650486666299498
# Aumentando varianzas
#  --------------------- Individuo 144 ---------------------
# Accuracy: 0.5267 Loss: 1.622914691105523
# Aumentando varianzas
#  --------------------- Individuo 145 ---------------------
# Accuracy: 0.5384 Loss: 1.614568357348747
# Aumentando varianzas
#  --------------------- Individuo 146 ---------------------
# Accuracy: 0.5425 Loss: 1.6227175111660872
# Aumentando varianzas
#  --------------------- Individuo 147 ---------------------
# Accuracy: 0.5496 Loss: 1.594107009794401
# Aumentando varianzas
#  --------------------- Individuo 148 ---------------------
# Accuracy: 0.5521 Loss: 1.5857524192699082
# Aumentando varianzas
#  --------------------- Individuo 149 ---------------------
# Accuracy: 0.5282 Loss: 1.6630311558008803
# Aumentando varianzas
#  --------------------- Individuo 150 ---------------------
# Accuracy: 0.5152 Loss: 1.6585603960029913
# Aumentando varianzas
#  --------------------- Individuo 151 ---------------------
# Accuracy: 0.5272 Loss: 1.6536324246765097
# Aumentando varianzas
#  --------------------- Individuo 152 ---------------------
# Accuracy: 0.5482 Loss: 1.6261355517160556
# Aumentando varianzas
#  --------------------- Individuo 153 ---------------------
# Accuracy: 0.5432 Loss: 1.6106703970438379
# Aumentando varianzas
#  --------------------- Individuo 154 ---------------------
# Accuracy: 0.5515 Loss: 1.6483632080695207
# Aumentando varianzas
#  --------------------- Individuo 155 ---------------------
# Accuracy: 0.5227 Loss: 1.6599773944491316
# Aumentando varianzas
#  --------------------- Individuo 156 ---------------------
# Accuracy: 0.5403 Loss: 1.5993434898841106
# Aumentando varianzas
#  --------------------- Individuo 157 ---------------------
# Accuracy: 0.5436 Loss: 1.5825957136081004
# Aumentando varianzas
#  --------------------- Individuo 158 ---------------------
# Accuracy: 0.5306 Loss: 1.651317586679288
# Aumentando varianzas
#  --------------------- Individuo 159 ---------------------
# Accuracy: 0.5606 Loss: 1.6319110398859624
# Aumentando varianzas
#  --------------------- Individuo 160 ---------------------
# Accuracy: 0.5517 Loss: 1.592206465466248
# Aumentando varianzas
#  --------------------- Individuo 161 ---------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 86
#      84 running_loss = 0.0
#      85 # Train for 1 epoch
# ---> 86 for i, data in enumerate(train_loader, 0):
#      87     inputs, labels = data[0].to(device), data[1].to(device)
#      88     optimizer.zero_grad()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\utils\data\dataloader.py:701, in _BaseDataLoaderIter.__next__(self)
#     698 if self._sampler_iter is None:
#     699     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     700     self._reset()  # type: ignore[call-arg]
# --> 701 data = self._next_data()
#     702 self._num_yielded += 1
#     703 if (
#     704     self._dataset_kind == _DatasetKind.Iterable
#     705     and self._IterableDataset_len_called is not None
#     706     and self._num_yielded > self._IterableDataset_len_called
#     707 ):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\utils\data\dataloader.py:1448, in _MultiProcessingDataLoaderIter._next_data(self)
#    1445     return self._process_data(data)
#    1447 assert not self._shutdown and self._tasks_outstanding > 0
# -> 1448 idx, data = self._get_data()
#    1449 self._tasks_outstanding -= 1
#    1450 if self._dataset_kind == _DatasetKind.Iterable:
#    1451     # Check for _IterableDatasetStopIteration
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\utils\data\dataloader.py:1412, in _MultiProcessingDataLoaderIter._get_data(self)
#    1408     # In this case, `self._data_queue` is a `queue.Queue`,. But we don't
#    1409     # need to call `.task_done()` because we don't use `.join()`.
#    1410 else:
#    1411     while True:
# -> 1412         success, data = self._try_get_data()
#    1413         if success:
#    1414             return data
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\utils\data\dataloader.py:1243, in _MultiProcessingDataLoaderIter._try_get_data(self, timeout)
#    1230 def _try_get_data(self, timeout=_utils.MP_STATUS_CHECK_INTERVAL):
#    1231     # Tries to fetch data from `self._data_queue` once for a given timeout.
#    1232     # This can also be used as inner loop of fetching without timeout, with
#    (...)
#    1240     # Returns a 2-tuple:
#    1241     #   (bool: whether successfully get data, any: data if successful else None)
#    1242     try:
# -> 1243         data = self._data_queue.get(timeout=timeout)
#    1244         return (True, data)
#    1245     except Exception as e:
#    1246         # At timeout and error, we manually check whether any worker has
#    1247         # failed. Note that this is the only mechanism for Windows to detect
#    1248         # worker failures.
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\multiprocessing\queues.py:113, in Queue.get(self, block, timeout)
#     111 if block:
#     112     timeout = deadline - time.monotonic()
# --> 113     if not self._poll(timeout):
#     114         raise Empty
#     115 elif not self._poll():
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\multiprocessing\connection.py:257, in _ConnectionBase.poll(self, timeout)
#     255 self._check_closed()
#     256 self._check_readable()
# --> 257 return self._poll(timeout)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\multiprocessing\connection.py:344, in PipeConnection._poll(self, timeout)
#     342 def _poll(self, timeout):
#     343     if (self._got_empty_message or
# --> 344                 _winapi.PeekNamedPipe(self._handle)[0] != 0):
#     345         return True
#     346     return bool(wait([self], timeout))
#
# KeyboardInterrupt:

# %%
print(train_loss)
print(test_accuracies)
print(max(test_accuracies))
# Out:
# [1.50049149418426, 1.4854221944613835, 1.502713525234281, 1.456143736991736, 1.5378741287361934, 1.5945767589542261, 1.566473709271692, 1.5893139355170451, 1.5708447819018303, 1.684862087907084, 1.6647542186100464, 1.6321755649183718, 1.5640829590427907, 1.6644935703948331, 1.6495685908190734, 1.625822213299744, 1.592269683128123, 1.6300708468612808, 1.6479128995514891, 1.5828428027574972, 1.6212999533356913, 1.596006612110016, 1.6269523623349416, 1.65605999754213, 1.6284000397948049, 1.6226268135525685, 1.5650270791614758, 1.6382954407226094, 1.5933403094558765, 1.650374567264791, 1.6436801672439136, 1.6108134983445677, 1.6159259391867595, 1.6440200740876405, 1.6666604381083223, 1.6816236559692246, 1.6231622400186252, 1.6538348298548433, 1.604066467346133, 1.6089378187571035, 1.5875594734078478, 1.6456133354350428, 1.6213259707631358, 1.6212913247630418, 1.626642387846242, 1.6606902022800787, 1.673521928775036, 1.634678560754527, 1.6504350807660682, 1.6160396458700186, 1.6255797688918345, 1.6414442100488316, 1.6568484373409729, 1.6392777782419454, 1.5750227930295804, 1.5850846227020254, 1.6120051761417438, 1.6290588232562364, 1.6226494158320415, 1.6212548991603315, 1.6094301772087127, 1.6429283482491817, 1.6290760247603706, 1.5902481768137353, 1.577808750788574, 1.685256895964103, 1.6168798906418977, 1.6545948250519344, 1.5920297043097904, 1.6116608330203444, 1.6113057452851853, 1.6313841659242234, 1.655106450361974, 1.6743646929483584, 1.6528211453229265, 1.640007507313243, 1.6419761743386994, 1.5845655345398446, 1.5739381298842028, 1.6402111633506882, 1.6271158555127165, 1.6514654908033892, 1.5901622224951644, 1.6636948169344832, 1.6001427559291614, 1.6006339302148356, 1.6889831789619172, 1.6041511053319477, 1.6435913645550417, 1.691973575164595, 1.6441459716738338, 1.6417090096284666, 1.590454183271169, 1.6511521261671316, 1.6279642296874004, 1.6249019072946076, 1.6027096295753098, 1.6050194703099672, 1.5941728888570195, 1.6522009560976492, 1.6457131376961613, 1.64914761060644, 1.611734612289902, 1.663099401137408, 1.6310878957019133, 1.613982433858125, 1.5771373216148532, 1.6690866576741115, 1.6047897697104823, 1.6283500177018784, 1.5994416104100855, 1.6323253701410025, 1.6174605096240178, 1.6275673736544216, 1.627254960405857, 1.6664224181638654, 1.6227773946264517, 1.6187341104230613, 1.5919852336806715, 1.6459430574303697, 1.581606644651164, 1.6449115963085839, 1.6499635656471447, 1.6429334273728569, 1.6829654796196676, 1.6168088580641296, 1.6588396196779998, 1.61562898701719, 1.6006755324275903, 1.618086317463604, 1.5716471765047448, 1.660652843125336, 1.593792756347705, 1.6207587751738555, 1.6081700205345593, 1.6261041058451318, 1.634837568111127, 1.6077997759175118, 1.5918938972608512, 1.672303950542684, 1.6155163992548842, 1.6368911235838595, 1.650486666299498, 1.622914691105523, 1.614568357348747, 1.6227175111660872, 1.594107009794401, 1.5857524192699082, 1.6630311558008803, 1.6585603960029913, 1.6536324246765097, 1.6261355517160556, 1.6106703970438379, 1.6483632080695207, 1.6599773944491316, 1.5993434898841106, 1.5825957136081004, 1.651317586679288, 1.6319110398859624, 1.592206465466248]
# [0.5656, 0.5522, 0.578, 0.5779, 0.5542, 0.5723, 0.5456, 0.5573, 0.5736, 0.5349, 0.5305, 0.5217, 0.5613, 0.5209, 0.5016, 0.5518, 0.5447, 0.53, 0.5284, 0.5652, 0.5549, 0.5333, 0.5367, 0.545, 0.5565, 0.5371, 0.5652, 0.5573, 0.5478, 0.5055, 0.5324, 0.5574, 0.5549, 0.5367, 0.5289, 0.5347, 0.5329, 0.5354, 0.523, 0.5456, 0.5728, 0.5441, 0.5453, 0.5664, 0.5416, 0.5302, 0.531, 0.5525, 0.5339, 0.5473, 0.5174, 0.5348, 0.54, 0.56, 0.5773, 0.5614, 0.5343, 0.5449, 0.5472, 0.5423, 0.5443, 0.5086, 0.5581, 0.5626, 0.5801, 0.5183, 0.5567, 0.5218, 0.5712, 0.5407, 0.5485, 0.5577, 0.5528, 0.5419, 0.5401, 0.5532, 0.5479, 0.5507, 0.5715, 0.5466, 0.5272, 0.5419, 0.579, 0.5147, 0.5581, 0.5485, 0.5407, 0.5592, 0.5592, 0.531, 0.5428, 0.5552, 0.5301, 0.5479, 0.5462, 0.5617, 0.547, 0.527, 0.5311, 0.521, 0.5348, 0.5335, 0.5319, 0.5449, 0.5635, 0.5507, 0.5478, 0.5447, 0.565, 0.5542, 0.5469, 0.5229, 0.5516, 0.5274, 0.5474, 0.5549, 0.5643, 0.5515, 0.5588, 0.5549, 0.5558, 0.5304, 0.5264, 0.5283, 0.5326, 0.556, 0.5468, 0.5503, 0.5404, 0.5391, 0.5577, 0.5372, 0.5668, 0.5612, 0.5477, 0.5479, 0.552, 0.5583, 0.5543, 0.5365, 0.5609, 0.5442, 0.4925, 0.5267, 0.5384, 0.5425, 0.5496, 0.5521, 0.5282, 0.5152, 0.5272, 0.5482, 0.5432, 0.5515, 0.5227, 0.5403, 0.5436, 0.5306, 0.5606, 0.5517]
# 0.5801

# %%
# Creamos la figura y definimos dos subgráficos (1 fila, 2 columnas)
plt.figure(figsize=(10, 5))

# Primer gráfico en la posición 1 (izquierda)
plt.subplot(1, 2, 1)  # 1 fila, 2 columnas, primer gráfico
plt.plot(train_loss, color='blue', marker='o')
plt.title("Gráfico de Pérdida")
plt.xlabel("Pérdida")
plt.ylabel("Valores")

# Calcular la regresión lineal para train_loss
epochs = np.arange(len(train_loss))
m, b = np.polyfit(epochs, train_loss, 1)
plt.plot(epochs, m*epochs + b, color='red', linestyle='--', label='Tendencia')


# Segundo gráfico en la posición 2 (derecha)
plt.subplot(1, 2, 2)  # 1 fila, 2 columnas, segundo gráfico
plt.plot(test_accuracies, color='green', marker='s')
plt.title("Gráfico de aciertos")
plt.xlabel("% Aciertos")
plt.ylabel("Valores")

# Calcular la regresión lineal para test_accuracies
epochs_test = np.arange(len(test_accuracies))
m, b = np.polyfit(epochs_test, test_accuracies, 1)
plt.plot(epochs_test, m*epochs_test + b, color='red', linestyle='--', label='Tendencia')

# Mostramos los gráficos
plt.tight_layout()  # Ajustamos para que no se solapen los gráficos
plt.legend()
plt.show()

# %%
# while epoch <= 1:
#             net = apply_mask(net, individuo)
#             #guardar el estado de la red en un txt en una carpeta
#             with open(f'pesos/individuo{n_individuo}_epoch{epoch}.txt', 'w') as f:
#                 f.write(str(net.state_dict()))
#             net.train()
#             running_loss = 0.0
#             # Train for 1 epoch
#             for i, data in enumerate(train_loader, 0):
#                 inputs, labels = data[0].to(device), data[1].to(device)
#                 optimizer.zero_grad()
#                 outputs = net(inputs)
#                 loss = criterion(outputs, labels)
#                 loss.backward()
#                 optimizer.step()
#                 running_loss += loss.item()
#             train_loss.append(running_loss / len(train_loader))
#             print(f"Epoch: {epoch}, Loss: {train_loss[-1]}")

#             epoch += 1
