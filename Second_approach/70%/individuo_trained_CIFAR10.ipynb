# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

import numpy as np
import matplotlib.pyplot as plt

from utils.prune import apply_mask
from utils.count_improvement import improvements

# %%
# Verificar si la GPU está disponible y establecer el dispositivo
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1)
        self.fc1 = nn.Linear(128 * 4 * 4, 128)  # Adjusted dimensions here
        self.fc2 = nn.Linear(128, 10)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.max_pool2d(x, 2)
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2)
        x = F.relu(self.conv3(x))
        x = F.max_pool2d(x, 2)
        x = x.view(-1, 128 * 4 * 4)  # Adjusted dimensions here
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return F.log_softmax(x, dim=1)

# %%
net = Net().to(device)
varianzas_net = Net().to(device)
individuo = Net().to(device)

# %% [markdown]
# Cargamos los datos

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

train_dataset = datasets.CIFAR10('./../data', train=True, download=True, transform=transform)
test_dataset = datasets.CIFAR10('./../data', train=False, download=True, transform=transform)

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True, num_workers=4)
test_loader = DataLoader(test_dataset, batch_size=1000, shuffle=False, num_workers=4)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# Definimos la función de pérdida para calcular el error
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr=0.001)

# %% [markdown]
# Realizamos el "entrenamiento"

# %%
# train loop
train_loss = []
train_loss_mean = []
test_accuracies = []
n_individuo = 1
accuracy_threshold = 0.95

# Multiplicamos los pesos de varianzas para que sean numero sgrandes
with torch.no_grad():
    for param in varianzas_net.parameters():
        param *= 10000

#Guardo el mejor individuo y la red original que tendrá que ser reestablecida cad epoca
best_individo_state_dict = individuo.state_dict()
net_state_dict = net.state_dict()

#train loop
while True:
    net.load_state_dict(net_state_dict)
    if n_individuo == 1:
        print(f" --------------------- Individuo {n_individuo} --------------------- ")

        masked_net = apply_mask(net, individuo)
        
        masked_net.train()
        running_loss = 0.0
        # Train for 1 epoch
        for i, data in enumerate(train_loader, 0):
            inputs, labels = data[0].to(device), data[1].to(device)
            optimizer.zero_grad()
            outputs = masked_net(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
        train_loss.append(running_loss / len(train_loader))

        masked_net.eval()
        correct = 0
        total = 0
        with torch.no_grad():
            for data in test_loader:
                images, labels = data[0].to(device), data[1].to(device)
                outputs = masked_net(images)
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
        accuracy = correct / total
        #train_loss_mean.append(np.mean(train_loss))
        test_accuracies.append(accuracy)
        #print(f"Accuracy: {accuracy}, loss mean: {train_loss_mean[-1]}")
        print(f"Accuracy: {accuracy}", f"Loss: {train_loss[-1]}")
        best_loss = train_loss[-1]
        if accuracy > accuracy_threshold:
            break
        n_individuo += 1

        #sumamos varianzas para crear un nuevo individuo desde el anterior
        nuevo_individuo = Net().to(device)
        state_dict_ind = individuo.state_dict()
        state_dict_var = varianzas_net.state_dict()
        state_dict_suma = {}

        for key in state_dict_ind:
            if state_dict_ind[key].size() == state_dict_var[key].size():  
                std_dev = state_dict_var[key]
                noise = torch.normal(0, torch.abs(std_dev))
                state_dict_suma[key] = state_dict_ind[key] + torch.sign(std_dev) * noise
            else:
                state_dict_suma[key] = state_dict_ind[key]

        nuevo_individuo.load_state_dict(state_dict_suma)
        
    else:
        print(f" --------------------- Individuo {n_individuo} --------------------- ")

        masked_net = apply_mask(net, nuevo_individuo)

        masked_net.train()
        running_loss = 0.0
        # Train for 1 epoch
        for i, data in enumerate(train_loader, 0):
            inputs, labels = data[0].to(device), data[1].to(device)
            optimizer.zero_grad()
            outputs = masked_net(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
        train_loss.append(running_loss / len(train_loader))

        masked_net.eval()
        correct = 0
        total = 0
        with torch.no_grad():
            for data in test_loader:
                images, labels = data[0].to(device), data[1].to(device)
                outputs = masked_net(images)
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
        accuracy = correct / total
        test_accuracies.append(accuracy)
        print(f"Accuracy: {accuracy}", f"Loss: {train_loss[-1]}")
        if accuracy > accuracy_threshold:
            break

        # Verificamos que individuo tiene mejor desempeño
        if train_loss[-1] < best_loss:
            print("Nuevo mejor individuo")
            best_loss = train_loss[-1]
            best_individo_state_dict = nuevo_individuo.state_dict()
        
        # actualizamos el individuo
        individuo.load_state_dict(best_individo_state_dict)

        if n_individuo >10:
            # actualizmos el vector de varianzas
            print("Aumentando varianzas")
            if improvements(train_loss) > 2:## +mejoras que peoras (lejos de la solucion)
                with torch.no_grad():
                    for param in varianzas_net.parameters():
                        param *= (1/0.82)

            elif improvements(train_loss) < 2: ## -mejoras que peoras (cerca de la solucion)
                print("Disminuyendo varianzas")
                with torch.no_grad():
                    for param in varianzas_net.parameters():
                        param *= 0.82
        
            else:
                pass

        #sumamos varianzas para crear un nuevo individuo desde el anterior
        nuevo_individuo = Net().to(device)
        state_dict_ind = individuo.state_dict()
        state_dict_var = varianzas_net.state_dict()
        state_dict_suma = {}

        for key in state_dict_ind:
            if state_dict_ind[key].size() == state_dict_var[key].size():  
                std_dev = state_dict_var[key]
                noise = torch.normal(0, torch.abs(std_dev))
                state_dict_suma[key] = state_dict_ind[key] + torch.sign(std_dev) * noise
            else:
                state_dict_suma[key] = state_dict_ind[key]

        nuevo_individuo.load_state_dict(state_dict_suma)

        n_individuo += 1
# Out:
#  --------------------- Individuo 1 ---------------------
# Accuracy: 0.5416 Loss: 1.5366269322612403
#  --------------------- Individuo 2 ---------------------
# Accuracy: 0.5617 Loss: 1.5089055784523029
# Nuevo mejor individuo
#  --------------------- Individuo 3 ---------------------
# Accuracy: 0.5431 Loss: 1.5480052968272773
#  --------------------- Individuo 4 ---------------------
# Accuracy: 0.5941 Loss: 1.4707063085892622
# Nuevo mejor individuo
#  --------------------- Individuo 5 ---------------------
# Accuracy: 0.5798 Loss: 1.501553131110223
#  --------------------- Individuo 6 ---------------------
# Accuracy: 0.5592 Loss: 1.5669426058259461
#  --------------------- Individuo 7 ---------------------
# Accuracy: 0.5583 Loss: 1.5537487716626024
#  --------------------- Individuo 8 ---------------------
# Accuracy: 0.5221 Loss: 1.597888582045465
#  --------------------- Individuo 9 ---------------------
# Accuracy: 0.5456 Loss: 1.6419106192143678
#  --------------------- Individuo 10 ---------------------
# Accuracy: 0.5525 Loss: 1.5793040985494013
#  --------------------- Individuo 11 ---------------------
# Accuracy: 0.5651 Loss: 1.5818934272164884
# Aumentando varianzas
#  --------------------- Individuo 12 ---------------------
# Accuracy: 0.5732 Loss: 1.5519480294431263
# Aumentando varianzas
#  --------------------- Individuo 13 ---------------------
# Accuracy: 0.5379 Loss: 1.6189054557124671
# Aumentando varianzas
#  --------------------- Individuo 14 ---------------------
# Accuracy: 0.5438 Loss: 1.5897444969857746
# Aumentando varianzas
#  --------------------- Individuo 15 ---------------------
# Accuracy: 0.5202 Loss: 1.6233114554449115
# Aumentando varianzas
#  --------------------- Individuo 16 ---------------------
# Accuracy: 0.5386 Loss: 1.6539621813522885
# Aumentando varianzas
#  --------------------- Individuo 17 ---------------------
# Accuracy: 0.544 Loss: 1.6116638042585318
# Aumentando varianzas
#  --------------------- Individuo 18 ---------------------
# Accuracy: 0.5397 Loss: 1.579713589623761
# Aumentando varianzas
#  --------------------- Individuo 19 ---------------------
# Accuracy: 0.5594 Loss: 1.595141377442938
# Aumentando varianzas
#  --------------------- Individuo 20 ---------------------
# Accuracy: 0.5604 Loss: 1.6277315811732846
# Aumentando varianzas
#  --------------------- Individuo 21 ---------------------
# Accuracy: 0.5439 Loss: 1.5779795632185534
# Aumentando varianzas
#  --------------------- Individuo 22 ---------------------
# Accuracy: 0.5474 Loss: 1.6542368002254944
# Aumentando varianzas
#  --------------------- Individuo 23 ---------------------
# Accuracy: 0.5401 Loss: 1.670785726031379
# Aumentando varianzas
#  --------------------- Individuo 24 ---------------------
# Accuracy: 0.524 Loss: 1.6572293333537744
# Aumentando varianzas
#  --------------------- Individuo 25 ---------------------
# Accuracy: 0.5543 Loss: 1.6113693422978492
# Aumentando varianzas
#  --------------------- Individuo 26 ---------------------
# Accuracy: 0.5403 Loss: 1.609875773987197
# Aumentando varianzas
#  --------------------- Individuo 27 ---------------------
# Accuracy: 0.5504 Loss: 1.6009026609570778
# Aumentando varianzas
#  --------------------- Individuo 28 ---------------------
# Accuracy: 0.5412 Loss: 1.6217543908092371
# Aumentando varianzas
#  --------------------- Individuo 29 ---------------------
# Accuracy: 0.5405 Loss: 1.6096744506102998
# Aumentando varianzas
#  --------------------- Individuo 30 ---------------------
# Accuracy: 0.5314 Loss: 1.6348500148109768
# Aumentando varianzas
#  --------------------- Individuo 31 ---------------------
# Accuracy: 0.5584 Loss: 1.5758165106596544
# Aumentando varianzas
#  --------------------- Individuo 32 ---------------------
# Accuracy: 0.5502 Loss: 1.6089631271789142
# Aumentando varianzas
#  --------------------- Individuo 33 ---------------------
# Accuracy: 0.5412 Loss: 1.5974485297946979
# Aumentando varianzas
#  --------------------- Individuo 34 ---------------------
# Accuracy: 0.5434 Loss: 1.6397531603455848
# Aumentando varianzas
#  --------------------- Individuo 35 ---------------------
# Accuracy: 0.5441 Loss: 1.6350784204195223
# Aumentando varianzas
#  --------------------- Individuo 36 ---------------------
# Accuracy: 0.5329 Loss: 1.6580117149731082
# Aumentando varianzas
#  --------------------- Individuo 37 ---------------------
# Accuracy: 0.5549 Loss: 1.6107346121307529
# Aumentando varianzas
#  --------------------- Individuo 38 ---------------------
# Accuracy: 0.5598 Loss: 1.5982492871754004
# Aumentando varianzas
#  --------------------- Individuo 39 ---------------------
# Accuracy: 0.5028 Loss: 1.5978783257019795
# Aumentando varianzas
#  --------------------- Individuo 40 ---------------------
# Accuracy: 0.536 Loss: 1.6915462639020837
# Aumentando varianzas
#  --------------------- Individuo 41 ---------------------
# Accuracy: 0.5336 Loss: 1.624682362427187
# Aumentando varianzas
#  --------------------- Individuo 42 ---------------------
# Accuracy: 0.5439 Loss: 1.6073821039151048
# Aumentando varianzas
#  --------------------- Individuo 43 ---------------------
# Accuracy: 0.5501 Loss: 1.5941292001768146
# Aumentando varianzas
#  --------------------- Individuo 44 ---------------------
# Accuracy: 0.5533 Loss: 1.6124925114919462
# Aumentando varianzas
#  --------------------- Individuo 45 ---------------------
# Accuracy: 0.5297 Loss: 1.6115190628392007
# Aumentando varianzas
#  --------------------- Individuo 46 ---------------------
# Accuracy: 0.5356 Loss: 1.6346619360129853
# Aumentando varianzas
#  --------------------- Individuo 47 ---------------------
# Accuracy: 0.5481 Loss: 1.6230940085542782
# Aumentando varianzas
#  --------------------- Individuo 48 ---------------------
# Accuracy: 0.5484 Loss: 1.5998159159937173
# Aumentando varianzas
#  --------------------- Individuo 49 ---------------------
# Accuracy: 0.5529 Loss: 1.6105299989128357
# Aumentando varianzas
#  --------------------- Individuo 50 ---------------------
# Accuracy: 0.5229 Loss: 1.6286127824917473
# Aumentando varianzas
#  --------------------- Individuo 51 ---------------------
# Accuracy: 0.5328 Loss: 1.6054859951024165
# Aumentando varianzas
#  --------------------- Individuo 52 ---------------------
# Accuracy: 0.5421 Loss: 1.6123024256485503
# Aumentando varianzas
#  --------------------- Individuo 53 ---------------------
# Accuracy: 0.5089 Loss: 1.6478491427800845
# Aumentando varianzas
#  --------------------- Individuo 54 ---------------------
# Accuracy: 0.5423 Loss: 1.5670894978906187
# Aumentando varianzas
#  --------------------- Individuo 55 ---------------------
# Accuracy: 0.5392 Loss: 1.6624754690148336
# Aumentando varianzas
#  --------------------- Individuo 56 ---------------------
# Accuracy: 0.549 Loss: 1.6268765517817738
# Aumentando varianzas
#  --------------------- Individuo 57 ---------------------
# Accuracy: 0.5378 Loss: 1.6591793349027024
# Aumentando varianzas
#  --------------------- Individuo 58 ---------------------
# Accuracy: 0.5556 Loss: 1.6055738964044224
# Aumentando varianzas
#  --------------------- Individuo 59 ---------------------
# Accuracy: 0.5587 Loss: 1.6213629603995692
# Aumentando varianzas
#  --------------------- Individuo 60 ---------------------
# Accuracy: 0.5026 Loss: 1.6548226955906509
# Aumentando varianzas
#  --------------------- Individuo 61 ---------------------
# Accuracy: 0.5283 Loss: 1.6158668181627913
# Aumentando varianzas
#  --------------------- Individuo 62 ---------------------
# Accuracy: 0.5561 Loss: 1.5731156331956233
# Aumentando varianzas
#  --------------------- Individuo 63 ---------------------
# Accuracy: 0.55 Loss: 1.6058058989474842
# Aumentando varianzas
#  --------------------- Individuo 64 ---------------------
# Accuracy: 0.5468 Loss: 1.6175357194812707
# Aumentando varianzas
#  --------------------- Individuo 65 ---------------------
# Accuracy: 0.5577 Loss: 1.6173798771160643
# Aumentando varianzas
#  --------------------- Individuo 66 ---------------------
# Accuracy: 0.5256 Loss: 1.6280201788601059
# Aumentando varianzas
#  --------------------- Individuo 67 ---------------------
# Accuracy: 0.5502 Loss: 1.6312122259603437
# Aumentando varianzas
#  --------------------- Individuo 68 ---------------------
# Accuracy: 0.5727 Loss: 1.5521747472188663
# Aumentando varianzas
#  --------------------- Individuo 69 ---------------------
# Accuracy: 0.5351 Loss: 1.6495418232267776
# Aumentando varianzas
#  --------------------- Individuo 70 ---------------------
# Accuracy: 0.5387 Loss: 1.6024160271562884
# Aumentando varianzas
#  --------------------- Individuo 71 ---------------------
# Accuracy: 0.5402 Loss: 1.615762068563715
# Aumentando varianzas
#  --------------------- Individuo 72 ---------------------
# Accuracy: 0.5399 Loss: 1.6346886114543662
# Aumentando varianzas
#  --------------------- Individuo 73 ---------------------
# Accuracy: 0.5819 Loss: 1.5627877991979995
# Aumentando varianzas
#  --------------------- Individuo 74 ---------------------
# Accuracy: 0.5711 Loss: 1.5760640780944044
# Aumentando varianzas
#  --------------------- Individuo 75 ---------------------
# Accuracy: 0.523 Loss: 1.601476159546991
# Aumentando varianzas
#  --------------------- Individuo 76 ---------------------
# Accuracy: 0.5415 Loss: 1.6272068910129236
# Aumentando varianzas
#  --------------------- Individuo 77 ---------------------
# Accuracy: 0.56 Loss: 1.5712665936068806
# Aumentando varianzas
#  --------------------- Individuo 78 ---------------------
# Accuracy: 0.5211 Loss: 1.608243583108458
# Aumentando varianzas
#  --------------------- Individuo 79 ---------------------
# Accuracy: 0.5229 Loss: 1.6374811549930621
# Aumentando varianzas
#  --------------------- Individuo 80 ---------------------
# Accuracy: 0.5268 Loss: 1.6576749741116448
# Aumentando varianzas
#  --------------------- Individuo 81 ---------------------
# Accuracy: 0.5563 Loss: 1.6024755484917586
# Aumentando varianzas
#  --------------------- Individuo 82 ---------------------
# Accuracy: 0.5298 Loss: 1.64703880551526
# Aumentando varianzas
#  --------------------- Individuo 83 ---------------------
# Accuracy: 0.5583 Loss: 1.5691277114936457
# Aumentando varianzas
#  --------------------- Individuo 84 ---------------------
# Accuracy: 0.5264 Loss: 1.6174630450318233
# Aumentando varianzas
#  --------------------- Individuo 85 ---------------------
# Accuracy: 0.5451 Loss: 1.6239080490053768
# Aumentando varianzas
#  --------------------- Individuo 86 ---------------------
# Accuracy: 0.5623 Loss: 1.5998875243432076
# Aumentando varianzas
#  --------------------- Individuo 87 ---------------------
# Accuracy: 0.5278 Loss: 1.6298657227355196
# Aumentando varianzas
#  --------------------- Individuo 88 ---------------------
# Accuracy: 0.5545 Loss: 1.5958158293038682
# Aumentando varianzas
#  --------------------- Individuo 89 ---------------------
# Accuracy: 0.5413 Loss: 1.6158698047213542
# Aumentando varianzas
#  --------------------- Individuo 90 ---------------------
# Accuracy: 0.5465 Loss: 1.6102867098263158
# Aumentando varianzas
#  --------------------- Individuo 91 ---------------------
# Accuracy: 0.5591 Loss: 1.5938569404127654
# Aumentando varianzas
#  --------------------- Individuo 92 ---------------------
# Accuracy: 0.5359 Loss: 1.6376463356225386
# Aumentando varianzas
#  --------------------- Individuo 93 ---------------------
# Accuracy: 0.5348 Loss: 1.6333600209497126
# Aumentando varianzas
#  --------------------- Individuo 94 ---------------------
# Accuracy: 0.5428 Loss: 1.6091261419188945
# Aumentando varianzas
#  --------------------- Individuo 95 ---------------------
# Accuracy: 0.5659 Loss: 1.5954742160294673
# Aumentando varianzas
#  --------------------- Individuo 96 ---------------------
# Accuracy: 0.5357 Loss: 1.685975384986614
# Aumentando varianzas
#  --------------------- Individuo 97 ---------------------
# Accuracy: 0.5565 Loss: 1.604734435944301
# Aumentando varianzas
#  --------------------- Individuo 98 ---------------------
# Accuracy: 0.5324 Loss: 1.649416262688844
# Aumentando varianzas
#  --------------------- Individuo 99 ---------------------
# Accuracy: 0.5358 Loss: 1.5946735730561454
# Aumentando varianzas
#  --------------------- Individuo 100 ---------------------
# Accuracy: 0.5508 Loss: 1.612200249567666
# Aumentando varianzas
#  --------------------- Individuo 101 ---------------------
# Accuracy: 0.5399 Loss: 1.6158165078028999
# Aumentando varianzas
#  --------------------- Individuo 102 ---------------------
# Accuracy: 0.5279 Loss: 1.6142588452914792
# Aumentando varianzas
#  --------------------- Individuo 103 ---------------------
# Accuracy: 0.5613 Loss: 1.6095571593402902
# Aumentando varianzas
#  --------------------- Individuo 104 ---------------------
# Accuracy: 0.555 Loss: 1.6149213955835309
# Aumentando varianzas
#  --------------------- Individuo 105 ---------------------
# Accuracy: 0.5306 Loss: 1.6233143095317704
# Aumentando varianzas
#  --------------------- Individuo 106 ---------------------
# Accuracy: 0.5465 Loss: 1.6317342961840617
# Aumentando varianzas
#  --------------------- Individuo 107 ---------------------
# Accuracy: 0.52 Loss: 1.6810166404375335
# Aumentando varianzas
#  --------------------- Individuo 108 ---------------------
# Accuracy: 0.5696 Loss: 1.5577235638790423
# Aumentando varianzas
#  --------------------- Individuo 109 ---------------------
# Accuracy: 0.5102 Loss: 1.6576791329457021
# Aumentando varianzas
#  --------------------- Individuo 110 ---------------------
# Accuracy: 0.5728 Loss: 1.5743388472615605
# Aumentando varianzas
#  --------------------- Individuo 111 ---------------------
# Accuracy: 0.5568 Loss: 1.618550538864282
# Aumentando varianzas
#  --------------------- Individuo 112 ---------------------
# Accuracy: 0.5644 Loss: 1.5797853136763853
# Aumentando varianzas
#  --------------------- Individuo 113 ---------------------
# Accuracy: 0.5597 Loss: 1.6248731847919162
# Aumentando varianzas
#  --------------------- Individuo 114 ---------------------
# Accuracy: 0.5457 Loss: 1.6412956637647145
# Aumentando varianzas
#  --------------------- Individuo 115 ---------------------
# Accuracy: 0.5224 Loss: 1.5754395711909779
# Aumentando varianzas
#  --------------------- Individuo 116 ---------------------
# Accuracy: 0.5194 Loss: 1.6661931783951762
# Aumentando varianzas
#  --------------------- Individuo 117 ---------------------
# Accuracy: 0.5252 Loss: 1.6180427809962836
# Aumentando varianzas
#  --------------------- Individuo 118 ---------------------
# Accuracy: 0.5634 Loss: 1.6212484360960744
# Aumentando varianzas
#  --------------------- Individuo 119 ---------------------
# Accuracy: 0.5357 Loss: 1.6272886526554138
# Aumentando varianzas
#  --------------------- Individuo 120 ---------------------
# Accuracy: 0.5798 Loss: 1.5729601283360015
# Aumentando varianzas
#  --------------------- Individuo 121 ---------------------
# Accuracy: 0.521 Loss: 1.607367646968578
# Aumentando varianzas
#  --------------------- Individuo 122 ---------------------
# Accuracy: 0.5445 Loss: 1.6056913567321074
# Aumentando varianzas
#  --------------------- Individuo 123 ---------------------
# Accuracy: 0.5789 Loss: 1.566676589153002
# Aumentando varianzas
#  --------------------- Individuo 124 ---------------------
# Accuracy: 0.5591 Loss: 1.6123536427307616
# Aumentando varianzas
#  --------------------- Individuo 125 ---------------------
# Accuracy: 0.5579 Loss: 1.6165596080558073
# Aumentando varianzas
#  --------------------- Individuo 126 ---------------------
# Accuracy: 0.5565 Loss: 1.6252227870704572
# Aumentando varianzas
#  --------------------- Individuo 127 ---------------------
# Accuracy: 0.5411 Loss: 1.6068230907020666
# Aumentando varianzas
#  --------------------- Individuo 128 ---------------------
# Accuracy: 0.5506 Loss: 1.6308526639133463
# Aumentando varianzas
#  --------------------- Individuo 129 ---------------------
# Accuracy: 0.5486 Loss: 1.6347550309984886
# Aumentando varianzas
#  --------------------- Individuo 130 ---------------------
# Accuracy: 0.5478 Loss: 1.5801279852000039
# Aumentando varianzas
#  --------------------- Individuo 131 ---------------------
# Accuracy: 0.5196 Loss: 1.6171675168949624
# Aumentando varianzas
#  --------------------- Individuo 132 ---------------------
# Accuracy: 0.557 Loss: 1.590840692334163
# Aumentando varianzas
#  --------------------- Individuo 133 ---------------------
# Accuracy: 0.5649 Loss: 1.6205084852855225
# Aumentando varianzas
#  --------------------- Individuo 134 ---------------------
# Accuracy: 0.5368 Loss: 1.6292651828445133
# Aumentando varianzas
#  --------------------- Individuo 135 ---------------------
# Accuracy: 0.5684 Loss: 1.5891863848547192
# Aumentando varianzas
#  --------------------- Individuo 136 ---------------------
# Accuracy: 0.5537 Loss: 1.6015249618788814
# Aumentando varianzas
#  --------------------- Individuo 137 ---------------------
# Accuracy: 0.5288 Loss: 1.6897704183598004
# Aumentando varianzas
#  --------------------- Individuo 138 ---------------------
# Accuracy: 0.5381 Loss: 1.6044632958634126
# Aumentando varianzas
#  --------------------- Individuo 139 ---------------------
# Accuracy: 0.5354 Loss: 1.6142117527439772
# Aumentando varianzas
#  --------------------- Individuo 140 ---------------------
# Accuracy: 0.5602 Loss: 1.5960180970561473
# Aumentando varianzas
#  --------------------- Individuo 141 ---------------------
# Accuracy: 0.5429 Loss: 1.6127241950510713
# Aumentando varianzas
#  --------------------- Individuo 142 ---------------------
# Accuracy: 0.5328 Loss: 1.644092451276072
# Aumentando varianzas
#  --------------------- Individuo 143 ---------------------
# Accuracy: 0.5228 Loss: 1.6434482340617558
# Aumentando varianzas
#  --------------------- Individuo 144 ---------------------
# Accuracy: 0.5414 Loss: 1.5993068315031584
# Aumentando varianzas
#  --------------------- Individuo 145 ---------------------
# Accuracy: 0.5437 Loss: 1.6017997549165546
# Aumentando varianzas
#  --------------------- Individuo 146 ---------------------
# Accuracy: 0.5521 Loss: 1.6206600948063004
# Aumentando varianzas
#  --------------------- Individuo 147 ---------------------
# Accuracy: 0.5459 Loss: 1.6107237611890144
# Aumentando varianzas
#  --------------------- Individuo 148 ---------------------
# Accuracy: 0.5495 Loss: 1.6226183096771045
# Aumentando varianzas
#  --------------------- Individuo 149 ---------------------
# Accuracy: 0.5257 Loss: 1.6230369896992394
# Aumentando varianzas
#  --------------------- Individuo 150 ---------------------
# Accuracy: 0.5466 Loss: 1.6423502876935407
# Aumentando varianzas
#  --------------------- Individuo 151 ---------------------
# Accuracy: 0.5416 Loss: 1.5773034676566453
# Aumentando varianzas
#  --------------------- Individuo 152 ---------------------
# Accuracy: 0.5591 Loss: 1.6254889923135947
# Aumentando varianzas
#  --------------------- Individuo 153 ---------------------
# Accuracy: 0.5532 Loss: 1.5751796038559331
# Aumentando varianzas
#  --------------------- Individuo 154 ---------------------
# Accuracy: 0.5436 Loss: 1.5975897174204707
# Aumentando varianzas
#  --------------------- Individuo 155 ---------------------
# Accuracy: 0.5369 Loss: 1.6141777442544318
# Aumentando varianzas
#  --------------------- Individuo 156 ---------------------
# Accuracy: 0.5297 Loss: 1.6807292887316945
# Aumentando varianzas
#  --------------------- Individuo 157 ---------------------
# Accuracy: 0.5403 Loss: 1.5798521307880615
# Aumentando varianzas
#  --------------------- Individuo 158 ---------------------
# Accuracy: 0.5656 Loss: 1.5738757391414984
# Aumentando varianzas
#  --------------------- Individuo 159 ---------------------
# Accuracy: 0.5288 Loss: 1.641755967188979
# Aumentando varianzas
#  --------------------- Individuo 160 ---------------------
# Accuracy: 0.544 Loss: 1.6205147584076123
# Aumentando varianzas
#  --------------------- Individuo 161 ---------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 101
#      99         _, predicted = torch.max(outputs.data, 1)
#     100         total += labels.size(0)
# --> 101         correct += (predicted == labels).sum().item()
#     102 accuracy = correct / total
#     103 test_accuracies.append(accuracy)
#
# KeyboardInterrupt:

# %%
print(train_loss)
print(test_accuracies)
print(max(test_accuracies))
index_max_accuracy = test_accuracies.index(max(test_accuracies))
print(index_max_accuracy)

print("-----------------")
print(min(train_loss))
index = train_loss.index(min(train_loss))
print(index)
# Out:
# [1.5366269322612403, 1.5089055784523029, 1.5480052968272773, 1.4707063085892622, 1.501553131110223, 1.5669426058259461, 1.5537487716626024, 1.597888582045465, 1.6419106192143678, 1.5793040985494013, 1.5818934272164884, 1.5519480294431263, 1.6189054557124671, 1.5897444969857746, 1.6233114554449115, 1.6539621813522885, 1.6116638042585318, 1.579713589623761, 1.595141377442938, 1.6277315811732846, 1.5779795632185534, 1.6542368002254944, 1.670785726031379, 1.6572293333537744, 1.6113693422978492, 1.609875773987197, 1.6009026609570778, 1.6217543908092371, 1.6096744506102998, 1.6348500148109768, 1.5758165106596544, 1.6089631271789142, 1.5974485297946979, 1.6397531603455848, 1.6350784204195223, 1.6580117149731082, 1.6107346121307529, 1.5982492871754004, 1.5978783257019795, 1.6915462639020837, 1.624682362427187, 1.6073821039151048, 1.5941292001768146, 1.6124925114919462, 1.6115190628392007, 1.6346619360129853, 1.6230940085542782, 1.5998159159937173, 1.6105299989128357, 1.6286127824917473, 1.6054859951024165, 1.6123024256485503, 1.6478491427800845, 1.5670894978906187, 1.6624754690148336, 1.6268765517817738, 1.6591793349027024, 1.6055738964044224, 1.6213629603995692, 1.6548226955906509, 1.6158668181627913, 1.5731156331956233, 1.6058058989474842, 1.6175357194812707, 1.6173798771160643, 1.6280201788601059, 1.6312122259603437, 1.5521747472188663, 1.6495418232267776, 1.6024160271562884, 1.615762068563715, 1.6346886114543662, 1.5627877991979995, 1.5760640780944044, 1.601476159546991, 1.6272068910129236, 1.5712665936068806, 1.608243583108458, 1.6374811549930621, 1.6576749741116448, 1.6024755484917586, 1.64703880551526, 1.5691277114936457, 1.6174630450318233, 1.6239080490053768, 1.5998875243432076, 1.6298657227355196, 1.5958158293038682, 1.6158698047213542, 1.6102867098263158, 1.5938569404127654, 1.6376463356225386, 1.6333600209497126, 1.6091261419188945, 1.5954742160294673, 1.685975384986614, 1.604734435944301, 1.649416262688844, 1.5946735730561454, 1.612200249567666, 1.6158165078028999, 1.6142588452914792, 1.6095571593402902, 1.6149213955835309, 1.6233143095317704, 1.6317342961840617, 1.6810166404375335, 1.5577235638790423, 1.6576791329457021, 1.5743388472615605, 1.618550538864282, 1.5797853136763853, 1.6248731847919162, 1.6412956637647145, 1.5754395711909779, 1.6661931783951762, 1.6180427809962836, 1.6212484360960744, 1.6272886526554138, 1.5729601283360015, 1.607367646968578, 1.6056913567321074, 1.566676589153002, 1.6123536427307616, 1.6165596080558073, 1.6252227870704572, 1.6068230907020666, 1.6308526639133463, 1.6347550309984886, 1.5801279852000039, 1.6171675168949624, 1.590840692334163, 1.6205084852855225, 1.6292651828445133, 1.5891863848547192, 1.6015249618788814, 1.6897704183598004, 1.6044632958634126, 1.6142117527439772, 1.5960180970561473, 1.6127241950510713, 1.644092451276072, 1.6434482340617558, 1.5993068315031584, 1.6017997549165546, 1.6206600948063004, 1.6107237611890144, 1.6226183096771045, 1.6230369896992394, 1.6423502876935407, 1.5773034676566453, 1.6254889923135947, 1.5751796038559331, 1.5975897174204707, 1.6141777442544318, 1.6807292887316945, 1.5798521307880615, 1.5738757391414984, 1.641755967188979, 1.6205147584076123, 1.607902184395534]
# [0.5416, 0.5617, 0.5431, 0.5941, 0.5798, 0.5592, 0.5583, 0.5221, 0.5456, 0.5525, 0.5651, 0.5732, 0.5379, 0.5438, 0.5202, 0.5386, 0.544, 0.5397, 0.5594, 0.5604, 0.5439, 0.5474, 0.5401, 0.524, 0.5543, 0.5403, 0.5504, 0.5412, 0.5405, 0.5314, 0.5584, 0.5502, 0.5412, 0.5434, 0.5441, 0.5329, 0.5549, 0.5598, 0.5028, 0.536, 0.5336, 0.5439, 0.5501, 0.5533, 0.5297, 0.5356, 0.5481, 0.5484, 0.5529, 0.5229, 0.5328, 0.5421, 0.5089, 0.5423, 0.5392, 0.549, 0.5378, 0.5556, 0.5587, 0.5026, 0.5283, 0.5561, 0.55, 0.5468, 0.5577, 0.5256, 0.5502, 0.5727, 0.5351, 0.5387, 0.5402, 0.5399, 0.5819, 0.5711, 0.523, 0.5415, 0.56, 0.5211, 0.5229, 0.5268, 0.5563, 0.5298, 0.5583, 0.5264, 0.5451, 0.5623, 0.5278, 0.5545, 0.5413, 0.5465, 0.5591, 0.5359, 0.5348, 0.5428, 0.5659, 0.5357, 0.5565, 0.5324, 0.5358, 0.5508, 0.5399, 0.5279, 0.5613, 0.555, 0.5306, 0.5465, 0.52, 0.5696, 0.5102, 0.5728, 0.5568, 0.5644, 0.5597, 0.5457, 0.5224, 0.5194, 0.5252, 0.5634, 0.5357, 0.5798, 0.521, 0.5445, 0.5789, 0.5591, 0.5579, 0.5565, 0.5411, 0.5506, 0.5486, 0.5478, 0.5196, 0.557, 0.5649, 0.5368, 0.5684, 0.5537, 0.5288, 0.5381, 0.5354, 0.5602, 0.5429, 0.5328, 0.5228, 0.5414, 0.5437, 0.5521, 0.5459, 0.5495, 0.5257, 0.5466, 0.5416, 0.5591, 0.5532, 0.5436, 0.5369, 0.5297, 0.5403, 0.5656, 0.5288, 0.544]
# 0.5941
# 3
# -----------------
# 1.4707063085892622
# 3

# %%
# Creamos la figura y definimos dos subgráficos (1 fila, 2 columnas)
plt.figure(figsize=(10, 5))

# Primer gráfico en la posición 1 (izquierda)
plt.subplot(1, 2, 1)  # 1 fila, 2 columnas, primer gráfico
plt.plot(train_loss, color='blue', marker='o')
plt.title("Gráfico de Pérdida")
plt.xlabel("Épocas")
plt.ylabel("Valores de pérdida")

# Calcular la regresión lineal para train_loss
epochs = np.arange(len(train_loss))
m, b = np.polyfit(epochs, train_loss, 1)
plt.plot(epochs, m*epochs + b, color='red', linestyle='--', label='Tendencia')


# Segundo gráfico en la posición 2 (derecha)
plt.subplot(1, 2, 2)  # 1 fila, 2 columnas, segundo gráfico
plt.plot(test_accuracies, color='green', marker='s')
plt.title("Gráfico de aciertos")
plt.xlabel("Épocas")
plt.ylabel("% de aciertos")

# Calcular la regresión lineal para test_accuracies
epochs_test = np.arange(len(test_accuracies))
m, b = np.polyfit(epochs_test, test_accuracies, 1)
plt.plot(epochs_test, m*epochs_test + b, color='red', linestyle='--', label='Tendencia')

# Mostramos los gráficos
plt.tight_layout()  # Ajustamos para que no se solapen los gráficos
plt.legend()
plt.show()
