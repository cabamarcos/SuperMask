# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import torch.nn.init as init

import numpy as np
import matplotlib.pyplot as plt

from utils.prune import apply_mask
from utils.count_improvement import improvements

# %%
# Verificar si la GPU está disponible y establecer el dispositivo
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(784, 256)
        self.fc2 = nn.Linear(256, 128)
        self.fc3 = nn.Linear(128, 10)

    def forward(self, x):
        x = x.view(-1, 784)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return F.log_softmax(x, dim=1)

# %%
net = Net().to(device)
varianzas_net = Net().to(device)
individuo = Net().to(device)

# %% [markdown]
# Cargamos los datos

# %%
# Definimos el transform para los datos de MNIST
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))
])

# Cargamos el dataset de MNIST
train_dataset = datasets.MNIST('./../data', train=True, download=True, transform=transform)
test_dataset = datasets.MNIST('./../data', train=False, download=True, transform=transform)

# Definimos los DataLoaders para los conjuntos de entrenamiento y prueba
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True, num_workers=4)
test_loader = DataLoader(test_dataset, batch_size=1000, shuffle=False, num_workers=4)

# %%
# Definimos la función de pérdida para calcular el error
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr=0.001)

# %% [markdown]
# Realizamos el "entrenamiento"

# %%
# train loop
train_loss = []
train_loss_mean = []
test_accuracies = []
n_individuo = 1
accuracy_threshold = 0.4

# Multiplicamos los pesos de varianzas para que sean numero sgrandes
with torch.no_grad():
    for param in varianzas_net.parameters():
        param *= 10000

#Guardo el mejor individuo y la red original que tendrá que ser reestablecida cad epoca
best_individo_state_dict = individuo.state_dict()
net_state_dict = net.state_dict()

#train loop
while True:
    net.load_state_dict(net_state_dict)
    if n_individuo == 1:
        print(f" --------------------- Individuo {n_individuo} --------------------- ")

        masked_net = apply_mask(net, individuo)

        running_loss = 0.0
        # Train for 1 epoch
        for i, data in enumerate(train_loader, 0):
            inputs, labels = data[0].to(device), data[1].to(device)
            #optimizer.zero_grad()
            outputs = masked_net(inputs)
            loss = criterion(outputs, labels)
            #loss.backward()
            #optimizer.step()
            running_loss += loss.item()
        train_loss.append(running_loss / len(train_loader))

        masked_net.eval()
        correct = 0
        total = 0
        with torch.no_grad():
            for data in test_loader:
                images, labels = data[0].to(device), data[1].to(device)
                outputs = masked_net(images)
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
        accuracy = correct / total
        #train_loss_mean.append(np.mean(train_loss))
        test_accuracies.append(accuracy)
        #print(f"Accuracy: {accuracy}, loss mean: {train_loss_mean[-1]}")
        print(f"Accuracy: {accuracy}", f"Loss: {train_loss[-1]}")
        best_loss = train_loss[-1]
        if accuracy > accuracy_threshold:
            break
        n_individuo += 1

        #sumamos varianzas para crear un nuevo individuo desde el anterior
        nuevo_individuo = Net().to(device)
        state_dict_ind = individuo.state_dict()
        state_dict_var = varianzas_net.state_dict()
        state_dict_suma = {}

        for key in state_dict_ind:
            if state_dict_ind[key].size() == state_dict_var[key].size():  
                std_dev = state_dict_var[key]
                noise = torch.normal(0, torch.abs(std_dev))
                state_dict_suma[key] = state_dict_ind[key] + torch.sign(std_dev) * noise
            else:
                state_dict_suma[key] = state_dict_ind[key]

        nuevo_individuo.load_state_dict(state_dict_suma)
        
    else:
        print(f" --------------------- Individuo {n_individuo} --------------------- ")

        masked_net = apply_mask(net, nuevo_individuo)
        
        running_loss = 0.0
        for i, data in enumerate(train_loader, 0):
            inputs, labels = data[0].to(device), data[1].to(device)
            outputs = masked_net(inputs)
            loss = criterion(outputs, labels)
            running_loss += loss.item()
        train_loss.append(running_loss / len(train_loader))

        masked_net.eval()
        correct = 0
        total = 0
        with torch.no_grad():
            for data in test_loader:
                images, labels = data[0].to(device), data[1].to(device)
                outputs = masked_net(images)
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
        accuracy = correct / total
        test_accuracies.append(accuracy)
        print(f"Accuracy: {accuracy}", f"Loss: {train_loss[-1]}")
        if accuracy > accuracy_threshold:
            break

        # Verificamos que individuo tiene mejor desempeño
        if train_loss[-1] < best_loss:
            print("Nuevo mejor individuo")
            best_loss = train_loss[-1]
            best_individo_state_dict = nuevo_individuo.state_dict()
        
        # actualizamos el individuo
        individuo.load_state_dict(best_individo_state_dict)

        if n_individuo >10:
            # actualizmos el vector de varianzas
            if improvements(train_loss) > 2:## +mejoras que peoras (lejos de la solucion)
                print("Aumentando varianzas")
                with torch.no_grad():
                    for param in varianzas_net.parameters():
                        param *= (1/0.82)

            elif improvements(train_loss) <= 2: ## -mejoras que peoras (cerca de la solucion)
                print("Disminuyendo varianzas")
                with torch.no_grad():
                    for param in varianzas_net.parameters():
                        param *= 0.82
        
            else:
                pass

        #sumamos varianzas para crear un nuevo individuo desde el anterior
        nuevo_individuo = Net().to(device)
        state_dict_ind = individuo.state_dict()
        state_dict_var = varianzas_net.state_dict()
        state_dict_suma = {}

        for key in state_dict_ind:
            if state_dict_ind[key].size() == state_dict_var[key].size():  
                std_dev = state_dict_var[key]
                noise = torch.normal(0, torch.abs(std_dev))
                state_dict_suma[key] = state_dict_ind[key] + torch.sign(std_dev) * noise
            else:
                state_dict_suma[key] = state_dict_ind[key]

        nuevo_individuo.load_state_dict(state_dict_suma)

        n_individuo += 1
# Out:
#  --------------------- Individuo 1 ---------------------
# Accuracy: 0.0974 Loss: 2.3036268171725243
#  --------------------- Individuo 2 ---------------------
# Accuracy: 0.103 Loss: 2.303715947086115
#  --------------------- Individuo 3 ---------------------
# Accuracy: 0.1028 Loss: 2.302244860480335
# Nuevo mejor individuo
#  --------------------- Individuo 4 ---------------------
# Accuracy: 0.1027 Loss: 2.304209221400686
#  --------------------- Individuo 5 ---------------------
# Accuracy: 0.0844 Loss: 2.304744796458084
#  --------------------- Individuo 6 ---------------------
# Accuracy: 0.1034 Loss: 2.3029458797308426
#  --------------------- Individuo 7 ---------------------
# Accuracy: 0.1032 Loss: 2.30526505146962
#  --------------------- Individuo 8 ---------------------
# Accuracy: 0.11 Loss: 2.303483760178979
#  --------------------- Individuo 9 ---------------------
# Accuracy: 0.1028 Loss: 2.3022516114371165
#  --------------------- Individuo 10 ---------------------
# Accuracy: 0.1051 Loss: 2.3032341890497756
#  --------------------- Individuo 11 ---------------------
# Accuracy: 0.105 Loss: 2.301976225523552
# Nuevo mejor individuo
# Aumentando varianzas
#  --------------------- Individuo 12 ---------------------
# Accuracy: 0.095 Loss: 2.3040693746700978
# Aumentando varianzas
#  --------------------- Individuo 13 ---------------------
# Accuracy: 0.1028 Loss: 2.3067153359272843
# Aumentando varianzas
#  --------------------- Individuo 14 ---------------------
# Accuracy: 0.0881 Loss: 2.3040241407178867
# Aumentando varianzas
#  --------------------- Individuo 15 ---------------------
# Accuracy: 0.1029 Loss: 2.3032688433681723
# Aumentando varianzas
#  --------------------- Individuo 16 ---------------------
# Accuracy: 0.0966 Loss: 2.3027588706026707
# Aumentando varianzas
#  --------------------- Individuo 17 ---------------------
# Accuracy: 0.0892 Loss: 2.3033000403629944
# Aumentando varianzas
#  --------------------- Individuo 18 ---------------------
# Accuracy: 0.09 Loss: 2.304641556638136
# Aumentando varianzas
#  --------------------- Individuo 19 ---------------------
# Accuracy: 0.0972 Loss: 2.3031627654012587
# Aumentando varianzas
#  --------------------- Individuo 20 ---------------------
# Accuracy: 0.1028 Loss: 2.302015719891611
# Aumentando varianzas
#  --------------------- Individuo 21 ---------------------
# Accuracy: 0.1028 Loss: 2.3046474322072985
# Aumentando varianzas
#  --------------------- Individuo 22 ---------------------
# Accuracy: 0.121 Loss: 2.3008234300084713
# Nuevo mejor individuo
# Aumentando varianzas
#  --------------------- Individuo 23 ---------------------
# Accuracy: 0.1119 Loss: 2.302061269278211
# Aumentando varianzas
#  --------------------- Individuo 24 ---------------------
# Accuracy: 0.0974 Loss: 2.304560980054615
# Aumentando varianzas
#  --------------------- Individuo 25 ---------------------
# Accuracy: 0.0892 Loss: 2.3026224557778985
# Aumentando varianzas
#  --------------------- Individuo 26 ---------------------
# Accuracy: 0.1028 Loss: 2.303801012191691
# Aumentando varianzas
#  --------------------- Individuo 27 ---------------------
# Accuracy: 0.1388 Loss: 2.302500336154946
# Aumentando varianzas
#  --------------------- Individuo 28 ---------------------
# Accuracy: 0.1031 Loss: 2.3019233016825433
# Aumentando varianzas
#  --------------------- Individuo 29 ---------------------
# Accuracy: 0.112 Loss: 2.3032216934252903
# Aumentando varianzas
#  --------------------- Individuo 30 ---------------------
# Accuracy: 0.1028 Loss: 2.3003596019134847
# Nuevo mejor individuo
# Aumentando varianzas
#  --------------------- Individuo 31 ---------------------
# Accuracy: 0.0857 Loss: 2.3028770992750807
# Aumentando varianzas
#  --------------------- Individuo 32 ---------------------
# Accuracy: 0.1031 Loss: 2.3007607556609457
# Aumentando varianzas
#  --------------------- Individuo 33 ---------------------
# Accuracy: 0.1211 Loss: 2.302831086268557
# Aumentando varianzas
#  --------------------- Individuo 34 ---------------------
# Accuracy: 0.0934 Loss: 2.305346708562074
# Aumentando varianzas
#  --------------------- Individuo 35 ---------------------
# Accuracy: 0.1028 Loss: 2.3038842581482584
# Aumentando varianzas
#  --------------------- Individuo 36 ---------------------
# Accuracy: 0.0996 Loss: 2.302980139057265
# Aumentando varianzas
#  --------------------- Individuo 37 ---------------------
# Accuracy: 0.0962 Loss: 2.3034116657558026
# Aumentando varianzas
#  --------------------- Individuo 38 ---------------------
# Accuracy: 0.0786 Loss: 2.306117186159976
# Aumentando varianzas
#  --------------------- Individuo 39 ---------------------
# Accuracy: 0.1199 Loss: 2.3027923323198167
# Aumentando varianzas
#  --------------------- Individuo 40 ---------------------
# Accuracy: 0.1286 Loss: 2.3023476041456274
# Aumentando varianzas
#  --------------------- Individuo 41 ---------------------
# Accuracy: 0.0974 Loss: 2.3036541895571547
# Aumentando varianzas
#  --------------------- Individuo 42 ---------------------
# Accuracy: 0.0898 Loss: 2.3039428875136223
# Aumentando varianzas
#  --------------------- Individuo 43 ---------------------
# Accuracy: 0.1028 Loss: 2.3048736794925193
# Aumentando varianzas
#  --------------------- Individuo 44 ---------------------
# Accuracy: 0.1028 Loss: 2.301876480137107
# Aumentando varianzas
#  --------------------- Individuo 45 ---------------------
# Accuracy: 0.1049 Loss: 2.303688367800926
# Aumentando varianzas
#  --------------------- Individuo 46 ---------------------
# Accuracy: 0.1029 Loss: 2.3030966804988346
# Aumentando varianzas
#  --------------------- Individuo 47 ---------------------
# Accuracy: 0.1031 Loss: 2.302443574232333
# Aumentando varianzas
#  --------------------- Individuo 48 ---------------------
# Accuracy: 0.0866 Loss: 2.3055373498880023
# Aumentando varianzas
#  --------------------- Individuo 49 ---------------------
# Accuracy: 0.1027 Loss: 2.305103169321251
# Aumentando varianzas
#  --------------------- Individuo 50 ---------------------
# Accuracy: 0.0785 Loss: 2.305490284077903
# Aumentando varianzas
#  --------------------- Individuo 51 ---------------------
# Accuracy: 0.1041 Loss: 2.3033737577100806
# Aumentando varianzas
#  --------------------- Individuo 52 ---------------------
# Accuracy: 0.0752 Loss: 2.303127812424194
# Aumentando varianzas
#  --------------------- Individuo 53 ---------------------
# Accuracy: 0.1024 Loss: 2.3012176081061617
# Aumentando varianzas
#  --------------------- Individuo 54 ---------------------
# Accuracy: 0.1038 Loss: 2.3024412172435444
# Aumentando varianzas
#  --------------------- Individuo 55 ---------------------
# Accuracy: 0.142 Loss: 2.3008368523644487
# Aumentando varianzas
#  --------------------- Individuo 56 ---------------------
# Accuracy: 0.1028 Loss: 2.3018921453561356
# Aumentando varianzas
#  --------------------- Individuo 57 ---------------------
# Accuracy: 0.1102 Loss: 2.3053535764405466
# Aumentando varianzas
#  --------------------- Individuo 58 ---------------------
# Accuracy: 0.1028 Loss: 2.3033585284056186
# Aumentando varianzas
#  --------------------- Individuo 59 ---------------------
# Accuracy: 0.1158 Loss: 2.300597090965141
# Aumentando varianzas
#  --------------------- Individuo 60 ---------------------
# Accuracy: 0.1184 Loss: 2.303364999258696
# Aumentando varianzas
#  --------------------- Individuo 61 ---------------------
# Accuracy: 0.103 Loss: 2.301905512555576
# Aumentando varianzas
#  --------------------- Individuo 62 ---------------------
# Accuracy: 0.1175 Loss: 2.3037974033782733
# Aumentando varianzas
#  --------------------- Individuo 63 ---------------------
# Accuracy: 0.1029 Loss: 2.30127104131906
# Aumentando varianzas
#  --------------------- Individuo 64 ---------------------
# Accuracy: 0.1028 Loss: 2.3027550259124494
# Aumentando varianzas
#  --------------------- Individuo 65 ---------------------
# Accuracy: 0.1007 Loss: 2.306873805233156
# Aumentando varianzas
#  --------------------- Individuo 66 ---------------------
# Accuracy: 0.0894 Loss: 2.3027798435581266
# Aumentando varianzas
#  --------------------- Individuo 67 ---------------------
# Accuracy: 0.0894 Loss: 2.3045228973888894
# Aumentando varianzas
#  --------------------- Individuo 68 ---------------------
# Accuracy: 0.1167 Loss: 2.301638416389921
# Aumentando varianzas
#  --------------------- Individuo 69 ---------------------
# Accuracy: 0.0952 Loss: 2.3037023671400316
# Aumentando varianzas
#  --------------------- Individuo 70 ---------------------
# Accuracy: 0.0944 Loss: 2.30451889434603
# Aumentando varianzas
#  --------------------- Individuo 71 ---------------------
# Accuracy: 0.1054 Loss: 2.3035463674236207
# Aumentando varianzas
#  --------------------- Individuo 72 ---------------------
# Accuracy: 0.0976 Loss: 2.3038594664286958
# Aumentando varianzas
#  --------------------- Individuo 73 ---------------------
# Accuracy: 0.113 Loss: 2.3030972790870585
# Aumentando varianzas
#  --------------------- Individuo 74 ---------------------
# Accuracy: 0.1041 Loss: 2.3030442853472124
# Aumentando varianzas
#  --------------------- Individuo 75 ---------------------
# Accuracy: 0.1252 Loss: 2.301917785266315
# Aumentando varianzas
#  --------------------- Individuo 76 ---------------------
# Accuracy: 0.1034 Loss: 2.3014790645794574
# Aumentando varianzas
#  --------------------- Individuo 77 ---------------------
# Accuracy: 0.0701 Loss: 2.301822544415114
# Aumentando varianzas
#  --------------------- Individuo 78 ---------------------
# Accuracy: 0.1031 Loss: 2.303266590338018
# Aumentando varianzas
#  --------------------- Individuo 79 ---------------------
# Accuracy: 0.1028 Loss: 2.300644741892052
# Aumentando varianzas
#  --------------------- Individuo 80 ---------------------
# Accuracy: 0.1029 Loss: 2.3033747027423592
# Aumentando varianzas
#  --------------------- Individuo 81 ---------------------
# Accuracy: 0.1028 Loss: 2.305485357353682
# Aumentando varianzas
#  --------------------- Individuo 82 ---------------------
# Accuracy: 0.103 Loss: 2.3039667052246613
# Aumentando varianzas
#  --------------------- Individuo 83 ---------------------
# Accuracy: 0.103 Loss: 2.3039004500232525
# Aumentando varianzas
#  --------------------- Individuo 84 ---------------------
# Accuracy: 0.0867 Loss: 2.304546122611967
# Aumentando varianzas
#  --------------------- Individuo 85 ---------------------
# Accuracy: 0.0818 Loss: 2.301109046061664
# Aumentando varianzas
#  --------------------- Individuo 86 ---------------------
# Accuracy: 0.107 Loss: 2.3039056731185426
# Aumentando varianzas
#  --------------------- Individuo 87 ---------------------
# Accuracy: 0.1028 Loss: 2.3017733084367538
# Aumentando varianzas
#  --------------------- Individuo 88 ---------------------
# Accuracy: 0.1028 Loss: 2.303268712975069
# Aumentando varianzas
#  --------------------- Individuo 89 ---------------------
# Accuracy: 0.1025 Loss: 2.3037522469502267
# Aumentando varianzas
#  --------------------- Individuo 90 ---------------------
# Accuracy: 0.0755 Loss: 2.3048070018479563
# Aumentando varianzas
#  --------------------- Individuo 91 ---------------------
# Accuracy: 0.0974 Loss: 2.3029550214820325
# Aumentando varianzas
#  --------------------- Individuo 92 ---------------------
# Accuracy: 0.1016 Loss: 2.304061783656383
# Aumentando varianzas
#  --------------------- Individuo 93 ---------------------
# Accuracy: 0.1198 Loss: 2.301401744773393
# Aumentando varianzas
#  --------------------- Individuo 94 ---------------------
# Accuracy: 0.0974 Loss: 2.304321238735337
# Aumentando varianzas
#  --------------------- Individuo 95 ---------------------
# Accuracy: 0.0987 Loss: 2.3040966029360352
# Aumentando varianzas
#  --------------------- Individuo 96 ---------------------
# Accuracy: 0.1028 Loss: 2.305565045078172
# Aumentando varianzas
#  --------------------- Individuo 97 ---------------------
# Accuracy: 0.1031 Loss: 2.3034232201606732
# Aumentando varianzas
#  --------------------- Individuo 98 ---------------------
# Accuracy: 0.1116 Loss: 2.3020033193295446
# Aumentando varianzas
#  --------------------- Individuo 99 ---------------------
# Accuracy: 0.1006 Loss: 2.3044581776742996
# Aumentando varianzas
#  --------------------- Individuo 100 ---------------------
# Accuracy: 0.1107 Loss: 2.3016306339804804
# Aumentando varianzas
#  --------------------- Individuo 101 ---------------------
# Accuracy: 0.1037 Loss: 2.304669387559138
# Aumentando varianzas
#  --------------------- Individuo 102 ---------------------
# Accuracy: 0.1202 Loss: 2.301992617690487
# Aumentando varianzas
#  --------------------- Individuo 103 ---------------------
# Accuracy: 0.1028 Loss: 2.3023425978638214
# Aumentando varianzas
#  --------------------- Individuo 104 ---------------------
# Accuracy: 0.1029 Loss: 2.3015060455306
# Aumentando varianzas
#  --------------------- Individuo 105 ---------------------
# Accuracy: 0.0953 Loss: 2.3017205383731865
# Aumentando varianzas
#  --------------------- Individuo 106 ---------------------
# Accuracy: 0.1219 Loss: 2.301059321045621
# Aumentando varianzas
#  --------------------- Individuo 107 ---------------------
# Accuracy: 0.0974 Loss: 2.3020496454828585
# Aumentando varianzas
#  --------------------- Individuo 108 ---------------------
# Accuracy: 0.1036 Loss: 2.3027880616279552
# Aumentando varianzas
#  --------------------- Individuo 109 ---------------------
# Accuracy: 0.0932 Loss: 2.303270204489165
# Aumentando varianzas
#  --------------------- Individuo 110 ---------------------
# Accuracy: 0.1056 Loss: 2.3013202155322663
# Aumentando varianzas
#  --------------------- Individuo 111 ---------------------
# Accuracy: 0.1028 Loss: 2.3018504007538754
# Aumentando varianzas
#  --------------------- Individuo 112 ---------------------
# Accuracy: 0.1173 Loss: 2.3018328619918336
# Aumentando varianzas
#  --------------------- Individuo 113 ---------------------
# Accuracy: 0.0973 Loss: 2.303501842626885
# Aumentando varianzas
#  --------------------- Individuo 114 ---------------------
# Accuracy: 0.1448 Loss: 2.302338166023368
# Aumentando varianzas
#  --------------------- Individuo 115 ---------------------
# Accuracy: 0.1162 Loss: 2.3012990809198635
# Aumentando varianzas
#  --------------------- Individuo 116 ---------------------
# Accuracy: 0.1028 Loss: 2.3034079227366173
# Aumentando varianzas
#  --------------------- Individuo 117 ---------------------
# Accuracy: 0.1059 Loss: 2.3024358286786435
# Aumentando varianzas
#  --------------------- Individuo 118 ---------------------
# Accuracy: 0.1027 Loss: 2.301709726421055
# Aumentando varianzas
#  --------------------- Individuo 119 ---------------------
# Accuracy: 0.1152 Loss: 2.303402187473484
# Aumentando varianzas
#  --------------------- Individuo 120 ---------------------
# Accuracy: 0.1044 Loss: 2.3023245977694544
# Aumentando varianzas
#  --------------------- Individuo 121 ---------------------
# Accuracy: 0.0974 Loss: 2.301209033170997
# Aumentando varianzas
#  --------------------- Individuo 122 ---------------------
# Accuracy: 0.1007 Loss: 2.303156671239369
# Aumentando varianzas
#  --------------------- Individuo 123 ---------------------
# Accuracy: 0.1033 Loss: 2.3026869795215665
# Aumentando varianzas
#  --------------------- Individuo 124 ---------------------
# Accuracy: 0.0679 Loss: 2.30679421943388
# Aumentando varianzas
#  --------------------- Individuo 125 ---------------------
# Accuracy: 0.103 Loss: 2.30327570438385
# Aumentando varianzas
#  --------------------- Individuo 126 ---------------------
# Accuracy: 0.0974 Loss: 2.301037534467701
# Aumentando varianzas
#  --------------------- Individuo 127 ---------------------
# Accuracy: 0.1031 Loss: 2.3033244373447603
# Aumentando varianzas
#  --------------------- Individuo 128 ---------------------
# Accuracy: 0.1018 Loss: 2.3029117912117605
# Aumentando varianzas
#  --------------------- Individuo 129 ---------------------
# Accuracy: 0.1088 Loss: 2.3033822952811396
# Aumentando varianzas
#  --------------------- Individuo 130 ---------------------
# Accuracy: 0.0706 Loss: 2.3026068876547092
# Aumentando varianzas
#  --------------------- Individuo 131 ---------------------
# Accuracy: 0.1166 Loss: 2.303429005496792
# Aumentando varianzas
#  --------------------- Individuo 132 ---------------------
# Accuracy: 0.0967 Loss: 2.3059890913302454
# Aumentando varianzas
#  --------------------- Individuo 133 ---------------------
# Accuracy: 0.089 Loss: 2.3040445961677696
# Aumentando varianzas
#  --------------------- Individuo 134 ---------------------
# Accuracy: 0.1262 Loss: 2.301532203200529
# Aumentando varianzas
#  --------------------- Individuo 135 ---------------------
# Accuracy: 0.1028 Loss: 2.3005647705053724
# Aumentando varianzas
#  --------------------- Individuo 136 ---------------------
# Accuracy: 0.137 Loss: 2.301801191718339
# Aumentando varianzas
#  --------------------- Individuo 137 ---------------------
# Accuracy: 0.1035 Loss: 2.301853779282397
# Aumentando varianzas
#  --------------------- Individuo 138 ---------------------
# Accuracy: 0.1078 Loss: 2.301581938129498
# Aumentando varianzas
#  --------------------- Individuo 139 ---------------------
# Accuracy: 0.1153 Loss: 2.301341998805878
# Aumentando varianzas
#  --------------------- Individuo 140 ---------------------
# Accuracy: 0.0988 Loss: 2.3039415579106506
# Aumentando varianzas
#  --------------------- Individuo 141 ---------------------
# Accuracy: 0.0981 Loss: 2.3024459609599
# Aumentando varianzas
#  --------------------- Individuo 142 ---------------------
# Accuracy: 0.1024 Loss: 2.3042391396280544
# Aumentando varianzas
#  --------------------- Individuo 143 ---------------------
# Accuracy: 0.0897 Loss: 2.3034140362160036
# Aumentando varianzas
#  --------------------- Individuo 144 ---------------------
# Accuracy: 0.0972 Loss: 2.303536906171201
# Aumentando varianzas
#  --------------------- Individuo 145 ---------------------
# Accuracy: 0.1027 Loss: 2.305091622033353
# Aumentando varianzas
#  --------------------- Individuo 146 ---------------------
# Accuracy: 0.1037 Loss: 2.3025287679517703
# Aumentando varianzas
#  --------------------- Individuo 147 ---------------------
# Accuracy: 0.1031 Loss: 2.3007743201021955
# Aumentando varianzas
#  --------------------- Individuo 148 ---------------------
# Accuracy: 0.1089 Loss: 2.3023438781563406
# Aumentando varianzas
#  --------------------- Individuo 149 ---------------------
# Accuracy: 0.1192 Loss: 2.3049868070748825
# Aumentando varianzas
#  --------------------- Individuo 150 ---------------------
# Accuracy: 0.1288 Loss: 2.3031513078380494
# Aumentando varianzas
#  --------------------- Individuo 151 ---------------------
# Accuracy: 0.1078 Loss: 2.3028710302767723
# Aumentando varianzas
#  --------------------- Individuo 152 ---------------------
# Accuracy: 0.1401 Loss: 2.302526559911049
# Aumentando varianzas
#  --------------------- Individuo 153 ---------------------
# Accuracy: 0.099 Loss: 2.306294103421128
# Aumentando varianzas
#  --------------------- Individuo 154 ---------------------
# Accuracy: 0.1031 Loss: 2.302972108824675
# Aumentando varianzas
#  --------------------- Individuo 155 ---------------------
# Accuracy: 0.0974 Loss: 2.305100015994074
# Aumentando varianzas
#  --------------------- Individuo 156 ---------------------
# Accuracy: 0.1152 Loss: 2.3033074946291667
# Aumentando varianzas
#  --------------------- Individuo 157 ---------------------
# Accuracy: 0.0957 Loss: 2.301719423041923
# Aumentando varianzas
#  --------------------- Individuo 158 ---------------------
# Accuracy: 0.0972 Loss: 2.3018587738720337
# Aumentando varianzas
#  --------------------- Individuo 159 ---------------------
# Accuracy: 0.1046 Loss: 2.302408487303679
# Aumentando varianzas
#  --------------------- Individuo 160 ---------------------
# Accuracy: 0.1049 Loss: 2.3036316302793622
# Aumentando varianzas
#  --------------------- Individuo 161 ---------------------
# Accuracy: 0.0919 Loss: 2.30290357644624
# Aumentando varianzas
#  --------------------- Individuo 162 ---------------------
# Accuracy: 0.0912 Loss: 2.3043293332748576
# Aumentando varianzas
#  --------------------- Individuo 163 ---------------------
# Accuracy: 0.0995 Loss: 2.3051623299177777
# Aumentando varianzas
#  --------------------- Individuo 164 ---------------------
# Accuracy: 0.1028 Loss: 2.3043305002041716
# Aumentando varianzas
#  --------------------- Individuo 165 ---------------------
# Accuracy: 0.097 Loss: 2.3029046236579096
# Aumentando varianzas
#  --------------------- Individuo 166 ---------------------
# Accuracy: 0.0832 Loss: 2.304276096032881
# Aumentando varianzas
#  --------------------- Individuo 167 ---------------------
# Accuracy: 0.1025 Loss: 2.3036138818208087
# Aumentando varianzas
#  --------------------- Individuo 168 ---------------------
# Accuracy: 0.1047 Loss: 2.303518545907189
# Aumentando varianzas
#  --------------------- Individuo 169 ---------------------
# Accuracy: 0.1216 Loss: 2.303159326632648
# Aumentando varianzas
#  --------------------- Individuo 170 ---------------------
# Accuracy: 0.1057 Loss: 2.303314074016075
# Aumentando varianzas
#  --------------------- Individuo 171 ---------------------
# Accuracy: 0.1028 Loss: 2.303816621237472
# Aumentando varianzas
#  --------------------- Individuo 172 ---------------------
# Accuracy: 0.1033 Loss: 2.302136093060345
# Aumentando varianzas
#  --------------------- Individuo 173 ---------------------
# Accuracy: 0.1029 Loss: 2.3017757955644687
# Aumentando varianzas
#  --------------------- Individuo 174 ---------------------
# Accuracy: 0.1029 Loss: 2.303430349587886
# Aumentando varianzas
#  --------------------- Individuo 175 ---------------------
# Accuracy: 0.1028 Loss: 2.305048840894882
# Aumentando varianzas
#  --------------------- Individuo 176 ---------------------
# Accuracy: 0.1088 Loss: 2.304909536070915
# Aumentando varianzas
#  --------------------- Individuo 177 ---------------------
# Accuracy: 0.1028 Loss: 2.3019032244489135
# Aumentando varianzas
#  --------------------- Individuo 178 ---------------------
# Accuracy: 0.0934 Loss: 2.3035363469805037
# Aumentando varianzas
#  --------------------- Individuo 179 ---------------------
# Accuracy: 0.0977 Loss: 2.3036986991032355
# Aumentando varianzas
#  --------------------- Individuo 180 ---------------------
# Accuracy: 0.109 Loss: 2.3017367937925783
# Aumentando varianzas
#  --------------------- Individuo 181 ---------------------
# Accuracy: 0.1027 Loss: 2.3026181151871996
# Aumentando varianzas
#  --------------------- Individuo 182 ---------------------
# Accuracy: 0.1028 Loss: 2.303489460111427
# Aumentando varianzas
#  --------------------- Individuo 183 ---------------------
# Accuracy: 0.0974 Loss: 2.3033349986777885
# Aumentando varianzas
#  --------------------- Individuo 184 ---------------------
# Accuracy: 0.1132 Loss: 2.30405081894352
# Aumentando varianzas
#  --------------------- Individuo 185 ---------------------
# Accuracy: 0.1037 Loss: 2.3036566533005316
# Aumentando varianzas
#  --------------------- Individuo 186 ---------------------
# Accuracy: 0.1028 Loss: 2.305257981774141
# Aumentando varianzas
#  --------------------- Individuo 187 ---------------------
# Accuracy: 0.1036 Loss: 2.3015003016254285
# Aumentando varianzas
#  --------------------- Individuo 188 ---------------------
# Accuracy: 0.0974 Loss: 2.3036015595454398
# Aumentando varianzas
#  --------------------- Individuo 189 ---------------------
# Accuracy: 0.1026 Loss: 2.3012722390038625
# Aumentando varianzas
#  --------------------- Individuo 190 ---------------------
# Accuracy: 0.1048 Loss: 2.3005117302510274
# Aumentando varianzas
#  --------------------- Individuo 191 ---------------------
# Accuracy: 0.1028 Loss: 2.3042521034476597
# Aumentando varianzas
#  --------------------- Individuo 192 ---------------------
# Accuracy: 0.1028 Loss: 2.3018491840057536
# Aumentando varianzas
#  --------------------- Individuo 193 ---------------------
# Accuracy: 0.0937 Loss: 2.304338760721658
# Aumentando varianzas
#  --------------------- Individuo 194 ---------------------
# Accuracy: 0.0967 Loss: 2.303798531418416
# Aumentando varianzas
#  --------------------- Individuo 195 ---------------------
# Accuracy: 0.0971 Loss: 2.302994927363609
# Aumentando varianzas
#  --------------------- Individuo 196 ---------------------
# Accuracy: 0.103 Loss: 2.300938028262368
# Aumentando varianzas
#  --------------------- Individuo 197 ---------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 79
#      76 masked_net = apply_mask(net, nuevo_individuo)
#      78 running_loss = 0.0
# ---> 79 for i, data in enumerate(train_loader, 0):
#      80     inputs, labels = data[0].to(device), data[1].to(device)
#      81     outputs = masked_net(inputs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\utils\data\dataloader.py:701, in _BaseDataLoaderIter.__next__(self)
#     698 if self._sampler_iter is None:
#     699     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     700     self._reset()  # type: ignore[call-arg]
# --> 701 data = self._next_data()
#     702 self._num_yielded += 1
#     703 if (
#     704     self._dataset_kind == _DatasetKind.Iterable
#     705     and self._IterableDataset_len_called is not None
#     706     and self._num_yielded > self._IterableDataset_len_called
#     707 ):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\utils\data\dataloader.py:1437, in _MultiProcessingDataLoaderIter._next_data(self)
#    1434 else:
#    1435     # no valid `self._rcvd_idx` is found (i.e., didn't break)
#    1436     if not self._persistent_workers:
# -> 1437         self._shutdown_workers()
#    1438     raise StopIteration
#    1440 # Now `self._rcvd_idx` is the batch index we want to fetch
#    1441
#    1442 # Check if the next sample has already been generated
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\utils\data\dataloader.py:1568, in _MultiProcessingDataLoaderIter._shutdown_workers(self)
#    1563         self._mark_worker_as_unavailable(worker_id, shutdown=True)
#    1564 for w in self._workers:
#    1565     # We should be able to join here, but in case anything went
#    1566     # wrong, we set a timeout and if the workers fail to join,
#    1567     # they are killed in the `finally` block.
# -> 1568     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#    1569 for q in self._index_queues:
#    1570     q.cancel_join_thread()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\multiprocessing\process.py:149, in BaseProcess.join(self, timeout)
#     147 assert self._parent_pid == os.getpid(), 'can only join a child process'
#     148 assert self._popen is not None, 'can only join a started process'
# --> 149 res = self._popen.wait(timeout)
#     150 if res is not None:
#     151     _children.discard(self)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\multiprocessing\popen_spawn_win32.py:112, in Popen.wait(self, timeout)
#     109 else:
#     110     msecs = max(0, int(timeout * 1000 + 0.5))
# --> 112 res = _winapi.WaitForSingleObject(int(self._handle), msecs)
#     113 if res == _winapi.WAIT_OBJECT_0:
#     114     code = _winapi.GetExitCodeProcess(self._handle)
#
# KeyboardInterrupt:

# %%
print(train_loss)
print(test_accuracies)
print(max(test_accuracies))
index_max_accuracy = test_accuracies.index(max(test_accuracies))
print(index_max_accuracy)
print("-----------------")
print(min(train_loss))
index = train_loss.index(min(train_loss))
print(index)
# Out:
# [2.3036268171725243, 2.303715947086115, 2.302244860480335, 2.304209221400686, 2.304744796458084, 2.3029458797308426, 2.30526505146962, 2.303483760178979, 2.3022516114371165, 2.3032341890497756, 2.301976225523552, 2.3040693746700978, 2.3067153359272843, 2.3040241407178867, 2.3032688433681723, 2.3027588706026707, 2.3033000403629944, 2.304641556638136, 2.3031627654012587, 2.302015719891611, 2.3046474322072985, 2.3008234300084713, 2.302061269278211, 2.304560980054615, 2.3026224557778985, 2.303801012191691, 2.302500336154946, 2.3019233016825433, 2.3032216934252903, 2.3003596019134847, 2.3028770992750807, 2.3007607556609457, 2.302831086268557, 2.305346708562074, 2.3038842581482584, 2.302980139057265, 2.3034116657558026, 2.306117186159976, 2.3027923323198167, 2.3023476041456274, 2.3036541895571547, 2.3039428875136223, 2.3048736794925193, 2.301876480137107, 2.303688367800926, 2.3030966804988346, 2.302443574232333, 2.3055373498880023, 2.305103169321251, 2.305490284077903, 2.3033737577100806, 2.303127812424194, 2.3012176081061617, 2.3024412172435444, 2.3008368523644487, 2.3018921453561356, 2.3053535764405466, 2.3033585284056186, 2.300597090965141, 2.303364999258696, 2.301905512555576, 2.3037974033782733, 2.30127104131906, 2.3027550259124494, 2.306873805233156, 2.3027798435581266, 2.3045228973888894, 2.301638416389921, 2.3037023671400316, 2.30451889434603, 2.3035463674236207, 2.3038594664286958, 2.3030972790870585, 2.3030442853472124, 2.301917785266315, 2.3014790645794574, 2.301822544415114, 2.303266590338018, 2.300644741892052, 2.3033747027423592, 2.305485357353682, 2.3039667052246613, 2.3039004500232525, 2.304546122611967, 2.301109046061664, 2.3039056731185426, 2.3017733084367538, 2.303268712975069, 2.3037522469502267, 2.3048070018479563, 2.3029550214820325, 2.304061783656383, 2.301401744773393, 2.304321238735337, 2.3040966029360352, 2.305565045078172, 2.3034232201606732, 2.3020033193295446, 2.3044581776742996, 2.3016306339804804, 2.304669387559138, 2.301992617690487, 2.3023425978638214, 2.3015060455306, 2.3017205383731865, 2.301059321045621, 2.3020496454828585, 2.3027880616279552, 2.303270204489165, 2.3013202155322663, 2.3018504007538754, 2.3018328619918336, 2.303501842626885, 2.302338166023368, 2.3012990809198635, 2.3034079227366173, 2.3024358286786435, 2.301709726421055, 2.303402187473484, 2.3023245977694544, 2.301209033170997, 2.303156671239369, 2.3026869795215665, 2.30679421943388, 2.30327570438385, 2.301037534467701, 2.3033244373447603, 2.3029117912117605, 2.3033822952811396, 2.3026068876547092, 2.303429005496792, 2.3059890913302454, 2.3040445961677696, 2.301532203200529, 2.3005647705053724, 2.301801191718339, 2.301853779282397, 2.301581938129498, 2.301341998805878, 2.3039415579106506, 2.3024459609599, 2.3042391396280544, 2.3034140362160036, 2.303536906171201, 2.305091622033353, 2.3025287679517703, 2.3007743201021955, 2.3023438781563406, 2.3049868070748825, 2.3031513078380494, 2.3028710302767723, 2.302526559911049, 2.306294103421128, 2.302972108824675, 2.305100015994074, 2.3033074946291667, 2.301719423041923, 2.3018587738720337, 2.302408487303679, 2.3036316302793622, 2.30290357644624, 2.3043293332748576, 2.3051623299177777, 2.3043305002041716, 2.3029046236579096, 2.304276096032881, 2.3036138818208087, 2.303518545907189, 2.303159326632648, 2.303314074016075, 2.303816621237472, 2.302136093060345, 2.3017757955644687, 2.303430349587886, 2.305048840894882, 2.304909536070915, 2.3019032244489135, 2.3035363469805037, 2.3036986991032355, 2.3017367937925783, 2.3026181151871996, 2.303489460111427, 2.3033349986777885, 2.30405081894352, 2.3036566533005316, 2.305257981774141, 2.3015003016254285, 2.3036015595454398, 2.3012722390038625, 2.3005117302510274, 2.3042521034476597, 2.3018491840057536, 2.304338760721658, 2.303798531418416, 2.302994927363609, 2.300938028262368]
# [0.0974, 0.103, 0.1028, 0.1027, 0.0844, 0.1034, 0.1032, 0.11, 0.1028, 0.1051, 0.105, 0.095, 0.1028, 0.0881, 0.1029, 0.0966, 0.0892, 0.09, 0.0972, 0.1028, 0.1028, 0.121, 0.1119, 0.0974, 0.0892, 0.1028, 0.1388, 0.1031, 0.112, 0.1028, 0.0857, 0.1031, 0.1211, 0.0934, 0.1028, 0.0996, 0.0962, 0.0786, 0.1199, 0.1286, 0.0974, 0.0898, 0.1028, 0.1028, 0.1049, 0.1029, 0.1031, 0.0866, 0.1027, 0.0785, 0.1041, 0.0752, 0.1024, 0.1038, 0.142, 0.1028, 0.1102, 0.1028, 0.1158, 0.1184, 0.103, 0.1175, 0.1029, 0.1028, 0.1007, 0.0894, 0.0894, 0.1167, 0.0952, 0.0944, 0.1054, 0.0976, 0.113, 0.1041, 0.1252, 0.1034, 0.0701, 0.1031, 0.1028, 0.1029, 0.1028, 0.103, 0.103, 0.0867, 0.0818, 0.107, 0.1028, 0.1028, 0.1025, 0.0755, 0.0974, 0.1016, 0.1198, 0.0974, 0.0987, 0.1028, 0.1031, 0.1116, 0.1006, 0.1107, 0.1037, 0.1202, 0.1028, 0.1029, 0.0953, 0.1219, 0.0974, 0.1036, 0.0932, 0.1056, 0.1028, 0.1173, 0.0973, 0.1448, 0.1162, 0.1028, 0.1059, 0.1027, 0.1152, 0.1044, 0.0974, 0.1007, 0.1033, 0.0679, 0.103, 0.0974, 0.1031, 0.1018, 0.1088, 0.0706, 0.1166, 0.0967, 0.089, 0.1262, 0.1028, 0.137, 0.1035, 0.1078, 0.1153, 0.0988, 0.0981, 0.1024, 0.0897, 0.0972, 0.1027, 0.1037, 0.1031, 0.1089, 0.1192, 0.1288, 0.1078, 0.1401, 0.099, 0.1031, 0.0974, 0.1152, 0.0957, 0.0972, 0.1046, 0.1049, 0.0919, 0.0912, 0.0995, 0.1028, 0.097, 0.0832, 0.1025, 0.1047, 0.1216, 0.1057, 0.1028, 0.1033, 0.1029, 0.1029, 0.1028, 0.1088, 0.1028, 0.0934, 0.0977, 0.109, 0.1027, 0.1028, 0.0974, 0.1132, 0.1037, 0.1028, 0.1036, 0.0974, 0.1026, 0.1048, 0.1028, 0.1028, 0.0937, 0.0967, 0.0971, 0.103]
# 0.1448
# 113
# -----------------
# 2.3003596019134847
# 29

# %%
# Creamos la figura y definimos dos subgráficos (1 fila, 2 columnas)
plt.figure(figsize=(10, 5))

# Primer gráfico en la posición 1 (izquierda)
plt.subplot(1, 2, 1)  # 1 fila, 2 columnas, primer gráfico
plt.plot(train_loss, color='blue', marker='o')
plt.title("Gráfico de Pérdida")
plt.xlabel("Épocas")
plt.ylabel("Valores de pérdida")

# Calcular la regresión lineal para train_loss
epochs = np.arange(len(train_loss))
m, b = np.polyfit(epochs, train_loss, 1)
plt.plot(epochs, m*epochs + b, color='red', linestyle='--', label='Tendencia')


# Segundo gráfico en la posición 2 (derecha)
plt.subplot(1, 2, 2)  # 1 fila, 2 columnas, segundo gráfico
plt.plot(test_accuracies, color='green', marker='s')
plt.title("Gráfico de aciertos")
plt.xlabel("Épocas")
plt.ylabel("% de aciertos")

# Calcular la regresión lineal para test_accuracies
epochs_test = np.arange(len(test_accuracies))
m, b = np.polyfit(epochs_test, test_accuracies, 1)
plt.plot(epochs_test, m*epochs_test + b, color='red', linestyle='--', label='Tendencia')

# Mostramos los gráficos
plt.tight_layout()  # Ajustamos para que no se solapen los gráficos
plt.legend()
plt.show()
