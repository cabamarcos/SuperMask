# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import torch.nn.init as init

import numpy as np
import matplotlib.pyplot as plt

from utils.prune import apply_mask
from utils.count_improvement import improvements
from utils.active_weights import calculate_active_weights_percentage

# %%
# Verificar si la GPU está disponible y establecer el dispositivo
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(784, 256)
        self.fc2 = nn.Linear(256, 128)
        self.fc3 = nn.Linear(128, 10)

    def forward(self, x):
        x = x.view(-1, 784)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return F.log_softmax(x, dim=1)

# %%
net = Net().to(device)
varianzas_net = Net().to(device)
individuo = Net().to(device)

# %% [markdown]
# Cargamos los datos

# %%
# Definimos el transform para los datos de MNIST
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))
])

# Cargamos el dataset de MNIST
train_dataset = datasets.MNIST('./../data', train=True, download=True, transform=transform)
test_dataset = datasets.MNIST('./../data', train=False, download=True, transform=transform)

# Definimos los DataLoaders para los conjuntos de entrenamiento y prueba
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True, num_workers=4)
test_loader = DataLoader(test_dataset, batch_size=1000, shuffle=False, num_workers=4)

# %%
# Definimos la función de pérdida para calcular el error
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr=0.001)

# %% [markdown]
# Realizamos el "entrenamiento"

# %%
# train loop
train_loss = []
train_loss_mean = []
test_accuracies = []
n_individuo = 1
accuracy_threshold = 0.4

# Multiplicamos los pesos de varianzas para que sean numero sgrandes
with torch.no_grad():
    for param in varianzas_net.parameters():
        param *= 10000

#Guardo el mejor individuo y la red original que tendrá que ser reestablecida cad epoca
best_individo_state_dict = individuo.state_dict()
net_state_dict = net.state_dict()

#train loop
while True:
    net.load_state_dict(net_state_dict)
    if n_individuo == 1:
        print(f" --------------------- Individuo {n_individuo} --------------------- ")

        masked_net = apply_mask(net, individuo)

        results = calculate_active_weights_percentage(individuo)
        print("Porcentaje de parámetros activos: {:.2f}%".format(results["active_percentage"]))

        running_loss = 0.0
        # Train for 1 epoch
        for i, data in enumerate(train_loader, 0):
            inputs, labels = data[0].to(device), data[1].to(device)
            #optimizer.zero_grad()
            outputs = masked_net(inputs)
            loss = criterion(outputs, labels)
            #loss.backward()
            #optimizer.step()
            running_loss += loss.item()
        train_loss.append(running_loss / len(train_loader))

        masked_net.eval()
        correct = 0
        total = 0
        with torch.no_grad():
            for data in test_loader:
                images, labels = data[0].to(device), data[1].to(device)
                outputs = masked_net(images)
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
        accuracy = correct / total
        #train_loss_mean.append(np.mean(train_loss))
        test_accuracies.append(accuracy)
        #print(f"Accuracy: {accuracy}, loss mean: {train_loss_mean[-1]}")
        print(f"Accuracy: {accuracy}", f"Loss: {train_loss[-1]}")
        best_loss = train_loss[-1]
        if accuracy > accuracy_threshold:
            break
        n_individuo += 1

        #sumamos varianzas para crear un nuevo individuo desde el anterior
        nuevo_individuo = Net().to(device)
        state_dict_ind = individuo.state_dict()
        state_dict_var = varianzas_net.state_dict()
        state_dict_suma = {}

        for key in state_dict_ind:
            if state_dict_ind[key].size() == state_dict_var[key].size():  
                std_dev = state_dict_var[key]
                noise = torch.normal(0, torch.abs(std_dev))
                state_dict_suma[key] = state_dict_ind[key] + torch.sign(std_dev) * noise
            else:
                state_dict_suma[key] = state_dict_ind[key]

        nuevo_individuo.load_state_dict(state_dict_suma)
        
    else:
        print(f" --------------------- Individuo {n_individuo} --------------------- ")

        masked_net = apply_mask(net, nuevo_individuo)
        results = calculate_active_weights_percentage(individuo)
        print("Porcentaje de parámetros activos: {:.2f}%".format(results["active_percentage"]))
        running_loss = 0.0
        for i, data in enumerate(train_loader, 0):
            inputs, labels = data[0].to(device), data[1].to(device)
            outputs = masked_net(inputs)
            loss = criterion(outputs, labels)
            running_loss += loss.item()
        train_loss.append(running_loss / len(train_loader))

        masked_net.eval()
        correct = 0
        total = 0
        with torch.no_grad():
            for data in test_loader:
                images, labels = data[0].to(device), data[1].to(device)
                outputs = masked_net(images)
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
        accuracy = correct / total
        test_accuracies.append(accuracy)
        print(f"Accuracy: {accuracy}", f"Loss: {train_loss[-1]}")
        if accuracy > accuracy_threshold:
            break

        # Verificamos que individuo tiene mejor desempeño
        if train_loss[-1] < best_loss:
            print("Nuevo mejor individuo")
            best_loss = train_loss[-1]
            best_individo_state_dict = nuevo_individuo.state_dict()
        
        # actualizamos el individuo
        individuo.load_state_dict(best_individo_state_dict)

        if n_individuo >10:
            # actualizmos el vector de varianzas
            if improvements(train_loss) > 2:## +mejoras que peoras (lejos de la solucion)
                print("Aumentando varianzas")
                with torch.no_grad():
                    for param in varianzas_net.parameters():
                        param *= (1/0.82)

            elif improvements(train_loss) <= 2: ## -mejoras que peoras (cerca de la solucion)
                print("Disminuyendo varianzas")
                with torch.no_grad():
                    for param in varianzas_net.parameters():
                        param *= 0.82
        
            else:
                pass

        #sumamos varianzas para crear un nuevo individuo desde el anterior
        nuevo_individuo = Net().to(device)
        state_dict_ind = individuo.state_dict()
        state_dict_var = varianzas_net.state_dict()
        state_dict_suma = {}

        for key in state_dict_ind:
            if state_dict_ind[key].size() == state_dict_var[key].size():  
                std_dev = state_dict_var[key]
                noise = torch.normal(0, torch.abs(std_dev))
                state_dict_suma[key] = state_dict_ind[key] + torch.sign(std_dev) * noise
            else:
                state_dict_suma[key] = state_dict_ind[key]

        nuevo_individuo.load_state_dict(state_dict_suma)

        n_individuo += 1
# Out:
#  --------------------- Individuo 1 ---------------------
# Accuracy: 0.101 Loss: 2.3031585440198494
#  --------------------- Individuo 2 ---------------------
# Accuracy: 0.0892 Loss: 2.3026239206033474
# Nuevo mejor individuo
#  --------------------- Individuo 3 ---------------------
# Accuracy: 0.1066 Loss: 2.3024988799715347
# Nuevo mejor individuo
#  --------------------- Individuo 4 ---------------------
# Accuracy: 0.0858 Loss: 2.303244349290567
#  --------------------- Individuo 5 ---------------------
# Accuracy: 0.1338 Loss: 2.3027134495757537
#  --------------------- Individuo 6 ---------------------
# Accuracy: 0.0812 Loss: 2.3038667925893623
#  --------------------- Individuo 7 ---------------------
# Accuracy: 0.088 Loss: 2.3027080510979268
#  --------------------- Individuo 8 ---------------------
# Accuracy: 0.1029 Loss: 2.3028528115896783
#  --------------------- Individuo 9 ---------------------
# Accuracy: 0.0913 Loss: 2.302439732592243
# Nuevo mejor individuo
#  --------------------- Individuo 10 ---------------------
# Accuracy: 0.0892 Loss: 2.3025764938610704
#  --------------------- Individuo 11 ---------------------
# Accuracy: 0.0891 Loss: 2.3028007089964615
# Aumentando varianzas
#  --------------------- Individuo 12 ---------------------
# Accuracy: 0.1091 Loss: 2.30264035623465
# Aumentando varianzas
#  --------------------- Individuo 13 ---------------------
# Accuracy: 0.0671 Loss: 2.3030115421901125
# Aumentando varianzas
#  --------------------- Individuo 14 ---------------------
# Accuracy: 0.1121 Loss: 2.302343959747347
# Nuevo mejor individuo
# Aumentando varianzas
#  --------------------- Individuo 15 ---------------------
# Accuracy: 0.0621 Loss: 2.3026450320855893
# Aumentando varianzas
#  --------------------- Individuo 16 ---------------------
# Accuracy: 0.1238 Loss: 2.3021613938976198
# Nuevo mejor individuo
# Aumentando varianzas
#  --------------------- Individuo 17 ---------------------
# Accuracy: 0.098 Loss: 2.3027480380621546
# Aumentando varianzas
#  --------------------- Individuo 18 ---------------------
# Accuracy: 0.1596 Loss: 2.3019259181866514
# Nuevo mejor individuo
# Aumentando varianzas
#  --------------------- Individuo 19 ---------------------
# Accuracy: 0.1177 Loss: 2.303720775951963
# Aumentando varianzas
#  --------------------- Individuo 20 ---------------------
# Accuracy: 0.1357 Loss: 2.3024817168839706
# Aumentando varianzas
#  --------------------- Individuo 21 ---------------------
# Accuracy: 0.1575 Loss: 2.302681097597964
# Aumentando varianzas
#  --------------------- Individuo 22 ---------------------
# Accuracy: 0.0394 Loss: 2.3031052783099826
# Aumentando varianzas
#  --------------------- Individuo 23 ---------------------
# Accuracy: 0.1092 Loss: 2.3029094815000035
# Aumentando varianzas
#  --------------------- Individuo 24 ---------------------
# Accuracy: 0.0687 Loss: 2.302695358739987
# Aumentando varianzas
#  --------------------- Individuo 25 ---------------------
# Accuracy: 0.1064 Loss: 2.3023270719341125
# Aumentando varianzas
#  --------------------- Individuo 26 ---------------------
# Accuracy: 0.0622 Loss: 2.302929026739938
# Aumentando varianzas
#  --------------------- Individuo 27 ---------------------
# Accuracy: 0.0908 Loss: 2.3028103695241118
# Aumentando varianzas
#  --------------------- Individuo 28 ---------------------
# Accuracy: 0.1078 Loss: 2.302825585865517
# Aumentando varianzas
#  --------------------- Individuo 29 ---------------------
# Accuracy: 0.105 Loss: 2.30253586916527
# Aumentando varianzas
#  --------------------- Individuo 30 ---------------------
# Accuracy: 0.0949 Loss: 2.3023897511110123
# Aumentando varianzas
#  --------------------- Individuo 31 ---------------------
# Accuracy: 0.0979 Loss: 2.303057267721782
# Aumentando varianzas
#  --------------------- Individuo 32 ---------------------
# Accuracy: 0.0999 Loss: 2.3026796335350475
# Aumentando varianzas
#  --------------------- Individuo 33 ---------------------
# Accuracy: 0.0827 Loss: 2.302818424920283
# Aumentando varianzas
#  --------------------- Individuo 34 ---------------------
# Accuracy: 0.0907 Loss: 2.3026152015494894
# Aumentando varianzas
#  --------------------- Individuo 35 ---------------------
# Accuracy: 0.0815 Loss: 2.303078849432565
# Aumentando varianzas
#  --------------------- Individuo 36 ---------------------
# Accuracy: 0.0829 Loss: 2.302368214898018
# Aumentando varianzas
#  --------------------- Individuo 37 ---------------------
# Accuracy: 0.091 Loss: 2.3026064995255298
# Aumentando varianzas
#  --------------------- Individuo 38 ---------------------
# Accuracy: 0.1454 Loss: 2.302296996879171
# Aumentando varianzas
#  --------------------- Individuo 39 ---------------------
# Accuracy: 0.106 Loss: 2.302283148267376
# Aumentando varianzas
#  --------------------- Individuo 40 ---------------------
# Accuracy: 0.0806 Loss: 2.302831597928045
# Aumentando varianzas
#  --------------------- Individuo 41 ---------------------
# Accuracy: 0.0825 Loss: 2.302736378936117
# Aumentando varianzas
#  --------------------- Individuo 42 ---------------------
# Accuracy: 0.0733 Loss: 2.302646151737872
# Aumentando varianzas
#  --------------------- Individuo 43 ---------------------
# Accuracy: 0.1225 Loss: 2.303049953507462
# Aumentando varianzas
#  --------------------- Individuo 44 ---------------------
# Accuracy: 0.0983 Loss: 2.3025030723766986
# Aumentando varianzas
#  --------------------- Individuo 45 ---------------------
# Accuracy: 0.1127 Loss: 2.302862585226356
# Aumentando varianzas
#  --------------------- Individuo 46 ---------------------
# Accuracy: 0.0924 Loss: 2.3025397540155503
# Aumentando varianzas
#  --------------------- Individuo 47 ---------------------
# Accuracy: 0.1235 Loss: 2.3027068229118135
# Aumentando varianzas
#  --------------------- Individuo 48 ---------------------
# Accuracy: 0.098 Loss: 2.3024391220576725
# Aumentando varianzas
#  --------------------- Individuo 49 ---------------------
# Accuracy: 0.0783 Loss: 2.3026675062138895
# Aumentando varianzas
#  --------------------- Individuo 50 ---------------------
# Accuracy: 0.0573 Loss: 2.302919957683539
# Aumentando varianzas
#  --------------------- Individuo 51 ---------------------
# Accuracy: 0.0932 Loss: 2.302378247033304
# Aumentando varianzas
#  --------------------- Individuo 52 ---------------------
# Accuracy: 0.069 Loss: 2.302638716026664
# Aumentando varianzas
#  --------------------- Individuo 53 ---------------------
# Accuracy: 0.0888 Loss: 2.3029284360312197
# Aumentando varianzas
#  --------------------- Individuo 54 ---------------------
# Accuracy: 0.0882 Loss: 2.303301362340638
# Aumentando varianzas
#  --------------------- Individuo 55 ---------------------
# Accuracy: 0.086 Loss: 2.302645976609513
# Aumentando varianzas
#  --------------------- Individuo 56 ---------------------
# Accuracy: 0.089 Loss: 2.302984675873063
# Aumentando varianzas
#  --------------------- Individuo 57 ---------------------
# Accuracy: 0.0532 Loss: 2.3030988438043005
# Disminuyendo varianzas
#  --------------------- Individuo 58 ---------------------
# Accuracy: 0.1357 Loss: 2.302305141237499
# Aumentando varianzas
#  --------------------- Individuo 59 ---------------------
# Accuracy: 0.0981 Loss: 2.3022900044536794
# Aumentando varianzas
#  --------------------- Individuo 60 ---------------------
# Accuracy: 0.0971 Loss: 2.302776957371596
# Aumentando varianzas
#  --------------------- Individuo 61 ---------------------
# Accuracy: 0.0904 Loss: 2.3032854142219525
# Aumentando varianzas
#  --------------------- Individuo 62 ---------------------
# Accuracy: 0.0715 Loss: 2.3032025365687128
# Aumentando varianzas
#  --------------------- Individuo 63 ---------------------
# Accuracy: 0.0961 Loss: 2.3023009968718995
# Aumentando varianzas
#  --------------------- Individuo 64 ---------------------
# Accuracy: 0.1201 Loss: 2.303008885780123
# Aumentando varianzas
#  --------------------- Individuo 65 ---------------------
# Accuracy: 0.0763 Loss: 2.3032870363833298
# Aumentando varianzas
#  --------------------- Individuo 66 ---------------------
# Accuracy: 0.1392 Loss: 2.302232183118873
# Aumentando varianzas
#  --------------------- Individuo 67 ---------------------
# Accuracy: 0.0882 Loss: 2.302798910435837
# Aumentando varianzas
#  --------------------- Individuo 68 ---------------------
# Accuracy: 0.1071 Loss: 2.3025117296654023
# Aumentando varianzas
#  --------------------- Individuo 69 ---------------------
# Accuracy: 0.0883 Loss: 2.3026859084172036
# Aumentando varianzas
#  --------------------- Individuo 70 ---------------------
# Accuracy: 0.0682 Loss: 2.303476531876684
# Aumentando varianzas
#  --------------------- Individuo 71 ---------------------
# Accuracy: 0.0866 Loss: 2.3026827126423686
# Aumentando varianzas
#  --------------------- Individuo 72 ---------------------
# Accuracy: 0.0377 Loss: 2.3030984549125884
# Aumentando varianzas
#  --------------------- Individuo 73 ---------------------
# Accuracy: 0.0883 Loss: 2.302265687029499
# Aumentando varianzas
#  --------------------- Individuo 74 ---------------------
# Accuracy: 0.0767 Loss: 2.302661868554951
# Aumentando varianzas
#  --------------------- Individuo 75 ---------------------
# Accuracy: 0.0953 Loss: 2.302687160750188
# Aumentando varianzas
#  --------------------- Individuo 76 ---------------------
# Accuracy: 0.1258 Loss: 2.3028400727172396
# Aumentando varianzas
#  --------------------- Individuo 77 ---------------------
# Accuracy: 0.0979 Loss: 2.302635399009119
# Aumentando varianzas
#  --------------------- Individuo 78 ---------------------
# Accuracy: 0.0822 Loss: 2.3030098691932173
# Aumentando varianzas
#  --------------------- Individuo 79 ---------------------
# Accuracy: 0.104 Loss: 2.3026895289227904
# Aumentando varianzas
#  --------------------- Individuo 80 ---------------------
# Accuracy: 0.0955 Loss: 2.302625157939854
# Aumentando varianzas
#  --------------------- Individuo 81 ---------------------
# Accuracy: 0.1158 Loss: 2.3023897592446954
# Aumentando varianzas
#  --------------------- Individuo 82 ---------------------
# Accuracy: 0.0959 Loss: 2.302848100408054
# Aumentando varianzas
#  --------------------- Individuo 83 ---------------------
# Accuracy: 0.067 Loss: 2.303136402101659
# Aumentando varianzas
#  --------------------- Individuo 84 ---------------------
# Accuracy: 0.0995 Loss: 2.302485991642673
# Aumentando varianzas
#  --------------------- Individuo 85 ---------------------
# Accuracy: 0.0676 Loss: 2.302765657144315
# Aumentando varianzas
#  --------------------- Individuo 86 ---------------------
# Accuracy: 0.098 Loss: 2.3023619501829655
# Aumentando varianzas
#  --------------------- Individuo 87 ---------------------
# Accuracy: 0.0942 Loss: 2.3021135843638927
# Aumentando varianzas
#  --------------------- Individuo 88 ---------------------
# Accuracy: 0.1051 Loss: 2.3029777325038463
# Aumentando varianzas
#  --------------------- Individuo 89 ---------------------
# Accuracy: 0.0738 Loss: 2.302755903587667
# Aumentando varianzas
#  --------------------- Individuo 90 ---------------------
# Accuracy: 0.0635 Loss: 2.3027829554543566
# Aumentando varianzas
#  --------------------- Individuo 91 ---------------------
# Accuracy: 0.1058 Loss: 2.3032913096169674
# Aumentando varianzas
#  --------------------- Individuo 92 ---------------------
# Accuracy: 0.1409 Loss: 2.3024324946312
# Aumentando varianzas
#  --------------------- Individuo 93 ---------------------
# Accuracy: 0.0987 Loss: 2.3025648756576245
# Aumentando varianzas
#  --------------------- Individuo 94 ---------------------
# Accuracy: 0.0893 Loss: 2.3023028025494963
# Aumentando varianzas
#  --------------------- Individuo 95 ---------------------
# Accuracy: 0.1127 Loss: 2.302758632438269
# Aumentando varianzas
#  --------------------- Individuo 96 ---------------------
# Accuracy: 0.0838 Loss: 2.30256275124133
# Aumentando varianzas
#  --------------------- Individuo 97 ---------------------
# Accuracy: 0.098 Loss: 2.3028039578944126
# Aumentando varianzas
#  --------------------- Individuo 98 ---------------------
# Accuracy: 0.0961 Loss: 2.3025854500626197
# Aumentando varianzas
#  --------------------- Individuo 99 ---------------------
# Accuracy: 0.092 Loss: 2.3027960140822032
# Aumentando varianzas
#  --------------------- Individuo 100 ---------------------
# Accuracy: 0.105 Loss: 2.302652954292704
# Aumentando varianzas
#  --------------------- Individuo 101 ---------------------
# Accuracy: 0.1053 Loss: 2.302588304731129
# Aumentando varianzas
#  --------------------- Individuo 102 ---------------------
# Accuracy: 0.0881 Loss: 2.302737792417693
# Aumentando varianzas
#  --------------------- Individuo 103 ---------------------
# Accuracy: 0.0939 Loss: 2.3023464509419034
# Aumentando varianzas
#  --------------------- Individuo 104 ---------------------
# Accuracy: 0.1984 Loss: 2.302236415175741
# Aumentando varianzas
#  --------------------- Individuo 105 ---------------------
# Accuracy: 0.1084 Loss: 2.3023267687002478
# Aumentando varianzas
#  --------------------- Individuo 106 ---------------------
# Accuracy: 0.1053 Loss: 2.302349577326256
# Aumentando varianzas
#  --------------------- Individuo 107 ---------------------
# Accuracy: 0.1858 Loss: 2.302033129785615
# Aumentando varianzas
#  --------------------- Individuo 108 ---------------------
# Accuracy: 0.1034 Loss: 2.3025044380728876
# Aumentando varianzas
#  --------------------- Individuo 109 ---------------------
# Accuracy: 0.1064 Loss: 2.3025091360372776
# Aumentando varianzas
#  --------------------- Individuo 110 ---------------------
# Accuracy: 0.0953 Loss: 2.303048004727882
# Aumentando varianzas
#  --------------------- Individuo 111 ---------------------
# Accuracy: 0.0555 Loss: 2.3027227423084318
# Aumentando varianzas
#  --------------------- Individuo 112 ---------------------
# Accuracy: 0.0896 Loss: 2.303025374026187
# Aumentando varianzas
#  --------------------- Individuo 113 ---------------------
# Accuracy: 0.098 Loss: 2.302350751880898
# Aumentando varianzas
#  --------------------- Individuo 114 ---------------------
# Accuracy: 0.098 Loss: 2.3030824567209174
# Aumentando varianzas
#  --------------------- Individuo 115 ---------------------
# Accuracy: 0.0845 Loss: 2.302829426997252
# Aumentando varianzas
#  --------------------- Individuo 116 ---------------------
# Accuracy: 0.1096 Loss: 2.3025213281737207
# Aumentando varianzas
#  --------------------- Individuo 117 ---------------------
# Accuracy: 0.0917 Loss: 2.3027888320402297
# Aumentando varianzas
#  --------------------- Individuo 118 ---------------------
# Accuracy: 0.1176 Loss: 2.3025313384497346
# Aumentando varianzas
#  --------------------- Individuo 119 ---------------------
# Accuracy: 0.0863 Loss: 2.3028644257262827
# Aumentando varianzas
#  --------------------- Individuo 120 ---------------------
# Accuracy: 0.1097 Loss: 2.302634018824807
# Aumentando varianzas
#  --------------------- Individuo 121 ---------------------
# Accuracy: 0.1034 Loss: 2.3028919447713823
# Aumentando varianzas
#  --------------------- Individuo 122 ---------------------
# Accuracy: 0.1632 Loss: 2.302463398050906
# Aumentando varianzas
#  --------------------- Individuo 123 ---------------------
# Accuracy: 0.1292 Loss: 2.3025478376254345
# Aumentando varianzas
#  --------------------- Individuo 124 ---------------------
# Accuracy: 0.0781 Loss: 2.3027557121919418
# Aumentando varianzas
#  --------------------- Individuo 125 ---------------------
# Accuracy: 0.098 Loss: 2.302431029551573
# Aumentando varianzas
#  --------------------- Individuo 126 ---------------------
# Accuracy: 0.1241 Loss: 2.3025243511077944
# Aumentando varianzas
#  --------------------- Individuo 127 ---------------------
# Accuracy: 0.0976 Loss: 2.3030028887140723
# Aumentando varianzas
#  --------------------- Individuo 128 ---------------------
# Accuracy: 0.1107 Loss: 2.302452382248348
# Aumentando varianzas
#  --------------------- Individuo 129 ---------------------
# Accuracy: 0.0962 Loss: 2.3023629213955354
# Aumentando varianzas
#  --------------------- Individuo 130 ---------------------
# Accuracy: 0.0843 Loss: 2.3024835708553093
# Aumentando varianzas
#  --------------------- Individuo 131 ---------------------
# Accuracy: 0.133 Loss: 2.3024042049196485
# Aumentando varianzas
#  --------------------- Individuo 132 ---------------------
# Accuracy: 0.0998 Loss: 2.3025254476299164
# Aumentando varianzas
#  --------------------- Individuo 133 ---------------------
# Accuracy: 0.058 Loss: 2.3030106751903543
# Aumentando varianzas
#  --------------------- Individuo 134 ---------------------
# Accuracy: 0.092 Loss: 2.302900395922061
# Aumentando varianzas
#  --------------------- Individuo 135 ---------------------
# Accuracy: 0.1168 Loss: 2.302900048461296
# Aumentando varianzas
#  --------------------- Individuo 136 ---------------------
# Accuracy: 0.0778 Loss: 2.302941786963294
# Aumentando varianzas
#  --------------------- Individuo 137 ---------------------
# Accuracy: 0.085 Loss: 2.302716795315366
# Aumentando varianzas
#  --------------------- Individuo 138 ---------------------
# Accuracy: 0.1027 Loss: 2.302692658103097
# Aumentando varianzas
#  --------------------- Individuo 139 ---------------------
# Accuracy: 0.0911 Loss: 2.3023872911802994
# Aumentando varianzas
#  --------------------- Individuo 140 ---------------------
# Accuracy: 0.0948 Loss: 2.302503016965984
# Aumentando varianzas
#  --------------------- Individuo 141 ---------------------
# Accuracy: 0.1245 Loss: 2.3028036272093684
# Aumentando varianzas
#  --------------------- Individuo 142 ---------------------
# Accuracy: 0.0982 Loss: 2.3028171492029608
# Aumentando varianzas
#  --------------------- Individuo 143 ---------------------
# Accuracy: 0.1028 Loss: 2.3025059163697494
# Aumentando varianzas
#  --------------------- Individuo 144 ---------------------
# Accuracy: 0.0788 Loss: 2.3029919905957383
# Aumentando varianzas
#  --------------------- Individuo 145 ---------------------
# Accuracy: 0.1014 Loss: 2.302394565488738
# Aumentando varianzas
#  --------------------- Individuo 146 ---------------------
# Accuracy: 0.0846 Loss: 2.303119979687591
# Aumentando varianzas
#  --------------------- Individuo 147 ---------------------
# Accuracy: 0.1026 Loss: 2.3027040597472364
# Aumentando varianzas
#  --------------------- Individuo 148 ---------------------
# Accuracy: 0.1143 Loss: 2.302436701524486
# Aumentando varianzas
#  --------------------- Individuo 149 ---------------------
# Accuracy: 0.0948 Loss: 2.302798846128907
# Aumentando varianzas
#  --------------------- Individuo 150 ---------------------
# Accuracy: 0.0893 Loss: 2.302482291579501
# Aumentando varianzas
#  --------------------- Individuo 151 ---------------------
# Accuracy: 0.0884 Loss: 2.30284169030342
# Aumentando varianzas
#  --------------------- Individuo 152 ---------------------
# Accuracy: 0.0802 Loss: 2.3030197788149054
# Aumentando varianzas
#  --------------------- Individuo 153 ---------------------
# Accuracy: 0.1031 Loss: 2.3031876620961658
# Aumentando varianzas
#  --------------------- Individuo 154 ---------------------
# Accuracy: 0.0803 Loss: 2.3025669055198557
# Aumentando varianzas
#  --------------------- Individuo 155 ---------------------
# Accuracy: 0.0985 Loss: 2.302366412778907
# Aumentando varianzas
#  --------------------- Individuo 156 ---------------------
# Accuracy: 0.0838 Loss: 2.3027158096146736
# Aumentando varianzas
#  --------------------- Individuo 157 ---------------------
# Accuracy: 0.1278 Loss: 2.3030887539707012
# Aumentando varianzas
#  --------------------- Individuo 158 ---------------------
# Accuracy: 0.1582 Loss: 2.302449846826891
# Aumentando varianzas
#  --------------------- Individuo 159 ---------------------
# Accuracy: 0.079 Loss: 2.3025399464279857
# Aumentando varianzas
#  --------------------- Individuo 160 ---------------------
# Accuracy: 0.091 Loss: 2.302773502589797
# Aumentando varianzas
#  --------------------- Individuo 161 ---------------------
# Accuracy: 0.0998 Loss: 2.302669787457757
# Aumentando varianzas
#  --------------------- Individuo 162 ---------------------
# Accuracy: 0.115 Loss: 2.302297020009332
# Aumentando varianzas
#  --------------------- Individuo 163 ---------------------
# Accuracy: 0.098 Loss: 2.3026548817213666
# Aumentando varianzas
#  --------------------- Individuo 164 ---------------------
# Accuracy: 0.0995 Loss: 2.303219647041516
# Aumentando varianzas
#  --------------------- Individuo 165 ---------------------
# Accuracy: 0.1123 Loss: 2.3025524542529956
# Aumentando varianzas
#  --------------------- Individuo 166 ---------------------
# Accuracy: 0.087 Loss: 2.302571201629476
# Aumentando varianzas
#  --------------------- Individuo 167 ---------------------
# Accuracy: 0.0865 Loss: 2.3030369533404613
# Aumentando varianzas
#  --------------------- Individuo 168 ---------------------
# Accuracy: 0.1289 Loss: 2.3027734380286895
# Aumentando varianzas
#  --------------------- Individuo 169 ---------------------
# Accuracy: 0.1012 Loss: 2.3036020089314184
# Aumentando varianzas
#  --------------------- Individuo 170 ---------------------
# Accuracy: 0.1141 Loss: 2.302547142449727
# Aumentando varianzas
#  --------------------- Individuo 171 ---------------------
# Accuracy: 0.089 Loss: 2.302547678001908
# Aumentando varianzas
#  --------------------- Individuo 172 ---------------------
# Accuracy: 0.0982 Loss: 2.302668774051707
# Aumentando varianzas
#  --------------------- Individuo 173 ---------------------
# Accuracy: 0.0941 Loss: 2.3027141897408945
# Aumentando varianzas
#  --------------------- Individuo 174 ---------------------
# Accuracy: 0.0829 Loss: 2.3032718302090287
# Disminuyendo varianzas
#  --------------------- Individuo 175 ---------------------
# Accuracy: 0.0602 Loss: 2.3029389701672454
# Aumentando varianzas
#  --------------------- Individuo 176 ---------------------
# Accuracy: 0.1081 Loss: 2.3022801710852683
# Aumentando varianzas
#  --------------------- Individuo 177 ---------------------
# Accuracy: 0.0867 Loss: 2.302599126850364
# Aumentando varianzas
#  --------------------- Individuo 178 ---------------------
# Accuracy: 0.0833 Loss: 2.30262370099391
# Aumentando varianzas
#  --------------------- Individuo 179 ---------------------
# Accuracy: 0.101 Loss: 2.30274886846034
# Disminuyendo varianzas
#  --------------------- Individuo 180 ---------------------
# Accuracy: 0.1153 Loss: 2.3025770243297
# Aumentando varianzas
#  --------------------- Individuo 181 ---------------------
# Accuracy: 0.0922 Loss: 2.303028797289964
# Aumentando varianzas
#  --------------------- Individuo 182 ---------------------
# Accuracy: 0.118 Loss: 2.30252014294362
# Aumentando varianzas
#  --------------------- Individuo 183 ---------------------
# Accuracy: 0.1339 Loss: 2.3024794831713127
# Aumentando varianzas
#  --------------------- Individuo 184 ---------------------
# Accuracy: 0.0662 Loss: 2.3033430672911948
# Aumentando varianzas
#  --------------------- Individuo 185 ---------------------
# Accuracy: 0.0834 Loss: 2.3030885768089213
# Aumentando varianzas
#  --------------------- Individuo 186 ---------------------
# Accuracy: 0.0984 Loss: 2.302366925200928
# Aumentando varianzas
#  --------------------- Individuo 187 ---------------------
# Accuracy: 0.1003 Loss: 2.302421433585031
# Aumentando varianzas
#  --------------------- Individuo 188 ---------------------
# Accuracy: 0.1103 Loss: 2.3023058890279677
# Aumentando varianzas
#  --------------------- Individuo 189 ---------------------
# Accuracy: 0.0618 Loss: 2.303095177800925
# Aumentando varianzas
#  --------------------- Individuo 190 ---------------------
# Accuracy: 0.0778 Loss: 2.3025647084087706
# Aumentando varianzas
#  --------------------- Individuo 191 ---------------------
# Accuracy: 0.0767 Loss: 2.3034114850355363
# Aumentando varianzas
#  --------------------- Individuo 192 ---------------------
# Accuracy: 0.1104 Loss: 2.302981979303014
# Aumentando varianzas
#  --------------------- Individuo 193 ---------------------
# Accuracy: 0.1167 Loss: 2.3025699858980646
# Aumentando varianzas
#  --------------------- Individuo 194 ---------------------
# Accuracy: 0.0885 Loss: 2.3027614817690494
# Aumentando varianzas
#  --------------------- Individuo 195 ---------------------
# Accuracy: 0.0567 Loss: 2.3027220684836416
# Aumentando varianzas
#  --------------------- Individuo 196 ---------------------
# Accuracy: 0.1404 Loss: 2.3027829325783737
# Aumentando varianzas
#  --------------------- Individuo 197 ---------------------
# Accuracy: 0.1076 Loss: 2.3033136914788024
# Aumentando varianzas
#  --------------------- Individuo 198 ---------------------
# Accuracy: 0.0796 Loss: 2.3028005275136625
# Aumentando varianzas
#  --------------------- Individuo 199 ---------------------
# Accuracy: 0.1105 Loss: 2.3023466258160847
# Aumentando varianzas
#  --------------------- Individuo 200 ---------------------
# Accuracy: 0.1232 Loss: 2.3023626682346565
# Aumentando varianzas
#  --------------------- Individuo 201 ---------------------
# Accuracy: 0.0748 Loss: 2.3026899302692048
# Aumentando varianzas
#  --------------------- Individuo 202 ---------------------
# Accuracy: 0.0859 Loss: 2.3039093790278
# Aumentando varianzas
#  --------------------- Individuo 203 ---------------------
# Accuracy: 0.0961 Loss: 2.302470472575759
# Aumentando varianzas
#  --------------------- Individuo 204 ---------------------
# Accuracy: 0.1007 Loss: 2.3022575335207778
# Aumentando varianzas
#  --------------------- Individuo 205 ---------------------
# Accuracy: 0.1121 Loss: 2.3024556072536053
# Aumentando varianzas
#  --------------------- Individuo 206 ---------------------
# Accuracy: 0.1012 Loss: 2.302383398958869
# Aumentando varianzas
#  --------------------- Individuo 207 ---------------------
# Accuracy: 0.0844 Loss: 2.3023483730328365
# Aumentando varianzas
#  --------------------- Individuo 208 ---------------------
# Accuracy: 0.0887 Loss: 2.302603395254627
# Aumentando varianzas
#  --------------------- Individuo 209 ---------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 90
#      88 total = 0
#      89 with torch.no_grad():
# ---> 90     for data in test_loader:
#      91         images, labels = data[0].to(device), data[1].to(device)
#      92         outputs = masked_net(images)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\utils\data\dataloader.py:701, in _BaseDataLoaderIter.__next__(self)
#     698 if self._sampler_iter is None:
#     699     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     700     self._reset()  # type: ignore[call-arg]
# --> 701 data = self._next_data()
#     702 self._num_yielded += 1
#     703 if (
#     704     self._dataset_kind == _DatasetKind.Iterable
#     705     and self._IterableDataset_len_called is not None
#     706     and self._num_yielded > self._IterableDataset_len_called
#     707 ):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\utils\data\dataloader.py:1448, in _MultiProcessingDataLoaderIter._next_data(self)
#    1445     return self._process_data(data)
#    1447 assert not self._shutdown and self._tasks_outstanding > 0
# -> 1448 idx, data = self._get_data()
#    1449 self._tasks_outstanding -= 1
#    1450 if self._dataset_kind == _DatasetKind.Iterable:
#    1451     # Check for _IterableDatasetStopIteration
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\utils\data\dataloader.py:1412, in _MultiProcessingDataLoaderIter._get_data(self)
#    1408     # In this case, `self._data_queue` is a `queue.Queue`,. But we don't
#    1409     # need to call `.task_done()` because we don't use `.join()`.
#    1410 else:
#    1411     while True:
# -> 1412         success, data = self._try_get_data()
#    1413         if success:
#    1414             return data
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\utils\data\dataloader.py:1243, in _MultiProcessingDataLoaderIter._try_get_data(self, timeout)
#    1230 def _try_get_data(self, timeout=_utils.MP_STATUS_CHECK_INTERVAL):
#    1231     # Tries to fetch data from `self._data_queue` once for a given timeout.
#    1232     # This can also be used as inner loop of fetching without timeout, with
#    (...)
#    1240     # Returns a 2-tuple:
#    1241     #   (bool: whether successfully get data, any: data if successful else None)
#    1242     try:
# -> 1243         data = self._data_queue.get(timeout=timeout)
#    1244         return (True, data)
#    1245     except Exception as e:
#    1246         # At timeout and error, we manually check whether any worker has
#    1247         # failed. Note that this is the only mechanism for Windows to detect
#    1248         # worker failures.
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\multiprocessing\queues.py:113, in Queue.get(self, block, timeout)
#     111 if block:
#     112     timeout = deadline - time.monotonic()
# --> 113     if not self._poll(timeout):
#     114         raise Empty
#     115 elif not self._poll():
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\multiprocessing\connection.py:257, in _ConnectionBase.poll(self, timeout)
#     255 self._check_closed()
#     256 self._check_readable()
# --> 257 return self._poll(timeout)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\multiprocessing\connection.py:346, in PipeConnection._poll(self, timeout)
#     343 if (self._got_empty_message or
#     344             _winapi.PeekNamedPipe(self._handle)[0] != 0):
#     345     return True
# --> 346 return bool(wait([self], timeout))
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\multiprocessing\connection.py:896, in wait(object_list, timeout)
#     893                 ready_objects.add(o)
#     894                 timeout = 0
# --> 896     ready_handles = _exhaustive_wait(waithandle_to_obj.keys(), timeout)
#     897 finally:
#     898     # request that overlapped reads stop
#     899     for ov in ov_list:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\multiprocessing\connection.py:828, in _exhaustive_wait(handles, timeout)
#     826 ready = []
#     827 while L:
# --> 828     res = _winapi.WaitForMultipleObjects(L, False, timeout)
#     829     if res == WAIT_TIMEOUT:
#     830         break
#
# KeyboardInterrupt:

# %%
print(train_loss)
print(test_accuracies)
print(max(test_accuracies))
index_max_accuracy = test_accuracies.index(max(test_accuracies))
print(index_max_accuracy)
print("-----------------")
print(min(train_loss))
index = train_loss.index(min(train_loss))
print(index)
# Out:
# [2.3031585440198494, 2.3026239206033474, 2.3024988799715347, 2.303244349290567, 2.3027134495757537, 2.3038667925893623, 2.3027080510979268, 2.3028528115896783, 2.302439732592243, 2.3025764938610704, 2.3028007089964615, 2.30264035623465, 2.3030115421901125, 2.302343959747347, 2.3026450320855893, 2.3021613938976198, 2.3027480380621546, 2.3019259181866514, 2.303720775951963, 2.3024817168839706, 2.302681097597964, 2.3031052783099826, 2.3029094815000035, 2.302695358739987, 2.3023270719341125, 2.302929026739938, 2.3028103695241118, 2.302825585865517, 2.30253586916527, 2.3023897511110123, 2.303057267721782, 2.3026796335350475, 2.302818424920283, 2.3026152015494894, 2.303078849432565, 2.302368214898018, 2.3026064995255298, 2.302296996879171, 2.302283148267376, 2.302831597928045, 2.302736378936117, 2.302646151737872, 2.303049953507462, 2.3025030723766986, 2.302862585226356, 2.3025397540155503, 2.3027068229118135, 2.3024391220576725, 2.3026675062138895, 2.302919957683539, 2.302378247033304, 2.302638716026664, 2.3029284360312197, 2.303301362340638, 2.302645976609513, 2.302984675873063, 2.3030988438043005, 2.302305141237499, 2.3022900044536794, 2.302776957371596, 2.3032854142219525, 2.3032025365687128, 2.3023009968718995, 2.303008885780123, 2.3032870363833298, 2.302232183118873, 2.302798910435837, 2.3025117296654023, 2.3026859084172036, 2.303476531876684, 2.3026827126423686, 2.3030984549125884, 2.302265687029499, 2.302661868554951, 2.302687160750188, 2.3028400727172396, 2.302635399009119, 2.3030098691932173, 2.3026895289227904, 2.302625157939854, 2.3023897592446954, 2.302848100408054, 2.303136402101659, 2.302485991642673, 2.302765657144315, 2.3023619501829655, 2.3021135843638927, 2.3029777325038463, 2.302755903587667, 2.3027829554543566, 2.3032913096169674, 2.3024324946312, 2.3025648756576245, 2.3023028025494963, 2.302758632438269, 2.30256275124133, 2.3028039578944126, 2.3025854500626197, 2.3027960140822032, 2.302652954292704, 2.302588304731129, 2.302737792417693, 2.3023464509419034, 2.302236415175741, 2.3023267687002478, 2.302349577326256, 2.302033129785615, 2.3025044380728876, 2.3025091360372776, 2.303048004727882, 2.3027227423084318, 2.303025374026187, 2.302350751880898, 2.3030824567209174, 2.302829426997252, 2.3025213281737207, 2.3027888320402297, 2.3025313384497346, 2.3028644257262827, 2.302634018824807, 2.3028919447713823, 2.302463398050906, 2.3025478376254345, 2.3027557121919418, 2.302431029551573, 2.3025243511077944, 2.3030028887140723, 2.302452382248348, 2.3023629213955354, 2.3024835708553093, 2.3024042049196485, 2.3025254476299164, 2.3030106751903543, 2.302900395922061, 2.302900048461296, 2.302941786963294, 2.302716795315366, 2.302692658103097, 2.3023872911802994, 2.302503016965984, 2.3028036272093684, 2.3028171492029608, 2.3025059163697494, 2.3029919905957383, 2.302394565488738, 2.303119979687591, 2.3027040597472364, 2.302436701524486, 2.302798846128907, 2.302482291579501, 2.30284169030342, 2.3030197788149054, 2.3031876620961658, 2.3025669055198557, 2.302366412778907, 2.3027158096146736, 2.3030887539707012, 2.302449846826891, 2.3025399464279857, 2.302773502589797, 2.302669787457757, 2.302297020009332, 2.3026548817213666, 2.303219647041516, 2.3025524542529956, 2.302571201629476, 2.3030369533404613, 2.3027734380286895, 2.3036020089314184, 2.302547142449727, 2.302547678001908, 2.302668774051707, 2.3027141897408945, 2.3032718302090287, 2.3029389701672454, 2.3022801710852683, 2.302599126850364, 2.30262370099391, 2.30274886846034, 2.3025770243297, 2.303028797289964, 2.30252014294362, 2.3024794831713127, 2.3033430672911948, 2.3030885768089213, 2.302366925200928, 2.302421433585031, 2.3023058890279677, 2.303095177800925, 2.3025647084087706, 2.3034114850355363, 2.302981979303014, 2.3025699858980646, 2.3027614817690494, 2.3027220684836416, 2.3027829325783737, 2.3033136914788024, 2.3028005275136625, 2.3023466258160847, 2.3023626682346565, 2.3026899302692048, 2.3039093790278, 2.302470472575759, 2.3022575335207778, 2.3024556072536053, 2.3023 ...
# [0.101, 0.0892, 0.1066, 0.0858, 0.1338, 0.0812, 0.088, 0.1029, 0.0913, 0.0892, 0.0891, 0.1091, 0.0671, 0.1121, 0.0621, 0.1238, 0.098, 0.1596, 0.1177, 0.1357, 0.1575, 0.0394, 0.1092, 0.0687, 0.1064, 0.0622, 0.0908, 0.1078, 0.105, 0.0949, 0.0979, 0.0999, 0.0827, 0.0907, 0.0815, 0.0829, 0.091, 0.1454, 0.106, 0.0806, 0.0825, 0.0733, 0.1225, 0.0983, 0.1127, 0.0924, 0.1235, 0.098, 0.0783, 0.0573, 0.0932, 0.069, 0.0888, 0.0882, 0.086, 0.089, 0.0532, 0.1357, 0.0981, 0.0971, 0.0904, 0.0715, 0.0961, 0.1201, 0.0763, 0.1392, 0.0882, 0.1071, 0.0883, 0.0682, 0.0866, 0.0377, 0.0883, 0.0767, 0.0953, 0.1258, 0.0979, 0.0822, 0.104, 0.0955, 0.1158, 0.0959, 0.067, 0.0995, 0.0676, 0.098, 0.0942, 0.1051, 0.0738, 0.0635, 0.1058, 0.1409, 0.0987, 0.0893, 0.1127, 0.0838, 0.098, 0.0961, 0.092, 0.105, 0.1053, 0.0881, 0.0939, 0.1984, 0.1084, 0.1053, 0.1858, 0.1034, 0.1064, 0.0953, 0.0555, 0.0896, 0.098, 0.098, 0.0845, 0.1096, 0.0917, 0.1176, 0.0863, 0.1097, 0.1034, 0.1632, 0.1292, 0.0781, 0.098, 0.1241, 0.0976, 0.1107, 0.0962, 0.0843, 0.133, 0.0998, 0.058, 0.092, 0.1168, 0.0778, 0.085, 0.1027, 0.0911, 0.0948, 0.1245, 0.0982, 0.1028, 0.0788, 0.1014, 0.0846, 0.1026, 0.1143, 0.0948, 0.0893, 0.0884, 0.0802, 0.1031, 0.0803, 0.0985, 0.0838, 0.1278, 0.1582, 0.079, 0.091, 0.0998, 0.115, 0.098, 0.0995, 0.1123, 0.087, 0.0865, 0.1289, 0.1012, 0.1141, 0.089, 0.0982, 0.0941, 0.0829, 0.0602, 0.1081, 0.0867, 0.0833, 0.101, 0.1153, 0.0922, 0.118, 0.1339, 0.0662, 0.0834, 0.0984, 0.1003, 0.1103, 0.0618, 0.0778, 0.0767, 0.1104, 0.1167, 0.0885, 0.0567, 0.1404, 0.1076, 0.0796, 0.1105, 0.1232, 0.0748, 0.0859, 0.0961, 0.1007, 0.1121, 0.1012, 0.0844, 0.0887]
# 0.1984
# 103
# -----------------
# 2.3019259181866514
# 17

# %%
# Creamos la figura y definimos dos subgráficos (1 fila, 2 columnas)
plt.figure(figsize=(10, 5))

# Primer gráfico en la posición 1 (izquierda)
plt.subplot(1, 2, 1)  # 1 fila, 2 columnas, primer gráfico
plt.plot(train_loss, color='blue', marker='o')
plt.title("Gráfico de Pérdida")
plt.xlabel("Épocas")
plt.ylabel("Valores de pérdida")

# Calcular la regresión lineal para train_loss
epochs = np.arange(len(train_loss))
m, b = np.polyfit(epochs, train_loss, 1)
plt.plot(epochs, m*epochs + b, color='red', linestyle='--', label='Tendencia')


# Segundo gráfico en la posición 2 (derecha)
plt.subplot(1, 2, 2)  # 1 fila, 2 columnas, segundo gráfico
plt.plot(test_accuracies, color='green', marker='s')
plt.title("Gráfico de aciertos")
plt.xlabel("Épocas")
plt.ylabel("% de aciertos")

# Calcular la regresión lineal para test_accuracies
epochs_test = np.arange(len(test_accuracies))
m, b = np.polyfit(epochs_test, test_accuracies, 1)
plt.plot(epochs_test, m*epochs_test + b, color='red', linestyle='--', label='Tendencia')

# Mostramos los gráficos
plt.tight_layout()  # Ajustamos para que no se solapen los gráficos
plt.legend()
plt.show()
