# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

import numpy as np
import matplotlib.pyplot as plt

from utils.prune import apply_mask
from utils.count_improvement import improvements

# %%
# Verificar si la GPU está disponible y establecer el dispositivo
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1)
        self.fc1 = nn.Linear(128 * 4 * 4, 128)  # Adjusted dimensions here
        self.fc2 = nn.Linear(128, 10)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.max_pool2d(x, 2)
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2)
        x = F.relu(self.conv3(x))
        x = F.max_pool2d(x, 2)
        x = x.view(-1, 128 * 4 * 4)  # Adjusted dimensions here
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return F.log_softmax(x, dim=1)

# %%
net = Net().to(device)
varianzas_net = Net().to(device)
individuo = Net().to(device)

# %% [markdown]
# Cargamos los datos

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

train_dataset = datasets.CIFAR10('./../data', train=True, download=True, transform=transform)
test_dataset = datasets.CIFAR10('./../data', train=False, download=True, transform=transform)

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True, num_workers=4)
test_loader = DataLoader(test_dataset, batch_size=1000, shuffle=False, num_workers=4)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# Definimos la función de pérdida para calcular el error
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr=0.001)

# %% [markdown]
# Realizamos el "entrenamiento"

# %%
# train loop
train_loss = []
train_loss_mean = []
test_accuracies = []
n_individuo = 1
accuracy_threshold = 0.95

# Multiplicamos los pesos de varianzas para que sean numero sgrandes
with torch.no_grad():
    for param in varianzas_net.parameters():
        param *= 10000

#Guardo el mejor individuo y la red original que tendrá que ser reestablecida cad epoca
best_individo_state_dict = individuo.state_dict()
net_state_dict = net.state_dict()

#train loop
while True:
    net.load_state_dict(net_state_dict)
    if n_individuo == 1:
        print(f" --------------------- Individuo {n_individuo} --------------------- ")

        masked_net = apply_mask(net, individuo)

        masked_net.train()
        running_loss = 0.0
        # Train for 1 epoch
        for i, data in enumerate(train_loader, 0):
            inputs, labels = data[0].to(device), data[1].to(device)
            optimizer.zero_grad()
            outputs = masked_net(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
        train_loss.append(running_loss / len(train_loader))

        masked_net.eval()
        correct = 0
        total = 0
        with torch.no_grad():
            for data in test_loader:
                images, labels = data[0].to(device), data[1].to(device)
                outputs = masked_net(images)
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
        accuracy = correct / total
        #train_loss_mean.append(np.mean(train_loss))
        test_accuracies.append(accuracy)
        #print(f"Accuracy: {accuracy}, loss mean: {train_loss_mean[-1]}")
        print(f"Accuracy: {accuracy}", f"Loss: {train_loss[-1]}")
        best_loss = train_loss[-1]
        if accuracy > accuracy_threshold:
            break
        n_individuo += 1

        #sumamos varianzas para crear un nuevo individuo desde el anterior
        nuevo_individuo = Net().to(device)
        state_dict_ind = individuo.state_dict()
        state_dict_var = varianzas_net.state_dict()
        state_dict_suma = {}

        for key in state_dict_ind:
            if state_dict_ind[key].size() == state_dict_var[key].size():  
                std_dev = state_dict_var[key]
                noise = torch.normal(0, torch.abs(std_dev))
                state_dict_suma[key] = state_dict_ind[key] + torch.sign(std_dev) * noise
            else:
                state_dict_suma[key] = state_dict_ind[key]

        nuevo_individuo.load_state_dict(state_dict_suma)
        
    else:
        print(f" --------------------- Individuo {n_individuo} --------------------- ")

        masked_net = apply_mask(net, nuevo_individuo)
        
        masked_net.train()
        running_loss = 0.0
        # Train for 1 epoch
        for i, data in enumerate(train_loader, 0):
            inputs, labels = data[0].to(device), data[1].to(device)
            optimizer.zero_grad()
            outputs = masked_net(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
        train_loss.append(running_loss / len(train_loader))

        masked_net.eval()
        correct = 0
        total = 0
        with torch.no_grad():
            for data in test_loader:
                images, labels = data[0].to(device), data[1].to(device)
                outputs = masked_net(images)
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
        accuracy = correct / total
        test_accuracies.append(accuracy)
        print(f"Accuracy: {accuracy}", f"Loss: {train_loss[-1]}")
        if accuracy > accuracy_threshold:
            break

        # Verificamos que individuo tiene mejor desempeño
        if train_loss[-1] < best_loss:
            print("Nuevo mejor individuo")
            best_loss = train_loss[-1]
            best_individo_state_dict = nuevo_individuo.state_dict()
        
        # actualizamos el individuo
        individuo.load_state_dict(best_individo_state_dict)

        if n_individuo >10:
            # actualizmos el vector de varianzas
            print("Aumentando varianzas")
            if improvements(train_loss) > 2:## +mejoras que peoras (lejos de la solucion)
                with torch.no_grad():
                    for param in varianzas_net.parameters():
                        param *= (1/0.82)

            elif improvements(train_loss) < 2: ## -mejoras que peoras (cerca de la solucion)
                print("Disminuyendo varianzas")
                with torch.no_grad():
                    for param in varianzas_net.parameters():
                        param *= 0.82
        
            else:
                pass

        #sumamos varianzas para crear un nuevo individuo desde el anterior
        nuevo_individuo = Net().to(device)
        state_dict_ind = individuo.state_dict()
        state_dict_var = varianzas_net.state_dict()
        state_dict_suma = {}

        for key in state_dict_ind:
            if state_dict_ind[key].size() == state_dict_var[key].size():  
                std_dev = state_dict_var[key]
                noise = torch.normal(0, torch.abs(std_dev))
                state_dict_suma[key] = state_dict_ind[key] + torch.sign(std_dev) * noise
            else:
                state_dict_suma[key] = state_dict_ind[key]

        nuevo_individuo.load_state_dict(state_dict_suma)

        n_individuo += 1
# Out:
#  --------------------- Individuo 1 ---------------------
# Accuracy: 0.4837 Loss: 1.7398091833609755
#  --------------------- Individuo 2 ---------------------
# Accuracy: 0.5139 Loss: 1.6404514466710103
# Nuevo mejor individuo
#  --------------------- Individuo 3 ---------------------
# Accuracy: 0.537 Loss: 1.5585751423750387
# Nuevo mejor individuo
#  --------------------- Individuo 4 ---------------------
# Accuracy: 0.5155 Loss: 1.5840470208536328
#  --------------------- Individuo 5 ---------------------
# Accuracy: 0.5404 Loss: 1.5977383319221798
#  --------------------- Individuo 6 ---------------------
# Accuracy: 0.5037 Loss: 1.6426894137316652
#  --------------------- Individuo 7 ---------------------
# Accuracy: 0.4874 Loss: 1.6965119410353853
#  --------------------- Individuo 8 ---------------------
# Accuracy: 0.5295 Loss: 1.602287230817863
#  --------------------- Individuo 9 ---------------------
# Accuracy: 0.5068 Loss: 1.6779418432194253
#  --------------------- Individuo 10 ---------------------
# Accuracy: 0.5246 Loss: 1.6846842607268897
#  --------------------- Individuo 11 ---------------------
# Accuracy: 0.5085 Loss: 1.7510470784533665
# Aumentando varianzas
#  --------------------- Individuo 12 ---------------------
# Accuracy: 0.5344 Loss: 1.6660529387271619
# Aumentando varianzas
#  --------------------- Individuo 13 ---------------------
# Accuracy: 0.4997 Loss: 1.7833531210794473
# Aumentando varianzas
#  --------------------- Individuo 14 ---------------------
# Accuracy: 0.4764 Loss: 1.7705016177328652
# Aumentando varianzas
#  --------------------- Individuo 15 ---------------------
# Accuracy: 0.4769 Loss: 1.8778988755572483
# Aumentando varianzas
#  --------------------- Individuo 16 ---------------------
# Accuracy: 0.5117 Loss: 1.7423474245211656
# Aumentando varianzas
#  --------------------- Individuo 17 ---------------------
# Accuracy: 0.4867 Loss: 1.8367824758715032
# Aumentando varianzas
#  --------------------- Individuo 18 ---------------------
# Accuracy: 0.5078 Loss: 1.7844117593277447
# Aumentando varianzas
#  --------------------- Individuo 19 ---------------------
# Accuracy: 0.5271 Loss: 1.695369417557631
# Aumentando varianzas
#  --------------------- Individuo 20 ---------------------
# Accuracy: 0.4994 Loss: 1.7636312601511435
# Aumentando varianzas
#  --------------------- Individuo 21 ---------------------
# Accuracy: 0.4919 Loss: 1.776803370631869
# Aumentando varianzas
#  --------------------- Individuo 22 ---------------------
# Accuracy: 0.518 Loss: 1.7646365257175378
# Aumentando varianzas
#  --------------------- Individuo 23 ---------------------
# Accuracy: 0.5074 Loss: 1.7948097949442656
# Aumentando varianzas
#  --------------------- Individuo 24 ---------------------
# Accuracy: 0.513 Loss: 1.7644936081088718
# Aumentando varianzas
#  --------------------- Individuo 25 ---------------------
# Accuracy: 0.4964 Loss: 1.8189880995799208
# Aumentando varianzas
#  --------------------- Individuo 26 ---------------------
# Accuracy: 0.5149 Loss: 1.7323593652766685
# Aumentando varianzas
#  --------------------- Individuo 27 ---------------------
# Accuracy: 0.5102 Loss: 1.7779257419469106
# Aumentando varianzas
#  --------------------- Individuo 28 ---------------------
# Accuracy: 0.4922 Loss: 1.742587387561798
# Aumentando varianzas
#  --------------------- Individuo 29 ---------------------
# Accuracy: 0.488 Loss: 1.8884543371017632
# Aumentando varianzas
#  --------------------- Individuo 30 ---------------------
# Accuracy: 0.4665 Loss: 1.7735998302774356
# Aumentando varianzas
#  --------------------- Individuo 31 ---------------------
# Accuracy: 0.495 Loss: 1.768127400704357
# Aumentando varianzas
#  --------------------- Individuo 32 ---------------------
# Accuracy: 0.4662 Loss: 1.9138081502121733
# Aumentando varianzas
#  --------------------- Individuo 33 ---------------------
# Accuracy: 0.4771 Loss: 1.8744711407919978
# Aumentando varianzas
#  --------------------- Individuo 34 ---------------------
# Accuracy: 0.4916 Loss: 1.8216763263773126
# Aumentando varianzas
#  --------------------- Individuo 35 ---------------------
# Accuracy: 0.4945 Loss: 1.8390814719907462
# Aumentando varianzas
#  --------------------- Individuo 36 ---------------------
# Accuracy: 0.4988 Loss: 1.8802122440179596
# Aumentando varianzas
#  --------------------- Individuo 37 ---------------------
# Accuracy: 0.5268 Loss: 1.722600146022904
# Aumentando varianzas
#  --------------------- Individuo 38 ---------------------
# Accuracy: 0.4974 Loss: 1.8464390447987316
# Aumentando varianzas
#  --------------------- Individuo 39 ---------------------
# Accuracy: 0.5267 Loss: 1.765490376431009
# Aumentando varianzas
#  --------------------- Individuo 40 ---------------------
# Accuracy: 0.4795 Loss: 1.9011868157655076
# Aumentando varianzas
#  --------------------- Individuo 41 ---------------------
# Accuracy: 0.474 Loss: 1.8417123577478902
# Aumentando varianzas
#  --------------------- Individuo 42 ---------------------
# Accuracy: 0.4558 Loss: 1.899394909286743
# Aumentando varianzas
#  --------------------- Individuo 43 ---------------------
# Accuracy: 0.4947 Loss: 1.7877677926017195
# Aumentando varianzas
#  --------------------- Individuo 44 ---------------------
# Accuracy: 0.4981 Loss: 1.8455910362550974
# Aumentando varianzas
#  --------------------- Individuo 45 ---------------------
# Accuracy: 0.4921 Loss: 1.7978334230230288
# Aumentando varianzas
#  --------------------- Individuo 46 ---------------------
# Accuracy: 0.4788 Loss: 1.8023716121378457
# Aumentando varianzas
#  --------------------- Individuo 47 ---------------------
# Accuracy: 0.494 Loss: 1.8131709647605487
# Aumentando varianzas
#  --------------------- Individuo 48 ---------------------
# Accuracy: 0.5182 Loss: 1.7455891928709377
# Aumentando varianzas
#  --------------------- Individuo 49 ---------------------
# Accuracy: 0.4939 Loss: 1.841297131212776
# Aumentando varianzas
#  --------------------- Individuo 50 ---------------------
# Accuracy: 0.5019 Loss: 1.788119494457684
# Aumentando varianzas
#  --------------------- Individuo 51 ---------------------
# Accuracy: 0.5095 Loss: 1.6943771330749287
# Aumentando varianzas
#  --------------------- Individuo 52 ---------------------
# Accuracy: 0.5017 Loss: 1.802897443094522
# Aumentando varianzas
#  --------------------- Individuo 53 ---------------------
# Accuracy: 0.4477 Loss: 1.9918808853229903
# Aumentando varianzas
#  --------------------- Individuo 54 ---------------------
# Accuracy: 0.5116 Loss: 1.8099571980173936
# Aumentando varianzas
#  --------------------- Individuo 55 ---------------------
# Accuracy: 0.5252 Loss: 1.6989876444992202
# Aumentando varianzas
#  --------------------- Individuo 56 ---------------------
# Accuracy: 0.5231 Loss: 1.760910534492844
# Aumentando varianzas
#  --------------------- Individuo 57 ---------------------
# Accuracy: 0.4875 Loss: 1.7621905751850293
# Aumentando varianzas
#  --------------------- Individuo 58 ---------------------
# Accuracy: 0.4999 Loss: 1.7579753490360193
# Aumentando varianzas
#  --------------------- Individuo 59 ---------------------
# Accuracy: 0.519 Loss: 1.7173310181368953
# Aumentando varianzas
#  --------------------- Individuo 60 ---------------------
# Accuracy: 0.4774 Loss: 1.797019266563913
# Aumentando varianzas
#  --------------------- Individuo 61 ---------------------
# Accuracy: 0.4675 Loss: 1.8566811304263142
# Aumentando varianzas
#  --------------------- Individuo 62 ---------------------
# Accuracy: 0.4867 Loss: 1.8677564107853433
# Aumentando varianzas
#  --------------------- Individuo 63 ---------------------
# Accuracy: 0.5035 Loss: 1.7886495485025293
# Aumentando varianzas
#  --------------------- Individuo 64 ---------------------
# Accuracy: 0.4662 Loss: 1.9038025925836295
# Aumentando varianzas
#  --------------------- Individuo 65 ---------------------
# Accuracy: 0.4844 Loss: 1.8302670461137582
# Aumentando varianzas
#  --------------------- Individuo 66 ---------------------
# Accuracy: 0.4307 Loss: 1.866434060704068
# Aumentando varianzas
#  --------------------- Individuo 67 ---------------------
# Accuracy: 0.5009 Loss: 1.747107320124536
# Aumentando varianzas
#  --------------------- Individuo 68 ---------------------
# Accuracy: 0.4976 Loss: 1.805785434630216
# Aumentando varianzas
#  --------------------- Individuo 69 ---------------------
# Accuracy: 0.4797 Loss: 1.8021105908981674
# Aumentando varianzas
#  --------------------- Individuo 70 ---------------------
# Accuracy: 0.5126 Loss: 1.7619904639470914
# Aumentando varianzas
#  --------------------- Individuo 71 ---------------------
# Accuracy: 0.48 Loss: 1.8942397005112885
# Aumentando varianzas
#  --------------------- Individuo 72 ---------------------
# Accuracy: 0.5192 Loss: 1.7672191807985915
# Aumentando varianzas
#  --------------------- Individuo 73 ---------------------
# Accuracy: 0.4962 Loss: 1.7893622267581617
# Aumentando varianzas
#  --------------------- Individuo 74 ---------------------
# Accuracy: 0.52 Loss: 1.7101774546496398
# Aumentando varianzas
#  --------------------- Individuo 75 ---------------------
# Accuracy: 0.5093 Loss: 1.7738434590037218
# Aumentando varianzas
#  --------------------- Individuo 76 ---------------------
# Accuracy: 0.4603 Loss: 1.9310082585915276
# Aumentando varianzas
#  --------------------- Individuo 77 ---------------------
# Accuracy: 0.5026 Loss: 1.7619026301766905
# Aumentando varianzas
#  --------------------- Individuo 78 ---------------------
# Accuracy: 0.4897 Loss: 1.8550679650148163
# Aumentando varianzas
#  --------------------- Individuo 79 ---------------------
# Accuracy: 0.5078 Loss: 1.7548015087156954
# Aumentando varianzas
#  --------------------- Individuo 80 ---------------------
# Accuracy: 0.5094 Loss: 1.8110331639914257
# Aumentando varianzas
#  --------------------- Individuo 81 ---------------------
# Accuracy: 0.4707 Loss: 1.9070216091087713
# Aumentando varianzas
#  --------------------- Individuo 82 ---------------------
# Accuracy: 0.5086 Loss: 1.7257202909425702
# Aumentando varianzas
#  --------------------- Individuo 83 ---------------------
# Accuracy: 0.507 Loss: 1.7714953914932583
# Aumentando varianzas
#  --------------------- Individuo 84 ---------------------
# Accuracy: 0.5086 Loss: 1.7810561974030321
# Aumentando varianzas
#  --------------------- Individuo 85 ---------------------
# Accuracy: 0.5313 Loss: 1.6946000589434143
# Aumentando varianzas
#  --------------------- Individuo 86 ---------------------
# Accuracy: 0.5049 Loss: 1.7942910517573052
# Aumentando varianzas
#  --------------------- Individuo 87 ---------------------
# Accuracy: 0.4966 Loss: 1.8197184936774662
# Aumentando varianzas
#  --------------------- Individuo 88 ---------------------
# Accuracy: 0.5073 Loss: 1.7435103252415767
# Aumentando varianzas
#  --------------------- Individuo 89 ---------------------
# Accuracy: 0.5004 Loss: 1.7835018067713588
# Aumentando varianzas
#  --------------------- Individuo 90 ---------------------
# Accuracy: 0.5101 Loss: 1.7991626934932017
# Aumentando varianzas
#  --------------------- Individuo 91 ---------------------
# Accuracy: 0.4637 Loss: 1.906218238041529
# Aumentando varianzas
#  --------------------- Individuo 92 ---------------------
# Accuracy: 0.4973 Loss: 1.7985243461930844
# Aumentando varianzas
#  --------------------- Individuo 93 ---------------------
# Accuracy: 0.5163 Loss: 1.7631847506288982
# Aumentando varianzas
#  --------------------- Individuo 94 ---------------------
# Accuracy: 0.4948 Loss: 1.922934362498086
# Aumentando varianzas
#  --------------------- Individuo 95 ---------------------
# Accuracy: 0.5012 Loss: 1.8353237482288
# Aumentando varianzas
#  --------------------- Individuo 96 ---------------------
# Accuracy: 0.5155 Loss: 1.727729476626267
# Aumentando varianzas
#  --------------------- Individuo 97 ---------------------
# Accuracy: 0.4825 Loss: 1.7873841844251395
# Aumentando varianzas
#  --------------------- Individuo 98 ---------------------
# Accuracy: 0.5025 Loss: 1.7911848383181541
# Aumentando varianzas
#  --------------------- Individuo 99 ---------------------
# Accuracy: 0.4823 Loss: 1.9276886567130418
# Aumentando varianzas
#  --------------------- Individuo 100 ---------------------
# Accuracy: 0.4509 Loss: 1.9013563144542371
# Aumentando varianzas
#  --------------------- Individuo 101 ---------------------
# Accuracy: 0.5 Loss: 1.7844299738059568
# Aumentando varianzas
#  --------------------- Individuo 102 ---------------------
# Accuracy: 0.5237 Loss: 1.7768359333657853
# Aumentando varianzas
#  --------------------- Individuo 103 ---------------------
# Accuracy: 0.5165 Loss: 1.8149716785496763
# Aumentando varianzas
#  --------------------- Individuo 104 ---------------------
# Accuracy: 0.4659 Loss: 1.8941579639454327
# Aumentando varianzas
#  --------------------- Individuo 105 ---------------------
# Accuracy: 0.5279 Loss: 1.7591735806001727
# Aumentando varianzas
#  --------------------- Individuo 106 ---------------------
# Accuracy: 0.5017 Loss: 1.8223586576369109
# Aumentando varianzas
#  --------------------- Individuo 107 ---------------------
# Accuracy: 0.4767 Loss: 1.9115367505861365
# Aumentando varianzas
#  --------------------- Individuo 108 ---------------------
# Accuracy: 0.4783 Loss: 1.9358672178005014
# Aumentando varianzas
#  --------------------- Individuo 109 ---------------------
# Accuracy: 0.5322 Loss: 1.7246669541539439
# Aumentando varianzas
#  --------------------- Individuo 110 ---------------------
# Accuracy: 0.4878 Loss: 1.8766895898467744
# Aumentando varianzas
#  --------------------- Individuo 111 ---------------------
# Accuracy: 0.486 Loss: 1.8052506068783343
# Aumentando varianzas
#  --------------------- Individuo 112 ---------------------
# Accuracy: 0.4896 Loss: 1.8271165148681388
# Aumentando varianzas
#  --------------------- Individuo 113 ---------------------
# Accuracy: 0.4816 Loss: 1.9127663742855687
# Aumentando varianzas
#  --------------------- Individuo 114 ---------------------
# Accuracy: 0.4855 Loss: 1.8120382417498342
# Aumentando varianzas
#  --------------------- Individuo 115 ---------------------
# Accuracy: 0.5106 Loss: 1.810231229838203
# Aumentando varianzas
#  --------------------- Individuo 116 ---------------------
# Accuracy: 0.5052 Loss: 1.796253689719588
# Aumentando varianzas
#  --------------------- Individuo 117 ---------------------
# Accuracy: 0.5012 Loss: 1.7454455308901988
# Aumentando varianzas
#  --------------------- Individuo 118 ---------------------
# Accuracy: 0.5404 Loss: 1.7614042406801678
# Aumentando varianzas
#  --------------------- Individuo 119 ---------------------
# Accuracy: 0.5259 Loss: 1.741394816152275
# Aumentando varianzas
#  --------------------- Individuo 120 ---------------------
# Accuracy: 0.4788 Loss: 1.8306983171216666
# Aumentando varianzas
#  --------------------- Individuo 121 ---------------------
# Accuracy: 0.5129 Loss: 1.7687515845079251
# Aumentando varianzas
#  --------------------- Individuo 122 ---------------------
# Accuracy: 0.4989 Loss: 1.8430974407269216
# Aumentando varianzas
#  --------------------- Individuo 123 ---------------------
# Accuracy: 0.5014 Loss: 1.8408539485748467
# Aumentando varianzas
#  --------------------- Individuo 124 ---------------------
# Accuracy: 0.4728 Loss: 1.880145932097569
# Aumentando varianzas
#  --------------------- Individuo 125 ---------------------
# Accuracy: 0.5134 Loss: 1.7177788246318202
# Aumentando varianzas
#  --------------------- Individuo 126 ---------------------
# Accuracy: 0.4813 Loss: 1.8606711511721696
# Aumentando varianzas
#  --------------------- Individuo 127 ---------------------
# Accuracy: 0.511 Loss: 1.7740996861091964
# Aumentando varianzas
#  --------------------- Individuo 128 ---------------------
# Accuracy: 0.5153 Loss: 1.7293781954461656
# Aumentando varianzas
#  --------------------- Individuo 129 ---------------------
# Accuracy: 0.5149 Loss: 1.762356191644888
# Aumentando varianzas
#  --------------------- Individuo 130 ---------------------
# Accuracy: 0.4949 Loss: 1.8546851685894725
# Aumentando varianzas
#  --------------------- Individuo 131 ---------------------
# Accuracy: 0.4676 Loss: 1.78176157020242
# Aumentando varianzas
#  --------------------- Individuo 132 ---------------------
# Accuracy: 0.4967 Loss: 1.749969653003966
# Aumentando varianzas
#  --------------------- Individuo 133 ---------------------
# Accuracy: 0.517 Loss: 1.759467847969221
# Aumentando varianzas
#  --------------------- Individuo 134 ---------------------
# Accuracy: 0.5136 Loss: 1.760521800316813
# Aumentando varianzas
#  --------------------- Individuo 135 ---------------------
# Accuracy: 0.4879 Loss: 1.7445527908137388
# Aumentando varianzas
#  --------------------- Individuo 136 ---------------------
# Accuracy: 0.4774 Loss: 1.8381823571136846
# Aumentando varianzas
#  --------------------- Individuo 137 ---------------------
# Accuracy: 0.511 Loss: 1.8285540580139745
# Aumentando varianzas
#  --------------------- Individuo 138 ---------------------
# Accuracy: 0.4902 Loss: 1.8118005631220004
# Aumentando varianzas
#  --------------------- Individuo 139 ---------------------
# Accuracy: 0.5293 Loss: 1.7401306019414722
# Aumentando varianzas
#  --------------------- Individuo 140 ---------------------
# Accuracy: 0.4905 Loss: 1.8547397261995184
# Aumentando varianzas
#  --------------------- Individuo 141 ---------------------
# Accuracy: 0.5259 Loss: 1.788049111890671
# Aumentando varianzas
#  --------------------- Individuo 142 ---------------------
# Accuracy: 0.4578 Loss: 1.9235228728455351
# Aumentando varianzas
#  --------------------- Individuo 143 ---------------------
# Accuracy: 0.4521 Loss: 1.811507155447055
# Aumentando varianzas
#  --------------------- Individuo 144 ---------------------
# Accuracy: 0.5214 Loss: 1.7442324422204587
# Aumentando varianzas
#  --------------------- Individuo 145 ---------------------
# Accuracy: 0.4594 Loss: 1.8653378675660819
# Aumentando varianzas
#  --------------------- Individuo 146 ---------------------
# Accuracy: 0.4467 Loss: 1.8701675366562651
# Aumentando varianzas
#  --------------------- Individuo 147 ---------------------
# Accuracy: 0.4691 Loss: 1.9648207951994503
# Aumentando varianzas
#  --------------------- Individuo 148 ---------------------
# Accuracy: 0.5154 Loss: 1.7656635178629394
# Aumentando varianzas
#  --------------------- Individuo 149 ---------------------
# Accuracy: 0.4883 Loss: 1.728384294015977
# Aumentando varianzas
#  --------------------- Individuo 150 ---------------------
# Accuracy: 0.4945 Loss: 1.8111371936090768
# Aumentando varianzas
#  --------------------- Individuo 151 ---------------------
# Accuracy: 0.4988 Loss: 1.885163276396749
# Aumentando varianzas
#  --------------------- Individuo 152 ---------------------
# Accuracy: 0.5129 Loss: 1.6921189787137845
# Aumentando varianzas
#  --------------------- Individuo 153 ---------------------
# Accuracy: 0.4335 Loss: 1.9544728267223328
# Aumentando varianzas
#  --------------------- Individuo 154 ---------------------
# Accuracy: 0.4986 Loss: 1.7734574013963684
# Aumentando varianzas
#  --------------------- Individuo 155 ---------------------
# Accuracy: 0.4804 Loss: 1.800953139429507
# Aumentando varianzas
#  --------------------- Individuo 156 ---------------------
# Accuracy: 0.4786 Loss: 1.8135279648749114
# Aumentando varianzas
#  --------------------- Individuo 157 ---------------------
# Accuracy: 0.5257 Loss: 1.6827298449280927
# Aumentando varianzas
#  --------------------- Individuo 158 ---------------------
# Accuracy: 0.5252 Loss: 1.7180055550602087
# Aumentando varianzas
#  --------------------- Individuo 159 ---------------------
# Accuracy: 0.4668 Loss: 1.9449327528629157
# Aumentando varianzas
#  --------------------- Individuo 160 ---------------------
# Accuracy: 0.4866 Loss: 1.8201191560996464
# Aumentando varianzas
#  --------------------- Individuo 161 ---------------------
# Accuracy: 0.5065 Loss: 1.7725687661134373
# Aumentando varianzas
#  --------------------- Individuo 162 ---------------------
# Accuracy: 0.5041 Loss: 1.8183787890407435
# Aumentando varianzas
#  --------------------- Individuo 163 ---------------------
# Accuracy: 0.482 Loss: 1.803987310975409
# Aumentando varianzas
#  --------------------- Individuo 164 ---------------------
# Accuracy: 0.4617 Loss: 1.8450754554680242
# Aumentando varianzas
#  --------------------- Individuo 165 ---------------------
# Accuracy: 0.5213 Loss: 1.7951161196774534
# Aumentando varianzas
#  --------------------- Individuo 166 ---------------------
# Accuracy: 0.4969 Loss: 1.7630349345829175
# Aumentando varianzas
#  --------------------- Individuo 167 ---------------------
# Accuracy: 0.4989 Loss: 1.8285700878523805
# Aumentando varianzas
#  --------------------- Individuo 168 ---------------------
# Accuracy: 0.4139 Loss: 2.0860674849251652
# Aumentando varianzas
#  --------------------- Individuo 169 ---------------------
# Accuracy: 0.4983 Loss: 1.8507828329835097
# Aumentando varianzas
#  --------------------- Individuo 170 ---------------------
# Accuracy: 0.5213 Loss: 1.7297506963505465
# Aumentando varianzas
#  --------------------- Individuo 171 ---------------------
# Accuracy: 0.4809 Loss: 1.8713247327853346
# Aumentando varianzas
#  --------------------- Individuo 172 ---------------------
# Accuracy: 0.517 Loss: 1.742101088356789
# Aumentando varianzas
#  --------------------- Individuo 173 ---------------------
# Accuracy: 0.521 Loss: 1.727206690689487
# Aumentando varianzas
#  --------------------- Individuo 174 ---------------------
# Accuracy: 0.5146 Loss: 1.8370540762496421
# Aumentando varianzas
#  --------------------- Individuo 175 ---------------------
# Accuracy: 0.529 Loss: 1.736894048388352
# Aumentando varianzas
#  --------------------- Individuo 176 ---------------------
# Accuracy: 0.4468 Loss: 1.9301857076337576
# Aumentando varianzas
#  --------------------- Individuo 177 ---------------------
# Accuracy: 0.4888 Loss: 1.798714131802854
# Aumentando varianzas
#  --------------------- Individuo 178 ---------------------
# Accuracy: 0.5184 Loss: 1.7516757152269564
# Aumentando varianzas
#  --------------------- Individuo 179 ---------------------
# Accuracy: 0.4972 Loss: 1.796250140423055
# Aumentando varianzas
#  --------------------- Individuo 180 ---------------------
# Accuracy: 0.5082 Loss: 1.826932721888013
# Aumentando varianzas
#  --------------------- Individuo 181 ---------------------
# Accuracy: 0.4765 Loss: 1.902047520708245
# Aumentando varianzas
#  --------------------- Individuo 182 ---------------------
# Accuracy: 0.5236 Loss: 1.7632616198886082
# Aumentando varianzas
#  --------------------- Individuo 183 ---------------------
# Accuracy: 0.4867 Loss: 1.7922634395492045
# Aumentando varianzas
#  --------------------- Individuo 184 ---------------------
# Accuracy: 0.496 Loss: 1.7675813561510247
# Aumentando varianzas
#  --------------------- Individuo 185 ---------------------
# Accuracy: 0.4991 Loss: 1.801524434553083
# Aumentando varianzas
#  --------------------- Individuo 186 ---------------------
# Accuracy: 0.4828 Loss: 1.9611295091221705
# Aumentando varianzas
#  --------------------- Individuo 187 ---------------------
# Accuracy: 0.5121 Loss: 1.8272536611922867
# Aumentando varianzas
#  --------------------- Individuo 188 ---------------------
# Accuracy: 0.4508 Loss: 1.9448712699858428
# Aumentando varianzas
#  --------------------- Individuo 189 ---------------------
# Accuracy: 0.5088 Loss: 1.773790449437583
# Aumentando varianzas
#  --------------------- Individuo 190 ---------------------
# Accuracy: 0.4788 Loss: 1.89477833747254
# Aumentando varianzas
#  --------------------- Individuo 191 ---------------------
# Accuracy: 0.5206 Loss: 1.8043530656553595
# Aumentando varianzas
#  --------------------- Individuo 192 ---------------------
# Accuracy: 0.507 Loss: 1.6853632164733183
# Aumentando varianzas
#  --------------------- Individuo 193 ---------------------
# Accuracy: 0.4461 Loss: 1.9851709415235788
# Aumentando varianzas
#  --------------------- Individuo 194 ---------------------
# Accuracy: 0.4972 Loss: 1.8161718767622244
# Aumentando varianzas
#  --------------------- Individuo 195 ---------------------
# Accuracy: 0.5297 Loss: 1.7191791141124637
# Aumentando varianzas
#  --------------------- Individuo 196 ---------------------
# Accuracy: 0.4711 Loss: 1.8579073621488897
# Aumentando varianzas
#  --------------------- Individuo 197 ---------------------
# Accuracy: 0.4747 Loss: 1.7938388999160904
# Aumentando varianzas
#  --------------------- Individuo 198 ---------------------
# Accuracy: 0.5093 Loss: 1.7459050669999379
# Aumentando varianzas
#  --------------------- Individuo 199 ---------------------
# Accuracy: 0.5282 Loss: 1.7385541186918079
# Aumentando varianzas
#  --------------------- Individuo 200 ---------------------
# Accuracy: 0.5113 Loss: 1.7841963124702045
# Aumentando varianzas
#  --------------------- Individuo 201 ---------------------
# Accuracy: 0.5063 Loss: 1.7326125324229755
# Aumentando varianzas
#  --------------------- Individuo 202 ---------------------
# Accuracy: 0.4863 Loss: 1.8925676987604108
# Aumentando varianzas
#  --------------------- Individuo 203 ---------------------
# Accuracy: 0.5295 Loss: 1.7886431491588388
# Aumentando varianzas
#  --------------------- Individuo 204 ---------------------
# Accuracy: 0.4193 Loss: 2.1274804585730025
# Aumentando varianzas
#  --------------------- Individuo 205 ---------------------
# Accuracy: 0.488 Loss: 1.8229181612544048
# Aumentando varianzas
#  --------------------- Individuo 206 ---------------------
# Accuracy: 0.4659 Loss: 1.8195578329398503
# Aumentando varianzas
#  --------------------- Individuo 207 ---------------------
# Accuracy: 0.4607 Loss: 1.8184980231782664
# Aumentando varianzas
#  --------------------- Individuo 208 ---------------------
# Accuracy: 0.5222 Loss: 1.751162770916434
# Aumentando varianzas
#  --------------------- Individuo 209 ---------------------
# Accuracy: 0.516 Loss: 1.7617252028506736
# Aumentando varianzas
#  --------------------- Individuo 210 ---------------------
# Accuracy: 0.4515 Loss: 2.059945353461653
# Aumentando varianzas
#  --------------------- Individuo 211 ---------------------
# Accuracy: 0.5155 Loss: 1.7717313281715374
# Aumentando varianzas
#  --------------------- Individuo 212 ---------------------
# Accuracy: 0.4975 Loss: 1.7837584913539155
# Aumentando varianzas
#  --------------------- Individuo 213 ---------------------
# Accuracy: 0.5146 Loss: 1.7807378095129263
# Aumentando varianzas
#  --------------------- Individuo 214 ---------------------
# Accuracy: 0.4985 Loss: 1.8036131729250369
# Aumentando varianzas
#  --------------------- Individuo 215 ---------------------
# Accuracy: 0.5092 Loss: 1.7401484726639964
# Aumentando varianzas
#  --------------------- Individuo 216 ---------------------
# Accuracy: 0.5174 Loss: 1.780558030318726
# Aumentando varianzas
#  --------------------- Individuo 217 ---------------------
# Accuracy: 0.4953 Loss: 1.8904421696882419
# Aumentando varianzas
#  --------------------- Individuo 218 ---------------------
# Accuracy: 0.489 Loss: 1.7718582697536633
# Aumentando varianzas
#  --------------------- Individuo 219 ---------------------
# Accuracy: 0.4899 Loss: 1.8434221954906689
# Aumentando varianzas
#  --------------------- Individuo 220 ---------------------
# Accuracy: 0.4936 Loss: 1.8689993316560145
# Aumentando varianzas
#  --------------------- Individuo 221 ---------------------
# Accuracy: 0.4946 Loss: 1.7960729416069168
# Aumentando varianzas
#  --------------------- Individuo 222 ---------------------
# Accuracy: 0.4732 Loss: 1.7590309601000813
# Aumentando varianzas
#  --------------------- Individuo 223 ---------------------
# Accuracy: 0.4874 Loss: 1.8135289944651183
# Aumentando varianzas
#  --------------------- Individuo 224 ---------------------
# Accuracy: 0.4576 Loss: 1.883265027762069
# Aumentando varianzas
#  --------------------- Individuo 225 ---------------------
# Accuracy: 0.5163 Loss: 1.7714145396981398
# Aumentando varianzas
#  --------------------- Individuo 226 ---------------------
# Accuracy: 0.4921 Loss: 1.810669035100571
# Aumentando varianzas
#  --------------------- Individuo 227 ---------------------
# Accuracy: 0.5042 Loss: 1.8051124698365741
# Aumentando varianzas
#  --------------------- Individuo 228 ---------------------
# Accuracy: 0.4943 Loss: 1.7841523425353458
# Aumentando varianzas
#  --------------------- Individuo 229 ---------------------
# Accuracy: 0.4969 Loss: 1.7597154104496207
# Aumentando varianzas
#  --------------------- Individuo 230 ---------------------
# Accuracy: 0.5187 Loss: 1.7176137470528292
# Aumentando varianzas
#  --------------------- Individuo 231 ---------------------
# Accuracy: 0.5016 Loss: 1.8206472764234714
# Aumentando varianzas
#  --------------------- Individuo 232 ---------------------
# Accuracy: 0.4959 Loss: 1.829249592540819
# Aumentando varianzas
#  --------------------- Individuo 233 ---------------------
# Accuracy: 0.4526 Loss: 1.9953715100007898
# Aumentando varianzas
#  --------------------- Individuo 234 ---------------------
# Accuracy: 0.5196 Loss: 1.8012763026272853
# Aumentando varianzas
#  --------------------- Individuo 235 ---------------------
# Accuracy: 0.4962 Loss: 1.7792687423698736
# Aumentando varianzas
#  --------------------- Individuo 236 ---------------------
# Accuracy: 0.4953 Loss: 1.7454842095789702
# Aumentando varianzas
#  --------------------- Individuo 237 ---------------------
# Accuracy: 0.4944 Loss: 1.7718600004225435
# Aumentando varianzas
#  --------------------- Individuo 238 ---------------------
# Accuracy: 0.5069 Loss: 1.7541562943812221
# Aumentando varianzas
#  --------------------- Individuo 239 ---------------------
# Accuracy: 0.5084 Loss: 1.8316853829966786
# Aumentando varianzas
#  --------------------- Individuo 240 ---------------------
# Accuracy: 0.5108 Loss: 1.8223822363807112
# Aumentando varianzas
#  --------------------- Individuo 241 ---------------------
# Accuracy: 0.5122 Loss: 1.78953430750181
# Aumentando varianzas
#  --------------------- Individuo 242 ---------------------
# Accuracy: 0.5106 Loss: 1.7077949329105484
# Aumentando varianzas
#  --------------------- Individuo 243 ---------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 96
#      94 total = 0
#      95 with torch.no_grad():
# ---> 96     for data in test_loader:
#      97         images, labels = data[0].to(device), data[1].to(device)
#      98         outputs = masked_net(images)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\utils\data\dataloader.py:484, in DataLoader.__iter__(self)
#     482     return self._iterator
#     483 else:
# --> 484     return self._get_iterator()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\utils\data\dataloader.py:415, in DataLoader._get_iterator(self)
#     413 else:
#     414     self.check_worker_number_rationality()
# --> 415     return _MultiProcessingDataLoaderIter(self)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\utils\data\dataloader.py:1138, in _MultiProcessingDataLoaderIter.__init__(self, loader)
#    1131 w.daemon = True
#    1132 # NB: Process.start() actually take some time as it needs to
#    1133 #     start a process and pass the arguments over via a pipe.
#    1134 #     Therefore, we only add a worker to self._workers list after
#    1135 #     it started, so that we do not call .join() if program dies
#    1136 #     before it starts, and __del__ tries to join but will get:
#    1137 #     AssertionError: can only join a started process.
# -> 1138 w.start()
#    1139 self._index_queues.append(index_queue)
#    1140 self._workers.append(w)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\multiprocessing\process.py:121, in BaseProcess.start(self)
#     118 assert not _current_process._config.get('daemon'), \
#     119        'daemonic processes are not allowed to have children'
#     120 _cleanup()
# --> 121 self._popen = self._Popen(self)
#     122 self._sentinel = self._popen.sentinel
#     123 # Avoid a refcycle if the target function holds an indirect
#     124 # reference to the process object (see bpo-30775)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\multiprocessing\context.py:224, in Process._Popen(process_obj)
#     222 @staticmethod
#     223 def _Popen(process_obj):
# --> 224     return _default_context.get_context().Process._Popen(process_obj)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\multiprocessing\context.py:336, in SpawnProcess._Popen(process_obj)
#     333 @staticmethod
#     334 def _Popen(process_obj):
#     335     from .popen_spawn_win32 import Popen
# --> 336     return Popen(process_obj)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\multiprocessing\popen_spawn_win32.py:95, in Popen.__init__(self, process_obj)
#      93 try:
#      94     reduction.dump(prep_data, to_child)
# ---> 95     reduction.dump(process_obj, to_child)
#      96 finally:
#      97     set_spawning_popen(None)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\multiprocessing\reduction.py:60, in dump(obj, file, protocol)
#      58 def dump(obj, file, protocol=None):
#      59     '''Replacement for pickle.dump() using ForkingPickler.'''
# ---> 60     ForkingPickler(file, protocol).dump(obj)
#
# KeyboardInterrupt:

# %%
print(train_loss)
print(test_accuracies)
print(max(test_accuracies))
index_max_accuracy = test_accuracies.index(max(test_accuracies))
print(index_max_accuracy)

print("-----------------")
print(min(train_loss))
index = train_loss.index(min(train_loss))
print(index)
# Out:
# [1.7398091833609755, 1.6404514466710103, 1.5585751423750387, 1.5840470208536328, 1.5977383319221798, 1.6426894137316652, 1.6965119410353853, 1.602287230817863, 1.6779418432194253, 1.6846842607268897, 1.7510470784533665, 1.6660529387271619, 1.7833531210794473, 1.7705016177328652, 1.8778988755572483, 1.7423474245211656, 1.8367824758715032, 1.7844117593277447, 1.695369417557631, 1.7636312601511435, 1.776803370631869, 1.7646365257175378, 1.7948097949442656, 1.7644936081088718, 1.8189880995799208, 1.7323593652766685, 1.7779257419469106, 1.742587387561798, 1.8884543371017632, 1.7735998302774356, 1.768127400704357, 1.9138081502121733, 1.8744711407919978, 1.8216763263773126, 1.8390814719907462, 1.8802122440179596, 1.722600146022904, 1.8464390447987316, 1.765490376431009, 1.9011868157655076, 1.8417123577478902, 1.899394909286743, 1.7877677926017195, 1.8455910362550974, 1.7978334230230288, 1.8023716121378457, 1.8131709647605487, 1.7455891928709377, 1.841297131212776, 1.788119494457684, 1.6943771330749287, 1.802897443094522, 1.9918808853229903, 1.8099571980173936, 1.6989876444992202, 1.760910534492844, 1.7621905751850293, 1.7579753490360193, 1.7173310181368953, 1.797019266563913, 1.8566811304263142, 1.8677564107853433, 1.7886495485025293, 1.9038025925836295, 1.8302670461137582, 1.866434060704068, 1.747107320124536, 1.805785434630216, 1.8021105908981674, 1.7619904639470914, 1.8942397005112885, 1.7672191807985915, 1.7893622267581617, 1.7101774546496398, 1.7738434590037218, 1.9310082585915276, 1.7619026301766905, 1.8550679650148163, 1.7548015087156954, 1.8110331639914257, 1.9070216091087713, 1.7257202909425702, 1.7714953914932583, 1.7810561974030321, 1.6946000589434143, 1.7942910517573052, 1.8197184936774662, 1.7435103252415767, 1.7835018067713588, 1.7991626934932017, 1.906218238041529, 1.7985243461930844, 1.7631847506288982, 1.922934362498086, 1.8353237482288, 1.727729476626267, 1.7873841844251395, 1.7911848383181541, 1.9276886567130418, 1.9013563144542371, 1.7844299738059568, 1.7768359333657853, 1.8149716785496763, 1.8941579639454327, 1.7591735806001727, 1.8223586576369109, 1.9115367505861365, 1.9358672178005014, 1.7246669541539439, 1.8766895898467744, 1.8052506068783343, 1.8271165148681388, 1.9127663742855687, 1.8120382417498342, 1.810231229838203, 1.796253689719588, 1.7454455308901988, 1.7614042406801678, 1.741394816152275, 1.8306983171216666, 1.7687515845079251, 1.8430974407269216, 1.8408539485748467, 1.880145932097569, 1.7177788246318202, 1.8606711511721696, 1.7740996861091964, 1.7293781954461656, 1.762356191644888, 1.8546851685894725, 1.78176157020242, 1.749969653003966, 1.759467847969221, 1.760521800316813, 1.7445527908137388, 1.8381823571136846, 1.8285540580139745, 1.8118005631220004, 1.7401306019414722, 1.8547397261995184, 1.788049111890671, 1.9235228728455351, 1.811507155447055, 1.7442324422204587, 1.8653378675660819, 1.8701675366562651, 1.9648207951994503, 1.7656635178629394, 1.728384294015977, 1.8111371936090768, 1.885163276396749, 1.6921189787137845, 1.9544728267223328, 1.7734574013963684, 1.800953139429507, 1.8135279648749114, 1.6827298449280927, 1.7180055550602087, 1.9449327528629157, 1.8201191560996464, 1.7725687661134373, 1.8183787890407435, 1.803987310975409, 1.8450754554680242, 1.7951161196774534, 1.7630349345829175, 1.8285700878523805, 2.0860674849251652, 1.8507828329835097, 1.7297506963505465, 1.8713247327853346, 1.742101088356789, 1.727206690689487, 1.8370540762496421, 1.736894048388352, 1.9301857076337576, 1.798714131802854, 1.7516757152269564, 1.796250140423055, 1.826932721888013, 1.902047520708245, 1.7632616198886082, 1.7922634395492045, 1.7675813561510247, 1.801524434553083, 1.9611295091221705, 1.8272536611922867, 1.9448712699858428, 1.773790449437583, 1.89477833747254, 1.8043530656553595, 1.6853632164733183, 1.9851709415235788, 1.8161718767622244, 1.7191791141124637, 1.8579073621488897, 1.7938388999160904, 1.7459050669999379, 1.7385541186918079, 1.7841963124702045, 1.7326125324229755, 1.8925676987604108, 1.788643 ...
# [0.4837, 0.5139, 0.537, 0.5155, 0.5404, 0.5037, 0.4874, 0.5295, 0.5068, 0.5246, 0.5085, 0.5344, 0.4997, 0.4764, 0.4769, 0.5117, 0.4867, 0.5078, 0.5271, 0.4994, 0.4919, 0.518, 0.5074, 0.513, 0.4964, 0.5149, 0.5102, 0.4922, 0.488, 0.4665, 0.495, 0.4662, 0.4771, 0.4916, 0.4945, 0.4988, 0.5268, 0.4974, 0.5267, 0.4795, 0.474, 0.4558, 0.4947, 0.4981, 0.4921, 0.4788, 0.494, 0.5182, 0.4939, 0.5019, 0.5095, 0.5017, 0.4477, 0.5116, 0.5252, 0.5231, 0.4875, 0.4999, 0.519, 0.4774, 0.4675, 0.4867, 0.5035, 0.4662, 0.4844, 0.4307, 0.5009, 0.4976, 0.4797, 0.5126, 0.48, 0.5192, 0.4962, 0.52, 0.5093, 0.4603, 0.5026, 0.4897, 0.5078, 0.5094, 0.4707, 0.5086, 0.507, 0.5086, 0.5313, 0.5049, 0.4966, 0.5073, 0.5004, 0.5101, 0.4637, 0.4973, 0.5163, 0.4948, 0.5012, 0.5155, 0.4825, 0.5025, 0.4823, 0.4509, 0.5, 0.5237, 0.5165, 0.4659, 0.5279, 0.5017, 0.4767, 0.4783, 0.5322, 0.4878, 0.486, 0.4896, 0.4816, 0.4855, 0.5106, 0.5052, 0.5012, 0.5404, 0.5259, 0.4788, 0.5129, 0.4989, 0.5014, 0.4728, 0.5134, 0.4813, 0.511, 0.5153, 0.5149, 0.4949, 0.4676, 0.4967, 0.517, 0.5136, 0.4879, 0.4774, 0.511, 0.4902, 0.5293, 0.4905, 0.5259, 0.4578, 0.4521, 0.5214, 0.4594, 0.4467, 0.4691, 0.5154, 0.4883, 0.4945, 0.4988, 0.5129, 0.4335, 0.4986, 0.4804, 0.4786, 0.5257, 0.5252, 0.4668, 0.4866, 0.5065, 0.5041, 0.482, 0.4617, 0.5213, 0.4969, 0.4989, 0.4139, 0.4983, 0.5213, 0.4809, 0.517, 0.521, 0.5146, 0.529, 0.4468, 0.4888, 0.5184, 0.4972, 0.5082, 0.4765, 0.5236, 0.4867, 0.496, 0.4991, 0.4828, 0.5121, 0.4508, 0.5088, 0.4788, 0.5206, 0.507, 0.4461, 0.4972, 0.5297, 0.4711, 0.4747, 0.5093, 0.5282, 0.5113, 0.5063, 0.4863, 0.5295, 0.4193, 0.488, 0.4659, 0.4607, 0.5222, 0.516, 0.4515, 0.5155, 0.4975, 0.5146, 0.4985, 0.5092, 0.5174, 0.4953, 0.489, 0.4899, 0.4936, 0.4946, 0.4732, 0.4874, 0.4576, 0.5163, 0.4921, 0.5042, 0.4943, 0.4969, 0.5187, 0.5016, 0.4959, 0.4526, 0.5196, 0.4962, 0.4953, 0.4944, 0.5069, 0.5084, 0.5108, 0.5122, 0.5106]
# 0.5404
# 4
# -----------------
# 1.5585751423750387
# 2

# %%
# Creamos la figura y definimos dos subgráficos (1 fila, 2 columnas)
plt.figure(figsize=(10, 5))

# Primer gráfico en la posición 1 (izquierda)
plt.subplot(1, 2, 1)  # 1 fila, 2 columnas, primer gráfico
plt.plot(train_loss, color='blue', marker='o')
plt.title("Gráfico de Pérdida")
plt.xlabel("Épocas")
plt.ylabel("Valores de pérdida")

# Calcular la regresión lineal para train_loss
epochs = np.arange(len(train_loss))
m, b = np.polyfit(epochs, train_loss, 1)
plt.plot(epochs, m*epochs + b, color='red', linestyle='--', label='Tendencia')


# Segundo gráfico en la posición 2 (derecha)
plt.subplot(1, 2, 2)  # 1 fila, 2 columnas, segundo gráfico
plt.plot(test_accuracies, color='green', marker='s')
plt.title("Gráfico de aciertos")
plt.xlabel("Épocas")
plt.ylabel("% de aciertos")

# Calcular la regresión lineal para test_accuracies
epochs_test = np.arange(len(test_accuracies))
m, b = np.polyfit(epochs_test, test_accuracies, 1)
plt.plot(epochs_test, m*epochs_test + b, color='red', linestyle='--', label='Tendencia')

# Mostramos los gráficos
plt.tight_layout()  # Ajustamos para que no se solapen los gráficos
plt.legend()
plt.show()
