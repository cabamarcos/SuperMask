# %%
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms, models
from torch.utils.data import DataLoader, random_split
import copy
import matplotlib.pyplot as plt

from utils.apply_mask_alexnet import *

# %%
# Configuración
batch_size = 64
threshold_accuracy = 0.70
sparsity_percentage = 0.1  # Porcentaje de pesos a conservar (más altos)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# Dataset Animals10
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
])

data_dir = "./animals10"

train_dataset = datasets.ImageFolder(root=os.path.join(data_dir, "train"), transform=transform)
test_dataset = datasets.ImageFolder(root=os.path.join(data_dir, "test"), transform=transform)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
net = models.alexnet(pretrained=False)
net.classifier[6] = nn.Linear(net.classifier[6].in_features, 10)

mask = models.alexnet(pretrained=False)
mask.classifier[6] = nn.Linear(mask.classifier[6].in_features, 10)

net.to(device)
mask.to(device)
# Out:
# C:\Users\Usuario\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\Usuario\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=4096, out_features=10, bias=True)
#   )
# )

# %%
# Congelar los parámetros de net (no se entrenarán)
for param in net.parameters():
    param.requires_grad = False

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(mask.parameters(), lr=0.001)
epoch = 0
saved = False
losses = []
accuracies = []

while True:
    masked_model = MaskedForward(net, mask, sparsity_percentage).to(device)
    # Guardar copia de los pesos de net para verificar que no cambian
    # net_before = [p.clone().detach() for p in net.parameters()]
    masked_model.train()
    running_loss = 0.0

    epoch += 1

    print(f"\n===== Epoch {epoch} =====")

        # Guardar copia de los pesos de mask
    # mask_before = [p.clone().detach() for p in mask.parameters()]

    for batch_idx, (images, labels) in enumerate(train_loader):
        images, labels = images.to(device), labels.to(device)
    
        optimizer.zero_grad()
        outputs = masked_model(images)
        loss = criterion(outputs, labels)
        loss.backward()

        # # Verificar gradientes
        # for name, param in mask.named_parameters():
        #     if param.grad is not None:
        #         print(f"[Grad] {name}: grad norm = {param.grad.norm().item():.6f}")
        #     else:
        #         print(f"[Grad] {name}: NO grad")
        optimizer.step()

        running_loss += loss.item()
        # if batch_idx % 10 == 0:
        #     print(f"Batch {batch_idx}, Loss: {loss.item():.4f}")

    avg_loss = running_loss / len(train_loader)
    losses.append(avg_loss)

    # Evaluación
    masked_model.eval()
    correct, total = 0, 0
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = masked_model(images)
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    accuracy = 100.0 * correct / total
    accuracies.append(accuracy)

    #     # Verificar cambios en los parámetros de mask
    # for (before, after), name in zip(zip(mask_before, mask.parameters()), mask.state_dict().keys()):
    #     delta = (after - before).abs().sum().item()
    #     print(f"[Update] {name}: Δ = {delta:.6f}")

    # # Verificar que net no ha sido modificado
    # for (before, after), name in zip(zip(net_before, net.parameters()), net.state_dict().keys()):
    #     delta = (after - before).abs().sum().item()
    #     print(f"[Check Net] {name}: Δ = {delta:.6f}")

    print(f"Epoch {epoch}: Avg Loss = {avg_loss:.4f}, Test Accuracy = {accuracy:.2f}%")

    if accuracy >= threshold_accuracy * 100:
        print("Reached target accuracy. Stopping training.")
        if not saved:
            # Guardar net y mask
            torch.save(net.state_dict(), "net.pth")
            torch.save(mask.state_dict(), "mask.pth")
            print(f"Models saved)")
            saved = True
        else:
            print("Model already saved, skipping save.")
        break
# Out:
# ===== Epoch 1 =====
# Epoch 1: Avg Loss = 2.2170, Test Accuracy = 18.57%
#
# ===== Epoch 2 =====
# Epoch 2: Avg Loss = 2.2104, Test Accuracy = 18.57%
#
# ===== Epoch 3 =====
# Epoch 3: Avg Loss = 2.2087, Test Accuracy = 18.41%
#
# ===== Epoch 4 =====
# Epoch 4: Avg Loss = 2.2055, Test Accuracy = 18.41%
#
# ===== Epoch 5 =====
# Epoch 5: Avg Loss = 2.2033, Test Accuracy = 18.41%
#
# ===== Epoch 6 =====
# Epoch 6: Avg Loss = 2.1813, Test Accuracy = 19.06%
#
# ===== Epoch 7 =====
# Epoch 7: Avg Loss = 2.1163, Test Accuracy = 22.67%
#
# ===== Epoch 8 =====
# Epoch 8: Avg Loss = 2.0738, Test Accuracy = 26.88%
#
# ===== Epoch 9 =====
# Epoch 9: Avg Loss = 2.0081, Test Accuracy = 27.46%
#
# ===== Epoch 10 =====
# Epoch 10: Avg Loss = 1.9725, Test Accuracy = 30.85%
#
# ===== Epoch 11 =====
# Epoch 11: Avg Loss = 1.9344, Test Accuracy = 30.68%
#
# ===== Epoch 12 =====
# Epoch 12: Avg Loss = 1.9164, Test Accuracy = 31.83%
#
# ===== Epoch 13 =====
# Epoch 13: Avg Loss = 1.8872, Test Accuracy = 32.89%
#
# ===== Epoch 14 =====
# Epoch 14: Avg Loss = 1.8678, Test Accuracy = 32.84%
#
# ===== Epoch 15 =====
# Epoch 15: Avg Loss = 1.8421, Test Accuracy = 33.81%
#
# ===== Epoch 16 =====
# Epoch 16: Avg Loss = 1.8266, Test Accuracy = 34.25%
#
# ===== Epoch 17 =====
# Epoch 17: Avg Loss = 1.8075, Test Accuracy = 34.15%
#
# ===== Epoch 18 =====
# Epoch 18: Avg Loss = 1.7982, Test Accuracy = 35.39%
#
# ===== Epoch 19 =====
# Epoch 19: Avg Loss = 1.7817, Test Accuracy = 33.70%
#
# ===== Epoch 20 =====
# Epoch 20: Avg Loss = 1.7801, Test Accuracy = 36.10%
#
# ===== Epoch 21 =====
# Epoch 21: Avg Loss = 1.7635, Test Accuracy = 37.84%
#
# ===== Epoch 22 =====
# Epoch 22: Avg Loss = 1.7457, Test Accuracy = 37.49%
#
# ===== Epoch 23 =====
# Epoch 23: Avg Loss = 1.7391, Test Accuracy = 35.47%
#
# ===== Epoch 24 =====
# Epoch 24: Avg Loss = 1.7324, Test Accuracy = 37.72%
#
# ===== Epoch 25 =====
# Epoch 25: Avg Loss = 1.7200, Test Accuracy = 39.04%
#
# ===== Epoch 26 =====
# Epoch 26: Avg Loss = 1.7124, Test Accuracy = 36.52%
#
# ===== Epoch 27 =====
# Epoch 27: Avg Loss = 1.7065, Test Accuracy = 38.83%
#
# ===== Epoch 28 =====
# Epoch 28: Avg Loss = 1.7002, Test Accuracy = 39.55%
#
# ===== Epoch 29 =====
# Epoch 29: Avg Loss = 1.6869, Test Accuracy = 40.93%
#
# ===== Epoch 30 =====
# Epoch 30: Avg Loss = 1.6758, Test Accuracy = 40.09%
#
# ===== Epoch 31 =====
# Epoch 31: Avg Loss = 1.6714, Test Accuracy = 41.56%
#
# ===== Epoch 32 =====
# Epoch 32: Avg Loss = 1.6656, Test Accuracy = 39.06%
#
# ===== Epoch 33 =====
# Epoch 33: Avg Loss = 1.6613, Test Accuracy = 40.72%
#
# ===== Epoch 34 =====
# Epoch 34: Avg Loss = 1.6490, Test Accuracy = 42.53%
#
# ===== Epoch 35 =====
# Epoch 35: Avg Loss = 1.6368, Test Accuracy = 42.61%
#
# ===== Epoch 36 =====
# Epoch 36: Avg Loss = 1.6256, Test Accuracy = 42.30%
#
# ===== Epoch 37 =====
# Epoch 37: Avg Loss = 1.6280, Test Accuracy = 43.01%
#
# ===== Epoch 38 =====
# Epoch 38: Avg Loss = 1.6279, Test Accuracy = 43.06%
#
# ===== Epoch 39 =====
# Epoch 39: Avg Loss = 1.6139, Test Accuracy = 41.82%
#
# ===== Epoch 40 =====
# Epoch 40: Avg Loss = 1.6059, Test Accuracy = 43.39%
#
# ===== Epoch 41 =====
# Epoch 41: Avg Loss = 1.6042, Test Accuracy = 43.20%
#
# ===== Epoch 42 =====
# Epoch 42: Avg Loss = 1.5970, Test Accuracy = 43.87%
#
# ===== Epoch 43 =====
# Epoch 43: Avg Loss = 1.5854, Test Accuracy = 42.28%
#
# ===== Epoch 44 =====
# Epoch 44: Avg Loss = 1.5935, Test Accuracy = 41.46%
#
# ===== Epoch 45 =====
# Epoch 45: Avg Loss = 1.5759, Test Accuracy = 41.69%
#
# ===== Epoch 46 =====
# Epoch 46: Avg Loss = 1.5759, Test Accuracy = 44.08%
#
# ===== Epoch 47 =====
# Epoch 47: Avg Loss = 1.5718, Test Accuracy = 45.18%
#
# ===== Epoch 48 =====
# Epoch 48: Avg Loss = 1.5667, Test Accuracy = 45.37%
#
# ===== Epoch 49 =====
# Epoch 49: Avg Loss = 1.5573, Test Accuracy = 44.11%
#
# ===== Epoch 50 =====
# Epoch 50: Avg Loss = 1.5540, Test Accuracy = 41.98%
#
# ===== Epoch 51 =====
# Epoch 51: Avg Loss = 1.5552, Test Accuracy = 46.44%
#
# ===== Epoch 52 =====
# Epoch 52: Avg Loss = 1.5449, Test Accuracy = 44.90%
#
# ===== Epoch 53 =====
# Epoch 53: Avg Loss = 1.5410, Test Accuracy = 46.12%
#
# ===== Epoch 54 =====
# Epoch 54: Avg Loss = 1.5330, Test Accuracy = 47.07%
#
# ===== Epoch 55 =====
# Epoch 55: Avg Loss = 1.5202, Test Accuracy = 44.23%
#
# ===== Epoch 56 =====
# Epoch 56: Avg Loss = 1.5229, Test Accuracy = 46.58%
#
# ===== Epoch 57 =====
# Epoch 57: Avg Loss = 1.5170, Test Accuracy = 41.73%
#
# ===== Epoch 58 =====
# Epoch 58: Avg Loss = 1.5190, Test Accuracy = 44.90%
#
# ===== Epoch 59 =====
# Epoch 59: Avg Loss = 1.5136, Test Accuracy = 47.41%
#
# ===== Epoch 60 =====
# Epoch 60: Avg Loss = 1.5156, Test Accuracy = 47.64%
#
# ===== Epoch 61 =====
# Epoch 61: Avg Loss = 1.5033, Test Accuracy = 44.82%
#
# ===== Epoch 62 =====
# Epoch 62: Avg Loss = 1.5031, Test Accuracy = 44.97%
#
# ===== Epoch 63 =====
# Epoch 63: Avg Loss = 1.4945, Test Accuracy = 48.12%
#
# ===== Epoch 64 =====
# Epoch 64: Avg Loss = 1.4823, Test Accuracy = 48.65%
#
# ===== Epoch 65 =====
# Epoch 65: Avg Loss = 1.4868, Test Accuracy = 48.41%
#
# ===== Epoch 66 =====
# Epoch 66: Avg Loss = 1.4823, Test Accuracy = 47.70%
#
# ===== Epoch 67 =====
# Epoch 67: Avg Loss = 1.4776, Test Accuracy = 48.56%
#
# ===== Epoch 68 =====
# Epoch 68: Avg Loss = 1.4809, Test Accuracy = 49.84%
#
# ===== Epoch 69 =====
# Epoch 69: Avg Loss = 1.4722, Test Accuracy = 44.00%
#
# ===== Epoch 70 =====
# Epoch 70: Avg Loss = 1.4725, Test Accuracy = 49.30%
#
# ===== Epoch 71 =====
# Epoch 71: Avg Loss = 1.4677, Test Accuracy = 49.32%
#
# ===== Epoch 72 =====
# Epoch 72: Avg Loss = 1.4620, Test Accuracy = 48.58%
#
# ===== Epoch 73 =====
# Epoch 73: Avg Loss = 1.4592, Test Accuracy = 48.24%
#
# ===== Epoch 74 =====
# Epoch 74: Avg Loss = 1.4622, Test Accuracy = 50.43%
# Reached target accuracy. Stopping training.
# Models saved)

# %%
while True:
    masked_model = MaskedForward(net, mask, sparsity_percentage).to(device)
    # Guardar copia de los pesos de net para verificar que no cambian
    # net_before = [p.clone().detach() for p in net.parameters()]
    masked_model.train()
    running_loss = 0.0

    epoch += 1

    print(f"\n===== Epoch {epoch} =====")

        # Guardar copia de los pesos de mask
    # mask_before = [p.clone().detach() for p in mask.parameters()]

    for batch_idx, (images, labels) in enumerate(train_loader):
        images, labels = images.to(device), labels.to(device)
    
        optimizer.zero_grad()
        outputs = masked_model(images)
        loss = criterion(outputs, labels)
        loss.backward()

        # # Verificar gradientes
        # for name, param in mask.named_parameters():
        #     if param.grad is not None:
        #         print(f"[Grad] {name}: grad norm = {param.grad.norm().item():.6f}")
        #     else:
        #         print(f"[Grad] {name}: NO grad")
        optimizer.step()

        running_loss += loss.item()
        # if batch_idx % 10 == 0:
        #     print(f"Batch {batch_idx}, Loss: {loss.item():.4f}")

    avg_loss = running_loss / len(train_loader)
    losses.append(avg_loss)

    # Evaluación
    masked_model.eval()
    correct, total = 0, 0
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = masked_model(images)
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    accuracy = 100.0 * correct / total
    accuracies.append(accuracy)

    #     # Verificar cambios en los parámetros de mask
    # for (before, after), name in zip(zip(mask_before, mask.parameters()), mask.state_dict().keys()):
    #     delta = (after - before).abs().sum().item()
    #     print(f"[Update] {name}: Δ = {delta:.6f}")

    # # Verificar que net no ha sido modificado
    # for (before, after), name in zip(zip(net_before, net.parameters()), net.state_dict().keys()):
    #     delta = (after - before).abs().sum().item()
    #     print(f"[Check Net] {name}: Δ = {delta:.6f}")

    print(f"Epoch {epoch}: Avg Loss = {avg_loss:.4f}, Test Accuracy = {accuracy:.2f}%")

    if accuracy >= threshold_accuracy * 100:
        print("Reached target accuracy. Stopping training.")
        if not saved:
            # Guardar net y mask
            torch.save(net.state_dict(), "net.pth")
            torch.save(mask.state_dict(), "mask.pth")
            print(f"Models saved)")
            saved = True
        else:
            print("Model already saved, skipping save.")
        break
# Out:
# ===== Epoch 75 =====
# Epoch 75: Avg Loss = 1.4508, Test Accuracy = 49.34%
#
# ===== Epoch 76 =====
# Epoch 76: Avg Loss = 1.4483, Test Accuracy = 50.22%
#
# ===== Epoch 77 =====
# Epoch 77: Avg Loss = 1.4487, Test Accuracy = 50.49%
#
# ===== Epoch 78 =====
# Epoch 78: Avg Loss = 1.4445, Test Accuracy = 51.23%
#
# ===== Epoch 79 =====
# Epoch 79: Avg Loss = 1.4422, Test Accuracy = 46.75%
#
# ===== Epoch 80 =====
# Epoch 80: Avg Loss = 1.4406, Test Accuracy = 48.71%
#
# ===== Epoch 81 =====
# Epoch 81: Avg Loss = 1.4392, Test Accuracy = 49.97%
#
# ===== Epoch 82 =====
# Epoch 82: Avg Loss = 1.4367, Test Accuracy = 51.14%
#
# ===== Epoch 83 =====
# Epoch 83: Avg Loss = 1.4413, Test Accuracy = 51.42%
#
# ===== Epoch 84 =====
# Epoch 84: Avg Loss = 1.4336, Test Accuracy = 49.61%
#
# ===== Epoch 85 =====
# Epoch 85: Avg Loss = 1.4311, Test Accuracy = 51.25%
#
# ===== Epoch 86 =====
# Epoch 86: Avg Loss = 1.4262, Test Accuracy = 50.14%
#
# ===== Epoch 87 =====
# Epoch 87: Avg Loss = 1.4288, Test Accuracy = 49.17%
#
# ===== Epoch 88 =====
# Epoch 88: Avg Loss = 1.4297, Test Accuracy = 50.05%
#
# ===== Epoch 89 =====
# Epoch 89: Avg Loss = 1.4240, Test Accuracy = 51.50%
#
# ===== Epoch 90 =====
# Epoch 90: Avg Loss = 1.4275, Test Accuracy = 50.79%
#
# ===== Epoch 91 =====
# Epoch 91: Avg Loss = 1.4260, Test Accuracy = 50.75%
#
# ===== Epoch 92 =====
# Epoch 92: Avg Loss = 1.4219, Test Accuracy = 43.41%
#
# ===== Epoch 93 =====
# Epoch 93: Avg Loss = 1.4201, Test Accuracy = 49.55%
#
# ===== Epoch 94 =====
# Epoch 94: Avg Loss = 1.4219, Test Accuracy = 50.66%
#
# ===== Epoch 95 =====
# Epoch 95: Avg Loss = 1.4212, Test Accuracy = 52.36%
#
# ===== Epoch 96 =====
# Epoch 96: Avg Loss = 1.4079, Test Accuracy = 51.35%
#
# ===== Epoch 97 =====
# Epoch 97: Avg Loss = 1.4174, Test Accuracy = 49.76%
#
# ===== Epoch 98 =====
# Epoch 98: Avg Loss = 1.4106, Test Accuracy = 50.01%
#
# ===== Epoch 99 =====
# Epoch 99: Avg Loss = 1.4120, Test Accuracy = 52.59%
#
# ===== Epoch 100 =====
# Epoch 100: Avg Loss = 1.4133, Test Accuracy = 52.78%
#
# ===== Epoch 101 =====
# Epoch 101: Avg Loss = 1.4079, Test Accuracy = 48.43%
#
# ===== Epoch 102 =====
# Epoch 102: Avg Loss = 1.4131, Test Accuracy = 50.83%
#
# ===== Epoch 103 =====
# Epoch 103: Avg Loss = 1.4069, Test Accuracy = 50.10%
#
# ===== Epoch 104 =====
# Epoch 104: Avg Loss = 1.4064, Test Accuracy = 51.73%
#
# ===== Epoch 105 =====
# Epoch 105: Avg Loss = 1.4023, Test Accuracy = 50.77%
#
# ===== Epoch 106 =====
# Epoch 106: Avg Loss = 1.4002, Test Accuracy = 48.50%
#
# ===== Epoch 107 =====
# Epoch 107: Avg Loss = 1.4028, Test Accuracy = 51.23%
#
# ===== Epoch 108 =====
# Epoch 108: Avg Loss = 1.4065, Test Accuracy = 53.10%
#
# ===== Epoch 109 =====
# Epoch 109: Avg Loss = 1.4002, Test Accuracy = 50.18%
#
# ===== Epoch 110 =====
# Epoch 110: Avg Loss = 1.4048, Test Accuracy = 52.85%
#
# ===== Epoch 111 =====
# Epoch 111: Avg Loss = 1.4006, Test Accuracy = 49.91%
#
# ===== Epoch 112 =====
# Epoch 112: Avg Loss = 1.4038, Test Accuracy = 50.05%
#
# ===== Epoch 113 =====
# Epoch 113: Avg Loss = 1.4001, Test Accuracy = 49.70%
#
# ===== Epoch 114 =====
# Epoch 114: Avg Loss = 1.3935, Test Accuracy = 52.38%
#
# ===== Epoch 115 =====
# Epoch 115: Avg Loss = 1.3979, Test Accuracy = 49.30%
#
# ===== Epoch 116 =====
# Epoch 116: Avg Loss = 1.3990, Test Accuracy = 51.04%
#
# ===== Epoch 117 =====
# Epoch 117: Avg Loss = 1.3878, Test Accuracy = 51.96%
#
# ===== Epoch 118 =====
# Epoch 118: Avg Loss = 1.3933, Test Accuracy = 51.86%
#
# ===== Epoch 119 =====
# Epoch 119: Avg Loss = 1.3927, Test Accuracy = 50.96%
#
# ===== Epoch 120 =====
# Epoch 120: Avg Loss = 1.3897, Test Accuracy = 52.34%
#
# ===== Epoch 121 =====
# Epoch 121: Avg Loss = 1.3872, Test Accuracy = 52.20%
#
# ===== Epoch 122 =====
# Epoch 122: Avg Loss = 1.3867, Test Accuracy = 51.27%
#
# ===== Epoch 123 =====
# Epoch 123: Avg Loss = 1.3921, Test Accuracy = 52.11%
#
# ===== Epoch 124 =====
# Epoch 124: Avg Loss = 1.3883, Test Accuracy = 52.45%
#
# ===== Epoch 125 =====
# Epoch 125: Avg Loss = 1.3858, Test Accuracy = 53.25%
#
# ===== Epoch 126 =====
# Epoch 126: Avg Loss = 1.3928, Test Accuracy = 50.28%
#
# ===== Epoch 127 =====
# Epoch 127: Avg Loss = 1.3880, Test Accuracy = 48.50%
#
# ===== Epoch 128 =====
# Epoch 128: Avg Loss = 1.3869, Test Accuracy = 50.10%
#
# ===== Epoch 129 =====
# Epoch 129: Avg Loss = 1.3846, Test Accuracy = 53.29%
#
# ===== Epoch 130 =====
# Epoch 130: Avg Loss = 1.3818, Test Accuracy = 52.55%
#
# ===== Epoch 131 =====
# Epoch 131: Avg Loss = 1.3743, Test Accuracy = 52.34%
#
# ===== Epoch 132 =====
# Epoch 132: Avg Loss = 1.3749, Test Accuracy = 49.27%
#
# ===== Epoch 133 =====
# Epoch 133: Avg Loss = 1.3751, Test Accuracy = 52.32%
#
# ===== Epoch 134 =====
# Epoch 134: Avg Loss = 1.3730, Test Accuracy = 51.27%
#
# ===== Epoch 135 =====
# Epoch 135: Avg Loss = 1.3767, Test Accuracy = 51.12%
#
# ===== Epoch 136 =====
# Epoch 136: Avg Loss = 1.3753, Test Accuracy = 52.59%
#
# ===== Epoch 137 =====
# Epoch 137: Avg Loss = 1.3713, Test Accuracy = 50.85%
#
# ===== Epoch 138 =====
# Epoch 138: Avg Loss = 1.3741, Test Accuracy = 52.30%
#
# ===== Epoch 139 =====
# Epoch 139: Avg Loss = 1.3666, Test Accuracy = 44.95%
#
# ===== Epoch 140 =====
# Epoch 140: Avg Loss = 1.3656, Test Accuracy = 52.53%
#
# ===== Epoch 141 =====
# Epoch 141: Avg Loss = 1.3753, Test Accuracy = 53.44%
#
# ===== Epoch 142 =====
# Epoch 142: Avg Loss = 1.3746, Test Accuracy = 50.91%
#
# ===== Epoch 143 =====
# Epoch 143: Avg Loss = 1.3697, Test Accuracy = 52.99%
#
# ===== Epoch 144 =====
# Epoch 144: Avg Loss = 1.3713, Test Accuracy = 51.27%
#
# ===== Epoch 145 =====
# Epoch 145: Avg Loss = 1.3647, Test Accuracy = 53.90%
#
# ===== Epoch 146 =====
# Epoch 146: Avg Loss = 1.3614, Test Accuracy = 49.70%
#
# ===== Epoch 147 =====
# Epoch 147: Avg Loss = 1.3595, Test Accuracy = 50.22%
#
# ===== Epoch 148 =====
# Epoch 148: Avg Loss = 1.3673, Test Accuracy = 52.60%
#
# ===== Epoch 149 =====
# Epoch 149: Avg Loss = 1.3648, Test Accuracy = 48.73%
#
# ===== Epoch 150 =====
# Epoch 150: Avg Loss = 1.3626, Test Accuracy = 51.75%
#
# ===== Epoch 151 =====
# Epoch 151: Avg Loss = 1.3689, Test Accuracy = 50.68%
#
# ===== Epoch 152 =====
# Epoch 152: Avg Loss = 1.3596, Test Accuracy = 53.62%
#
# ===== Epoch 153 =====
# Epoch 153: Avg Loss = 1.3634, Test Accuracy = 47.01%
#
# ===== Epoch 154 =====
# Epoch 154: Avg Loss = 1.3646, Test Accuracy = 52.87%
#
# ===== Epoch 155 =====
# Epoch 155: Avg Loss = 1.3620, Test Accuracy = 52.66%
#
# ===== Epoch 156 =====
# Epoch 156: Avg Loss = 1.3633, Test Accuracy = 49.90%
#
# ===== Epoch 157 =====
# Epoch 157: Avg Loss = 1.3568, Test Accuracy = 49.53%
#
# ===== Epoch 158 =====
# Epoch 158: Avg Loss = 1.3532, Test Accuracy = 51.88%
#
# ===== Epoch 159 =====
# Epoch 159: Avg Loss = 1.3538, Test Accuracy = 51.36%
#
# ===== Epoch 160 =====
# Epoch 160: Avg Loss = 1.3543, Test Accuracy = 50.58%
#
# ===== Epoch 161 =====
# Epoch 161: Avg Loss = 1.3495, Test Accuracy = 52.43%
#
# ===== Epoch 162 =====
# Epoch 162: Avg Loss = 1.3559, Test Accuracy = 53.25%
#
# ===== Epoch 163 =====
# Epoch 163: Avg Loss = 1.3541, Test Accuracy = 53.39%
#
# ===== Epoch 164 =====
# Epoch 164: Avg Loss = 1.3549, Test Accuracy = 53.75%
#
# ===== Epoch 165 =====
# Epoch 165: Avg Loss = 1.3476, Test Accuracy = 52.70%
#
# ===== Epoch 166 =====
# Epoch 166: Avg Loss = 1.3497, Test Accuracy = 52.60%
#
# ===== Epoch 167 =====
# Epoch 167: Avg Loss = 1.3468, Test Accuracy = 51.56%
#
# ===== Epoch 168 =====
# Epoch 168: Avg Loss = 1.3393, Test Accuracy = 53.79%
#
# ===== Epoch 169 =====
# Epoch 169: Avg Loss = 1.3467, Test Accuracy = 53.31%
#
# ===== Epoch 170 =====
# Epoch 170: Avg Loss = 1.3437, Test Accuracy = 52.15%
#
# ===== Epoch 171 =====
# Epoch 171: Avg Loss = 1.3427, Test Accuracy = 52.09%
#
# ===== Epoch 172 =====
# Epoch 172: Avg Loss = 1.3425, Test Accuracy = 52.47%
#
# ===== Epoch 173 =====
# Epoch 173: Avg Loss = 1.3446, Test Accuracy = 54.36%
#
# ===== Epoch 174 =====
# Epoch 174: Avg Loss = 1.3362, Test Accuracy = 49.36%
#
# ===== Epoch 175 =====
# Epoch 175: Avg Loss = 1.3373, Test Accuracy = 49.72%
#
# ===== Epoch 176 =====
# Epoch 176: Avg Loss = 1.3435, Test Accuracy = 51.10%
#
# ===== Epoch 177 =====
# Epoch 177: Avg Loss = 1.3394, Test Accuracy = 50.56%
#
# ===== Epoch 178 =====
# Epoch 178: Avg Loss = 1.3408, Test Accuracy = 51.97%
#
# ===== Epoch 179 =====
# Epoch 179: Avg Loss = 1.3378, Test Accuracy = 50.39%
#
# ===== Epoch 180 =====
# Epoch 180: Avg Loss = 1.3384, Test Accuracy = 54.61%
#
# ===== Epoch 181 =====
# Epoch 181: Avg Loss = 1.3345, Test Accuracy = 52.93%
#
# ===== Epoch 182 =====
# Epoch 182: Avg Loss = 1.3376, Test Accuracy = 53.16%
#
# ===== Epoch 183 =====
# Epoch 183: Avg Loss = 1.3355, Test Accuracy = 53.46%
#
# ===== Epoch 184 =====
# Epoch 184: Avg Loss = 1.3390, Test Accuracy = 54.25%
#
# ===== Epoch 185 =====
# Epoch 185: Avg Loss = 1.3313, Test Accuracy = 52.49%
#
# ===== Epoch 186 =====
# Epoch 186: Avg Loss = 1.3360, Test Accuracy = 49.74%
#
# ===== Epoch 187 =====
# Epoch 187: Avg Loss = 1.3327, Test Accuracy = 53.54%
#
# ===== Epoch 188 =====
# Epoch 188: Avg Loss = 1.3361, Test Accuracy = 53.79%
#
# ===== Epoch 189 =====
# Epoch 189: Avg Loss = 1.3316, Test Accuracy = 53.20%
#
# ===== Epoch 190 =====
# Epoch 190: Avg Loss = 1.3342, Test Accuracy = 53.39%
#
# ===== Epoch 191 =====
# Epoch 191: Avg Loss = 1.3374, Test Accuracy = 53.20%
#
# ===== Epoch 192 =====
# Epoch 192: Avg Loss = 1.3364, Test Accuracy = 52.47%
#
# ===== Epoch 193 =====
# Epoch 193: Avg Loss = 1.3289, Test Accuracy = 53.37%
#
# ===== Epoch 194 =====
# Epoch 194: Avg Loss = 1.3353, Test Accuracy = 52.36%
#
# ===== Epoch 195 =====
# Epoch 195: Avg Loss = 1.3346, Test Accuracy = 51.33%
#
# ===== Epoch 196 =====
# Epoch 196: Avg Loss = 1.3369, Test Accuracy = 53.54%
#
# ===== Epoch 197 =====
# Epoch 197: Avg Loss = 1.3324, Test Accuracy = 53.56%
#
# ===== Epoch 198 =====
# Epoch 198: Avg Loss = 1.3387, Test Accuracy = 53.65%
#
# ===== Epoch 199 =====
# Epoch 199: Avg Loss = 1.3258, Test Accuracy = 54.04%
#
# ===== Epoch 200 =====
# Epoch 200: Avg Loss = 1.3311, Test Accuracy = 54.99%
#
# ===== Epoch 201 =====
# Epoch 201: Avg Loss = 1.3302, Test Accuracy = 54.55%
#
# ===== Epoch 202 =====
# Epoch 202: Avg Loss = 1.3226, Test Accuracy = 54.02%
#
# ===== Epoch 203 =====
# Epoch 203: Avg Loss = 1.3270, Test Accuracy = 52.99%
#
# ===== Epoch 204 =====
# Epoch 204: Avg Loss = 1.3233, Test Accuracy = 54.38%
#
# ===== Epoch 205 =====
# Epoch 205: Avg Loss = 1.3238, Test Accuracy = 53.14%
#
# ===== Epoch 206 =====
# Epoch 206: Avg Loss = 1.3318, Test Accuracy = 54.36%
#
# ===== Epoch 207 =====
# Epoch 207: Avg Loss = 1.3293, Test Accuracy = 53.65%
#
# ===== Epoch 208 =====
# Epoch 208: Avg Loss = 1.3288, Test Accuracy = 52.64%
#
# ===== Epoch 209 =====
# Epoch 209: Avg Loss = 1.3175, Test Accuracy = 54.15%
#
# ===== Epoch 210 =====
# Epoch 210: Avg Loss = 1.3221, Test Accuracy = 50.79%
#
# ===== Epoch 211 =====
# Epoch 211: Avg Loss = 1.3274, Test Accuracy = 53.54%
#
# ===== Epoch 212 =====
# Epoch 212: Avg Loss = 1.3272, Test Accuracy = 51.76%
#
# ===== Epoch 213 =====
# Epoch 213: Avg Loss = 1.3283, Test Accuracy = 53.31%
#
# ===== Epoch 214 =====
# Epoch 214: Avg Loss = 1.3248, Test Accuracy = 54.42%
#
# ===== Epoch 215 =====
# Epoch 215: Avg Loss = 1.3300, Test Accuracy = 53.69%
#
# ===== Epoch 216 =====
# Epoch 216: Avg Loss = 1.3260, Test Accuracy = 51.94%
#
# ===== Epoch 217 =====
# Epoch 217: Avg Loss = 1.3274, Test Accuracy = 52.39%
#
# ===== Epoch 218 =====
# Epoch 218: Avg Loss = 1.3219, Test Accuracy = 51.17%
#
# ===== Epoch 219 =====
# Epoch 219: Avg Loss = 1.3271, Test Accuracy = 53.71%
#
# ===== Epoch 220 =====
# Epoch 220: Avg Loss = 1.3220, Test Accuracy = 49.59%
#
# ===== Epoch 221 =====
# Epoch 221: Avg Loss = 1.3286, Test Accuracy = 52.11%
#
# ===== Epoch 222 =====
# Epoch 222: Avg Loss = 1.3227, Test Accuracy = 54.02%
#
# ===== Epoch 223 =====
# Epoch 223: Avg Loss = 1.3168, Test Accuracy = 54.11%
#
# ===== Epoch 224 =====
# Epoch 224: Avg Loss = 1.3208, Test Accuracy = 54.47%
#
# ===== Epoch 225 =====
# Epoch 225: Avg Loss = 1.3163, Test Accuracy = 53.46%
#
# ===== Epoch 226 =====
# Epoch 226: Avg Loss = 1.3157, Test Accuracy = 51.59%
#
# ===== Epoch 227 =====
# Epoch 227: Avg Loss = 1.3275, Test Accuracy = 52.74%
#
# ===== Epoch 228 =====
# Epoch 228: Avg Loss = 1.3184, Test Accuracy = 55.20%
#
# ===== Epoch 229 =====
# Epoch 229: Avg Loss = 1.3193, Test Accuracy = 54.47%
#
# ===== Epoch 230 =====
# Epoch 230: Avg Loss = 1.3154, Test Accuracy = 54.44%
#
# ===== Epoch 231 =====
# Epoch 231: Avg Loss = 1.3239, Test Accuracy = 54.36%
#
# ===== Epoch 232 =====
# Epoch 232: Avg Loss = 1.3217, Test Accuracy = 55.10%
#
# ===== Epoch 233 =====
# Epoch 233: Avg Loss = 1.3188, Test Accuracy = 54.55%
#
# ===== Epoch 234 =====
# Epoch 234: Avg Loss = 1.3099, Test Accuracy = 54.09%
#
# ===== Epoch 235 =====
# Epoch 235: Avg Loss = 1.3167, Test Accuracy = 55.24%
#
# ===== Epoch 236 =====
# Epoch 236: Avg Loss = 1.3186, Test Accuracy = 53.35%
#
# ===== Epoch 237 =====
# Epoch 237: Avg Loss = 1.3162, Test Accuracy = 54.91%
#
# ===== Epoch 238 =====
# Epoch 238: Avg Loss = 1.3193, Test Accuracy = 53.84%
#
# ===== Epoch 239 =====
# Epoch 239: Avg Loss = 1.3163, Test Accuracy = 51.04%
#
# ===== Epoch 240 =====
# Epoch 240: Avg Loss = 1.3153, Test Accuracy = 53.73%
#
# ===== Epoch 241 =====
# Epoch 241: Avg Loss = 1.3104, Test Accuracy = 53.18%
#
# ===== Epoch 242 =====
# Epoch 242: Avg Loss = 1.3113, Test Accuracy = 52.93%
#
# ===== Epoch 243 =====
# Epoch 243: Avg Loss = 1.3115, Test Accuracy = 49.82%
#
# ===== Epoch 244 =====
# Epoch 244: Avg Loss = 1.3104, Test Accuracy = 51.86%
#
# ===== Epoch 245 =====
# Epoch 245: Avg Loss = 1.3079, Test Accuracy = 53.46%
#
# ===== Epoch 246 =====
# Epoch 246: Avg Loss = 1.3118, Test Accuracy = 53.35%
#
# ===== Epoch 247 =====
# Epoch 247: Avg Loss = 1.3118, Test Accuracy = 53.54%
#
# ===== Epoch 248 =====
# Epoch 248: Avg Loss = 1.3071, Test Accuracy = 52.78%
#
# ===== Epoch 249 =====
# Epoch 249: Avg Loss = 1.3157, Test Accuracy = 52.24%
#
# ===== Epoch 250 =====
# Epoch 250: Avg Loss = 1.3041, Test Accuracy = 55.16%
#
# ===== Epoch 251 =====
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 20
#      18 optimizer.zero_grad()
#      19 outputs = masked_model(images)
# ---> 20 loss = criterion(outputs, labels)
#      21 loss.backward()
#      23 # # Verificar gradientes
#      24 # for name, param in mask.named_parameters():
#      25 #     if param.grad is not None:
#      26 #         print(f"[Grad] {name}: grad norm = {param.grad.norm().item():.6f}")
#      27 #     else:
#      28 #         print(f"[Grad] {name}: NO grad")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\loss.py:1293, in CrossEntropyLoss.forward(self, input, target)
#    1292 def forward(self, input: Tensor, target: Tensor) -> Tensor:
# -> 1293     return F.cross_entropy(
#    1294         input,
#    1295         target,
#    1296         weight=self.weight,
#    1297         ignore_index=self.ignore_index,
#    1298         reduction=self.reduction,
#    1299         label_smoothing=self.label_smoothing,
#    1300     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\functional.py:3479, in cross_entropy(input, target, weight, size_average, ignore_index, reduce, reduction, label_smoothing)
#    3477 if size_average is not None or reduce is not None:
#    3478     reduction = _Reduction.legacy_get_string(size_average, reduce)
# -> 3479 return torch._C._nn.cross_entropy_loss(
#    3480     input,
#    3481     target,
#    3482     weight,
#    3483     _Reduction.get_enum(reduction),
#    3484     ignore_index,
#    3485     label_smoothing,
#    3486 )
#
# KeyboardInterrupt:

# %%
# Guardar net y mask
torch.save(net.state_dict(), "net.pth")
torch.save(mask.state_dict(), "mask.pth")
print(f"Models saved")
# Out:
# Models saved

# %%
print(losses)
print(len(losses))
print(accuracies)
print(len(accuracies))
print(epoch)
# Out:
# [2.2170420914161495, 2.210403504895001, 2.20872983990646, 2.2054849048940146, 2.203337568335417, 2.1812992859177474, 2.1163125706882013, 2.0738425618264733, 2.0081008447379602, 1.9724520506655299, 1.9343535573017308, 1.9164086144144943, 1.8872428176606573, 1.8678179910270178, 1.8420520751941494, 1.8266336543530952, 1.8075370406959115, 1.7981911715937824, 1.7817181657727172, 1.7800613209241773, 1.763525407852196, 1.7456517074166276, 1.7391322578598813, 1.732369231014717, 1.719978434647002, 1.7124404783655958, 1.7064867452150438, 1.7002490944251782, 1.686897015426217, 1.675776308993014, 1.6714007472846566, 1.6656225138321155, 1.6612524684609435, 1.6489834640084244, 1.6368283716643728, 1.6256374298799328, 1.6279751011511174, 1.627916256829006, 1.6139364922192039, 1.6059013623289946, 1.604185411115972, 1.5970091543546536, 1.585404064597153, 1.5934951472573164, 1.5759431817909566, 1.575899345482268, 1.5717612763003606, 1.5666650246556213, 1.5573022478237384, 1.554019751345239, 1.5551542934121154, 1.5448793627139998, 1.5410444220391715, 1.5329521487398845, 1.5201991284038963, 1.5229231944171393, 1.517008091618375, 1.51896275289175, 1.5136301724649057, 1.5156207237301804, 1.503260002630513, 1.5030783080473178, 1.4944617497484858, 1.482297311832265, 1.4867946701805765, 1.4823415213968696, 1.477640681150483, 1.4809465553702377, 1.4721580144108795, 1.4725360757694013, 1.467718407148268, 1.461950867641263, 1.459154279493704, 1.4621916282467726, 1.4508183209634409, 1.448271187703784, 1.4486618467220447, 1.444466340832594, 1.4422287704741084, 1.4405807681926868, 1.4392318907307415, 1.4366771865908692, 1.4412975718335408, 1.4335555172548062, 1.431092108168253, 1.4261685871496432, 1.4287845768579623, 1.4296809994592898, 1.424011725478056, 1.4274706349867146, 1.4259553926020134, 1.4219353137219823, 1.4201018839347652, 1.4219044508730494, 1.4212462157011032, 1.4078714803951542, 1.4173944043677027, 1.4106237712066347, 1.4119737228242362, 1.4133367811034365, 1.4078711863698028, 1.4131100105076302, 1.4069409970103242, 1.406448138559737, 1.4022739798557469, 1.4001526280147274, 1.4028003106756908, 1.4064606889718916, 1.400244174570572, 1.4047551682082617, 1.4006459505819693, 1.4038308182867563, 1.4001087237422059, 1.3934869003005144, 1.3979336637549284, 1.3990335987835396, 1.3877823174726673, 1.3932792326299155, 1.392727999062073, 1.3896687038061095, 1.3872255824688005, 1.38673536588506, 1.3920607301520138, 1.3883280092623176, 1.3857539376107657, 1.3927733521999381, 1.3879563170598774, 1.3868528121128314, 1.3846444923703263, 1.381803415533973, 1.374288063587212, 1.3749242181458123, 1.3751440804179123, 1.3729539829783324, 1.3767120816358707, 1.3752624606940804, 1.3712811491838315, 1.3740759573695136, 1.3666297104663965, 1.3655522231285164, 1.375268446236122, 1.3746191179606972, 1.3696505721749328, 1.3713001074587428, 1.3647364766859427, 1.3614189512119061, 1.359494356847391, 1.3673450583364906, 1.364788078316828, 1.3625930587692958, 1.3689494881688096, 1.3596357061732105, 1.3634439187078942, 1.364604635209572, 1.3620022433560068, 1.3633240639436535, 1.356815796436333, 1.353243094028496, 1.3537658914560224, 1.3543308431782373, 1.3495207214500846, 1.3559485114202268, 1.35410785202573, 1.3548711556486968, 1.3475614749803775, 1.3496526119912542, 1.3467869346098202, 1.3392739968328942, 1.3466983840959827, 1.3436932683717915, 1.3426821671608018, 1.3424698058061484, 1.344639895165839, 1.3361613172583464, 1.3373040903995677, 1.3435092602924603, 1.3394311655585358, 1.3408027591138352, 1.3377683631530621, 1.3384125385342576, 1.3344620913267136, 1.3376379641817837, 1.335548906428058, 1.3389852101482995, 1.3313140907302135, 1.3359858113818053, 1.3327125307263397, 1.3361375913387392, 1.3315727638035286, 1.334248620198994, 1.337355235727822, 1.3364080937533844, 1.328873988331818, 1.3353223464474446, 1.3345549535460588, 1.3368797553021734, 1.332401693594165, 1.3386818319559097, 1.325843205720913, 1.3311050436118754, 1.3301909255181872, 1.3225882202386856, 1.326988 ...
# 250
# [18.565159320740317, 18.565159320740317, 18.41251669528716, 18.41251669528716, 18.41251669528716, 19.06124785346308, 22.667429879793932, 26.884182407937416, 27.45659225338676, 30.852890669719518, 30.681167716084715, 31.8259874069834, 32.8944857851555, 32.83724480061057, 33.81034153787445, 34.24918908605228, 34.153787445144054, 35.39400877695096, 33.695859568784584, 36.09998091967182, 37.83629078420149, 37.49284487693188, 35.470330089677546, 37.72180881511162, 39.038351459645106, 36.519748139668, 38.82846784964701, 39.55352032054952, 40.927303949627934, 40.087769509635564, 41.55695477962221, 39.05743178782675, 40.71742033962984, 42.53005151688609, 42.60637282961267, 42.30108757870635, 43.00705972142721, 43.064300705972144, 41.82407937416524, 43.388666285060104, 43.197863003243654, 43.86567448960122, 42.28200725052471, 41.46155313871399, 41.69051707689372, 44.07555809959931, 45.18221713413471, 45.37302041595115, 44.1137187559626, 41.97672199961839, 46.44151879412326, 44.89601221141004, 46.1171532150353, 47.07116962411754, 44.228200725052474, 46.57508109139477, 41.728677733257015, 44.89601221141004, 47.41461553138714, 47.64357946956687, 44.819690898683454, 44.972333524136616, 48.120587674107995, 48.65483686319405, 48.406792596832666, 47.70082045411181, 48.55943522228582, 49.837817210456016, 43.999236786872736, 49.30356802136997, 49.32264834955161, 48.578515550467465, 48.23506964319786, 50.429307384087004, 49.34172867773326, 50.219423774088916, 50.486548368631944, 51.230681167716085, 46.74680404502958, 48.71207784773898, 49.971379507727534, 51.135279526807864, 51.421484449532535, 49.608853272276285, 51.24976149589773, 50.14310246136233, 49.17000572409845, 50.04770082045411, 51.49780576225911, 50.79183361953826, 50.753672963174964, 43.40774661324175, 49.55161228773135, 50.65827132226674, 52.35642053043313, 51.34516313680595, 49.76149589772944, 50.00954016409082, 52.58538446861286, 52.77618775042931, 48.42587292501431, 50.82999427590155, 50.104941804999044, 51.72676970043885, 50.77275329135661, 48.50219423774089, 51.230681167716085, 53.10055332951727, 50.18126311772563, 52.852509063155885, 49.9141385231826, 50.04770082045411, 49.704254913184506, 52.37550085861477, 49.30356802136997, 51.039877885899635, 51.95573363861858, 51.86033199771036, 50.96355657317306, 52.337340202251475, 52.203777904979965, 51.268841824079374, 52.108376264071744, 52.45182217134135, 53.25319595497042, 50.27666475863385, 48.50219423774089, 50.104941804999044, 53.29135661133372, 52.54722381224957, 52.337340202251475, 49.26540736500668, 52.31825987406983, 51.268841824079374, 51.11619919862622, 52.58538446861286, 50.84907460408319, 52.29917954588819, 44.95325319595497, 52.528143484067925, 53.44399923678687, 50.906315588628125, 52.9860713604274, 51.268841824079374, 53.90192711314634, 49.704254913184506, 50.219423774088916, 52.6044647967945, 48.731158175920626, 51.745850028620495, 50.67735165044839, 53.61572219042168, 47.0139286395726, 52.87158939133753, 52.66170578133944, 49.895058195000956, 49.53253195954971, 51.879412325892005, 51.364243464987595, 50.581950009540165, 52.432741843159704, 53.25319595497042, 53.38675825224194, 53.74928448769319, 52.69986643770273, 52.6044647967945, 51.555046746804045, 53.78744514405648, 53.31043693951536, 52.14653692043503, 52.0892959358901, 52.47090249952299, 54.35985498950582, 49.3608090059149, 49.72333524136615, 51.097118870444575, 50.56286968135852, 51.97481396680023, 50.391146727723715, 54.6078992558672, 52.92883037588246, 53.1577943140622, 53.46307956496852, 54.245373020415954, 52.48998282770464, 49.742415569547795, 53.539400877695094, 53.78744514405648, 53.19595497042549, 53.38675825224194, 53.19595497042549, 52.47090249952299, 53.367677924060295, 52.35642053043313, 51.32608280862431, 53.539400877695094, 53.55848120587674, 53.65388284678497, 54.03548941041786, 54.989505819500096, 54.55065827132227, 54.016409082236216, 52.9860713604274, 54.378935317687464, 53.13871398588056, 54.35985498950582, 53.65388284678497, 52.64262545315 ...
# 250
# 251

# %%
# Gráficos de pérdida y precisión
plt.figure()
plt.plot(range(1, len(losses)+1), losses, label='Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss per Epoch')
plt.legend()
plt.grid(True)
plt.show()

plt.figure()
plt.plot(range(1, len(accuracies)+1), accuracies, label='Accuracy', color='green')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.title('Test Accuracy per Epoch')
plt.legend()
plt.grid(True)
plt.show()
