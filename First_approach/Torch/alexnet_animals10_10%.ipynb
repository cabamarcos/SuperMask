# %%
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms, models
from torch.utils.data import DataLoader, random_split
import copy
import matplotlib.pyplot as plt

from utils.apply_mask_alexnet import *

# %%
# Configuración
batch_size = 64
threshold_accuracy = 0.70
sparsity_percentage = 0.1  # Porcentaje de pesos a conservar (más altos)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# Dataset Animals10
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
])

data_dir = "./animals10"

train_dataset = datasets.ImageFolder(root=os.path.join(data_dir, "train"), transform=transform)
test_dataset = datasets.ImageFolder(root=os.path.join(data_dir, "test"), transform=transform)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
net = models.alexnet(pretrained=False)
net.classifier[6] = nn.Linear(net.classifier[6].in_features, 10)

mask = models.alexnet(pretrained=False)
mask.classifier[6] = nn.Linear(mask.classifier[6].in_features, 10)

net.to(device)
mask.to(device)
# Out:
# C:\Users\Usuario\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\Usuario\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=4096, out_features=10, bias=True)
#   )
# )

# %%
# Congelar los parámetros de net (no se entrenarán)
for param in net.parameters():
    param.requires_grad = False

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(mask.parameters(), lr=0.001)
epoch = 0
losses = []
accuracies = []

while True:
    masked_model = MaskedForward(net, mask, sparsity_percentage).to(device)
    # Guardar copia de los pesos de net para verificar que no cambian
    # net_before = [p.clone().detach() for p in net.parameters()]
    masked_model.train()
    running_loss = 0.0

    epoch += 1

    print(f"\n===== Epoch {epoch} =====")

        # Guardar copia de los pesos de mask
    # mask_before = [p.clone().detach() for p in mask.parameters()]

    for batch_idx, (images, labels) in enumerate(train_loader):
        images, labels = images.to(device), labels.to(device)
    
        optimizer.zero_grad()
        outputs = masked_model(images)
        loss = criterion(outputs, labels)
        loss.backward()

        # # Verificar gradientes
        # for name, param in mask.named_parameters():
        #     if param.grad is not None:
        #         print(f"[Grad] {name}: grad norm = {param.grad.norm().item():.6f}")
        #     else:
        #         print(f"[Grad] {name}: NO grad")
        optimizer.step()

        running_loss += loss.item()
        # if batch_idx % 10 == 0:
        #     print(f"Batch {batch_idx}, Loss: {loss.item():.4f}")

    avg_loss = running_loss / len(train_loader)
    losses.append(avg_loss)

    # Evaluación
    masked_model.eval()
    correct, total = 0, 0
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = masked_model(images)
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    accuracy = 100.0 * correct / total
    accuracies.append(accuracy)

    #     # Verificar cambios en los parámetros de mask
    # for (before, after), name in zip(zip(mask_before, mask.parameters()), mask.state_dict().keys()):
    #     delta = (after - before).abs().sum().item()
    #     print(f"[Update] {name}: Δ = {delta:.6f}")

    # # Verificar que net no ha sido modificado
    # for (before, after), name in zip(zip(net_before, net.parameters()), net.state_dict().keys()):
    #     delta = (after - before).abs().sum().item()
    #     print(f"[Check Net] {name}: Δ = {delta:.6f}")

    print(f"Epoch {epoch}: Avg Loss = {avg_loss:.4f}, Test Accuracy = {accuracy:.2f}%")

    if accuracy >= threshold_accuracy * 100:
        print("Reached target accuracy. Stopping training.")
        break
# Out:
# ===== Epoch 1 =====
# Epoch 1: Avg Loss = 2.2166, Test Accuracy = 18.41%
#
# ===== Epoch 2 =====
# Epoch 2: Avg Loss = 2.2124, Test Accuracy = 18.41%
#
# ===== Epoch 3 =====
# Epoch 3: Avg Loss = 2.2115, Test Accuracy = 18.41%
#
# ===== Epoch 4 =====
# Epoch 4: Avg Loss = 2.2107, Test Accuracy = 18.41%
#
# ===== Epoch 5 =====
# Epoch 5: Avg Loss = 2.2097, Test Accuracy = 18.41%
#
# ===== Epoch 6 =====
# Epoch 6: Avg Loss = 2.2072, Test Accuracy = 18.41%
#
# ===== Epoch 7 =====
# Epoch 7: Avg Loss = 2.1988, Test Accuracy = 18.41%
#
# ===== Epoch 8 =====
# Epoch 8: Avg Loss = 2.1823, Test Accuracy = 20.53%
#
# ===== Epoch 9 =====
# Epoch 9: Avg Loss = 2.1286, Test Accuracy = 24.86%
#
# ===== Epoch 10 =====
# Epoch 10: Avg Loss = 2.0910, Test Accuracy = 27.02%
#
# ===== Epoch 11 =====
# Epoch 11: Avg Loss = 2.0613, Test Accuracy = 27.67%
#
# ===== Epoch 12 =====
# Epoch 12: Avg Loss = 2.0302, Test Accuracy = 28.68%
#
# ===== Epoch 13 =====
# Epoch 13: Avg Loss = 2.0054, Test Accuracy = 28.05%
#
# ===== Epoch 14 =====
# Epoch 14: Avg Loss = 1.9730, Test Accuracy = 32.07%
#
# ===== Epoch 15 =====
# Epoch 15: Avg Loss = 1.9424, Test Accuracy = 32.78%
#
# ===== Epoch 16 =====
# Epoch 16: Avg Loss = 1.9084, Test Accuracy = 33.22%
#
# ===== Epoch 17 =====
# Epoch 17: Avg Loss = 1.8805, Test Accuracy = 33.91%
#
# ===== Epoch 18 =====
# Epoch 18: Avg Loss = 1.8566, Test Accuracy = 34.25%
#
# ===== Epoch 19 =====
# Epoch 19: Avg Loss = 1.8301, Test Accuracy = 35.37%
#
# ===== Epoch 20 =====
# Epoch 20: Avg Loss = 1.8134, Test Accuracy = 35.58%
#
# ===== Epoch 21 =====
# Epoch 21: Avg Loss = 1.7968, Test Accuracy = 35.09%
#
# ===== Epoch 22 =====
# Epoch 22: Avg Loss = 1.7803, Test Accuracy = 34.55%
#
# ===== Epoch 23 =====
# Epoch 23: Avg Loss = 1.7854, Test Accuracy = 36.67%
#
# ===== Epoch 24 =====
# Epoch 24: Avg Loss = 1.7582, Test Accuracy = 37.80%
#
# ===== Epoch 25 =====
# Epoch 25: Avg Loss = 1.7422, Test Accuracy = 37.72%
#
# ===== Epoch 26 =====
# Epoch 26: Avg Loss = 1.7403, Test Accuracy = 37.03%
#
# ===== Epoch 27 =====
# Epoch 27: Avg Loss = 1.7216, Test Accuracy = 36.21%
#
# ===== Epoch 28 =====
# Epoch 28: Avg Loss = 1.7053, Test Accuracy = 37.86%
#
# ===== Epoch 29 =====
# Epoch 29: Avg Loss = 1.7032, Test Accuracy = 38.79%
#
# ===== Epoch 30 =====
# Epoch 30: Avg Loss = 1.6839, Test Accuracy = 38.71%
#
# ===== Epoch 31 =====
# Epoch 31: Avg Loss = 1.6788, Test Accuracy = 38.41%
#
# ===== Epoch 32 =====
# Epoch 32: Avg Loss = 1.6744, Test Accuracy = 38.75%
#
# ===== Epoch 33 =====
# Epoch 33: Avg Loss = 1.6688, Test Accuracy = 39.13%
#
# ===== Epoch 34 =====
# Epoch 34: Avg Loss = 1.6600, Test Accuracy = 40.53%
#
# ===== Epoch 35 =====
# Epoch 35: Avg Loss = 1.6532, Test Accuracy = 39.53%
#
# ===== Epoch 36 =====
# Epoch 36: Avg Loss = 1.6523, Test Accuracy = 39.59%
#
# ===== Epoch 37 =====
# Epoch 37: Avg Loss = 1.6490, Test Accuracy = 38.73%
#
# ===== Epoch 38 =====
# Epoch 38: Avg Loss = 1.6402, Test Accuracy = 39.46%
#
# ===== Epoch 39 =====
# Epoch 39: Avg Loss = 1.6327, Test Accuracy = 41.29%
#
# ===== Epoch 40 =====
# Epoch 40: Avg Loss = 1.6240, Test Accuracy = 40.91%
#
# ===== Epoch 41 =====
# Epoch 41: Avg Loss = 1.6241, Test Accuracy = 41.12%
#
# ===== Epoch 42 =====
# Epoch 42: Avg Loss = 1.6217, Test Accuracy = 40.56%
#
# ===== Epoch 43 =====
# Epoch 43: Avg Loss = 1.6194, Test Accuracy = 40.43%
#
# ===== Epoch 44 =====
# Epoch 44: Avg Loss = 1.6090, Test Accuracy = 40.37%
#
# ===== Epoch 45 =====
# Epoch 45: Avg Loss = 1.6032, Test Accuracy = 42.76%
#
# ===== Epoch 46 =====
# Epoch 46: Avg Loss = 1.6009, Test Accuracy = 41.37%
#
# ===== Epoch 47 =====
# Epoch 47: Avg Loss = 1.5965, Test Accuracy = 41.94%
#
# ===== Epoch 48 =====
# Epoch 48: Avg Loss = 1.5874, Test Accuracy = 42.84%
#
# ===== Epoch 49 =====
# Epoch 49: Avg Loss = 1.5859, Test Accuracy = 42.55%
#
# ===== Epoch 50 =====
# Epoch 50: Avg Loss = 1.5813, Test Accuracy = 42.36%
#
# ===== Epoch 51 =====
# Epoch 51: Avg Loss = 1.5754, Test Accuracy = 40.24%
#
# ===== Epoch 52 =====
# Epoch 52: Avg Loss = 1.5798, Test Accuracy = 39.11%
#
# ===== Epoch 53 =====
# Epoch 53: Avg Loss = 1.5699, Test Accuracy = 41.44%
#
# ===== Epoch 54 =====
# Epoch 54: Avg Loss = 1.5752, Test Accuracy = 41.77%
#
# ===== Epoch 55 =====
# Epoch 55: Avg Loss = 1.5607, Test Accuracy = 43.60%
#
# ===== Epoch 56 =====
# Epoch 56: Avg Loss = 1.5588, Test Accuracy = 43.58%
#
# ===== Epoch 57 =====
# Epoch 57: Avg Loss = 1.5523, Test Accuracy = 43.79%
#
# ===== Epoch 58 =====
# Epoch 58: Avg Loss = 1.5588, Test Accuracy = 43.90%
#
# ===== Epoch 59 =====
# Epoch 59: Avg Loss = 1.5516, Test Accuracy = 43.54%
#
# ===== Epoch 60 =====
# Epoch 60: Avg Loss = 1.5434, Test Accuracy = 43.46%
#
# ===== Epoch 61 =====
# Epoch 61: Avg Loss = 1.5424, Test Accuracy = 43.67%
#
# ===== Epoch 62 =====
# Epoch 62: Avg Loss = 1.5396, Test Accuracy = 43.60%
#
# ===== Epoch 63 =====
# Epoch 63: Avg Loss = 1.5370, Test Accuracy = 42.99%
#
# ===== Epoch 64 =====
# Epoch 64: Avg Loss = 1.5351, Test Accuracy = 45.30%
#
# ===== Epoch 65 =====
# Epoch 65: Avg Loss = 1.5298, Test Accuracy = 45.05%
#
# ===== Epoch 66 =====
# Epoch 66: Avg Loss = 1.5309, Test Accuracy = 43.60%
#
# ===== Epoch 67 =====
# Epoch 67: Avg Loss = 1.5271, Test Accuracy = 44.29%
#
# ===== Epoch 68 =====
# Epoch 68: Avg Loss = 1.5175, Test Accuracy = 45.89%
#
# ===== Epoch 69 =====
# Epoch 69: Avg Loss = 1.5134, Test Accuracy = 44.34%
#
# ===== Epoch 70 =====
# Epoch 70: Avg Loss = 1.5132, Test Accuracy = 45.64%
#
# ===== Epoch 71 =====
# Epoch 71: Avg Loss = 1.5111, Test Accuracy = 43.01%
#
# ===== Epoch 72 =====
# Epoch 72: Avg Loss = 1.5121, Test Accuracy = 45.01%
#
# ===== Epoch 73 =====
# Epoch 73: Avg Loss = 1.5104, Test Accuracy = 44.09%
#
# ===== Epoch 74 =====
# Epoch 74: Avg Loss = 1.5061, Test Accuracy = 41.92%
#
# ===== Epoch 75 =====
# Epoch 75: Avg Loss = 1.4974, Test Accuracy = 45.56%
#
# ===== Epoch 76 =====
# Epoch 76: Avg Loss = 1.5043, Test Accuracy = 46.59%
#
# ===== Epoch 77 =====
# Epoch 77: Avg Loss = 1.4915, Test Accuracy = 43.79%
#
# ===== Epoch 78 =====
# Epoch 78: Avg Loss = 1.4905, Test Accuracy = 40.39%
#
# ===== Epoch 79 =====
# Epoch 79: Avg Loss = 1.4890, Test Accuracy = 46.69%
#
# ===== Epoch 80 =====
# Epoch 80: Avg Loss = 1.4852, Test Accuracy = 46.54%
#
# ===== Epoch 81 =====
# Epoch 81: Avg Loss = 1.4886, Test Accuracy = 45.64%
#
# ===== Epoch 82 =====
# Epoch 82: Avg Loss = 1.4908, Test Accuracy = 45.11%
#
# ===== Epoch 83 =====
# Epoch 83: Avg Loss = 1.4870, Test Accuracy = 47.70%
#
# ===== Epoch 84 =====
# Epoch 84: Avg Loss = 1.4814, Test Accuracy = 47.61%
#
# ===== Epoch 85 =====
# Epoch 85: Avg Loss = 1.4809, Test Accuracy = 46.75%
#
# ===== Epoch 86 =====
# Epoch 86: Avg Loss = 1.4813, Test Accuracy = 45.79%
#
# ===== Epoch 87 =====
# Epoch 87: Avg Loss = 1.4816, Test Accuracy = 47.51%
#
# ===== Epoch 88 =====
# Epoch 88: Avg Loss = 1.4761, Test Accuracy = 45.33%
#
# ===== Epoch 89 =====
# Epoch 89: Avg Loss = 1.4756, Test Accuracy = 47.40%
#
# ===== Epoch 90 =====
# Epoch 90: Avg Loss = 1.4775, Test Accuracy = 39.73%
#
# ===== Epoch 91 =====
# Epoch 91: Avg Loss = 1.4741, Test Accuracy = 47.70%
#
# ===== Epoch 92 =====
# Epoch 92: Avg Loss = 1.4777, Test Accuracy = 45.93%
#
# ===== Epoch 93 =====
# Epoch 93: Avg Loss = 1.4686, Test Accuracy = 45.70%
#
# ===== Epoch 94 =====
# Epoch 94: Avg Loss = 1.4641, Test Accuracy = 44.78%
#
# ===== Epoch 95 =====
# Epoch 95: Avg Loss = 1.4712, Test Accuracy = 42.43%
#
# ===== Epoch 96 =====
# Epoch 96: Avg Loss = 1.4611, Test Accuracy = 46.12%
#
# ===== Epoch 97 =====
# Epoch 97: Avg Loss = 1.4639, Test Accuracy = 47.01%
#
# ===== Epoch 98 =====
# Epoch 98: Avg Loss = 1.4662, Test Accuracy = 47.85%
#
# ===== Epoch 99 =====
# Epoch 99: Avg Loss = 1.4659, Test Accuracy = 47.20%
#
# ===== Epoch 100 =====
# Epoch 100: Avg Loss = 1.4639, Test Accuracy = 45.98%
#
# ===== Epoch 101 =====
# Epoch 101: Avg Loss = 1.4604, Test Accuracy = 46.65%
#
# ===== Epoch 102 =====
# Epoch 102: Avg Loss = 1.4646, Test Accuracy = 45.35%
#
# ===== Epoch 103 =====
# Epoch 103: Avg Loss = 1.4582, Test Accuracy = 46.98%
#
# ===== Epoch 104 =====
# Epoch 104: Avg Loss = 1.4602, Test Accuracy = 48.60%
#
# ===== Epoch 105 =====
# Epoch 105: Avg Loss = 1.4552, Test Accuracy = 46.61%
#
# ===== Epoch 106 =====
# Epoch 106: Avg Loss = 1.4558, Test Accuracy = 47.76%
#
# ===== Epoch 107 =====
# Epoch 107: Avg Loss = 1.4491, Test Accuracy = 47.51%
#
# ===== Epoch 108 =====
# Epoch 108: Avg Loss = 1.4546, Test Accuracy = 44.50%
#
# ===== Epoch 109 =====
# Epoch 109: Avg Loss = 1.4524, Test Accuracy = 46.44%
#
# ===== Epoch 110 =====
# Epoch 110: Avg Loss = 1.4507, Test Accuracy = 46.17%
#
# ===== Epoch 111 =====
# Epoch 111: Avg Loss = 1.4553, Test Accuracy = 45.72%
#
# ===== Epoch 112 =====
# Epoch 112: Avg Loss = 1.4532, Test Accuracy = 48.25%
#
# ===== Epoch 113 =====
# Epoch 113: Avg Loss = 1.4523, Test Accuracy = 48.52%
#
# ===== Epoch 114 =====
# Epoch 114: Avg Loss = 1.4478, Test Accuracy = 49.23%
#
# ===== Epoch 115 =====
# Epoch 115: Avg Loss = 1.4495, Test Accuracy = 48.60%
#
# ===== Epoch 116 =====
# Epoch 116: Avg Loss = 1.4432, Test Accuracy = 47.03%
#
# ===== Epoch 117 =====
# Epoch 117: Avg Loss = 1.4374, Test Accuracy = 48.06%
#
# ===== Epoch 118 =====
# Epoch 118: Avg Loss = 1.4393, Test Accuracy = 47.09%
#
# ===== Epoch 119 =====
# Epoch 119: Avg Loss = 1.4355, Test Accuracy = 46.67%
#
# ===== Epoch 120 =====
# Epoch 120: Avg Loss = 1.4405, Test Accuracy = 49.67%
#
# ===== Epoch 121 =====
# Epoch 121: Avg Loss = 1.4324, Test Accuracy = 48.43%
#
# ===== Epoch 122 =====
# Epoch 122: Avg Loss = 1.4284, Test Accuracy = 49.42%
#
# ===== Epoch 123 =====
# Epoch 123: Avg Loss = 1.4287, Test Accuracy = 49.70%
#
# ===== Epoch 124 =====
# Epoch 124: Avg Loss = 1.4290, Test Accuracy = 49.63%
#
# ===== Epoch 125 =====
# Epoch 125: Avg Loss = 1.4296, Test Accuracy = 48.33%
#
# ===== Epoch 126 =====
# Epoch 126: Avg Loss = 1.4287, Test Accuracy = 46.44%
#
# ===== Epoch 127 =====
# Epoch 127: Avg Loss = 1.4294, Test Accuracy = 49.27%
#
# ===== Epoch 128 =====
# Epoch 128: Avg Loss = 1.4317, Test Accuracy = 48.06%
#
# ===== Epoch 129 =====
# Epoch 129: Avg Loss = 1.4311, Test Accuracy = 46.96%
#
# ===== Epoch 130 =====
# Epoch 130: Avg Loss = 1.4344, Test Accuracy = 49.19%
#
# ===== Epoch 131 =====
# Epoch 131: Avg Loss = 1.4265, Test Accuracy = 48.24%
#
# ===== Epoch 132 =====
# Epoch 132: Avg Loss = 1.4256, Test Accuracy = 49.70%
#
# ===== Epoch 133 =====
# Epoch 133: Avg Loss = 1.4147, Test Accuracy = 45.30%
#
# ===== Epoch 134 =====
# Epoch 134: Avg Loss = 1.4290, Test Accuracy = 49.99%
#
# ===== Epoch 135 =====
# Epoch 135: Avg Loss = 1.4185, Test Accuracy = 46.58%
#
# ===== Epoch 136 =====
# Epoch 136: Avg Loss = 1.4257, Test Accuracy = 47.89%
#
# ===== Epoch 137 =====
# Epoch 137: Avg Loss = 1.4201, Test Accuracy = 48.88%
#
# ===== Epoch 138 =====
# Epoch 138: Avg Loss = 1.4123, Test Accuracy = 47.78%
#
# ===== Epoch 139 =====
# Epoch 139: Avg Loss = 1.4158, Test Accuracy = 42.87%
#
# ===== Epoch 140 =====
# Epoch 140: Avg Loss = 1.4110, Test Accuracy = 48.03%
#
# ===== Epoch 141 =====
# Epoch 141: Avg Loss = 1.4090, Test Accuracy = 47.97%
#
# ===== Epoch 142 =====
# Epoch 142: Avg Loss = 1.4124, Test Accuracy = 49.34%
#
# ===== Epoch 143 =====
# Epoch 143: Avg Loss = 1.4111, Test Accuracy = 48.33%
#
# ===== Epoch 144 =====
# Epoch 144: Avg Loss = 1.4013, Test Accuracy = 49.40%
#
# ===== Epoch 145 =====
# Epoch 145: Avg Loss = 1.4069, Test Accuracy = 49.48%
#
# ===== Epoch 146 =====
# Epoch 146: Avg Loss = 1.4088, Test Accuracy = 48.96%
#
# ===== Epoch 147 =====
# Epoch 147: Avg Loss = 1.4022, Test Accuracy = 50.24%
#
# ===== Epoch 148 =====
# Epoch 148: Avg Loss = 1.4021, Test Accuracy = 50.54%
#
# ===== Epoch 149 =====
# Epoch 149: Avg Loss = 1.4068, Test Accuracy = 44.21%
#
# ===== Epoch 150 =====
# Epoch 150: Avg Loss = 1.4046, Test Accuracy = 49.30%
#
# ===== Epoch 151 =====
# Epoch 151: Avg Loss = 1.4111, Test Accuracy = 48.85%
#
# ===== Epoch 152 =====
# Epoch 152: Avg Loss = 1.4018, Test Accuracy = 48.44%
#
# ===== Epoch 153 =====
# Epoch 153: Avg Loss = 1.4004, Test Accuracy = 46.58%
#
# ===== Epoch 154 =====
# Epoch 154: Avg Loss = 1.4028, Test Accuracy = 49.84%
#
# ===== Epoch 155 =====
# Epoch 155: Avg Loss = 1.4001, Test Accuracy = 48.01%
#
# ===== Epoch 156 =====
# Epoch 156: Avg Loss = 1.3975, Test Accuracy = 47.59%
#
# ===== Epoch 157 =====
# Epoch 157: Avg Loss = 1.3988, Test Accuracy = 40.58%
#
# ===== Epoch 158 =====
# Epoch 158: Avg Loss = 1.4048, Test Accuracy = 46.33%
#
# ===== Epoch 159 =====
# Epoch 159: Avg Loss = 1.3998, Test Accuracy = 49.90%
#
# ===== Epoch 160 =====
# Epoch 160: Avg Loss = 1.3989, Test Accuracy = 49.57%
#
# ===== Epoch 161 =====
# Epoch 161: Avg Loss = 1.4058, Test Accuracy = 48.96%
#
# ===== Epoch 162 =====
# Epoch 162: Avg Loss = 1.4007, Test Accuracy = 49.17%
#
# ===== Epoch 163 =====
# Epoch 163: Avg Loss = 1.3986, Test Accuracy = 46.77%
#
# ===== Epoch 164 =====
# Epoch 164: Avg Loss = 1.3999, Test Accuracy = 50.35%
#
# ===== Epoch 165 =====
# Epoch 165: Avg Loss = 1.3916, Test Accuracy = 49.65%
#
# ===== Epoch 166 =====
# Epoch 166: Avg Loss = 1.3940, Test Accuracy = 50.37%
#
# ===== Epoch 167 =====
# Epoch 167: Avg Loss = 1.3962, Test Accuracy = 49.95%
#
# ===== Epoch 168 =====
# Epoch 168: Avg Loss = 1.3912, Test Accuracy = 49.82%
#
# ===== Epoch 169 =====
# Epoch 169: Avg Loss = 1.3898, Test Accuracy = 49.97%
#
# ===== Epoch 170 =====
# Epoch 170: Avg Loss = 1.3973, Test Accuracy = 43.33%
#
# ===== Epoch 171 =====
# Epoch 171: Avg Loss = 1.3938, Test Accuracy = 50.05%
#
# ===== Epoch 172 =====
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 37
#      29     # # Verificar gradientes
#      30     # for name, param in mask.named_parameters():
#      31     #     if param.grad is not None:
#      32     #         print(f"[Grad] {name}: grad norm = {param.grad.norm().item():.6f}")
#      33     #     else:
#      34     #         print(f"[Grad] {name}: NO grad")
#      35     optimizer.step()
# ---> 37     running_loss += loss.item()
#      38     # if batch_idx % 10 == 0:
#      39     #     print(f"Batch {batch_idx}, Loss: {loss.item():.4f}")
#      41 avg_loss = running_loss / len(train_loader)
#
# KeyboardInterrupt:

# %%
# Gráficos de pérdida y precisión
plt.figure()
plt.plot(range(1, len(losses)+1), losses, label='Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss per Epoch')
plt.legend()
plt.grid(True)
plt.show()

plt.figure()
plt.plot(range(1, len(accuracies)+1), accuracies, label='Accuracy', color='green')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.title('Test Accuracy per Epoch')
plt.legend()
plt.grid(True)
plt.show()
