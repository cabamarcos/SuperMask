# %%
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms, models
from torch.utils.data import DataLoader, random_split
import copy
import matplotlib.pyplot as plt

from utils.apply_mask_alexnet import *

# %%
# Configuración
batch_size = 64
threshold_accuracy = 0.70
sparsity_percentage = 0.05 
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# Dataset Animals10
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
])

data_dir = "./animals10"

train_dataset = datasets.ImageFolder(root=os.path.join(data_dir, "train"), transform=transform)
test_dataset = datasets.ImageFolder(root=os.path.join(data_dir, "test"), transform=transform)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
net = models.alexnet(pretrained=False)
net.classifier[6] = nn.Linear(net.classifier[6].in_features, 10)

mask = models.alexnet(pretrained=False)
mask.classifier[6] = nn.Linear(mask.classifier[6].in_features, 10)

net.to(device)
mask.to(device)
# Out:
# C:\Users\Usuario\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\Usuario\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=4096, out_features=10, bias=True)
#   )
# )

# %%
# Congelar los parámetros de net (no se entrenarán)
for param in net.parameters():
    param.requires_grad = False

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(mask.parameters(), lr=0.001)
epoch = 0
losses = []
accuracies = []

while True:
    masked_model = MaskedForward(net, mask, sparsity_percentage).to(device)
    # Guardar copia de los pesos de net para verificar que no cambian
    # net_before = [p.clone().detach() for p in net.parameters()]
    masked_model.train()
    running_loss = 0.0

    epoch += 1

    print(f"\n===== Epoch {epoch} =====")

        # Guardar copia de los pesos de mask
    # mask_before = [p.clone().detach() for p in mask.parameters()]

    for batch_idx, (images, labels) in enumerate(train_loader):
        images, labels = images.to(device), labels.to(device)
    
        optimizer.zero_grad()
        outputs = masked_model(images)
        loss = criterion(outputs, labels)
        loss.backward()

        # # Verificar gradientes
        # for name, param in mask.named_parameters():
        #     if param.grad is not None:
        #         print(f"[Grad] {name}: grad norm = {param.grad.norm().item():.6f}")
        #     else:
        #         print(f"[Grad] {name}: NO grad")
        optimizer.step()

        running_loss += loss.item()
        # if batch_idx % 10 == 0:
        #     print(f"Batch {batch_idx}, Loss: {loss.item():.4f}")

    avg_loss = running_loss / len(train_loader)
    losses.append(avg_loss)

    # Evaluación
    masked_model.eval()
    correct, total = 0, 0
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = masked_model(images)
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    accuracy = 100.0 * correct / total
    accuracies.append(accuracy)

    #     # Verificar cambios en los parámetros de mask
    # for (before, after), name in zip(zip(mask_before, mask.parameters()), mask.state_dict().keys()):
    #     delta = (after - before).abs().sum().item()
    #     print(f"[Update] {name}: Δ = {delta:.6f}")

    # # Verificar que net no ha sido modificado
    # for (before, after), name in zip(zip(net_before, net.parameters()), net.state_dict().keys()):
    #     delta = (after - before).abs().sum().item()
    #     print(f"[Check Net] {name}: Δ = {delta:.6f}")

    print(f"Epoch {epoch}: Avg Loss = {avg_loss:.4f}, Test Accuracy = {accuracy:.2f}%")

    if accuracy >= threshold_accuracy * 100:
        print("Reached target accuracy. Stopping training.")
        break
# Out:
# ===== Epoch 1 =====
# Epoch 1: Avg Loss = 2.2163, Test Accuracy = 18.57%
#
# ===== Epoch 2 =====
# Epoch 2: Avg Loss = 2.2109, Test Accuracy = 18.41%
#
# ===== Epoch 3 =====
# Epoch 3: Avg Loss = 2.2093, Test Accuracy = 18.57%
#
# ===== Epoch 4 =====
# Epoch 4: Avg Loss = 2.2098, Test Accuracy = 18.41%
#
# ===== Epoch 5 =====
# Epoch 5: Avg Loss = 2.2097, Test Accuracy = 18.57%
#
# ===== Epoch 6 =====
# Epoch 6: Avg Loss = 2.2091, Test Accuracy = 18.41%
#
# ===== Epoch 7 =====
# Epoch 7: Avg Loss = 2.2094, Test Accuracy = 18.57%
#
# ===== Epoch 8 =====
# Epoch 8: Avg Loss = 2.2096, Test Accuracy = 18.41%
#
# ===== Epoch 9 =====
# Epoch 9: Avg Loss = 2.2090, Test Accuracy = 18.57%
#
# ===== Epoch 10 =====
# Epoch 10: Avg Loss = 2.2092, Test Accuracy = 18.57%
#
# ===== Epoch 11 =====
# Epoch 11: Avg Loss = 2.2097, Test Accuracy = 18.41%
#
# ===== Epoch 12 =====
# Epoch 12: Avg Loss = 2.2088, Test Accuracy = 18.57%
#
# ===== Epoch 13 =====
# Epoch 13: Avg Loss = 2.2088, Test Accuracy = 18.41%
#
# ===== Epoch 14 =====
# Epoch 14: Avg Loss = 2.2088, Test Accuracy = 18.57%
#
# ===== Epoch 15 =====
# Epoch 15: Avg Loss = 2.2069, Test Accuracy = 18.41%
#
# ===== Epoch 16 =====
# Epoch 16: Avg Loss = 2.2087, Test Accuracy = 18.41%
#
# ===== Epoch 17 =====
# Epoch 17: Avg Loss = 2.2017, Test Accuracy = 18.41%
#
# ===== Epoch 18 =====
# Epoch 18: Avg Loss = 2.1762, Test Accuracy = 18.41%
#
# ===== Epoch 19 =====
# Epoch 19: Avg Loss = 2.1274, Test Accuracy = 24.35%
#
# ===== Epoch 20 =====
# Epoch 20: Avg Loss = 2.0431, Test Accuracy = 28.03%
#
# ===== Epoch 21 =====
# Epoch 21: Avg Loss = 2.0131, Test Accuracy = 28.49%
#
# ===== Epoch 22 =====
# Epoch 22: Avg Loss = 1.9956, Test Accuracy = 28.89%
#
# ===== Epoch 23 =====
# Epoch 23: Avg Loss = 1.9864, Test Accuracy = 29.21%
#
# ===== Epoch 24 =====
# Epoch 24: Avg Loss = 1.9744, Test Accuracy = 29.56%
#
# ===== Epoch 25 =====
# Epoch 25: Avg Loss = 1.9562, Test Accuracy = 29.71%
#
# ===== Epoch 26 =====
# Epoch 26: Avg Loss = 1.9466, Test Accuracy = 30.20%
#
# ===== Epoch 27 =====
# Epoch 27: Avg Loss = 1.9406, Test Accuracy = 31.52%
#
# ===== Epoch 28 =====
# Epoch 28: Avg Loss = 1.9325, Test Accuracy = 31.04%
#
# ===== Epoch 29 =====
# Epoch 29: Avg Loss = 1.9267, Test Accuracy = 30.57%
#
# ===== Epoch 30 =====
# Epoch 30: Avg Loss = 1.9225, Test Accuracy = 30.85%
#
# ===== Epoch 31 =====
# Epoch 31: Avg Loss = 1.9142, Test Accuracy = 32.00%
#
# ===== Epoch 32 =====
# Epoch 32: Avg Loss = 1.9103, Test Accuracy = 30.32%
#
# ===== Epoch 33 =====
# Epoch 33: Avg Loss = 1.9053, Test Accuracy = 31.58%
#
# ===== Epoch 34 =====
# Epoch 34: Avg Loss = 1.9056, Test Accuracy = 32.30%
#
# ===== Epoch 35 =====
# Epoch 35: Avg Loss = 1.8990, Test Accuracy = 31.62%
#
# ===== Epoch 36 =====
# Epoch 36: Avg Loss = 1.8958, Test Accuracy = 31.58%
#
# ===== Epoch 37 =====
# Epoch 37: Avg Loss = 1.8941, Test Accuracy = 32.02%
#
# ===== Epoch 38 =====
# Epoch 38: Avg Loss = 1.8934, Test Accuracy = 32.07%
#
# ===== Epoch 39 =====
# Epoch 39: Avg Loss = 1.8858, Test Accuracy = 31.27%
#
# ===== Epoch 40 =====
# Epoch 40: Avg Loss = 1.8867, Test Accuracy = 31.83%
#
# ===== Epoch 41 =====
# Epoch 41: Avg Loss = 1.8815, Test Accuracy = 31.94%
#
# ===== Epoch 42 =====
# Epoch 42: Avg Loss = 1.8809, Test Accuracy = 32.80%
#
# ===== Epoch 43 =====
# Epoch 43: Avg Loss = 1.8778, Test Accuracy = 32.02%
#
# ===== Epoch 44 =====
# Epoch 44: Avg Loss = 1.8762, Test Accuracy = 31.83%
#
# ===== Epoch 45 =====
# Epoch 45: Avg Loss = 1.8785, Test Accuracy = 32.51%
#
# ===== Epoch 46 =====
# Epoch 46: Avg Loss = 1.8747, Test Accuracy = 32.86%
#
# ===== Epoch 47 =====
# Epoch 47: Avg Loss = 1.8747, Test Accuracy = 32.93%
#
# ===== Epoch 48 =====
# Epoch 48: Avg Loss = 1.8724, Test Accuracy = 32.46%
#
# ===== Epoch 49 =====
# Epoch 49: Avg Loss = 1.8703, Test Accuracy = 33.30%
#
# ===== Epoch 50 =====
# Epoch 50: Avg Loss = 1.8717, Test Accuracy = 32.57%
#
# ===== Epoch 51 =====
# Epoch 51: Avg Loss = 1.8715, Test Accuracy = 31.67%
#
# ===== Epoch 52 =====
# Epoch 52: Avg Loss = 1.8644, Test Accuracy = 33.31%
#
# ===== Epoch 53 =====
# Epoch 53: Avg Loss = 1.8654, Test Accuracy = 32.61%
#
# ===== Epoch 54 =====
# Epoch 54: Avg Loss = 1.8672, Test Accuracy = 32.78%
#
# ===== Epoch 55 =====
# Epoch 55: Avg Loss = 1.8669, Test Accuracy = 33.26%
#
# ===== Epoch 56 =====
# Epoch 56: Avg Loss = 1.8673, Test Accuracy = 33.01%
#
# ===== Epoch 57 =====
# Epoch 57: Avg Loss = 1.8677, Test Accuracy = 33.37%
#
# ===== Epoch 58 =====
# Epoch 58: Avg Loss = 1.8670, Test Accuracy = 33.49%
#
# ===== Epoch 59 =====
# Epoch 59: Avg Loss = 1.8696, Test Accuracy = 32.65%
#
# ===== Epoch 60 =====
# Epoch 60: Avg Loss = 1.8650, Test Accuracy = 33.85%
#
# ===== Epoch 61 =====
# Epoch 61: Avg Loss = 1.8637, Test Accuracy = 32.67%
#
# ===== Epoch 62 =====
# Epoch 62: Avg Loss = 1.8652, Test Accuracy = 33.79%
#
# ===== Epoch 63 =====
# Epoch 63: Avg Loss = 1.8634, Test Accuracy = 33.24%
#
# ===== Epoch 64 =====
# Epoch 64: Avg Loss = 1.8648, Test Accuracy = 33.16%
#
# ===== Epoch 65 =====
# Epoch 65: Avg Loss = 1.8639, Test Accuracy = 33.41%
#
# ===== Epoch 66 =====
# Epoch 66: Avg Loss = 1.8564, Test Accuracy = 33.62%
#
# ===== Epoch 67 =====
# Epoch 67: Avg Loss = 1.8624, Test Accuracy = 33.30%
#
# ===== Epoch 68 =====
# Epoch 68: Avg Loss = 1.8588, Test Accuracy = 33.16%
#
# ===== Epoch 69 =====
# Epoch 69: Avg Loss = 1.8621, Test Accuracy = 32.95%
#
# ===== Epoch 70 =====
# Epoch 70: Avg Loss = 1.8609, Test Accuracy = 32.46%
#
# ===== Epoch 71 =====
# Epoch 71: Avg Loss = 1.8613, Test Accuracy = 32.74%
#
# ===== Epoch 72 =====
# Epoch 72: Avg Loss = 1.8587, Test Accuracy = 32.76%
#
# ===== Epoch 73 =====
# Epoch 73: Avg Loss = 1.8613, Test Accuracy = 33.51%
#
# ===== Epoch 74 =====
# Epoch 74: Avg Loss = 1.8671, Test Accuracy = 32.04%
#
# ===== Epoch 75 =====
# Epoch 75: Avg Loss = 1.8595, Test Accuracy = 30.80%
#
# ===== Epoch 76 =====
# Epoch 76: Avg Loss = 1.8601, Test Accuracy = 33.60%
#
# ===== Epoch 77 =====
# Epoch 77: Avg Loss = 1.8599, Test Accuracy = 32.05%
#
# ===== Epoch 78 =====
# Epoch 78: Avg Loss = 1.8600, Test Accuracy = 33.64%
#
# ===== Epoch 79 =====
# Epoch 79: Avg Loss = 1.8597, Test Accuracy = 32.59%
#
# ===== Epoch 80 =====
# Epoch 80: Avg Loss = 1.8612, Test Accuracy = 33.43%
#
# ===== Epoch 81 =====
# Epoch 81: Avg Loss = 1.8596, Test Accuracy = 33.03%
#
# ===== Epoch 82 =====
# Epoch 82: Avg Loss = 1.8583, Test Accuracy = 32.07%
#
# ===== Epoch 83 =====
# Epoch 83: Avg Loss = 1.8620, Test Accuracy = 33.45%
#
# ===== Epoch 84 =====
# Epoch 84: Avg Loss = 1.8602, Test Accuracy = 32.93%
#
# ===== Epoch 85 =====
# Epoch 85: Avg Loss = 1.8612, Test Accuracy = 32.97%
#
# ===== Epoch 86 =====
# Epoch 86: Avg Loss = 1.8592, Test Accuracy = 32.26%
#
# ===== Epoch 87 =====
# Epoch 87: Avg Loss = 1.8560, Test Accuracy = 33.43%
#
# ===== Epoch 88 =====
# Epoch 88: Avg Loss = 1.8570, Test Accuracy = 33.41%
#
# ===== Epoch 89 =====
# Epoch 89: Avg Loss = 1.8584, Test Accuracy = 33.96%
#
# ===== Epoch 90 =====
# Epoch 90: Avg Loss = 1.8552, Test Accuracy = 33.92%
#
# ===== Epoch 91 =====
# Epoch 91: Avg Loss = 1.8544, Test Accuracy = 34.42%
#
# ===== Epoch 92 =====
# Epoch 92: Avg Loss = 1.8537, Test Accuracy = 32.51%
#
# ===== Epoch 93 =====
# Epoch 93: Avg Loss = 1.8552, Test Accuracy = 33.70%
#
# ===== Epoch 94 =====
# Epoch 94: Avg Loss = 1.8557, Test Accuracy = 33.83%
#
# ===== Epoch 95 =====
# Epoch 95: Avg Loss = 1.8559, Test Accuracy = 33.10%
#
# ===== Epoch 96 =====
# Epoch 96: Avg Loss = 1.8543, Test Accuracy = 32.63%
#
# ===== Epoch 97 =====
# Epoch 97: Avg Loss = 1.8509, Test Accuracy = 33.91%
#
# ===== Epoch 98 =====
# Epoch 98: Avg Loss = 1.8528, Test Accuracy = 33.41%
#
# ===== Epoch 99 =====
# Epoch 99: Avg Loss = 1.8540, Test Accuracy = 32.91%
#
# ===== Epoch 100 =====
# Epoch 100: Avg Loss = 1.8554, Test Accuracy = 33.24%
#
# ===== Epoch 101 =====
# Epoch 101: Avg Loss = 1.8513, Test Accuracy = 33.94%
#
# ===== Epoch 102 =====
# Epoch 102: Avg Loss = 1.8521, Test Accuracy = 33.45%
#
# ===== Epoch 103 =====
# Epoch 103: Avg Loss = 1.8494, Test Accuracy = 33.54%
#
# ===== Epoch 104 =====
# Epoch 104: Avg Loss = 1.8486, Test Accuracy = 33.43%
#
# ===== Epoch 105 =====
# Epoch 105: Avg Loss = 1.8514, Test Accuracy = 33.41%
#
# ===== Epoch 106 =====
# Epoch 106: Avg Loss = 1.8497, Test Accuracy = 33.31%
#
# ===== Epoch 107 =====
# Epoch 107: Avg Loss = 1.8516, Test Accuracy = 33.75%
#
# ===== Epoch 108 =====
# Epoch 108: Avg Loss = 1.8513, Test Accuracy = 33.37%
#
# ===== Epoch 109 =====
# Epoch 109: Avg Loss = 1.8517, Test Accuracy = 33.24%
#
# ===== Epoch 110 =====
# Epoch 110: Avg Loss = 1.8526, Test Accuracy = 33.83%
#
# ===== Epoch 111 =====
# Epoch 111: Avg Loss = 1.8481, Test Accuracy = 33.28%
#
# ===== Epoch 112 =====
# Epoch 112: Avg Loss = 1.8523, Test Accuracy = 34.55%
#
# ===== Epoch 113 =====
# Epoch 113: Avg Loss = 1.8506, Test Accuracy = 34.73%
#
# ===== Epoch 114 =====
# Epoch 114: Avg Loss = 1.8493, Test Accuracy = 34.48%
#
# ===== Epoch 115 =====
# Epoch 115: Avg Loss = 1.8478, Test Accuracy = 33.52%
#
# ===== Epoch 116 =====
# Epoch 116: Avg Loss = 1.8483, Test Accuracy = 33.96%
#
# ===== Epoch 117 =====
# Epoch 117: Avg Loss = 1.8488, Test Accuracy = 33.24%
#
# ===== Epoch 118 =====
# Epoch 118: Avg Loss = 1.8468, Test Accuracy = 33.60%
#
# ===== Epoch 119 =====
# Epoch 119: Avg Loss = 1.8509, Test Accuracy = 32.99%
#
# ===== Epoch 120 =====
# Epoch 120: Avg Loss = 1.8463, Test Accuracy = 33.28%
#
# ===== Epoch 121 =====
# Epoch 121: Avg Loss = 1.8477, Test Accuracy = 34.19%
#
# ===== Epoch 122 =====
# Epoch 122: Avg Loss = 1.8477, Test Accuracy = 33.16%
#
# ===== Epoch 123 =====
# Epoch 123: Avg Loss = 1.8489, Test Accuracy = 33.73%
#
# ===== Epoch 124 =====
# Epoch 124: Avg Loss = 1.8500, Test Accuracy = 33.39%
#
# ===== Epoch 125 =====
# Epoch 125: Avg Loss = 1.8475, Test Accuracy = 33.77%
#
# ===== Epoch 126 =====
# Epoch 126: Avg Loss = 1.8490, Test Accuracy = 32.59%
#
# ===== Epoch 127 =====
# Epoch 127: Avg Loss = 1.8460, Test Accuracy = 33.51%
#
# ===== Epoch 128 =====
# Epoch 128: Avg Loss = 1.8479, Test Accuracy = 32.72%
#
# ===== Epoch 129 =====
# Epoch 129: Avg Loss = 1.8465, Test Accuracy = 34.21%
#
# ===== Epoch 130 =====
# Epoch 130: Avg Loss = 1.8484, Test Accuracy = 33.60%
#
# ===== Epoch 131 =====
# Epoch 131: Avg Loss = 1.8483, Test Accuracy = 34.27%
#
# ===== Epoch 132 =====
# Epoch 132: Avg Loss = 1.8471, Test Accuracy = 33.94%
#
# ===== Epoch 133 =====
# Epoch 133: Avg Loss = 1.8453, Test Accuracy = 33.73%
#
# ===== Epoch 134 =====
# Epoch 134: Avg Loss = 1.8477, Test Accuracy = 33.47%
#
# ===== Epoch 135 =====
# Epoch 135: Avg Loss = 1.8497, Test Accuracy = 34.06%
#
# ===== Epoch 136 =====
# Epoch 136: Avg Loss = 1.8460, Test Accuracy = 34.00%
#
# ===== Epoch 137 =====
# Epoch 137: Avg Loss = 1.8459, Test Accuracy = 34.33%
#
# ===== Epoch 138 =====
# Epoch 138: Avg Loss = 1.8475, Test Accuracy = 33.62%
#
# ===== Epoch 139 =====
# Epoch 139: Avg Loss = 1.8474, Test Accuracy = 34.02%
#
# ===== Epoch 140 =====
# Epoch 140: Avg Loss = 1.8468, Test Accuracy = 33.45%
#
# ===== Epoch 141 =====
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 37
#      29     # # Verificar gradientes
#      30     # for name, param in mask.named_parameters():
#      31     #     if param.grad is not None:
#      32     #         print(f"[Grad] {name}: grad norm = {param.grad.norm().item():.6f}")
#      33     #     else:
#      34     #         print(f"[Grad] {name}: NO grad")
#      35     optimizer.step()
# ---> 37     running_loss += loss.item()
#      38     # if batch_idx % 10 == 0:
#      39     #     print(f"Batch {batch_idx}, Loss: {loss.item():.4f}")
#      41 avg_loss = running_loss / len(train_loader)
#
# KeyboardInterrupt:

# %%
# Gráficos de pérdida y precisión
plt.figure()
plt.plot(range(1, len(losses)+1), losses, label='Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss per Epoch')
plt.legend()
plt.grid(True)
plt.show()

plt.figure()
plt.plot(range(1, len(accuracies)+1), accuracies, label='Accuracy', color='green')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.title('Test Accuracy per Epoch')
plt.legend()
plt.grid(True)
plt.show()
